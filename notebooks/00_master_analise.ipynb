# %% [markdown]
# # Análise Estatística - TCC Engenharia de Software
# ## Tecnologias de Conteinerização: Curva de Aprendizagem Organizacional
#
# **Autor:** Guilherme Magalhães Leite
# **Orientador:** Arthur Pinheiro de Araújo Costa
# **Instituição:** MBA USP/ESALQ - Engenharia de Software
#
# ---
#
# ## Sobre Este Notebook
#
# Notebook principal que **orquestra todas as análises estatísticas** do projeto de pesquisa.
#
# ### Análises Implementadas
#
# 1. **Análise Descritiva** - Frequências, médias, tabelas de contingência
# 2. **Teste Qui-Quadrado** - Associações entre variáveis categóricas
# 3. **ANACOR** - Análise de Correspondência (mapas perceptuais 2D)
# 4. **Regressão Logística** - Fatores preditivos de curva de aprendizado
# 5. **Visualizações** - Gráficos exploratórios e descritivos
#
# ### Como Usar
#
# - **Executar tudo:** `Cell → Run All`
# - **Executar por partes:** Execute cada seção individualmente
# - **Notebooks individuais:** Disponíveis em `01_` até `05_`
#
# ### Estrutura Modular
#
# ```
# notebooks/
# ├── 00_master_analise.ipynb     ← VOCÊ ESTÁ AQUI
# ├── 01_analise_descritiva.ipynb
# ├── 02_qui_quadrado.ipynb
# ├── 03_anacor.ipynb
# ├── 04_regressao.ipynb
# └── 05_visualizacoes.ipynb
#
# src/
# └── utils.py                    # Funções reutilizáveis
# ```

# %% [markdown]
# ---
# ## Configuração Inicial

# %%
# %load_ext autoreload
# %autoreload 2

import sys; sys.path.append('../src')
import pandas as pd, warnings, utils

warnings.filterwarnings('ignore')
utils.configurar_visualizacoes()

# %% [markdown]
# ---
# ## Carregamento e Pré-processamento dos Dados

# %%
df = utils.carregar_e_preparar('../dados/respostas.csv')
# Out:
# Dataset carregado: 130 respostas × 29 variáveis
#   consolidação:         9 colunas
#   múltipla escolha:    26 colunas
#   derivadas:           15 colunas
# Pronto para análise: 130 respostas × 79 variáveis

# %% [markdown]
# ---
# ## Pipeline de Análises
#
# Execute cada análise individualmente ou use os notebooks especializados.

# %% [markdown]
# ### Análise Descritiva

# %%
utils.titulo_secao("Análise Descritiva")
# %run 01_analise_descritiva.ipynb
# Out:
# ================================================================================
# ANÁLISE DESCRITIVA
# ================================================================================
# 130 respostas × 79 variáveis
#
# DISTRIBUIÇÃO: Cargo (consolidado)
# <style type="text/css">
# #T_947a8 th {
#   text-align: left;
# }
# #T_947a8  {
#   border: 1px solid black;
# }
# #T_947a8 th {
#   border: 1px solid black;
# }
# #T_947a8 td {
#   border: 1px solid black;
# }
# #T_947a8_row0_col0, #T_947a8_row0_col1, #T_947a8_row0_col2, #T_947a8_row1_col0, #T_947a8_row1_col1, #T_947a8_row1_col2, #T_947a8_row2_col0, #T_947a8_row2_col1, #T_947a8_row2_col2, #T_947a8_row3_col0, #T_947a8_row3_col1, #T_947a8_row3_col2, #T_947a8_row4_col0, #T_947a8_row4_col1, #T_947a8_row4_col2, #T_947a8_row5_col0, #T_947a8_row5_col1, #T_947a8_row5_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_947a8">
#   <thead>
#     <tr>
#       <th id="T_947a8_level0_col0" class="col_heading level0 col0" >Cargo</th>
#       <th id="T_947a8_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_947a8_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_947a8_row0_col0" class="data row0 col0" >Engenheiro DevOps</td>
#       <td id="T_947a8_row0_col1" class="data row0 col1" >54</td>
#       <td id="T_947a8_row0_col2" class="data row0 col2" >41.54</td>
#     </tr>
#     <tr>
#       <td id="T_947a8_row1_col0" class="data row1 col0" >Desenvolvedor de Software</td>
#       <td id="T_947a8_row1_col1" class="data row1 col1" >34</td>
#       <td id="T_947a8_row1_col2" class="data row1 col2" >26.15</td>
#     </tr>
#     <tr>
#       <td id="T_947a8_row2_col0" class="data row2 col0" >Engenheiro de Confiabilidade (SRE)</td>
#       <td id="T_947a8_row2_col1" class="data row2 col1" >18</td>
#       <td id="T_947a8_row2_col2" class="data row2 col2" >13.85</td>
#     </tr>
#     <tr>
#       <td id="T_947a8_row3_col0" class="data row3 col0" >Outros</td>
#       <td id="T_947a8_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_947a8_row3_col2" class="data row3 col2" >7.69</td>
#     </tr>
#     <tr>
#       <td id="T_947a8_row4_col0" class="data row4 col0" >Arquiteto de Soluções</td>
#       <td id="T_947a8_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_947a8_row4_col2" class="data row4 col2" >5.38</td>
#     </tr>
#     <tr>
#       <td id="T_947a8_row5_col0" class="data row5 col0" >Líder Técnico</td>
#       <td id="T_947a8_row5_col1" class="data row5 col1" >7</td>
#       <td id="T_947a8_row5_col2" class="data row5 col2" >5.38</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tempo de Experiência em TI
# <style type="text/css">
# #T_8e3dd th {
#   text-align: left;
# }
# #T_8e3dd  {
#   border: 1px solid black;
# }
# #T_8e3dd th {
#   border: 1px solid black;
# }
# #T_8e3dd td {
#   border: 1px solid black;
# }
# #T_8e3dd_row0_col0, #T_8e3dd_row0_col1, #T_8e3dd_row0_col2, #T_8e3dd_row1_col0, #T_8e3dd_row1_col1, #T_8e3dd_row1_col2, #T_8e3dd_row2_col0, #T_8e3dd_row2_col1, #T_8e3dd_row2_col2, #T_8e3dd_row3_col0, #T_8e3dd_row3_col1, #T_8e3dd_row3_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_8e3dd">
#   <thead>
#     <tr>
#       <th id="T_8e3dd_level0_col0" class="col_heading level0 col0" >Tempo em TI</th>
#       <th id="T_8e3dd_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_8e3dd_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8e3dd_row0_col0" class="data row0 col0" >5-10 anos</td>
#       <td id="T_8e3dd_row0_col1" class="data row0 col1" >47</td>
#       <td id="T_8e3dd_row0_col2" class="data row0 col2" >36.15</td>
#     </tr>
#     <tr>
#       <td id="T_8e3dd_row1_col0" class="data row1 col0" >2-5 anos</td>
#       <td id="T_8e3dd_row1_col1" class="data row1 col1" >42</td>
#       <td id="T_8e3dd_row1_col2" class="data row1 col2" >32.31</td>
#     </tr>
#     <tr>
#       <td id="T_8e3dd_row2_col0" class="data row2 col0" >Mais de 10 anos</td>
#       <td id="T_8e3dd_row2_col1" class="data row2 col1" >31</td>
#       <td id="T_8e3dd_row2_col2" class="data row2 col2" >23.85</td>
#     </tr>
#     <tr>
#       <td id="T_8e3dd_row3_col0" class="data row3 col0" >Menos de 2 anos</td>
#       <td id="T_8e3dd_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_8e3dd_row3_col2" class="data row3 col2" >7.69</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tempo de Experiência com Containers
# <style type="text/css">
# #T_4b190 th {
#   text-align: left;
# }
# #T_4b190  {
#   border: 1px solid black;
# }
# #T_4b190 th {
#   border: 1px solid black;
# }
# #T_4b190 td {
#   border: 1px solid black;
# }
# #T_4b190_row0_col0, #T_4b190_row0_col1, #T_4b190_row0_col2, #T_4b190_row1_col0, #T_4b190_row1_col1, #T_4b190_row1_col2, #T_4b190_row2_col0, #T_4b190_row2_col1, #T_4b190_row2_col2, #T_4b190_row3_col0, #T_4b190_row3_col1, #T_4b190_row3_col2, #T_4b190_row4_col0, #T_4b190_row4_col1, #T_4b190_row4_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_4b190">
#   <thead>
#     <tr>
#       <th id="T_4b190_level0_col0" class="col_heading level0 col0" >Tempo com Containers</th>
#       <th id="T_4b190_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_4b190_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4b190_row0_col0" class="data row0 col0" >Mais de 5 anos</td>
#       <td id="T_4b190_row0_col1" class="data row0 col1" >41</td>
#       <td id="T_4b190_row0_col2" class="data row0 col2" >31.54</td>
#     </tr>
#     <tr>
#       <td id="T_4b190_row1_col0" class="data row1 col0" >1-3 anos</td>
#       <td id="T_4b190_row1_col1" class="data row1 col1" >40</td>
#       <td id="T_4b190_row1_col2" class="data row1 col2" >30.77</td>
#     </tr>
#     <tr>
#       <td id="T_4b190_row2_col0" class="data row2 col0" >3-5 anos</td>
#       <td id="T_4b190_row2_col1" class="data row2 col1" >34</td>
#       <td id="T_4b190_row2_col2" class="data row2 col2" >26.15</td>
#     </tr>
#     <tr>
#       <td id="T_4b190_row3_col0" class="data row3 col0" >6 meses - 1 ano</td>
#       <td id="T_4b190_row3_col1" class="data row3 col1" >9</td>
#       <td id="T_4b190_row3_col2" class="data row3 col2" >6.92</td>
#     </tr>
#     <tr>
#       <td id="T_4b190_row4_col0" class="data row4 col0" >Menos de 6 meses</td>
#       <td id="T_4b190_row4_col1" class="data row4 col1" >6</td>
#       <td id="T_4b190_row4_col2" class="data row4 col2" >4.62</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Porte da Empresa
# <style type="text/css">
# #T_970a2 th {
#   text-align: left;
# }
# #T_970a2  {
#   border: 1px solid black;
# }
# #T_970a2 th {
#   border: 1px solid black;
# }
# #T_970a2 td {
#   border: 1px solid black;
# }
# #T_970a2_row0_col0, #T_970a2_row0_col1, #T_970a2_row0_col2, #T_970a2_row1_col0, #T_970a2_row1_col1, #T_970a2_row1_col2, #T_970a2_row2_col0, #T_970a2_row2_col1, #T_970a2_row2_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_970a2">
#   <thead>
#     <tr>
#       <th id="T_970a2_level0_col0" class="col_heading level0 col0" >Porte</th>
#       <th id="T_970a2_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_970a2_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_970a2_row0_col0" class="data row0 col0" >Grande (mais de 250 funcionários)</td>
#       <td id="T_970a2_row0_col1" class="data row0 col1" >67</td>
#       <td id="T_970a2_row0_col2" class="data row0 col2" >51.54</td>
#     </tr>
#     <tr>
#       <td id="T_970a2_row1_col0" class="data row1 col0" >Média (50-250 funcionários)</td>
#       <td id="T_970a2_row1_col1" class="data row1 col1" >35</td>
#       <td id="T_970a2_row1_col2" class="data row1 col2" >26.92</td>
#     </tr>
#     <tr>
#       <td id="T_970a2_row2_col0" class="data row2 col0" >Pequena (menos de 50 funcionários)</td>
#       <td id="T_970a2_row2_col1" class="data row2 col1" >28</td>
#       <td id="T_970a2_row2_col2" class="data row2 col2" >21.54</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Setor de Atuação (consolidado)
# <style type="text/css">
# #T_4d6c7 th {
#   text-align: left;
# }
# #T_4d6c7  {
#   border: 1px solid black;
# }
# #T_4d6c7 th {
#   border: 1px solid black;
# }
# #T_4d6c7 td {
#   border: 1px solid black;
# }
# #T_4d6c7_row0_col0, #T_4d6c7_row0_col1, #T_4d6c7_row0_col2, #T_4d6c7_row1_col0, #T_4d6c7_row1_col1, #T_4d6c7_row1_col2, #T_4d6c7_row2_col0, #T_4d6c7_row2_col1, #T_4d6c7_row2_col2, #T_4d6c7_row3_col0, #T_4d6c7_row3_col1, #T_4d6c7_row3_col2, #T_4d6c7_row4_col0, #T_4d6c7_row4_col1, #T_4d6c7_row4_col2, #T_4d6c7_row5_col0, #T_4d6c7_row5_col1, #T_4d6c7_row5_col2, #T_4d6c7_row6_col0, #T_4d6c7_row6_col1, #T_4d6c7_row6_col2, #T_4d6c7_row7_col0, #T_4d6c7_row7_col1, #T_4d6c7_row7_col2, #T_4d6c7_row8_col0, #T_4d6c7_row8_col1, #T_4d6c7_row8_col2, #T_4d6c7_row9_col0, #T_4d6c7_row9_col1, #T_4d6c7_row9_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_4d6c7">
#   <thead>
#     <tr>
#       <th id="T_4d6c7_level0_col0" class="col_heading level0 col0" >Setor</th>
#       <th id="T_4d6c7_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_4d6c7_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4d6c7_row0_col0" class="data row0 col0" >Fintech/Serviços Financeiros</td>
#       <td id="T_4d6c7_row0_col1" class="data row0 col1" >39</td>
#       <td id="T_4d6c7_row0_col2" class="data row0 col2" >30.00</td>
#     </tr>
#     <tr>
#       <td id="T_4d6c7_row1_col0" class="data row1 col0" >Software/SaaS</td>
#       <td id="T_4d6c7_row1_col1" class="data row1 col1" >37</td>
#       <td id="T_4d6c7_row1_col2" class="data row1 col2" >28.46</td>
#     </tr>
#     <tr>
#       <td id="T_4d6c7_row2_col0" class="data row2 col0" >Telecom</td>
#       <td id="T_4d6c7_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_4d6c7_row2_col2" class="data row2 col2" >6.92</td>
#     </tr>
#     <tr>
#       <td id="T_4d6c7_row3_col0" class="data row3 col0" >Indústria/Logística</td>
#       <td id="T_4d6c7_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_4d6c7_row3_col2" class="data row3 col2" >6.15</td>
#     </tr>
#     <tr>
#       <td id="T_4d6c7_row4_col0" class="data row4 col0" >Educação/EdTech</td>
#       <td id="T_4d6c7_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_4d6c7_row4_col2" class="data row4 col2" >6.15</td>
#     </tr>
#     <tr>
#       <td id="T_4d6c7_row5_col0" class="data row5 col0" >Setor Público</td>
#       <td id="T_4d6c7_row5_col1" class="data row5 col1" >7</td>
#       <td id="T_4d6c7_row5_col2" class="data row5 col2" >5.38</td>
#     </tr>
#     <tr>
#       <td id="T_4d6c7_row6_col0" class="data row6 col0" >E-commerce/Varejo</td>
#       <td id="T_4d6c7_row6_col1" class="data row6 col1" >6</td>
#       <td id="T_4d6c7_row6_col2" class="data row6 col2" >4.62</td>
#     </tr>
#     <tr>
#       <td id="T_4d6c7_row7_col0" class="data row7 col0" >Saúde/HealthTech</td>
#       <td id="T_4d6c7_row7_col1" class="data row7 col1" >6</td>
#       <td id="T_4d6c7_row7_col2" class="data row7 col2" >4.62</td>
#     </tr>
#     <tr>
#       <td id="T_4d6c7_row8_col0" class="data row8 col0" >Consultoria/TI</td>
#       <td id="T_4d6c7_row8_col1" class="data row8 col1" >6</td>
#       <td id="T_4d6c7_row8_col2" class="data row8 col2" >4.62</td>
#     </tr>
#     <tr>
#       <td id="T_4d6c7_row9_col0" class="data row9 col0" >Mídia/Games</td>
#       <td id="T_4d6c7_row9_col1" class="data row9 col1" >4</td>
#       <td id="T_4d6c7_row9_col2" class="data row9 col2" >3.08</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tecnologia de Orquestração
# <style type="text/css">
# #T_73df3 th {
#   text-align: left;
# }
# #T_73df3  {
#   border: 1px solid black;
# }
# #T_73df3 th {
#   border: 1px solid black;
# }
# #T_73df3 td {
#   border: 1px solid black;
# }
# #T_73df3_row0_col0, #T_73df3_row0_col1, #T_73df3_row0_col2, #T_73df3_row1_col0, #T_73df3_row1_col1, #T_73df3_row1_col2, #T_73df3_row2_col0, #T_73df3_row2_col1, #T_73df3_row2_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_73df3">
#   <thead>
#     <tr>
#       <th id="T_73df3_level0_col0" class="col_heading level0 col0" >Tecnologia</th>
#       <th id="T_73df3_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_73df3_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_73df3_row0_col0" class="data row0 col0" >Kubernetes (self-hosted ou managed: EKS/AKS/GKE)</td>
#       <td id="T_73df3_row0_col1" class="data row0 col1" >97</td>
#       <td id="T_73df3_row0_col2" class="data row0 col2" >74.62</td>
#     </tr>
#     <tr>
#       <td id="T_73df3_row1_col0" class="data row1 col0" >Outras soluções (Nomad, OpenShift, ECS)</td>
#       <td id="T_73df3_row1_col1" class="data row1 col1" >20</td>
#       <td id="T_73df3_row1_col2" class="data row1 col2" >15.38</td>
#     </tr>
#     <tr>
#       <td id="T_73df3_row2_col0" class="data row2 col0" >Docker Swarm</td>
#       <td id="T_73df3_row2_col1" class="data row2 col1" >13</td>
#       <td id="T_73df3_row2_col2" class="data row2 col2" >10.00</td>
#     </tr>
#   </tbody>
# </table>
# ESTATÍSTICAS DESCRITIVAS: Desafios (Escala Likert 1-5)
# <style type="text/css">
# #T_a00b9 th {
#   text-align: left;
# }
# #T_a00b9  {
#   border: 1px solid black;
# }
# #T_a00b9 th {
#   border: 1px solid black;
# }
# #T_a00b9 td {
#   border: 1px solid black;
# }
# #T_a00b9_row0_col0, #T_a00b9_row0_col1, #T_a00b9_row0_col2, #T_a00b9_row0_col3, #T_a00b9_row0_col4, #T_a00b9_row0_col5, #T_a00b9_row1_col0, #T_a00b9_row1_col1, #T_a00b9_row1_col2, #T_a00b9_row1_col3, #T_a00b9_row1_col4, #T_a00b9_row1_col5, #T_a00b9_row2_col0, #T_a00b9_row2_col1, #T_a00b9_row2_col2, #T_a00b9_row2_col3, #T_a00b9_row2_col4, #T_a00b9_row2_col5, #T_a00b9_row3_col0, #T_a00b9_row3_col1, #T_a00b9_row3_col2, #T_a00b9_row3_col3, #T_a00b9_row3_col4, #T_a00b9_row3_col5, #T_a00b9_row4_col0, #T_a00b9_row4_col1, #T_a00b9_row4_col2, #T_a00b9_row4_col3, #T_a00b9_row4_col4, #T_a00b9_row4_col5, #T_a00b9_row5_col0, #T_a00b9_row5_col1, #T_a00b9_row5_col2, #T_a00b9_row5_col3, #T_a00b9_row5_col4, #T_a00b9_row5_col5 {
#   text-align: left;
# }
# </style>
# <table id="T_a00b9">
#   <thead>
#     <tr>
#       <th id="T_a00b9_level0_col0" class="col_heading level0 col0" >Desafio</th>
#       <th id="T_a00b9_level0_col1" class="col_heading level0 col1" >Média</th>
#       <th id="T_a00b9_level0_col2" class="col_heading level0 col2" >Desvio</th>
#       <th id="T_a00b9_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_a00b9_level0_col4" class="col_heading level0 col4" >Max</th>
#       <th id="T_a00b9_level0_col5" class="col_heading level0 col5" >% alto</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a00b9_row0_col0" class="data row0 col0" >Mudanças organizacionais</td>
#       <td id="T_a00b9_row0_col1" class="data row0 col1" >3.38</td>
#       <td id="T_a00b9_row0_col2" class="data row0 col2" >1.16</td>
#       <td id="T_a00b9_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_a00b9_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_a00b9_row0_col5" class="data row0 col5" >50.0</td>
#     </tr>
#     <tr>
#       <td id="T_a00b9_row1_col0" class="data row1 col0" >Treinamento</td>
#       <td id="T_a00b9_row1_col1" class="data row1 col1" >3.04</td>
#       <td id="T_a00b9_row1_col2" class="data row1 col2" >1.18</td>
#       <td id="T_a00b9_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_a00b9_row1_col4" class="data row1 col4" >5</td>
#       <td id="T_a00b9_row1_col5" class="data row1 col5" >39.2</td>
#     </tr>
#     <tr>
#       <td id="T_a00b9_row2_col0" class="data row2 col0" >Monitoramento</td>
#       <td id="T_a00b9_row2_col1" class="data row2 col1" >3.11</td>
#       <td id="T_a00b9_row2_col2" class="data row2 col2" >1.09</td>
#       <td id="T_a00b9_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_a00b9_row2_col4" class="data row2 col4" >5</td>
#       <td id="T_a00b9_row2_col5" class="data row2 col5" >38.5</td>
#     </tr>
#     <tr>
#       <td id="T_a00b9_row3_col0" class="data row3 col0" >Segurança</td>
#       <td id="T_a00b9_row3_col1" class="data row3 col1" >3.15</td>
#       <td id="T_a00b9_row3_col2" class="data row3 col2" >1.06</td>
#       <td id="T_a00b9_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_a00b9_row3_col4" class="data row3 col4" >5</td>
#       <td id="T_a00b9_row3_col5" class="data row3 col5" >36.2</td>
#     </tr>
#     <tr>
#       <td id="T_a00b9_row4_col0" class="data row4 col0" >Complexidade</td>
#       <td id="T_a00b9_row4_col1" class="data row4 col1" >3.08</td>
#       <td id="T_a00b9_row4_col2" class="data row4 col2" >1.05</td>
#       <td id="T_a00b9_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_a00b9_row4_col4" class="data row4 col4" >5</td>
#       <td id="T_a00b9_row4_col5" class="data row4 col5" >35.4</td>
#     </tr>
#     <tr>
#       <td id="T_a00b9_row5_col0" class="data row5 col0" >CI/CD</td>
#       <td id="T_a00b9_row5_col1" class="data row5 col1" >2.85</td>
#       <td id="T_a00b9_row5_col2" class="data row5 col2" >1.16</td>
#       <td id="T_a00b9_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_a00b9_row5_col4" class="data row5 col4" >5</td>
#       <td id="T_a00b9_row5_col5" class="data row5 col5" >29.2</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Principal Desafio Enfrentado (consolidado)
# <style type="text/css">
# #T_172fd th {
#   text-align: left;
# }
# #T_172fd  {
#   border: 1px solid black;
# }
# #T_172fd th {
#   border: 1px solid black;
# }
# #T_172fd td {
#   border: 1px solid black;
# }
# #T_172fd_row0_col0, #T_172fd_row0_col1, #T_172fd_row0_col2, #T_172fd_row1_col0, #T_172fd_row1_col1, #T_172fd_row1_col2, #T_172fd_row2_col0, #T_172fd_row2_col1, #T_172fd_row2_col2, #T_172fd_row3_col0, #T_172fd_row3_col1, #T_172fd_row3_col2, #T_172fd_row4_col0, #T_172fd_row4_col1, #T_172fd_row4_col2, #T_172fd_row5_col0, #T_172fd_row5_col1, #T_172fd_row5_col2, #T_172fd_row6_col0, #T_172fd_row6_col1, #T_172fd_row6_col2, #T_172fd_row7_col0, #T_172fd_row7_col1, #T_172fd_row7_col2, #T_172fd_row8_col0, #T_172fd_row8_col1, #T_172fd_row8_col2, #T_172fd_row9_col0, #T_172fd_row9_col1, #T_172fd_row9_col2, #T_172fd_row10_col0, #T_172fd_row10_col1, #T_172fd_row10_col2, #T_172fd_row11_col0, #T_172fd_row11_col1, #T_172fd_row11_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_172fd">
#   <thead>
#     <tr>
#       <th id="T_172fd_level0_col0" class="col_heading level0 col0" >Desafio</th>
#       <th id="T_172fd_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_172fd_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_172fd_row0_col0" class="data row0 col0" >Mudanças organizacionais e culturais (adoção de DevOps, colaboração entre equipes)</td>
#       <td id="T_172fd_row0_col1" class="data row0 col1" >32</td>
#       <td id="T_172fd_row0_col2" class="data row0 col2" >24.62</td>
#     </tr>
#     <tr>
#       <td id="T_172fd_row1_col0" class="data row1 col0" >Complexidade técnica (curva de aprendizado íngreme, novos conceitos)</td>
#       <td id="T_172fd_row1_col1" class="data row1 col1" >23</td>
#       <td id="T_172fd_row1_col2" class="data row1 col2" >17.69</td>
#     </tr>
#     <tr>
#       <td id="T_172fd_row2_col0" class="data row2 col0" >Monitoramento e observabilidade (monitoramento, logs, tracing)</td>
#       <td id="T_172fd_row2_col1" class="data row2 col1" >18</td>
#       <td id="T_172fd_row2_col2" class="data row2 col2" >13.85</td>
#     </tr>
#     <tr>
#       <td id="T_172fd_row3_col0" class="data row3 col0" >Segurança</td>
#       <td id="T_172fd_row3_col1" class="data row3 col1" >12</td>
#       <td id="T_172fd_row3_col2" class="data row3 col2" >9.23</td>
#     </tr>
#     <tr>
#       <td id="T_172fd_row4_col0" class="data row4 col0" >Integração com sistemas legados</td>
#       <td id="T_172fd_row4_col1" class="data row4 col1" >12</td>
#       <td id="T_172fd_row4_col2" class="data row4 col2" >9.23</td>
#     </tr>
#     <tr>
#       <td id="T_172fd_row5_col0" class="data row5 col0" >CI/CD (automação, fluxos de deploy)</td>
#       <td id="T_172fd_row5_col1" class="data row5 col1" >9</td>
#       <td id="T_172fd_row5_col2" class="data row5 col2" >6.92</td>
#     </tr>
#     <tr>
#       <td id="T_172fd_row6_col0" class="data row6 col0" >Treinamento e desenvolvimento de habilidades (falta de capacitação, upskilling)</td>
#       <td id="T_172fd_row6_col1" class="data row6 col1" >8</td>
#       <td id="T_172fd_row6_col2" class="data row6 col2" >6.15</td>
#     </tr>
#     <tr>
#       <td id="T_172fd_row7_col0" class="data row7 col0" >Custos de infraestrutura</td>
#       <td id="T_172fd_row7_col1" class="data row7 col1" >6</td>
#       <td id="T_172fd_row7_col2" class="data row7 col2" >4.62</td>
#     </tr>
#     <tr>
#       <td id="T_172fd_row8_col0" class="data row8 col0" >Networking</td>
#       <td id="T_172fd_row8_col1" class="data row8 col1" >4</td>
#       <td id="T_172fd_row8_col2" class="data row8 col2" >3.08</td>
#     </tr>
#     <tr>
#       <td id="T_172fd_row9_col0" class="data row9 col0" >Escalabilidade</td>
#       <td id="T_172fd_row9_col1" class="data row9 col1" >3</td>
#       <td id="T_172fd_row9_col2" class="data row9 col2" >2.31</td>
#     </tr>
#     <tr>
#       <td id="T_172fd_row10_col0" class="data row10 col0" >Sem desafio relevante</td>
#       <td id="T_172fd_row10_col1" class="data row10 col1" >2</td>
#       <td id="T_172fd_row10_col2" class="data row10 col2" >1.54</td>
#     </tr>
#     <tr>
#       <td id="T_172fd_row11_col0" class="data row11 col0" >Persistência de dados e gestão de estado</td>
#       <td id="T_172fd_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_172fd_row11_col2" class="data row11 col2" >0.77</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Empresa Ofereceu Treinamento?
# <style type="text/css">
# #T_7b186 th {
#   text-align: left;
# }
# #T_7b186  {
#   border: 1px solid black;
# }
# #T_7b186 th {
#   border: 1px solid black;
# }
# #T_7b186 td {
#   border: 1px solid black;
# }
# #T_7b186_row0_col0, #T_7b186_row0_col1, #T_7b186_row0_col2, #T_7b186_row1_col0, #T_7b186_row1_col1, #T_7b186_row1_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_7b186">
#   <thead>
#     <tr>
#       <th id="T_7b186_level0_col0" class="col_heading level0 col0" >Resposta</th>
#       <th id="T_7b186_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_7b186_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7b186_row0_col0" class="data row0 col0" >Não</td>
#       <td id="T_7b186_row0_col1" class="data row0 col1" >85</td>
#       <td id="T_7b186_row0_col2" class="data row0 col2" >65.38</td>
#     </tr>
#     <tr>
#       <td id="T_7b186_row1_col0" class="data row1 col0" >Sim</td>
#       <td id="T_7b186_row1_col1" class="data row1 col1" >45</td>
#       <td id="T_7b186_row1_col2" class="data row1 col2" >34.62</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Fonte Mais Útil de Aprendizado (consolidado)
# <style type="text/css">
# #T_e16b6 th {
#   text-align: left;
# }
# #T_e16b6  {
#   border: 1px solid black;
# }
# #T_e16b6 th {
#   border: 1px solid black;
# }
# #T_e16b6 td {
#   border: 1px solid black;
# }
# #T_e16b6_row0_col0, #T_e16b6_row0_col1, #T_e16b6_row0_col2, #T_e16b6_row1_col0, #T_e16b6_row1_col1, #T_e16b6_row1_col2, #T_e16b6_row2_col0, #T_e16b6_row2_col1, #T_e16b6_row2_col2, #T_e16b6_row3_col0, #T_e16b6_row3_col1, #T_e16b6_row3_col2, #T_e16b6_row4_col0, #T_e16b6_row4_col1, #T_e16b6_row4_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_e16b6">
#   <thead>
#     <tr>
#       <th id="T_e16b6_level0_col0" class="col_heading level0 col0" >Fonte</th>
#       <th id="T_e16b6_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_e16b6_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e16b6_row0_col0" class="data row0 col0" >Documentação e autoestudo</td>
#       <td id="T_e16b6_row0_col1" class="data row0 col1" >51</td>
#       <td id="T_e16b6_row0_col2" class="data row0 col2" >39.23</td>
#     </tr>
#     <tr>
#       <td id="T_e16b6_row1_col0" class="data row1 col0" >Treinamento formal</td>
#       <td id="T_e16b6_row1_col1" class="data row1 col1" >34</td>
#       <td id="T_e16b6_row1_col2" class="data row1 col2" >26.15</td>
#     </tr>
#     <tr>
#       <td id="T_e16b6_row2_col0" class="data row2 col0" >Mentoria/Comunidade</td>
#       <td id="T_e16b6_row2_col1" class="data row2 col1" >17</td>
#       <td id="T_e16b6_row2_col2" class="data row2 col2" >13.08</td>
#     </tr>
#     <tr>
#       <td id="T_e16b6_row3_col0" class="data row3 col0" >Agentes de IA</td>
#       <td id="T_e16b6_row3_col1" class="data row3 col1" >14</td>
#       <td id="T_e16b6_row3_col2" class="data row3 col2" >10.77</td>
#     </tr>
#     <tr>
#       <td id="T_e16b6_row4_col0" class="data row4 col0" >Prática/PoC</td>
#       <td id="T_e16b6_row4_col1" class="data row4 col1" >14</td>
#       <td id="T_e16b6_row4_col2" class="data row4 col2" >10.77</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Realizou POCs?
# <style type="text/css">
# #T_46705 th {
#   text-align: left;
# }
# #T_46705  {
#   border: 1px solid black;
# }
# #T_46705 th {
#   border: 1px solid black;
# }
# #T_46705 td {
#   border: 1px solid black;
# }
# #T_46705_row0_col0, #T_46705_row0_col1, #T_46705_row0_col2, #T_46705_row1_col0, #T_46705_row1_col1, #T_46705_row1_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_46705">
#   <thead>
#     <tr>
#       <th id="T_46705_level0_col0" class="col_heading level0 col0" >Resposta</th>
#       <th id="T_46705_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_46705_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_46705_row0_col0" class="data row0 col0" >Sim</td>
#       <td id="T_46705_row0_col1" class="data row0 col1" >105</td>
#       <td id="T_46705_row0_col2" class="data row0 col2" >80.77</td>
#     </tr>
#     <tr>
#       <td id="T_46705_row1_col0" class="data row1 col0" >Não</td>
#       <td id="T_46705_row1_col1" class="data row1 col1" >25</td>
#       <td id="T_46705_row1_col2" class="data row1 col2" >19.23</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tempo Individual para se Sentir Confortável
# <style type="text/css">
# #T_0bc3d th {
#   text-align: left;
# }
# #T_0bc3d  {
#   border: 1px solid black;
# }
# #T_0bc3d th {
#   border: 1px solid black;
# }
# #T_0bc3d td {
#   border: 1px solid black;
# }
# #T_0bc3d_row0_col0, #T_0bc3d_row0_col1, #T_0bc3d_row0_col2, #T_0bc3d_row1_col0, #T_0bc3d_row1_col1, #T_0bc3d_row1_col2, #T_0bc3d_row2_col0, #T_0bc3d_row2_col1, #T_0bc3d_row2_col2, #T_0bc3d_row3_col0, #T_0bc3d_row3_col1, #T_0bc3d_row3_col2, #T_0bc3d_row4_col0, #T_0bc3d_row4_col1, #T_0bc3d_row4_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_0bc3d">
#   <thead>
#     <tr>
#       <th id="T_0bc3d_level0_col0" class="col_heading level0 col0" >Tempo</th>
#       <th id="T_0bc3d_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_0bc3d_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0bc3d_row0_col0" class="data row0 col0" >3-6 meses</td>
#       <td id="T_0bc3d_row0_col1" class="data row0 col1" >47</td>
#       <td id="T_0bc3d_row0_col2" class="data row0 col2" >36.15</td>
#     </tr>
#     <tr>
#       <td id="T_0bc3d_row1_col0" class="data row1 col0" >6-12 meses</td>
#       <td id="T_0bc3d_row1_col1" class="data row1 col1" >41</td>
#       <td id="T_0bc3d_row1_col2" class="data row1 col2" >31.54</td>
#     </tr>
#     <tr>
#       <td id="T_0bc3d_row2_col0" class="data row2 col0" >Menos de 3 meses</td>
#       <td id="T_0bc3d_row2_col1" class="data row2 col1" >27</td>
#       <td id="T_0bc3d_row2_col2" class="data row2 col2" >20.77</td>
#     </tr>
#     <tr>
#       <td id="T_0bc3d_row3_col0" class="data row3 col0" >12-18 meses</td>
#       <td id="T_0bc3d_row3_col1" class="data row3 col1" >12</td>
#       <td id="T_0bc3d_row3_col2" class="data row3 col2" >9.23</td>
#     </tr>
#     <tr>
#       <td id="T_0bc3d_row4_col0" class="data row4 col0" >Mais de 18 meses</td>
#       <td id="T_0bc3d_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_0bc3d_row4_col2" class="data row4 col2" >2.31</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tempo da Equipe para Colocar em Produção
# <style type="text/css">
# #T_852b7 th {
#   text-align: left;
# }
# #T_852b7  {
#   border: 1px solid black;
# }
# #T_852b7 th {
#   border: 1px solid black;
# }
# #T_852b7 td {
#   border: 1px solid black;
# }
# #T_852b7_row0_col0, #T_852b7_row0_col1, #T_852b7_row0_col2, #T_852b7_row1_col0, #T_852b7_row1_col1, #T_852b7_row1_col2, #T_852b7_row2_col0, #T_852b7_row2_col1, #T_852b7_row2_col2, #T_852b7_row3_col0, #T_852b7_row3_col1, #T_852b7_row3_col2, #T_852b7_row4_col0, #T_852b7_row4_col1, #T_852b7_row4_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_852b7">
#   <thead>
#     <tr>
#       <th id="T_852b7_level0_col0" class="col_heading level0 col0" >Tempo</th>
#       <th id="T_852b7_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_852b7_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_852b7_row0_col0" class="data row0 col0" >3-6 meses</td>
#       <td id="T_852b7_row0_col1" class="data row0 col1" >46</td>
#       <td id="T_852b7_row0_col2" class="data row0 col2" >35.38</td>
#     </tr>
#     <tr>
#       <td id="T_852b7_row1_col0" class="data row1 col0" >1-3 meses</td>
#       <td id="T_852b7_row1_col1" class="data row1 col1" >36</td>
#       <td id="T_852b7_row1_col2" class="data row1 col2" >27.69</td>
#     </tr>
#     <tr>
#       <td id="T_852b7_row2_col0" class="data row2 col0" >Menos de 1 mês</td>
#       <td id="T_852b7_row2_col1" class="data row2 col1" >29</td>
#       <td id="T_852b7_row2_col2" class="data row2 col2" >22.31</td>
#     </tr>
#     <tr>
#       <td id="T_852b7_row3_col0" class="data row3 col0" >6-12 meses</td>
#       <td id="T_852b7_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_852b7_row3_col2" class="data row3 col2" >13.08</td>
#     </tr>
#     <tr>
#       <td id="T_852b7_row4_col0" class="data row4 col0" >Mais de 12 meses</td>
#       <td id="T_852b7_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_852b7_row4_col2" class="data row4 col2" >1.54</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Fator Mais Importante para Acelerar Aprendizado
# <style type="text/css">
# #T_90f59 th {
#   text-align: left;
# }
# #T_90f59  {
#   border: 1px solid black;
# }
# #T_90f59 th {
#   border: 1px solid black;
# }
# #T_90f59 td {
#   border: 1px solid black;
# }
# #T_90f59_row0_col0, #T_90f59_row0_col1, #T_90f59_row0_col2, #T_90f59_row1_col0, #T_90f59_row1_col1, #T_90f59_row1_col2, #T_90f59_row2_col0, #T_90f59_row2_col1, #T_90f59_row2_col2, #T_90f59_row3_col0, #T_90f59_row3_col1, #T_90f59_row3_col2, #T_90f59_row4_col0, #T_90f59_row4_col1, #T_90f59_row4_col2, #T_90f59_row5_col0, #T_90f59_row5_col1, #T_90f59_row5_col2, #T_90f59_row6_col0, #T_90f59_row6_col1, #T_90f59_row6_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_90f59">
#   <thead>
#     <tr>
#       <th id="T_90f59_level0_col0" class="col_heading level0 col0" >Fator</th>
#       <th id="T_90f59_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_90f59_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_90f59_row0_col0" class="data row0 col0" >Realização de POCs antes de produção</td>
#       <td id="T_90f59_row0_col1" class="data row0 col1" >39</td>
#       <td id="T_90f59_row0_col2" class="data row0 col2" >30.00</td>
#     </tr>
#     <tr>
#       <td id="T_90f59_row1_col0" class="data row1 col0" >Experiência prévia com Docker</td>
#       <td id="T_90f59_row1_col1" class="data row1 col1" >28</td>
#       <td id="T_90f59_row1_col2" class="data row1 col2" >21.54</td>
#     </tr>
#     <tr>
#       <td id="T_90f59_row2_col0" class="data row2 col0" >Tempo dedicado exclusivo para estudo</td>
#       <td id="T_90f59_row2_col1" class="data row2 col1" >25</td>
#       <td id="T_90f59_row2_col2" class="data row2 col2" >19.23</td>
#     </tr>
#     <tr>
#       <td id="T_90f59_row3_col0" class="data row3 col0" >Mentoria de especialistas internos ou externos</td>
#       <td id="T_90f59_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_90f59_row3_col2" class="data row3 col2" >13.08</td>
#     </tr>
#     <tr>
#       <td id="T_90f59_row4_col0" class="data row4 col0" >Treinamento formal estruturado</td>
#       <td id="T_90f59_row4_col1" class="data row4 col1" >14</td>
#       <td id="T_90f59_row4_col2" class="data row4 col2" >10.77</td>
#     </tr>
#     <tr>
#       <td id="T_90f59_row5_col0" class="data row5 col0" >Participação em comunidades técnicas</td>
#       <td id="T_90f59_row5_col1" class="data row5 col1" >5</td>
#       <td id="T_90f59_row5_col2" class="data row5 col2" >3.85</td>
#     </tr>
#     <tr>
#       <td id="T_90f59_row6_col0" class="data row6 col0" >Certificações profissionais</td>
#       <td id="T_90f59_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_90f59_row6_col2" class="data row6 col2" >1.54</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Avaliação do ROI
# <style type="text/css">
# #T_66373 th {
#   text-align: left;
# }
# #T_66373  {
#   border: 1px solid black;
# }
# #T_66373 th {
#   border: 1px solid black;
# }
# #T_66373 td {
#   border: 1px solid black;
# }
# #T_66373_row0_col0, #T_66373_row0_col1, #T_66373_row0_col2, #T_66373_row1_col0, #T_66373_row1_col1, #T_66373_row1_col2, #T_66373_row2_col0, #T_66373_row2_col1, #T_66373_row2_col2, #T_66373_row3_col0, #T_66373_row3_col1, #T_66373_row3_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_66373">
#   <thead>
#     <tr>
#       <th id="T_66373_level0_col0" class="col_heading level0 col0" >Nota</th>
#       <th id="T_66373_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_66373_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_66373_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_66373_row0_col1" class="data row0 col1" >66</td>
#       <td id="T_66373_row0_col2" class="data row0 col2" >50.77</td>
#     </tr>
#     <tr>
#       <td id="T_66373_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_66373_row1_col1" class="data row1 col1" >44</td>
#       <td id="T_66373_row1_col2" class="data row1 col2" >33.85</td>
#     </tr>
#     <tr>
#       <td id="T_66373_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_66373_row2_col1" class="data row2 col1" >18</td>
#       <td id="T_66373_row2_col2" class="data row2 col2" >13.85</td>
#     </tr>
#     <tr>
#       <td id="T_66373_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_66373_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_66373_row3_col2" class="data row3 col2" >1.54</td>
#     </tr>
#   </tbody>
# </table>
# Média: 4.34 | Mediana: 5.00
#
# DISTRIBUIÇÃO: Recomendaria a Adoção de Containers?
# <style type="text/css">
# #T_94aae th {
#   text-align: left;
# }
# #T_94aae  {
#   border: 1px solid black;
# }
# #T_94aae th {
#   border: 1px solid black;
# }
# #T_94aae td {
#   border: 1px solid black;
# }
# #T_94aae_row0_col0, #T_94aae_row0_col1, #T_94aae_row0_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_94aae">
#   <thead>
#     <tr>
#       <th id="T_94aae_level0_col0" class="col_heading level0 col0" >Resposta</th>
#       <th id="T_94aae_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_94aae_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_94aae_row0_col0" class="data row0 col0" >Sim</td>
#       <td id="T_94aae_row0_col1" class="data row0 col1" >130</td>
#       <td id="T_94aae_row0_col2" class="data row0 col2" >100.00</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# TABELA DE CONTINGÊNCIA: TEMPO PARA SE SENTIR CONFORTÁVEL (Q24) × FONTE DE APRENDIZADO MAIS ÚTIL (Q22 CONSOLIDADA)
# ================================================================================
# <style type="text/css">
# #T_eafb8 th {
#   text-align: left;
# }
# #T_eafb8  {
#   border: 1px solid black;
# }
# #T_eafb8 th {
#   border: 1px solid black;
# }
# #T_eafb8 td {
#   border: 1px solid black;
# }
# #T_eafb8_row0_col0, #T_eafb8_row0_col1, #T_eafb8_row0_col2, #T_eafb8_row0_col3, #T_eafb8_row0_col4, #T_eafb8_row1_col0, #T_eafb8_row1_col1, #T_eafb8_row1_col2, #T_eafb8_row1_col3, #T_eafb8_row1_col4, #T_eafb8_row2_col0, #T_eafb8_row2_col1, #T_eafb8_row2_col2, #T_eafb8_row2_col3, #T_eafb8_row2_col4, #T_eafb8_row3_col0, #T_eafb8_row3_col1, #T_eafb8_row3_col2, #T_eafb8_row3_col3, #T_eafb8_row3_col4, #T_eafb8_row4_col0, #T_eafb8_row4_col1, #T_eafb8_row4_col2, #T_eafb8_row4_col3, #T_eafb8_row4_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_eafb8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eafb8_level0_col0" class="col_heading level0 col0" >Agentes de IA</th>
#       <th id="T_eafb8_level0_col1" class="col_heading level0 col1" >Documentação e autoestudo</th>
#       <th id="T_eafb8_level0_col2" class="col_heading level0 col2" >Mentoria/Comunidade</th>
#       <th id="T_eafb8_level0_col3" class="col_heading level0 col3" >Prática/PoC</th>
#       <th id="T_eafb8_level0_col4" class="col_heading level0 col4" >Treinamento formal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eafb8_level0_row0" class="row_heading level0 row0" >12-18 meses</th>
#       <td id="T_eafb8_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_eafb8_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_eafb8_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_eafb8_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_eafb8_row0_col4" class="data row0 col4" >5</td>
#     </tr>
#     <tr>
#       <th id="T_eafb8_level0_row1" class="row_heading level0 row1" >3-6 meses</th>
#       <td id="T_eafb8_row1_col0" class="data row1 col0" >8</td>
#       <td id="T_eafb8_row1_col1" class="data row1 col1" >23</td>
#       <td id="T_eafb8_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_eafb8_row1_col3" class="data row1 col3" >6</td>
#       <td id="T_eafb8_row1_col4" class="data row1 col4" >7</td>
#     </tr>
#     <tr>
#       <th id="T_eafb8_level0_row2" class="row_heading level0 row2" >6-12 meses</th>
#       <td id="T_eafb8_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_eafb8_row2_col1" class="data row2 col1" >14</td>
#       <td id="T_eafb8_row2_col2" class="data row2 col2" >7</td>
#       <td id="T_eafb8_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_eafb8_row2_col4" class="data row2 col4" >14</td>
#     </tr>
#     <tr>
#       <th id="T_eafb8_level0_row3" class="row_heading level0 row3" >Mais de 18 meses</th>
#       <td id="T_eafb8_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_eafb8_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_eafb8_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_eafb8_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_eafb8_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_eafb8_level0_row4" class="row_heading level0 row4" >Menos de 3 meses</th>
#       <td id="T_eafb8_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_eafb8_row4_col1" class="data row4 col1" >10</td>
#       <td id="T_eafb8_row4_col2" class="data row4 col2" >5</td>
#       <td id="T_eafb8_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_eafb8_row4_col4" class="data row4 col4" >7</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# TABELA DE CONTINGÊNCIA: REALIZAÇÃO DE POCS × TEMPO DA EQUIPE PARA PRODUÇÃO
# ================================================================================
# <style type="text/css">
# #T_8e9fe th {
#   text-align: left;
# }
# #T_8e9fe  {
#   border: 1px solid black;
# }
# #T_8e9fe th {
#   border: 1px solid black;
# }
# #T_8e9fe td {
#   border: 1px solid black;
# }
# #T_8e9fe_row0_col0, #T_8e9fe_row0_col1, #T_8e9fe_row0_col2, #T_8e9fe_row0_col3, #T_8e9fe_row0_col4, #T_8e9fe_row1_col0, #T_8e9fe_row1_col1, #T_8e9fe_row1_col2, #T_8e9fe_row1_col3, #T_8e9fe_row1_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_8e9fe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e9fe_level0_col0" class="col_heading level0 col0" >1-3 meses</th>
#       <th id="T_8e9fe_level0_col1" class="col_heading level0 col1" >3-6 meses</th>
#       <th id="T_8e9fe_level0_col2" class="col_heading level0 col2" >6-12 meses</th>
#       <th id="T_8e9fe_level0_col3" class="col_heading level0 col3" >Mais de 12 meses</th>
#       <th id="T_8e9fe_level0_col4" class="col_heading level0 col4" >Menos de 1 mês</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e9fe_level0_row0" class="row_heading level0 row0" >Não</th>
#       <td id="T_8e9fe_row0_col0" class="data row0 col0" >8</td>
#       <td id="T_8e9fe_row0_col1" class="data row0 col1" >7</td>
#       <td id="T_8e9fe_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_8e9fe_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_8e9fe_row0_col4" class="data row0 col4" >5</td>
#     </tr>
#     <tr>
#       <th id="T_8e9fe_level0_row1" class="row_heading level0 row1" >Sim</th>
#       <td id="T_8e9fe_row1_col0" class="data row1 col0" >28</td>
#       <td id="T_8e9fe_row1_col1" class="data row1 col1" >39</td>
#       <td id="T_8e9fe_row1_col2" class="data row1 col2" >13</td>
#       <td id="T_8e9fe_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_8e9fe_row1_col4" class="data row1 col4" >24</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# ANÁLISE DESCRITIVA CONCLUÍDA
# ================================================================================

# %% [markdown]
# ### Teste Qui-Quadrado

# %%
utils.titulo_secao("Teste Qui-Quadrado")
# %run 02_qui_quadrado.ipynb
# Out:
# ================================================================================
# TESTE QUI-QUADRADO
# ================================================================================
# 130 respostas × 79 variáveis
# Bateria definida: 12 testes
#
#
# ================================================================================
# SEGURANÇA × CURVA RÁPIDA DA EQUIPE
# ================================================================================
# <style type="text/css">
# #T_f9e86 th {
#   text-align: left;
# }
# #T_f9e86  {
#   border: 1px solid black;
# }
# #T_f9e86 th {
#   border: 1px solid black;
# }
# #T_f9e86 td {
#   border: 1px solid black;
# }
# #T_f9e86_row0_col0, #T_f9e86_row0_col1, #T_f9e86_row1_col0, #T_f9e86_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_f9e86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9e86_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f9e86_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9e86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9e86_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_f9e86_row0_col1" class="data row0 col1" >45</td>
#     </tr>
#     <tr>
#       <th id="T_f9e86_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f9e86_row1_col0" class="data row1 col0" >27</td>
#       <td id="T_f9e86_row1_col1" class="data row1 col1" >20</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 1.1997 | p: 0.2734 | gl: 1 | V de Cramér: 0.096
# Fisher exato: p = 0.2733
# Esperado < 5: 0/4 (0%) | mínimo: 23.50
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# COMPLEXIDADE × CURVA RÁPIDA DA EQUIPE
# ================================================================================
# <style type="text/css">
# #T_681d2 th {
#   text-align: left;
# }
# #T_681d2  {
#   border: 1px solid black;
# }
# #T_681d2 th {
#   border: 1px solid black;
# }
# #T_681d2 td {
#   border: 1px solid black;
# }
# #T_681d2_row0_col0, #T_681d2_row0_col1, #T_681d2_row1_col0, #T_681d2_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_681d2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_681d2_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_681d2_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_681d2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_681d2_row0_col0" class="data row0 col0" >37</td>
#       <td id="T_681d2_row0_col1" class="data row0 col1" >47</td>
#     </tr>
#     <tr>
#       <th id="T_681d2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_681d2_row1_col0" class="data row1 col0" >28</td>
#       <td id="T_681d2_row1_col1" class="data row1 col1" >18</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 2.7252 | p: 0.0988 | gl: 1 | V de Cramér: 0.145
# Fisher exato: p = 0.0983
# Esperado < 5: 0/4 (0%) | mínimo: 23.00
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# MONITORAMENTO × CURVA RÁPIDA DA EQUIPE
# ================================================================================
# <style type="text/css">
# #T_c0108 th {
#   text-align: left;
# }
# #T_c0108  {
#   border: 1px solid black;
# }
# #T_c0108 th {
#   border: 1px solid black;
# }
# #T_c0108 td {
#   border: 1px solid black;
# }
# #T_c0108_row0_col0, #T_c0108_row0_col1, #T_c0108_row1_col0, #T_c0108_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_c0108">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0108_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_c0108_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0108_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0108_row0_col0" class="data row0 col0" >37</td>
#       <td id="T_c0108_row0_col1" class="data row0 col1" >43</td>
#     </tr>
#     <tr>
#       <th id="T_c0108_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c0108_row1_col0" class="data row1 col0" >28</td>
#       <td id="T_c0108_row1_col1" class="data row1 col1" >22</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 0.8125 | p: 0.3674 | gl: 1 | V de Cramér: 0.079
# Fisher exato: p = 0.3675
# Esperado < 5: 0/4 (0%) | mínimo: 25.00
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# MUDANÇAS ORGANIZACIONAIS × CURVA RÁPIDA DA EQUIPE
# ================================================================================
# <style type="text/css">
# #T_77284 th {
#   text-align: left;
# }
# #T_77284  {
#   border: 1px solid black;
# }
# #T_77284 th {
#   border: 1px solid black;
# }
# #T_77284 td {
#   border: 1px solid black;
# }
# #T_77284_row0_col0, #T_77284_row0_col1, #T_77284_row1_col0, #T_77284_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_77284">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77284_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_77284_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77284_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_77284_row0_col0" class="data row0 col0" >27</td>
#       <td id="T_77284_row0_col1" class="data row0 col1" >38</td>
#     </tr>
#     <tr>
#       <th id="T_77284_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_77284_row1_col0" class="data row1 col0" >38</td>
#       <td id="T_77284_row1_col1" class="data row1 col1" >27</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 3.0769 | p: 0.0794 | gl: 1 | V de Cramér: 0.154
# Fisher exato: p = 0.0790
# Esperado < 5: 0/4 (0%) | mínimo: 32.50
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# TREINAMENTO × CURVA RÁPIDA DA EQUIPE
# ================================================================================
# <style type="text/css">
# #T_5678f th {
#   text-align: left;
# }
# #T_5678f  {
#   border: 1px solid black;
# }
# #T_5678f th {
#   border: 1px solid black;
# }
# #T_5678f td {
#   border: 1px solid black;
# }
# #T_5678f_row0_col0, #T_5678f_row0_col1, #T_5678f_row1_col0, #T_5678f_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_5678f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5678f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_5678f_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5678f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5678f_row0_col0" class="data row0 col0" >41</td>
#       <td id="T_5678f_row0_col1" class="data row0 col1" >38</td>
#     </tr>
#     <tr>
#       <th id="T_5678f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5678f_row1_col0" class="data row1 col0" >24</td>
#       <td id="T_5678f_row1_col1" class="data row1 col1" >27</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 0.1291 | p: 0.7194 | gl: 1 | V de Cramér: 0.032
# Fisher exato: p = 0.7196
# Esperado < 5: 0/4 (0%) | mínimo: 25.50
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# CI/CD × CURVA RÁPIDA DA EQUIPE
# ================================================================================
# <style type="text/css">
# #T_23cde th {
#   text-align: left;
# }
# #T_23cde  {
#   border: 1px solid black;
# }
# #T_23cde th {
#   border: 1px solid black;
# }
# #T_23cde td {
#   border: 1px solid black;
# }
# #T_23cde_row0_col0, #T_23cde_row0_col1, #T_23cde_row1_col0, #T_23cde_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_23cde">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23cde_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_23cde_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23cde_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_23cde_row0_col0" class="data row0 col0" >39</td>
#       <td id="T_23cde_row0_col1" class="data row0 col1" >53</td>
#     </tr>
#     <tr>
#       <th id="T_23cde_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_23cde_row1_col0" class="data row1 col0" >26</td>
#       <td id="T_23cde_row1_col1" class="data row1 col1" >12</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 6.2843 | p: 0.0122 | gl: 1 | V de Cramér: 0.220
# Fisher exato: p = 0.0116
# Esperado < 5: 0/4 (0%) | mínimo: 19.00
# Associação significativa (p < 0.05).
#
#
# ================================================================================
# SEGURANÇA × CURVA RÁPIDA INDIVIDUAL
# ================================================================================
# <style type="text/css">
# #T_08c4a th {
#   text-align: left;
# }
# #T_08c4a  {
#   border: 1px solid black;
# }
# #T_08c4a th {
#   border: 1px solid black;
# }
# #T_08c4a td {
#   border: 1px solid black;
# }
# #T_08c4a_row0_col0, #T_08c4a_row0_col1, #T_08c4a_row1_col0, #T_08c4a_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_08c4a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08c4a_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_08c4a_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08c4a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_08c4a_row0_col0" class="data row0 col0" >33</td>
#       <td id="T_08c4a_row0_col1" class="data row0 col1" >50</td>
#     </tr>
#     <tr>
#       <th id="T_08c4a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_08c4a_row1_col0" class="data row1 col0" >23</td>
#       <td id="T_08c4a_row1_col1" class="data row1 col1" >24</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 0.6904 | p: 0.4060 | gl: 1 | V de Cramér: 0.073
# Fisher exato: p = 0.3586
# Esperado < 5: 0/4 (0%) | mínimo: 20.25
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# COMPLEXIDADE × CURVA RÁPIDA INDIVIDUAL
# ================================================================================
# <style type="text/css">
# #T_1b992 th {
#   text-align: left;
# }
# #T_1b992  {
#   border: 1px solid black;
# }
# #T_1b992 th {
#   border: 1px solid black;
# }
# #T_1b992 td {
#   border: 1px solid black;
# }
# #T_1b992_row0_col0, #T_1b992_row0_col1, #T_1b992_row1_col0, #T_1b992_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_1b992">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b992_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_1b992_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b992_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b992_row0_col0" class="data row0 col0" >32</td>
#       <td id="T_1b992_row0_col1" class="data row0 col1" >52</td>
#     </tr>
#     <tr>
#       <th id="T_1b992_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1b992_row1_col0" class="data row1 col0" >24</td>
#       <td id="T_1b992_row1_col1" class="data row1 col1" >22</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 1.8628 | p: 0.1723 | gl: 1 | V de Cramér: 0.120
# Fisher exato: p = 0.1406
# Esperado < 5: 0/4 (0%) | mínimo: 19.82
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# MONITORAMENTO × CURVA RÁPIDA INDIVIDUAL
# ================================================================================
# <style type="text/css">
# #T_0e89e th {
#   text-align: left;
# }
# #T_0e89e  {
#   border: 1px solid black;
# }
# #T_0e89e th {
#   border: 1px solid black;
# }
# #T_0e89e td {
#   border: 1px solid black;
# }
# #T_0e89e_row0_col0, #T_0e89e_row0_col1, #T_0e89e_row1_col0, #T_0e89e_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_0e89e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e89e_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_0e89e_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e89e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0e89e_row0_col0" class="data row0 col0" >31</td>
#       <td id="T_0e89e_row0_col1" class="data row0 col1" >49</td>
#     </tr>
#     <tr>
#       <th id="T_0e89e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0e89e_row1_col0" class="data row1 col0" >25</td>
#       <td id="T_0e89e_row1_col1" class="data row1 col1" >25</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 1.1625 | p: 0.2810 | gl: 1 | V de Cramér: 0.095
# Fisher exato: p = 0.2747
# Esperado < 5: 0/4 (0%) | mínimo: 21.54
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# MUDANÇAS ORGANIZACIONAIS × CURVA RÁPIDA INDIVIDUAL
# ================================================================================
# <style type="text/css">
# #T_f29ec th {
#   text-align: left;
# }
# #T_f29ec  {
#   border: 1px solid black;
# }
# #T_f29ec th {
#   border: 1px solid black;
# }
# #T_f29ec td {
#   border: 1px solid black;
# }
# #T_f29ec_row0_col0, #T_f29ec_row0_col1, #T_f29ec_row1_col0, #T_f29ec_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_f29ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f29ec_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f29ec_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f29ec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f29ec_row0_col0" class="data row0 col0" >26</td>
#       <td id="T_f29ec_row0_col1" class="data row0 col1" >39</td>
#     </tr>
#     <tr>
#       <th id="T_f29ec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f29ec_row1_col0" class="data row1 col0" >30</td>
#       <td id="T_f29ec_row1_col1" class="data row1 col1" >35</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 0.2823 | p: 0.5952 | gl: 1 | V de Cramér: 0.047
# Fisher exato: p = 0.5954
# Esperado < 5: 0/4 (0%) | mínimo: 28.00
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# TREINAMENTO × CURVA RÁPIDA INDIVIDUAL
# ================================================================================
# <style type="text/css">
# #T_c5611 th {
#   text-align: left;
# }
# #T_c5611  {
#   border: 1px solid black;
# }
# #T_c5611 th {
#   border: 1px solid black;
# }
# #T_c5611 td {
#   border: 1px solid black;
# }
# #T_c5611_row0_col0, #T_c5611_row0_col1, #T_c5611_row1_col0, #T_c5611_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_c5611">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5611_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_c5611_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5611_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c5611_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_c5611_row0_col1" class="data row0 col1" >41</td>
#     </tr>
#     <tr>
#       <th id="T_c5611_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c5611_row1_col0" class="data row1 col0" >18</td>
#       <td id="T_c5611_row1_col1" class="data row1 col1" >33</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 1.5837 | p: 0.2082 | gl: 1 | V de Cramér: 0.110
# Fisher exato: p = 0.2040
# Esperado < 5: 0/4 (0%) | mínimo: 21.97
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# CI/CD × CURVA RÁPIDA INDIVIDUAL
# ================================================================================
# <style type="text/css">
# #T_65483 th {
#   text-align: left;
# }
# #T_65483  {
#   border: 1px solid black;
# }
# #T_65483 th {
#   border: 1px solid black;
# }
# #T_65483 td {
#   border: 1px solid black;
# }
# #T_65483_row0_col0, #T_65483_row0_col1, #T_65483_row1_col0, #T_65483_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_65483">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65483_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_65483_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65483_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_65483_row0_col0" class="data row0 col0" >37</td>
#       <td id="T_65483_row0_col1" class="data row0 col1" >55</td>
#     </tr>
#     <tr>
#       <th id="T_65483_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_65483_row1_col0" class="data row1 col0" >19</td>
#       <td id="T_65483_row1_col1" class="data row1 col1" >19</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 0.6885 | p: 0.4067 | gl: 1 | V de Cramér: 0.073
# Fisher exato: p = 0.3348
# Esperado < 5: 0/4 (0%) | mínimo: 16.37
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# RESUMO DA BATERIA (12 TESTES)
# ================================================================================
#
# Premissa atendida em 12/12. Em 2x2 o p é o do Fisher exato.
# <style type="text/css">
# #T_274d9 th {
#   text-align: left;
# }
# #T_274d9  {
#   border: 1px solid black;
# }
# #T_274d9 th {
#   border: 1px solid black;
# }
# #T_274d9 td {
#   border: 1px solid black;
# }
# #T_274d9_row0_col0, #T_274d9_row0_col1, #T_274d9_row0_col2, #T_274d9_row0_col3, #T_274d9_row0_col4, #T_274d9_row0_col5, #T_274d9_row0_col6, #T_274d9_row0_col7, #T_274d9_row0_col8, #T_274d9_row1_col0, #T_274d9_row1_col1, #T_274d9_row1_col2, #T_274d9_row1_col3, #T_274d9_row1_col4, #T_274d9_row1_col5, #T_274d9_row1_col6, #T_274d9_row1_col7, #T_274d9_row1_col8, #T_274d9_row2_col0, #T_274d9_row2_col1, #T_274d9_row2_col2, #T_274d9_row2_col3, #T_274d9_row2_col4, #T_274d9_row2_col5, #T_274d9_row2_col6, #T_274d9_row2_col7, #T_274d9_row2_col8, #T_274d9_row3_col0, #T_274d9_row3_col1, #T_274d9_row3_col2, #T_274d9_row3_col3, #T_274d9_row3_col4, #T_274d9_row3_col5, #T_274d9_row3_col6, #T_274d9_row3_col7, #T_274d9_row3_col8, #T_274d9_row4_col0, #T_274d9_row4_col1, #T_274d9_row4_col2, #T_274d9_row4_col3, #T_274d9_row4_col4, #T_274d9_row4_col5, #T_274d9_row4_col6, #T_274d9_row4_col7, #T_274d9_row4_col8, #T_274d9_row5_col0, #T_274d9_row5_col1, #T_274d9_row5_col2, #T_274d9_row5_col3, #T_274d9_row5_col4, #T_274d9_row5_col5, #T_274d9_row5_col6, #T_274d9_row5_col7, #T_274d9_row5_col8, #T_274d9_row6_col0, #T_274d9_row6_col1, #T_274d9_row6_col2, #T_274d9_row6_col3, #T_274d9_row6_col4, #T_274d9_row6_col5, #T_274d9_row6_col6, #T_274d9_row6_col7, #T_274d9_row6_col8, #T_274d9_row7_col0, #T_274d9_row7_col1, #T_274d9_row7_col2, #T_274d9_row7_col3, #T_274d9_row7_col4, #T_274d9_row7_col5, #T_274d9_row7_col6, #T_274d9_row7_col7, #T_274d9_row7_col8, #T_274d9_row8_col0, #T_274d9_row8_col1, #T_274d9_row8_col2, #T_274d9_row8_col3, #T_274d9_row8_col4, #T_274d9_row8_col5, #T_274d9_row8_col6, #T_274d9_row8_col7, #T_274d9_row8_col8, #T_274d9_row9_col0, #T_274d9_row9_col1, #T_274d9_row9_col2, #T_274d9_row9_col3, #T_274d9_row9_col4, #T_274d9_row9_col5, #T_274d9_row9_col6, #T_274d9_row9_col7, #T_274d9_row9_col8, #T_274d9_row10_col0, #T_274d9_row10_col1, #T_274d9_row10_col2, #T_274d9_row10_col3, #T_274d9_row10_col4, #T_274d9_row10_col5, #T_274d9_row10_col6, #T_274d9_row10_col7, #T_274d9_row10_col8, #T_274d9_row11_col0, #T_274d9_row11_col1, #T_274d9_row11_col2, #T_274d9_row11_col3, #T_274d9_row11_col4, #T_274d9_row11_col5, #T_274d9_row11_col6, #T_274d9_row11_col7, #T_274d9_row11_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_274d9">
#   <thead>
#     <tr>
#       <th id="T_274d9_level0_col0" class="col_heading level0 col0" >Teste</th>
#       <th id="T_274d9_level0_col1" class="col_heading level0 col1" >n</th>
#       <th id="T_274d9_level0_col2" class="col_heading level0 col2" >Tabela</th>
#       <th id="T_274d9_level0_col3" class="col_heading level0 col3" >gl</th>
#       <th id="T_274d9_level0_col4" class="col_heading level0 col4" >Qui-quadrado</th>
#       <th id="T_274d9_level0_col5" class="col_heading level0 col5" >V de Cramér</th>
#       <th id="T_274d9_level0_col6" class="col_heading level0 col6" >p</th>
#       <th id="T_274d9_level0_col7" class="col_heading level0 col7" >Premissa</th>
#       <th id="T_274d9_level0_col8" class="col_heading level0 col8" >Significativo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_274d9_row0_col0" class="data row0 col0" >Segurança × curva rápida da equipe</td>
#       <td id="T_274d9_row0_col1" class="data row0 col1" >130</td>
#       <td id="T_274d9_row0_col2" class="data row0 col2" >2x2</td>
#       <td id="T_274d9_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_274d9_row0_col4" class="data row0 col4" >1.200000</td>
#       <td id="T_274d9_row0_col5" class="data row0 col5" >0.096000</td>
#       <td id="T_274d9_row0_col6" class="data row0 col6" >0.273300</td>
#       <td id="T_274d9_row0_col7" class="data row0 col7" >OK</td>
#       <td id="T_274d9_row0_col8" class="data row0 col8" >não</td>
#     </tr>
#     <tr>
#       <td id="T_274d9_row1_col0" class="data row1 col0" >Complexidade × curva rápida da equipe</td>
#       <td id="T_274d9_row1_col1" class="data row1 col1" >130</td>
#       <td id="T_274d9_row1_col2" class="data row1 col2" >2x2</td>
#       <td id="T_274d9_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_274d9_row1_col4" class="data row1 col4" >2.725000</td>
#       <td id="T_274d9_row1_col5" class="data row1 col5" >0.145000</td>
#       <td id="T_274d9_row1_col6" class="data row1 col6" >0.098300</td>
#       <td id="T_274d9_row1_col7" class="data row1 col7" >OK</td>
#       <td id="T_274d9_row1_col8" class="data row1 col8" >não</td>
#     </tr>
#     <tr>
#       <td id="T_274d9_row2_col0" class="data row2 col0" >Monitoramento × curva rápida da equipe</td>
#       <td id="T_274d9_row2_col1" class="data row2 col1" >130</td>
#       <td id="T_274d9_row2_col2" class="data row2 col2" >2x2</td>
#       <td id="T_274d9_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_274d9_row2_col4" class="data row2 col4" >0.812000</td>
#       <td id="T_274d9_row2_col5" class="data row2 col5" >0.079000</td>
#       <td id="T_274d9_row2_col6" class="data row2 col6" >0.367500</td>
#       <td id="T_274d9_row2_col7" class="data row2 col7" >OK</td>
#       <td id="T_274d9_row2_col8" class="data row2 col8" >não</td>
#     </tr>
#     <tr>
#       <td id="T_274d9_row3_col0" class="data row3 col0" >Mudanças organizacionais × curva rápida da equipe</td>
#       <td id="T_274d9_row3_col1" class="data row3 col1" >130</td>
#       <td id="T_274d9_row3_col2" class="data row3 col2" >2x2</td>
#       <td id="T_274d9_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_274d9_row3_col4" class="data row3 col4" >3.077000</td>
#       <td id="T_274d9_row3_col5" class="data row3 col5" >0.154000</td>
#       <td id="T_274d9_row3_col6" class="data row3 col6" >0.079000</td>
#       <td id="T_274d9_row3_col7" class="data row3 col7" >OK</td>
#       <td id="T_274d9_row3_col8" class="data row3 col8" >não</td>
#     </tr>
#     <tr>
#       <td id="T_274d9_row4_col0" class="data row4 col0" >Treinamento × curva rápida da equipe</td>
#       <td id="T_274d9_row4_col1" class="data row4 col1" >130</td>
#       <td id="T_274d9_row4_col2" class="data row4 col2" >2x2</td>
#       <td id="T_274d9_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_274d9_row4_col4" class="data row4 col4" >0.129000</td>
#       <td id="T_274d9_row4_col5" class="data row4 col5" >0.032000</td>
#       <td id="T_274d9_row4_col6" class="data row4 col6" >0.719600</td>
#       <td id="T_274d9_row4_col7" class="data row4 col7" >OK</td>
#       <td id="T_274d9_row4_col8" class="data row4 col8" >não</td>
#     </tr>
#     <tr>
#       <td id="T_274d9_row5_col0" class="data row5 col0" >CI/CD × curva rápida da equipe</td>
#       <td id="T_274d9_row5_col1" class="data row5 col1" >130</td>
#       <td id="T_274d9_row5_col2" class="data row5 col2" >2x2</td>
#       <td id="T_274d9_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_274d9_row5_col4" class="data row5 col4" >6.284000</td>
#       <td id="T_274d9_row5_col5" class="data row5 col5" >0.220000</td>
#       <td id="T_274d9_row5_col6" class="data row5 col6" >0.011600</td>
#       <td id="T_274d9_row5_col7" class="data row5 col7" >OK</td>
#       <td id="T_274d9_row5_col8" class="data row5 col8" >sim</td>
#     </tr>
#     <tr>
#       <td id="T_274d9_row6_col0" class="data row6 col0" >Segurança × curva rápida individual</td>
#       <td id="T_274d9_row6_col1" class="data row6 col1" >130</td>
#       <td id="T_274d9_row6_col2" class="data row6 col2" >2x2</td>
#       <td id="T_274d9_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_274d9_row6_col4" class="data row6 col4" >0.690000</td>
#       <td id="T_274d9_row6_col5" class="data row6 col5" >0.073000</td>
#       <td id="T_274d9_row6_col6" class="data row6 col6" >0.358600</td>
#       <td id="T_274d9_row6_col7" class="data row6 col7" >OK</td>
#       <td id="T_274d9_row6_col8" class="data row6 col8" >não</td>
#     </tr>
#     <tr>
#       <td id="T_274d9_row7_col0" class="data row7 col0" >Complexidade × curva rápida individual</td>
#       <td id="T_274d9_row7_col1" class="data row7 col1" >130</td>
#       <td id="T_27
# ACHADOS: 1
#   CI/CD × curva rápida da equipe: p = 0.0116 | V = 0.220
#
# Habilitados para ANACOR: 1
#   CI/CD × curva rápida da equipe

# %% [markdown]
# ### ANACOR (Análise de Correspondência)

# %%
utils.titulo_secao("ANACOR - Análise de Correspondência")
# %run 03_anacor.ipynb
# Out:
# ================================================================================
# ANACOR - ANÁLISE DE CORRESPONDÊNCIA
# ================================================================================
# 130 respostas × 79 variáveis
# Pares testados no notebook 02: 12
#
#   CI/CD × curva rápida da equipe
#     tabela 2x2 | dimensões possíveis: 1 | NÃO gera mapa 2D
#
# ================================================================================
# PRÉ-TESTE: PERFIL DE DESAFIO (Q17 CI/CD × Q13 COMPLEXIDADE) × TEMPO DA EQUIPE ATÉ PRODUÇÃO (Q25)
# ================================================================================
# <style type="text/css">
# #T_9c7bc th {
#   text-align: left;
# }
# #T_9c7bc  {
#   border: 1px solid black;
# }
# #T_9c7bc th {
#   border: 1px solid black;
# }
# #T_9c7bc td {
#   border: 1px solid black;
# }
# #T_9c7bc_row0_col0, #T_9c7bc_row0_col1, #T_9c7bc_row0_col2, #T_9c7bc_row1_col0, #T_9c7bc_row1_col1, #T_9c7bc_row1_col2, #T_9c7bc_row2_col0, #T_9c7bc_row2_col1, #T_9c7bc_row2_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_9c7bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c7bc_level0_col0" class="col_heading level0 col0" >Menos de 1 mês</th>
#       <th id="T_9c7bc_level0_col1" class="col_heading level0 col1" >1-3 meses</th>
#       <th id="T_9c7bc_level0_col2" class="col_heading level0 col2" >Mais de 3 meses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c7bc_level0_row0" class="row_heading level0 row0" >CI/CD alto</th>
#       <td id="T_9c7bc_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_9c7bc_row0_col1" class="data row0 col1" >8</td>
#       <td id="T_9c7bc_row0_col2" class="data row0 col2" >26</td>
#     </tr>
#     <tr>
#       <th id="T_9c7bc_level0_row1" class="row_heading level0 row1" >Complexidade alta, CI/CD não</th>
#       <td id="T_9c7bc_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_9c7bc_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_9c7bc_row1_col2" class="data row1 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_9c7bc_level0_row2" class="row_heading level0 row2" >Nenhum dos dois alto</th>
#       <td id="T_9c7bc_row2_col0" class="data row2 col0" >22</td>
#       <td id="T_9c7bc_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_9c7bc_row2_col2" class="data row2 col2" >22</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 15.4813 | p: 0.0038 | gl: 4 | V de Cramér: 0.244
# Esperado < 5: 0/9 (0%) | mínimo: 6.25
# Associação significativa (p < 0.05).
#
# Resíduos padronizados ajustados (* = |r| > 1,96):
#                              Menos de 1 mês 1-3 meses Mais de 3 meses
# CI/CD alto                           -2.07*    -1.09           +2.70*
# Complexidade alta, CI/CD não         -1.66     +0.12           +1.28
# Nenhum dos dois alto                 +3.25*    +0.89           -3.51*
#
# Pré-requisitos atendidos (p = 0.0038, V de Cramér = 0.244). Aplicando ANACOR.
#
#
# ================================================================================
# ANACOR: PERFIL DE DESAFIO (Q17 CI/CD × Q13 COMPLEXIDADE) × TEMPO DA EQUIPE ATÉ PRODUÇÃO (Q25)
# ================================================================================
# <style type="text/css">
# #T_61bcf th {
#   text-align: left;
# }
# #T_61bcf  {
#   border: 1px solid black;
# }
# #T_61bcf th {
#   border: 1px solid black;
# }
# #T_61bcf td {
#   border: 1px solid black;
# }
# #T_61bcf_row0_col0, #T_61bcf_row0_col1, #T_61bcf_row0_col2, #T_61bcf_row1_col0, #T_61bcf_row1_col1, #T_61bcf_row1_col2, #T_61bcf_row2_col0, #T_61bcf_row2_col1, #T_61bcf_row2_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_61bcf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61bcf_level0_col0" class="col_heading level0 col0" >Menos de 1 mês</th>
#       <th id="T_61bcf_level0_col1" class="col_heading level0 col1" >1-3 meses</th>
#       <th id="T_61bcf_level0_col2" class="col_heading level0 col2" >Mais de 3 meses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61bcf_level0_row0" class="row_heading level0 row0" >CI/CD alto</th>
#       <td id="T_61bcf_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_61bcf_row0_col1" class="data row0 col1" >8</td>
#       <td id="T_61bcf_row0_col2" class="data row0 col2" >26</td>
#     </tr>
#     <tr>
#       <th id="T_61bcf_level0_row1" class="row_heading level0 row1" >Complexidade alta, CI/CD não</th>
#       <td id="T_61bcf_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_61bcf_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_61bcf_row1_col2" class="data row1 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_61bcf_level0_row2" class="row_heading level0 row2" >Nenhum dos dois alto</th>
#       <td id="T_61bcf_row2_col0" class="data row2 col0" >22</td>
#       <td id="T_61bcf_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_61bcf_row2_col2" class="data row2 col2" >22</td>
#     </tr>
#   </tbody>
# </table>
# Inércia total: 0.1191
#   Dimensão 1: 97.72%
#   Dimensão 2: 2.28%
#   Acumulado: 100.00%  (a tabela admite exatamente 2 dimensões)
#
# Gráfico salvo: ../resultados/graficos/anacor/anacor_perfil_desafio_3_q25_faixa_deploy.png
# Figura (formato TCC) salva: ../resultados/graficos/anacor/figura_anacor_perfil_desafio_3_q25_faixa_deploy.png
#
# ================================================================================
# PRÉ-TESTE: PORTE DA EMPRESA (Q6) × PRINCIPAL DESAFIO (Q18)
# ================================================================================
# <style type="text/css">
# #T_bdf81 th {
#   text-align: left;
# }
# #T_bdf81  {
#   border: 1px solid black;
# }
# #T_bdf81 th {
#   border: 1px solid black;
# }
# #T_bdf81 td {
#   border: 1px solid black;
# }
# #T_bdf81_row0_col0, #T_bdf81_row0_col1, #T_bdf81_row0_col2, #T_bdf81_row0_col3, #T_bdf81_row0_col4, #T_bdf81_row0_col5, #T_bdf81_row0_col6, #T_bdf81_row0_col7, #T_bdf81_row1_col0, #T_bdf81_row1_col1, #T_bdf81_row1_col2, #T_bdf81_row1_col3, #T_bdf81_row1_col4, #T_bdf81_row1_col5, #T_bdf81_row1_col6, #T_bdf81_row1_col7, #T_bdf81_row2_col0, #T_bdf81_row2_col1, #T_bdf81_row2_col2, #T_bdf81_row2_col3, #T_bdf81_row2_col4, #T_bdf81_row2_col5, #T_bdf81_row2_col6, #T_bdf81_row2_col7 {
#   text-align: center;
# }
# </style>
# <table id="T_bdf81">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdf81_level0_col0" class="col_heading level0 col0" >CI/CD</th>
#       <th id="T_bdf81_level0_col1" class="col_heading level0 col1" >Complexidade técnica</th>
#       <th id="T_bdf81_level0_col2" class="col_heading level0 col2" >Infra/Escala</th>
#       <th id="T_bdf81_level0_col3" class="col_heading level0 col3" >Legado/Migração</th>
#       <th id="T_bdf81_level0_col4" class="col_heading level0 col4" >Monitoramento</th>
#       <th id="T_bdf81_level0_col5" class="col_heading level0 col5" >Organizacional/Cultural</th>
#       <th id="T_bdf81_level0_col6" class="col_heading level0 col6" >Segurança</th>
#       <th id="T_bdf81_level0_col7" class="col_heading level0 col7" >Sem desafio relevante</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdf81_level0_row0" class="row_heading level0 row0" >Grande (mais de 250 funcionários)</th>
#       <td id="T_bdf81_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_bdf81_row0_col1" class="data row0 col1" >11</td>
#       <td id="T_bdf81_row0_col2" class="data row0 col2" >7</td>
#       <td id="T_bdf81_row0_col3" class="data row0 col3" >7</td>
#       <td id="T_bdf81_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_bdf81_row0_col5" class="data row0 col5" >21</td>
#       <td id="T_bdf81_row0_col6" class="data row0 col6" >6</td>
#       <td id="T_bdf81_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_bdf81_level0_row1" class="row_heading level0 row1" >Média (50-250 funcionários)</th>
#       <td id="T_bdf81_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_bdf81_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_bdf81_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_bdf81_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_bdf81_row1_col4" class="data row1 col4" >4</td>
#       <td id="T_bdf81_row1_col5" class="data row1 col5" >12</td>
#       <td id="T_bdf81_row1_col6" class="data row1 col6" >4</td>
#       <td id="T_bdf81_row1_col7" class="data row1 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_bdf81_level0_row2" class="row_heading level0 row2" >Pequena (menos de 50 funcionários)</th>
#       <td id="T_bdf81_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_bdf81_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_bdf81_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_bdf81_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_bdf81_row2_col4" class="data row2 col4" >4</td>
#       <td id="T_bdf81_row2_col5" class="data row2 col5" >7</td>
#       <td id="T_bdf81_row2_col6" class="data row2 col6" >2</td>
#       <td id="T_bdf81_row2_col7" class="data row2 col7" >1</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 4.6753 | p: 0.9898 | gl: 14 | V de Cramér: 0.134
# Esperado < 5: 15/24 (62%) | mínimo: 0.43
# Premissa VIOLADA - p-valor não interpretável.
#
# ANACOR NÃO APLICADA a 'Porte da empresa (Q6) × Principal desafio (Q18)': premissa das frequências esperadas violada (62% das células com esperado < 5).
#
#
# ================================================================================
# PRÉ-TESTE: FONTE DE APRENDIZADO MAIS ÚTIL (Q22) × TEMPO INDIVIDUAL (Q24)
# ================================================================================
# <style type="text/css">
# #T_8b821 th {
#   text-align: left;
# }
# #T_8b821  {
#   border: 1px solid black;
# }
# #T_8b821 th {
#   border: 1px solid black;
# }
# #T_8b821 td {
#   border: 1px solid black;
# }
# #T_8b821_row0_col0, #T_8b821_row0_col1, #T_8b821_row0_col2, #T_8b821_row1_col0, #T_8b821_row1_col1, #T_8b821_row1_col2, #T_8b821_row2_col0, #T_8b821_row2_col1, #T_8b821_row2_col2, #T_8b821_row3_col0, #T_8b821_row3_col1, #T_8b821_row3_col2, #T_8b821_row4_col0, #T_8b821_row4_col1, #T_8b821_row4_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_8b821">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b821_level0_col0" class="col_heading level0 col0" >Até 3 meses</th>
#       <th id="T_8b821_level0_col1" class="col_heading level0 col1" >3-6 meses</th>
#       <th id="T_8b821_level0_col2" class="col_heading level0 col2" >Mais de 6 meses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b821_level0_row0" class="row_heading level0 row0" >Agentes de IA</th>
#       <td id="T_8b821_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_8b821_row0_col1" class="data row0 col1" >8</td>
#       <td id="T_8b821_row0_col2" class="data row0 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_8b821_level0_row1" class="row_heading level0 row1" >Documentação e autoestudo</th>
#       <td id="T_8b821_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_8b821_row1_col1" class="data row1 col1" >23</td>
#       <td id="T_8b821_row1_col2" class="data row1 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_8b821_level0_row2" class="row_heading level0 row2" >Mentoria/Comunidade</th>
#       <td id="T_8b821_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_8b821_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_8b821_row2_col2" class="data row2 col2" >9</td>
#     </tr>
#     <tr>
#       <th id="T_8b821_level0_row3" class="row_heading level0 row3" >Prática/PoC</th>
#       <td id="T_8b821_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_8b821_row3_col1" class="data row3 col1" >6</td>
#       <td id="T_8b821_row3_col2" class="data row3 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_8b821_level0_row4" class="row_heading level0 row4" >Treinamento formal</th>
#       <td id="T_8b821_row4_col0" class="data row4 col0" >7</td>
#       <td id="T_8b821_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_8b821_row4_col2" class="data row4 col2" >20</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 12.4102 | p: 0.1338 | gl: 8 | V de Cramér: 0.218
# Esperado < 5: 3/15 (20%) | mínimo: 2.91
# Sem evidência de associação (p >= 0.05).
#
# ANACOR NÃO APLICADA a 'Fonte de aprendizado mais útil (Q22) × Tempo individual (Q24)': associação não significativa (p = 0.1338).
#
#
# ================================================================================
# PRÉ-TESTE: FATOR ACELERADOR (Q26) × TEMPO DA EQUIPE (Q25)
# ================================================================================
# <style type="text/css">
# #T_cd056 th {
#   text-align: left;
# }
# #T_cd056  {
#   border: 1px solid black;
# }
# #T_cd056 th {
#   border: 1px solid black;
# }
# #T_cd056 td {
#   border: 1px solid black;
# }
# #T_cd056_row0_col0, #T_cd056_row0_col1, #T_cd056_row0_col2, #T_cd056_row1_col0, #T_cd056_row1_col1, #T_cd056_row1_col2, #T_cd056_row2_col0, #T_cd056_row2_col1, #T_cd056_row2_col2, #T_cd056_row3_col0, #T_cd056_row3_col1, #T_cd056_row3_col2, #T_cd056_row4_col0, #T_cd056_row4_col1, #T_cd056_row4_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_cd056">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd056_level0_col0" class="col_heading level0 col0" >Menos de 1 mês</th>
#       <th id="T_cd056_level0_col1" class="col_heading level0 col1" >1-3 meses</th>
#       <th id="T_cd056_level0_col2" class="col_heading level0 col2" >Mais de 3 meses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd056_level0_row0" class="row_heading level0 row0" >Experiência prévia</th>
#       <td id="T_cd056_row0_col0" class="data row0 col0" >8</td>
#       <td id="T_cd056_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_cd056_row0_col2" class="data row0 col2" >10</td>
#     </tr>
#     <tr>
#       <th id="T_cd056_level0_row1" class="row_heading level0 row1" >Formal/Certificação</th>
#       <td id="T_cd056_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_cd056_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_cd056_row1_col2" class="data row1 col2" >9</td>
#     </tr>
#     <tr>
#       <th id="T_cd056_level0_row2" class="row_heading level0 row2" >Mentoria/Comunidade</th>
#       <td id="T_cd056_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_cd056_row2_col1" class="data row2 col1" >6</td>
#       <td id="T_cd056_row2_col2" class="data row2 col2" >11</td>
#     </tr>
#     <tr>
#       <th id="T_cd056_level0_row3" class="row_heading level0 row3" >Prática/PoC</th>
#       <td id="T_cd056_row3_col0" class="data row3 col0" >7</td>
#       <td id="T_cd056_row3_col1" class="data row3 col1" >11</td>
#       <td id="T_cd056_row3_col2" class="data row3 col2" >21</td>
#     </tr>
#     <tr>
#       <th id="T_cd056_level0_row4" class="row_heading level0 row4" >Tempo dedicado</th>
#       <td id="T_cd056_row4_col0" class="data row4 col0" >6</td>
#       <td id="T_cd056_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_cd056_row4_col2" class="data row4 col2" >14</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 3.7443 | p: 0.8794 | gl: 8 | V de Cramér: 0.120
# Esperado < 5: 3/15 (20%) | mínimo: 3.57
# Sem evidência de associação (p >= 0.05).
#
# ANACOR NÃO APLICADA a 'Fator acelerador (Q26) × Tempo da equipe (Q25)': associação não significativa (p = 0.8794).
#
#
# ================================================================================
# PRÉ-TESTE: SENSIBILIDADE: FONTE MAIS ÚTIL EM 3 NÍVEIS (Q22) × TEMPO INDIVIDUAL (Q24)
# ================================================================================
# <style type="text/css">
# #T_9058b th {
#   text-align: left;
# }
# #T_9058b  {
#   border: 1px solid black;
# }
# #T_9058b th {
#   border: 1px solid black;
# }
# #T_9058b td {
#   border: 1px solid black;
# }
# #T_9058b_row0_col0, #T_9058b_row0_col1, #T_9058b_row0_col2, #T_9058b_row1_col0, #T_9058b_row1_col1, #T_9058b_row1_col2, #T_9058b_row2_col0, #T_9058b_row2_col1, #T_9058b_row2_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_9058b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9058b_level0_col0" class="col_heading level0 col0" >Até 3 meses</th>
#       <th id="T_9058b_level0_col1" class="col_heading level0 col1" >3-6 meses</th>
#       <th id="T_9058b_level0_col2" class="col_heading level0 col2" >Mais de 6 meses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9058b_level0_row0" class="row_heading level0 row0" >Autoestudo</th>
#       <td id="T_9058b_row0_col0" class="data row0 col0" >13</td>
#       <td id="T_9058b_row0_col1" class="data row0 col1" >31</td>
#       <td id="T_9058b_row0_col2" class="data row0 col2" >21</td>
#     </tr>
#     <tr>
#       <th id="T_9058b_level0_row1" class="row_heading level0 row1" >Social/Prática</th>
#       <td id="T_9058b_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_9058b_row1_col1" class="data row1 col1" >9</td>
#       <td id="T_9058b_row1_col2" class="data row1 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_9058b_level0_row2" class="row_heading level0 row2" >Treinamento formal</th>
#       <td id="T_9058b_row2_col0" class="data row2 col0" >7</td>
#       <td id="T_9058b_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_9058b_row2_col2" class="data row2 col2" >20</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 9.0851 | p: 0.0590 | gl: 4 | V de Cramér: 0.187
# Esperado < 5: 0/9 (0%) | mínimo: 6.44
# Sem evidência de associação (p >= 0.05).
#
# ANACOR NÃO APLICADA a 'Sensibilidade: Fonte mais útil em 3 níveis (Q22) × Tempo individual (Q24)': associação não significativa (p = 0.0590).
#
#
# ================================================================================
# ANACOR CONCLUÍDA
# ================================================================================
#
# Pares avaliados: 5 | mapas gerados: 1
#
#   MAPA     Perfil de desafio × Tempo da equipe
#            dim1 97.72% | dim2 2.28%
#   recusado Porte da empresa (Q6) × Principal desafio (Q18)
#            premissa das frequências esperadas violada (62% das células com esperado < 5)
#   recusado Fonte de aprendizado mais útil (Q22) × Tempo individual (Q24)
#            associação não significativa (p = 0.1338)
#   recusado Fator acelerador (Q26) × Tempo da equipe (Q25)
#            associação não significativa (p = 0.8794)
#   recusado Sensibilidade: Fonte em 3 níveis × Tempo individual
#            associação não significativa (p = 0.0590)

# %% [markdown]
# ### Regressão Logística

# %%
utils.titulo_secao("Regressão Logística")
# %run 04_regressao.ipynb
# Out:
# ================================================================================
# REGRESSÃO LOGÍSTICA
# ================================================================================
# 130 respostas × 79 variáveis
#
# ================================================================================
# REGRESSÃO LOGÍSTICA - FATORES PREDITIVOS DA CURVA DE APRENDIZADO
# ================================================================================
#
# MODELO:
#   Variável Dependente: Curva Rápida individual (até 6 meses)
#   Método: Regressão Logística Binária
#
# VARIÁVEIS PREDITORAS:
#   • Realizou provas de conceito antes da produção
#   • Possui certificação técnica
#   • Empresa ofereceu treinamento formal
#   • Experiência com contêineres (3 anos ou mais)
#
# ================================================================================
# RESUMO DOS DADOS
# ================================================================================
#   Total de observações: 130
#   Curva rápida (até 6 meses): 74 (56.9%)
#   Curva lenta (mais de 6 meses): 56 (43.1%)
#
# ================================================================================
# MÉTRICAS DO MODELO
# ================================================================================
#   Pseudo R² (McFadden): 0.0234
#   Log-Likelihood: -86.78
#   Teste de razão de verossimilhança: LR = 4.156 | gl = 4 | p = 0.3853
#   AIC: 183.56
#   BIC: 197.90
#   Convergência: Sim
#
# ================================================================================
# INTERPRETAÇÃO DOS COEFICIENTES (Odds Ratios)
# ================================================================================
# <style type="text/css">
# #T_f3927 th {
#   text-align: left;
# }
# #T_f3927  {
#   border: 1px solid black;
# }
# #T_f3927 th {
#   border: 1px solid black;
# }
# #T_f3927 td {
#   border: 1px solid black;
# }
# #T_f3927_row0_col0, #T_f3927_row0_col1, #T_f3927_row0_col2, #T_f3927_row0_col3, #T_f3927_row0_col4, #T_f3927_row1_col0, #T_f3927_row1_col1, #T_f3927_row1_col2, #T_f3927_row1_col3, #T_f3927_row1_col4, #T_f3927_row2_col0, #T_f3927_row2_col1, #T_f3927_row2_col2, #T_f3927_row2_col3, #T_f3927_row2_col4, #T_f3927_row3_col0, #T_f3927_row3_col1, #T_f3927_row3_col2, #T_f3927_row3_col3, #T_f3927_row3_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_f3927">
#   <thead>
#     <tr>
#       <th id="T_f3927_level0_col0" class="col_heading level0 col0" >Variável</th>
#       <th id="T_f3927_level0_col1" class="col_heading level0 col1" >Razão de chances</th>
#       <th id="T_f3927_level0_col2" class="col_heading level0 col2" >IC 95%</th>
#       <th id="T_f3927_level0_col3" class="col_heading level0 col3" >p-valor</th>
#       <th id="T_f3927_level0_col4" class="col_heading level0 col4" >Significativo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f3927_row0_col0" class="data row0 col0" >Realizou provas de conceito antes da produção</td>
#       <td id="T_f3927_row0_col1" class="data row0 col1" >1.046</td>
#       <td id="T_f3927_row0_col2" class="data row0 col2" >[0.39; 2.81]</td>
#       <td id="T_f3927_row0_col3" class="data row0 col3" >0.9290</td>
#       <td id="T_f3927_row0_col4" class="data row0 col4" >Não</td>
#     </tr>
#     <tr>
#       <td id="T_f3927_row1_col0" class="data row1 col0" >Possui certificação técnica</td>
#       <td id="T_f3927_row1_col1" class="data row1 col1" >0.502</td>
#       <td id="T_f3927_row1_col2" class="data row1 col2" >[0.23; 1.08]</td>
#       <td id="T_f3927_row1_col3" class="data row1 col3" >0.0765</td>
#       <td id="T_f3927_row1_col4" class="data row1 col4" >Não</td>
#     </tr>
#     <tr>
#       <td id="T_f3927_row2_col0" class="data row2 col0" >Empresa ofereceu treinamento formal</td>
#       <td id="T_f3927_row2_col1" class="data row2 col1" >0.771</td>
#       <td id="T_f3927_row2_col2" class="data row2 col2" >[0.36; 1.64]</td>
#       <td id="T_f3927_row2_col3" class="data row2 col3" >0.5012</td>
#       <td id="T_f3927_row2_col4" class="data row2 col4" >Não</td>
#     </tr>
#     <tr>
#       <td id="T_f3927_row3_col0" class="data row3 col0" >Experiência com contêineres (3 anos ou mais)</td>
#       <td id="T_f3927_row3_col1" class="data row3 col1" >1.058</td>
#       <td id="T_f3927_row3_col2" class="data row3 col2" >[0.49; 2.31]</td>
#       <td id="T_f3927_row3_col3" class="data row3 col3" >0.8868</td>
#       <td id="T_f3927_row3_col4" class="data row3 col4" >Não</td>
#     </tr>
#   </tbody>
# </table>
# RESULTADO: Nenhuma variável significativa (p ≥ 0.05 para todas)
#
# ================================================================================
# ANÁLISE DESCRITIVA: Impacto Real de Cada Variável
# ================================================================================
# <style type="text/css">
# #T_0ff10 th {
#   text-align: left;
# }
# #T_0ff10  {
#   border: 1px solid black;
# }
# #T_0ff10 th {
#   border: 1px solid black;
# }
# #T_0ff10 td {
#   border: 1px solid black;
# }
# #T_0ff10_row0_col0, #T_0ff10_row0_col1, #T_0ff10_row0_col2, #T_0ff10_row0_col3, #T_0ff10_row1_col0, #T_0ff10_row1_col1, #T_0ff10_row1_col2, #T_0ff10_row1_col3, #T_0ff10_row2_col0, #T_0ff10_row2_col1, #T_0ff10_row2_col2, #T_0ff10_row2_col3, #T_0ff10_row3_col0, #T_0ff10_row3_col1, #T_0ff10_row3_col2, #T_0ff10_row3_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_0ff10">
#   <thead>
#     <tr>
#       <th id="T_0ff10_level0_col0" class="col_heading level0 col0" >Variável</th>
#       <th id="T_0ff10_level0_col1" class="col_heading level0 col1" >Com fator</th>
#       <th id="T_0ff10_level0_col2" class="col_heading level0 col2" >Sem fator</th>
#       <th id="T_0ff10_level0_col3" class="col_heading level0 col3" >Diferença</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0ff10_row0_col0" class="data row0 col0" >Realizou provas de conceito antes da produção</td>
#       <td id="T_0ff10_row0_col1" class="data row0 col1" >59/105 (56.2%)</td>
#       <td id="T_0ff10_row0_col2" class="data row0 col2" >15/25 (60.0%)</td>
#       <td id="T_0ff10_row0_col3" class="data row0 col3" >-3.8pp</td>
#     </tr>
#     <tr>
#       <td id="T_0ff10_row1_col0" class="data row1 col0" >Possui certificação técnica</td>
#       <td id="T_0ff10_row1_col1" class="data row1 col1" >21/46 (45.7%)</td>
#       <td id="T_0ff10_row1_col2" class="data row1 col2" >53/84 (63.1%)</td>
#       <td id="T_0ff10_row1_col3" class="data row1 col3" >-17.4pp</td>
#     </tr>
#     <tr>
#       <td id="T_0ff10_row2_col0" class="data row2 col0" >Empresa ofereceu treinamento formal</td>
#       <td id="T_0ff10_row2_col1" class="data row2 col1" >23/45 (51.1%)</td>
#       <td id="T_0ff10_row2_col2" class="data row2 col2" >51/85 (60.0%)</td>
#       <td id="T_0ff10_row2_col3" class="data row2 col3" >-8.9pp</td>
#     </tr>
#     <tr>
#       <td id="T_0ff10_row3_col0" class="data row3 col0" >Experiência com contêineres (3 anos ou mais)</td>
#       <td id="T_0ff10_row3_col1" class="data row3 col1" >42/75 (56.0%)</td>
#       <td id="T_0ff10_row3_col2" class="data row3 col2" >32/55 (58.2%)</td>
#       <td id="T_0ff10_row3_col3" class="data row3 col3" >-2.2pp</td>
#     </tr>
#   </tbody>
# </table>
# Como interpretar:
#   • 'Com fator': % de curva rápida quando a característica está presente
#   • 'Sem fator': % de curva rápida quando a característica está ausente
#   • 'Diferença': Impacto em pontos percentuais (pp)
#   • Diferença positiva = fator favorece curva rápida
#   • Diferença negativa = fator dificulta curva rápida
# Gráfico salvo: ../resultados/graficos/regressao/impacto_fatores.png
#
# ================================================================================
# ANÁLISE DE REGRESSÃO LOGÍSTICA CONCLUÍDA
# ================================================================================
#
# Resultados:
#   - Modelo ajustado com sucesso
#   - Análise descritiva de impacto gerada
#   - Gráfico visual salvo em resultados/graficos/regressao/
#
# Próximo passo:
#   - Gerar visualizações adicionais (05_visualizacoes.ipynb)

# %% [markdown]
# ### Visualizações

# %%
utils.titulo_secao("Visualizações")
# %run 05_visualizacoes.ipynb
# Out:
# ================================================================================
# VISUALIZAÇÕES
# ================================================================================
# 130 respostas × 79 variáveis
# Gráfico salvo: ../resultados/graficos/descritivas/viz_cargos.png
# Gráfico salvo: ../resultados/graficos/descritivas/viz_porte_empresa.png
# Gráfico salvo: ../resultados/graficos/descritivas/viz_desafios_likert.png
# Gráfico salvo: ../resultados/graficos/descritivas/viz_tempo_individual.png
# Gráfico salvo: ../resultados/graficos/descritivas/viz_roi.png
#
# Média de ROI: 4.34
# Mediana de ROI: 5.0
# Gráfico salvo: ../resultados/graficos/descritivas/viz_desafio_por_porte.png
# Figura salva: ../resultados/graficos/descritivas/figura2_cargo.png
# Figura salva: ../resultados/graficos/descritivas/figura3_tempo_ti.png
# Figura salva: ../resultados/graficos/descritivas/figura4_tempo_conteineres.png
#
# ================================================================================
# VISUALIZAÇÕES CONCLUÍDAS
# ================================================================================
#
# Gráficos salvos em resultados/graficos/descritivas/:
#    - viz_cargos.png
#    - viz_porte_empresa.png
#    - viz_desafios_likert.png
#    - viz_tempo_individual.png
#    - viz_roi.png
#    - viz_desafio_por_porte.png
#
# Pipeline completa de análises finalizada!

# %% [markdown]
# ---
# ## Resumo Final

# %%
utils.titulo_secao("Análises Concluídas")

print("Análise Descritiva")
print("Teste Qui-Quadrado")
print("ANACOR")
print("Regressão Logística")
print("Visualizações")
print(f"\nResultados salvos em: ../resultados/")
# Out:
# ================================================================================
# ANÁLISES CONCLUÍDAS
# ================================================================================
# Análise Descritiva
# Teste Qui-Quadrado
# ANACOR
# Regressão Logística
# Visualizações
#
# Resultados salvos em: ../resultados/

# %% [markdown]
# ### 📚 Referências Metodológicas
#
# - **Qui-Quadrado:** Teste de independência entre variáveis categóricas
# - **ANACOR:** Análise de Correspondência (Hair et al., 2009)
# - **Regressão Logística:** Modelagem de fatores preditivos
