# %% [markdown]
# # Análise Estatística - TCC Engenharia de Software
# ## Tecnologias de Conteinerização: Curva de Aprendizagem Organizacional
#
# **Autor:** Guilherme Magalhães Leite
# **Orientador:** Arthur Pinheiro de Araújo Costa
# **Instituição:** MBA USP/ESALQ - Engenharia de Software
#
# ---
#
# ## Sobre Este Notebook
#
# Notebook principal que **orquestra todas as análises estatísticas** do projeto de pesquisa.
#
# ### Análises Implementadas
#
# 1. **Análise Descritiva** - Frequências, médias, tabelas de contingência
# 2. **Teste Qui-Quadrado** - Associações entre variáveis categóricas
# 3. **ANACOR** - Análise de Correspondência (mapas perceptuais 2D)
# 4. **Regressão Logística** - Fatores preditivos de curva de aprendizado
# 5. **Visualizações** - Gráficos exploratórios e descritivos
#
# ### Como Usar
#
# - **Executar tudo:** `Cell → Run All`
# - **Executar por partes:** Execute cada seção individualmente
# - **Notebooks individuais:** Disponíveis em `01_` até `05_`
#
# ### Estrutura Modular
#
# ```
# notebooks/
# ├── 00_master_analise.ipynb     ← VOCÊ ESTÁ AQUI
# ├── 01_analise_descritiva.ipynb
# ├── 02_qui_quadrado.ipynb
# ├── 03_anacor.ipynb
# ├── 04_regressao.ipynb
# └── 05_visualizacoes.ipynb
#
# src/
# └── utils.py                    # Funções reutilizáveis
# ```

# %% [markdown]
# ---
# ## Configuração Inicial

# %%
# %load_ext autoreload
# %autoreload 2

import sys; sys.path.append('../src')
import pandas as pd, warnings, utils

warnings.filterwarnings('ignore')
utils.configurar_visualizacoes()

# %% [markdown]
# ---
# ## Carregamento e Pré-processamento dos Dados

# %%
df = utils.carregar_dados('../dados/respostas.csv')
print(f"Dataset carregado: {len(df)} respostas × {len(df.columns)} variáveis")
# Out:
# Dataset carregado: 45 respostas × 29 variáveis

# %% [markdown]
# ---
# ## Pipeline de Análises
#
# Execute cada análise individualmente ou use os notebooks especializados.

# %% [markdown]
# ### Análise Descritiva

# %%
utils.titulo_secao("Análise Descritiva")
# %run 01_analise_descritiva.ipynb
# Out:
# ================================================================================
# ANÁLISE DESCRITIVA
# ================================================================================
# Usando dados já carregados
#
# DISTRIBUIÇÃO: Cargo
# <style type="text/css">
# #T_f93c0 th {
#   text-align: left;
# }
# #T_f93c0  {
#   border: 1px solid black;
# }
# #T_f93c0 th {
#   border: 1px solid black;
# }
# #T_f93c0 td {
#   border: 1px solid black;
# }
# #T_f93c0_row0_col0, #T_f93c0_row0_col1, #T_f93c0_row0_col2, #T_f93c0_row1_col0, #T_f93c0_row1_col1, #T_f93c0_row1_col2, #T_f93c0_row2_col0, #T_f93c0_row2_col1, #T_f93c0_row2_col2, #T_f93c0_row3_col0, #T_f93c0_row3_col1, #T_f93c0_row3_col2, #T_f93c0_row4_col0, #T_f93c0_row4_col1, #T_f93c0_row4_col2, #T_f93c0_row5_col0, #T_f93c0_row5_col1, #T_f93c0_row5_col2, #T_f93c0_row6_col0, #T_f93c0_row6_col1, #T_f93c0_row6_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_f93c0">
#   <thead>
#     <tr>
#       <th id="T_f93c0_level0_col0" class="col_heading level0 col0" >Cargo</th>
#       <th id="T_f93c0_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_f93c0_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f93c0_row0_col0" class="data row0 col0" >DevOps Engineer</td>
#       <td id="T_f93c0_row0_col1" class="data row0 col1" >21</td>
#       <td id="T_f93c0_row0_col2" class="data row0 col2" >46.67</td>
#     </tr>
#     <tr>
#       <td id="T_f93c0_row1_col0" class="data row1 col0" >Desenvolvedor</td>
#       <td id="T_f93c0_row1_col1" class="data row1 col1" >13</td>
#       <td id="T_f93c0_row1_col2" class="data row1 col2" >28.89</td>
#     </tr>
#     <tr>
#       <td id="T_f93c0_row2_col0" class="data row2 col0" >SRE (Site Reliability Engineer)</td>
#       <td id="T_f93c0_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_f93c0_row2_col2" class="data row2 col2" >11.11</td>
#     </tr>
#     <tr>
#       <td id="T_f93c0_row3_col0" class="data row3 col0" >Arquiteto de Soluções</td>
#       <td id="T_f93c0_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_f93c0_row3_col2" class="data row3 col2" >4.44</td>
#     </tr>
#     <tr>
#       <td id="T_f93c0_row4_col0" class="data row4 col0" >Estágio em tecnologia</td>
#       <td id="T_f93c0_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_f93c0_row4_col2" class="data row4 col2" >4.44</td>
#     </tr>
#     <tr>
#       <td id="T_f93c0_row5_col0" class="data row5 col0" >Não estou trabalhando no momento</td>
#       <td id="T_f93c0_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_f93c0_row5_col2" class="data row5 col2" >2.22</td>
#     </tr>
#     <tr>
#       <td id="T_f93c0_row6_col0" class="data row6 col0" >Technical Product Manager</td>
#       <td id="T_f93c0_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_f93c0_row6_col2" class="data row6 col2" >2.22</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tempo de Experiência em TI
# <style type="text/css">
# #T_26ae7 th {
#   text-align: left;
# }
# #T_26ae7  {
#   border: 1px solid black;
# }
# #T_26ae7 th {
#   border: 1px solid black;
# }
# #T_26ae7 td {
#   border: 1px solid black;
# }
# #T_26ae7_row0_col0, #T_26ae7_row0_col1, #T_26ae7_row0_col2, #T_26ae7_row1_col0, #T_26ae7_row1_col1, #T_26ae7_row1_col2, #T_26ae7_row2_col0, #T_26ae7_row2_col1, #T_26ae7_row2_col2, #T_26ae7_row3_col0, #T_26ae7_row3_col1, #T_26ae7_row3_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_26ae7">
#   <thead>
#     <tr>
#       <th id="T_26ae7_level0_col0" class="col_heading level0 col0" >Tempo em TI</th>
#       <th id="T_26ae7_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_26ae7_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_26ae7_row0_col0" class="data row0 col0" >2-5 anos</td>
#       <td id="T_26ae7_row0_col1" class="data row0 col1" >16</td>
#       <td id="T_26ae7_row0_col2" class="data row0 col2" >35.56</td>
#     </tr>
#     <tr>
#       <td id="T_26ae7_row1_col0" class="data row1 col0" >5-10 anos</td>
#       <td id="T_26ae7_row1_col1" class="data row1 col1" >15</td>
#       <td id="T_26ae7_row1_col2" class="data row1 col2" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_26ae7_row2_col0" class="data row2 col0" >Mais de 10 anos</td>
#       <td id="T_26ae7_row2_col1" class="data row2 col1" >10</td>
#       <td id="T_26ae7_row2_col2" class="data row2 col2" >22.22</td>
#     </tr>
#     <tr>
#       <td id="T_26ae7_row3_col0" class="data row3 col0" >Menos de 2 anos</td>
#       <td id="T_26ae7_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_26ae7_row3_col2" class="data row3 col2" >8.89</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tempo de Experiência com Containers
# <style type="text/css">
# #T_68313 th {
#   text-align: left;
# }
# #T_68313  {
#   border: 1px solid black;
# }
# #T_68313 th {
#   border: 1px solid black;
# }
# #T_68313 td {
#   border: 1px solid black;
# }
# #T_68313_row0_col0, #T_68313_row0_col1, #T_68313_row0_col2, #T_68313_row1_col0, #T_68313_row1_col1, #T_68313_row1_col2, #T_68313_row2_col0, #T_68313_row2_col1, #T_68313_row2_col2, #T_68313_row3_col0, #T_68313_row3_col1, #T_68313_row3_col2, #T_68313_row4_col0, #T_68313_row4_col1, #T_68313_row4_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_68313">
#   <thead>
#     <tr>
#       <th id="T_68313_level0_col0" class="col_heading level0 col0" >Tempo com Containers</th>
#       <th id="T_68313_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_68313_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_68313_row0_col0" class="data row0 col0" >1-3 anos</td>
#       <td id="T_68313_row0_col1" class="data row0 col1" >17</td>
#       <td id="T_68313_row0_col2" class="data row0 col2" >37.78</td>
#     </tr>
#     <tr>
#       <td id="T_68313_row1_col0" class="data row1 col0" >3-5 anos</td>
#       <td id="T_68313_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_68313_row1_col2" class="data row1 col2" >26.67</td>
#     </tr>
#     <tr>
#       <td id="T_68313_row2_col0" class="data row2 col0" >Mais de 5 anos</td>
#       <td id="T_68313_row2_col1" class="data row2 col1" >10</td>
#       <td id="T_68313_row2_col2" class="data row2 col2" >22.22</td>
#     </tr>
#     <tr>
#       <td id="T_68313_row3_col0" class="data row3 col0" >Menos de 6 meses</td>
#       <td id="T_68313_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_68313_row3_col2" class="data row3 col2" >6.67</td>
#     </tr>
#     <tr>
#       <td id="T_68313_row4_col0" class="data row4 col0" >6 meses - 1 ano</td>
#       <td id="T_68313_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_68313_row4_col2" class="data row4 col2" >6.67</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Porte da Empresa
# <style type="text/css">
# #T_8d2f1 th {
#   text-align: left;
# }
# #T_8d2f1  {
#   border: 1px solid black;
# }
# #T_8d2f1 th {
#   border: 1px solid black;
# }
# #T_8d2f1 td {
#   border: 1px solid black;
# }
# #T_8d2f1_row0_col0, #T_8d2f1_row0_col1, #T_8d2f1_row0_col2, #T_8d2f1_row1_col0, #T_8d2f1_row1_col1, #T_8d2f1_row1_col2, #T_8d2f1_row2_col0, #T_8d2f1_row2_col1, #T_8d2f1_row2_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_8d2f1">
#   <thead>
#     <tr>
#       <th id="T_8d2f1_level0_col0" class="col_heading level0 col0" >Porte</th>
#       <th id="T_8d2f1_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_8d2f1_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8d2f1_row0_col0" class="data row0 col0" >Grande (mais de 250 funcionários)</td>
#       <td id="T_8d2f1_row0_col1" class="data row0 col1" >23</td>
#       <td id="T_8d2f1_row0_col2" class="data row0 col2" >51.11</td>
#     </tr>
#     <tr>
#       <td id="T_8d2f1_row1_col0" class="data row1 col0" >Média (50-250 funcionários)</td>
#       <td id="T_8d2f1_row1_col1" class="data row1 col1" >16</td>
#       <td id="T_8d2f1_row1_col2" class="data row1 col2" >35.56</td>
#     </tr>
#     <tr>
#       <td id="T_8d2f1_row2_col0" class="data row2 col0" >Pequena (menos de 50 funcionários)</td>
#       <td id="T_8d2f1_row2_col1" class="data row2 col1" >6</td>
#       <td id="T_8d2f1_row2_col2" class="data row2 col2" >13.33</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Setor de Atuação
# <style type="text/css">
# #T_1d5df th {
#   text-align: left;
# }
# #T_1d5df  {
#   border: 1px solid black;
# }
# #T_1d5df th {
#   border: 1px solid black;
# }
# #T_1d5df td {
#   border: 1px solid black;
# }
# #T_1d5df_row0_col0, #T_1d5df_row0_col1, #T_1d5df_row0_col2, #T_1d5df_row1_col0, #T_1d5df_row1_col1, #T_1d5df_row1_col2, #T_1d5df_row2_col0, #T_1d5df_row2_col1, #T_1d5df_row2_col2, #T_1d5df_row3_col0, #T_1d5df_row3_col1, #T_1d5df_row3_col2, #T_1d5df_row4_col0, #T_1d5df_row4_col1, #T_1d5df_row4_col2, #T_1d5df_row5_col0, #T_1d5df_row5_col1, #T_1d5df_row5_col2, #T_1d5df_row6_col0, #T_1d5df_row6_col1, #T_1d5df_row6_col2, #T_1d5df_row7_col0, #T_1d5df_row7_col1, #T_1d5df_row7_col2, #T_1d5df_row8_col0, #T_1d5df_row8_col1, #T_1d5df_row8_col2, #T_1d5df_row9_col0, #T_1d5df_row9_col1, #T_1d5df_row9_col2, #T_1d5df_row10_col0, #T_1d5df_row10_col1, #T_1d5df_row10_col2, #T_1d5df_row11_col0, #T_1d5df_row11_col1, #T_1d5df_row11_col2, #T_1d5df_row12_col0, #T_1d5df_row12_col1, #T_1d5df_row12_col2, #T_1d5df_row13_col0, #T_1d5df_row13_col1, #T_1d5df_row13_col2, #T_1d5df_row14_col0, #T_1d5df_row14_col1, #T_1d5df_row14_col2, #T_1d5df_row15_col0, #T_1d5df_row15_col1, #T_1d5df_row15_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_1d5df">
#   <thead>
#     <tr>
#       <th id="T_1d5df_level0_col0" class="col_heading level0 col0" >Setor</th>
#       <th id="T_1d5df_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_1d5df_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1d5df_row0_col0" class="data row0 col0" >Fintech/Serviços Financeiros</td>
#       <td id="T_1d5df_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_1d5df_row0_col2" class="data row0 col2" >26.67</td>
#     </tr>
#     <tr>
#       <td id="T_1d5df_row1_col0" class="data row1 col0" >Saas/Software</td>
#       <td id="T_1d5df_row1_col1" class="data row1 col1" >10</td>
#       <td id="T_1d5df_row1_col2" class="data row1 col2" >22.22</td>
#     </tr>
#     <tr>
#       <td id="T_1d5df_row2_col0" class="data row2 col0" >Setor Público</td>
#       <td id="T_1d5df_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_1d5df_row2_col2" class="data row2 col2" >8.89</td>
#     </tr>
#     <tr>
#       <td id="T_1d5df_row3_col0" class="data row3 col0" >Telecom</td>
#       <td id="T_1d5df_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_1d5df_row3_col2" class="data row3 col2" >6.67</td>
#     </tr>
#     <tr>
#       <td id="T_1d5df_row4_col0" class="data row4 col0" >Educação/EdTech</td>
#       <td id="T_1d5df_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_1d5df_row4_col2" class="data row4 col2" >4.44</td>
#     </tr>
#     <tr>
#       <td id="T_1d5df_row5_col0" class="data row5 col0" >E-commerce/Varejo</td>
#       <td id="T_1d5df_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_1d5df_row5_col2" class="data row5 col2" >4.44</td>
#     </tr>
#     <tr>
#       <td id="T_1d5df_row6_col0" class="data row6 col0" >Saúde/HealthTech</td>
#       <td id="T_1d5df_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_1d5df_row6_col2" class="data row6 col2" >4.44</td>
#     </tr>
#     <tr>
#       <td id="T_1d5df_row7_col0" class="data row7 col0" >Mídia/Entretenimento</td>
#       <td id="T_1d5df_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_1d5df_row7_col2" class="data row7 col2" >4.44</td>
#     </tr>
#     <tr>
#       <td id="T_1d5df_row8_col0" class="data row8 col0" >Agro</td>
#       <td id="T_1d5df_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_1d5df_row8_col2" class="data row8 col2" >2.22</td>
#     </tr>
#     <tr>
#       <td id="T_1d5df_row9_col0" class="data row9 col0" >IndTech</td>
#       <td id="T_1d5df_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_1d5df_row9_col2" class="data row9 col2" >2.22</td>
#     </tr>
#     <tr>
#       <td id="T_1d5df_row10_col0" class="data row10 col0" >Benefícios</td>
#       <td id="T_1d5df_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_1d5df_row10_col2" class="data row10 col2" >2.22</td>
#     </tr>
#     <tr>
#       <td id="T_1d5df_row11_col0" class="data row11 col0" >Consultoria</td>
#       <td id="T_1d5df_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_1d5df_row11_col2" class="data row11 col2" >2.22</td>
#     </tr>
#     <tr>
#       <td id="T_1d5df_row12_col0" class="data row12 col0" >AWS Partner, foco em migrações cloud.</td>
#       <td id="T_1d5df_row12_col1" class="data row12 col1" >1</td>
#       <td id="T_1d5df_row12_col2" class="data row12 col2" >2.22</td>
#     </tr>
#     <tr>
#       <td id="T_1d5df_row13_col0" class="data row13 col0" >Setor logístico + Software</td>
#       <td id="T_1d5df_row13_col1" class="data row13 col1" >1</td>
#       <td id="T_1d5df_row13_col2" class="data row13 col2" >2.22</td>
#     </tr>
#     <tr>
#       <td id="T_1d5df_row14_col0" class="data row14 col0" >Manufatura </td>
#       <td id="T_1d5df_row14_col1" class="data row14 col1" >1</td>
#       <td id="T_1d5df_row14_col2" class="data row14 col2" >2.22</td>
#     </tr>
#     <tr>
#       <td id="T_1d5df_row15_col0" class="data row15 col0" >Engenharia Elétrica</td>
#       <td id="T_1d5df_row15_col1" class="data row15 col1" >1</td>
#       <td id="T_1d5df_row15_col2" class="data row15 col2" >2.22</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tecnologia de Orquestração
# <style type="text/css">
# #T_e179c th {
#   text-align: left;
# }
# #T_e179c  {
#   border: 1px solid black;
# }
# #T_e179c th {
#   border: 1px solid black;
# }
# #T_e179c td {
#   border: 1px solid black;
# }
# #T_e179c_row0_col0, #T_e179c_row0_col1, #T_e179c_row0_col2, #T_e179c_row1_col0, #T_e179c_row1_col1, #T_e179c_row1_col2, #T_e179c_row2_col0, #T_e179c_row2_col1, #T_e179c_row2_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_e179c">
#   <thead>
#     <tr>
#       <th id="T_e179c_level0_col0" class="col_heading level0 col0" >Tecnologia</th>
#       <th id="T_e179c_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_e179c_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e179c_row0_col0" class="data row0 col0" >Kubernetes (self-hosted ou managed: EKS/AKS/GKE)</td>
#       <td id="T_e179c_row0_col1" class="data row0 col1" >33</td>
#       <td id="T_e179c_row0_col2" class="data row0 col2" >73.33</td>
#     </tr>
#     <tr>
#       <td id="T_e179c_row1_col0" class="data row1 col0" >Outras soluções (Nomad, OpenShift, ECS)</td>
#       <td id="T_e179c_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_e179c_row1_col2" class="data row1 col2" >17.78</td>
#     </tr>
#     <tr>
#       <td id="T_e179c_row2_col0" class="data row2 col0" >Docker Swarm</td>
#       <td id="T_e179c_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_e179c_row2_col2" class="data row2 col2" >8.89</td>
#     </tr>
#   </tbody>
# </table>
# ESTATÍSTICAS DESCRITIVAS: Desafios (Escala Likert 1-5)
# <style type="text/css">
# #T_778e3 th {
#   text-align: left;
# }
# #T_778e3  {
#   border: 1px solid black;
# }
# #T_778e3 th {
#   border: 1px solid black;
# }
# #T_778e3 td {
#   border: 1px solid black;
# }
# #T_778e3_row0_col0, #T_778e3_row0_col1, #T_778e3_row0_col2, #T_778e3_row0_col3, #T_778e3_row0_col4, #T_778e3_row1_col0, #T_778e3_row1_col1, #T_778e3_row1_col2, #T_778e3_row1_col3, #T_778e3_row1_col4, #T_778e3_row2_col0, #T_778e3_row2_col1, #T_778e3_row2_col2, #T_778e3_row2_col3, #T_778e3_row2_col4, #T_778e3_row3_col0, #T_778e3_row3_col1, #T_778e3_row3_col2, #T_778e3_row3_col3, #T_778e3_row3_col4, #T_778e3_row4_col0, #T_778e3_row4_col1, #T_778e3_row4_col2, #T_778e3_row4_col3, #T_778e3_row4_col4, #T_778e3_row5_col0, #T_778e3_row5_col1, #T_778e3_row5_col2, #T_778e3_row5_col3, #T_778e3_row5_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_778e3">
#   <thead>
#     <tr>
#       <th id="T_778e3_level0_col0" class="col_heading level0 col0" >Desafio</th>
#       <th id="T_778e3_level0_col1" class="col_heading level0 col1" >Média</th>
#       <th id="T_778e3_level0_col2" class="col_heading level0 col2" >Desvio</th>
#       <th id="T_778e3_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_778e3_level0_col4" class="col_heading level0 col4" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_778e3_row0_col0" class="data row0 col0" >Segurança</td>
#       <td id="T_778e3_row0_col1" class="data row0 col1" >3.13</td>
#       <td id="T_778e3_row0_col2" class="data row0 col2" >0.87</td>
#       <td id="T_778e3_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_778e3_row0_col4" class="data row0 col4" >5</td>
#     </tr>
#     <tr>
#       <td id="T_778e3_row1_col0" class="data row1 col0" >Complexidade</td>
#       <td id="T_778e3_row1_col1" class="data row1 col1" >2.91</td>
#       <td id="T_778e3_row1_col2" class="data row1 col2" >1.02</td>
#       <td id="T_778e3_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_778e3_row1_col4" class="data row1 col4" >5</td>
#     </tr>
#     <tr>
#       <td id="T_778e3_row2_col0" class="data row2 col0" >Monitoramento</td>
#       <td id="T_778e3_row2_col1" class="data row2 col1" >3.04</td>
#       <td id="T_778e3_row2_col2" class="data row2 col2" >1.04</td>
#       <td id="T_778e3_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_778e3_row2_col4" class="data row2 col4" >5</td>
#     </tr>
#     <tr>
#       <td id="T_778e3_row3_col0" class="data row3 col0" >Mudanças Organizacionais</td>
#       <td id="T_778e3_row3_col1" class="data row3 col1" >3.29</td>
#       <td id="T_778e3_row3_col2" class="data row3 col2" >1.29</td>
#       <td id="T_778e3_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_778e3_row3_col4" class="data row3 col4" >5</td>
#     </tr>
#     <tr>
#       <td id="T_778e3_row4_col0" class="data row4 col0" >Treinamento</td>
#       <td id="T_778e3_row4_col1" class="data row4 col1" >2.82</td>
#       <td id="T_778e3_row4_col2" class="data row4 col2" >1.21</td>
#       <td id="T_778e3_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_778e3_row4_col4" class="data row4 col4" >5</td>
#     </tr>
#     <tr>
#       <td id="T_778e3_row5_col0" class="data row5 col0" >CI/CD</td>
#       <td id="T_778e3_row5_col1" class="data row5 col1" >2.73</td>
#       <td id="T_778e3_row5_col2" class="data row5 col2" >1.18</td>
#       <td id="T_778e3_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_778e3_row5_col4" class="data row5 col4" >5</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Principal Desafio Enfrentado
# <style type="text/css">
# #T_8e569 th {
#   text-align: left;
# }
# #T_8e569  {
#   border: 1px solid black;
# }
# #T_8e569 th {
#   border: 1px solid black;
# }
# #T_8e569 td {
#   border: 1px solid black;
# }
# #T_8e569_row0_col0, #T_8e569_row0_col1, #T_8e569_row0_col2, #T_8e569_row1_col0, #T_8e569_row1_col1, #T_8e569_row1_col2, #T_8e569_row2_col0, #T_8e569_row2_col1, #T_8e569_row2_col2, #T_8e569_row3_col0, #T_8e569_row3_col1, #T_8e569_row3_col2, #T_8e569_row4_col0, #T_8e569_row4_col1, #T_8e569_row4_col2, #T_8e569_row5_col0, #T_8e569_row5_col1, #T_8e569_row5_col2, #T_8e569_row6_col0, #T_8e569_row6_col1, #T_8e569_row6_col2, #T_8e569_row7_col0, #T_8e569_row7_col1, #T_8e569_row7_col2, #T_8e569_row8_col0, #T_8e569_row8_col1, #T_8e569_row8_col2, #T_8e569_row9_col0, #T_8e569_row9_col1, #T_8e569_row9_col2, #T_8e569_row10_col0, #T_8e569_row10_col1, #T_8e569_row10_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_8e569">
#   <thead>
#     <tr>
#       <th id="T_8e569_level0_col0" class="col_heading level0 col0" >Desafio</th>
#       <th id="T_8e569_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_8e569_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8e569_row0_col0" class="data row0 col0" >Complexidade técnica (curva de aprendizado íngreme, novos conceitos)</td>
#       <td id="T_8e569_row0_col1" class="data row0 col1" >8</td>
#       <td id="T_8e569_row0_col2" class="data row0 col2" >17.78</td>
#     </tr>
#     <tr>
#       <td id="T_8e569_row1_col0" class="data row1 col0" >Mudanças organizacionais e culturais (adoção de DevOps, colaboração entre equipes)</td>
#       <td id="T_8e569_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_8e569_row1_col2" class="data row1 col2" >17.78</td>
#     </tr>
#     <tr>
#       <td id="T_8e569_row2_col0" class="data row2 col0" >Monitoramento e observabilidade (monitoramento, logs, tracing)</td>
#       <td id="T_8e569_row2_col1" class="data row2 col1" >6</td>
#       <td id="T_8e569_row2_col2" class="data row2 col2" >13.33</td>
#     </tr>
#     <tr>
#       <td id="T_8e569_row3_col0" class="data row3 col0" >CI/CD (automação, fluxos de deploy)</td>
#       <td id="T_8e569_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_8e569_row3_col2" class="data row3 col2" >11.11</td>
#     </tr>
#     <tr>
#       <td id="T_8e569_row4_col0" class="data row4 col0" >Treinamento e desenvolvimento de habilidades (falta de capacitação, upskilling)</td>
#       <td id="T_8e569_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_8e569_row4_col2" class="data row4 col2" >8.89</td>
#     </tr>
#     <tr>
#       <td id="T_8e569_row5_col0" class="data row5 col0" >Segurança</td>
#       <td id="T_8e569_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_8e569_row5_col2" class="data row5 col2" >8.89</td>
#     </tr>
#     <tr>
#       <td id="T_8e569_row6_col0" class="data row6 col0" >Integração com sistemas legados</td>
#       <td id="T_8e569_row6_col1" class="data row6 col1" >4</td>
#       <td id="T_8e569_row6_col2" class="data row6 col2" >8.89</td>
#     </tr>
#     <tr>
#       <td id="T_8e569_row7_col0" class="data row7 col0" >Custos de infraestrutura</td>
#       <td id="T_8e569_row7_col1" class="data row7 col1" >3</td>
#       <td id="T_8e569_row7_col2" class="data row7 col2" >6.67</td>
#     </tr>
#     <tr>
#       <td id="T_8e569_row8_col0" class="data row8 col0" >Escalabilidade</td>
#       <td id="T_8e569_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_8e569_row8_col2" class="data row8 col2" >2.22</td>
#     </tr>
#     <tr>
#       <td id="T_8e569_row9_col0" class="data row9 col0" >A adoção foi tranquila.</td>
#       <td id="T_8e569_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_8e569_row9_col2" class="data row9 col2" >2.22</td>
#     </tr>
#     <tr>
#       <td id="T_8e569_row10_col0" class="data row10 col0" >Persistência de dados e gestão de estado</td>
#       <td id="T_8e569_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_8e569_row10_col2" class="data row10 col2" >2.22</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Empresa Ofereceu Treinamento?
# <style type="text/css">
# #T_587a6 th {
#   text-align: left;
# }
# #T_587a6  {
#   border: 1px solid black;
# }
# #T_587a6 th {
#   border: 1px solid black;
# }
# #T_587a6 td {
#   border: 1px solid black;
# }
# #T_587a6_row0_col0, #T_587a6_row0_col1, #T_587a6_row0_col2, #T_587a6_row1_col0, #T_587a6_row1_col1, #T_587a6_row1_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_587a6">
#   <thead>
#     <tr>
#       <th id="T_587a6_level0_col0" class="col_heading level0 col0" >Resposta</th>
#       <th id="T_587a6_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_587a6_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_587a6_row0_col0" class="data row0 col0" >Não</td>
#       <td id="T_587a6_row0_col1" class="data row0 col1" >28</td>
#       <td id="T_587a6_row0_col2" class="data row0 col2" >62.22</td>
#     </tr>
#     <tr>
#       <td id="T_587a6_row1_col0" class="data row1 col0" >Sim</td>
#       <td id="T_587a6_row1_col1" class="data row1 col1" >17</td>
#       <td id="T_587a6_row1_col2" class="data row1 col2" >37.78</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Fonte Mais Útil de Aprendizado
# <style type="text/css">
# #T_c7715 th {
#   text-align: left;
# }
# #T_c7715  {
#   border: 1px solid black;
# }
# #T_c7715 th {
#   border: 1px solid black;
# }
# #T_c7715 td {
#   border: 1px solid black;
# }
# #T_c7715_row0_col0, #T_c7715_row0_col1, #T_c7715_row0_col2, #T_c7715_row1_col0, #T_c7715_row1_col1, #T_c7715_row1_col2, #T_c7715_row2_col0, #T_c7715_row2_col1, #T_c7715_row2_col2, #T_c7715_row3_col0, #T_c7715_row3_col1, #T_c7715_row3_col2, #T_c7715_row4_col0, #T_c7715_row4_col1, #T_c7715_row4_col2, #T_c7715_row5_col0, #T_c7715_row5_col1, #T_c7715_row5_col2, #T_c7715_row6_col0, #T_c7715_row6_col1, #T_c7715_row6_col2, #T_c7715_row7_col0, #T_c7715_row7_col1, #T_c7715_row7_col2, #T_c7715_row8_col0, #T_c7715_row8_col1, #T_c7715_row8_col2, #T_c7715_row9_col0, #T_c7715_row9_col1, #T_c7715_row9_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_c7715">
#   <thead>
#     <tr>
#       <th id="T_c7715_level0_col0" class="col_heading level0 col0" >Fonte</th>
#       <th id="T_c7715_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_c7715_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c7715_row0_col0" class="data row0 col0" >Documentação oficial (Kubernetes, Docker Docs)</td>
#       <td id="T_c7715_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_c7715_row0_col2" class="data row0 col2" >20.00</td>
#     </tr>
#     <tr>
#       <td id="T_c7715_row1_col0" class="data row1 col0" >Treinamento formal / cursos pagos (ex.: Udemy, Coursera, KodeKloud, Linux Academy)</td>
#       <td id="T_c7715_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_c7715_row1_col2" class="data row1 col2" >15.56</td>
#     </tr>
#     <tr>
#       <td id="T_c7715_row2_col0" class="data row2 col0" >Agentes de inteligência artificial (IA)</td>
#       <td id="T_c7715_row2_col1" class="data row2 col1" >6</td>
#       <td id="T_c7715_row2_col2" class="data row2 col2" >13.33</td>
#     </tr>
#     <tr>
#       <td id="T_c7715_row3_col0" class="data row3 col0" >Aprendizado autodirigido (tentativa e erro)</td>
#       <td id="T_c7715_row3_col1" class="data row3 col1" >6</td>
#       <td id="T_c7715_row3_col2" class="data row3 col2" >13.33</td>
#     </tr>
#     <tr>
#       <td id="T_c7715_row4_col0" class="data row4 col0" >Comunidades técnicas (fóruns, Stack Overflow, Reddit)</td>
#       <td id="T_c7715_row4_col1" class="data row4 col1" >6</td>
#       <td id="T_c7715_row4_col2" class="data row4 col2" >13.33</td>
#     </tr>
#     <tr>
#       <td id="T_c7715_row5_col0" class="data row5 col0" >Provas de Conceito (PoCs) e projetos piloto</td>
#       <td id="T_c7715_row5_col1" class="data row5 col1" >5</td>
#       <td id="T_c7715_row5_col2" class="data row5 col2" >11.11</td>
#     </tr>
#     <tr>
#       <td id="T_c7715_row6_col0" class="data row6 col0" >Mentoria interna (desenvolvedores seniores ou especialistas)</td>
#       <td id="T_c7715_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_c7715_row6_col2" class="data row6 col2" >6.67</td>
#     </tr>
#     <tr>
#       <td id="T_c7715_row7_col0" class="data row7 col0" >Cursos estruturados (online ou presenciais)</td>
#       <td id="T_c7715_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_c7715_row7_col2" class="data row7 col2" >2.22</td>
#     </tr>
#     <tr>
#       <td id="T_c7715_row8_col0" class="data row8 col0" >Tutoriais e artigos online (blogs, Medium, Dev.to)</td>
#       <td id="T_c7715_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_c7715_row8_col2" class="data row8 col2" >2.22</td>
#     </tr>
#     <tr>
#       <td id="T_c7715_row9_col0" class="data row9 col0" >Livros técnicos</td>
#       <td id="T_c7715_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_c7715_row9_col2" class="data row9 col2" >2.22</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Realizou POCs?
# <style type="text/css">
# #T_29bcd th {
#   text-align: left;
# }
# #T_29bcd  {
#   border: 1px solid black;
# }
# #T_29bcd th {
#   border: 1px solid black;
# }
# #T_29bcd td {
#   border: 1px solid black;
# }
# #T_29bcd_row0_col0, #T_29bcd_row0_col1, #T_29bcd_row0_col2, #T_29bcd_row1_col0, #T_29bcd_row1_col1, #T_29bcd_row1_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_29bcd">
#   <thead>
#     <tr>
#       <th id="T_29bcd_level0_col0" class="col_heading level0 col0" >Resposta</th>
#       <th id="T_29bcd_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_29bcd_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_29bcd_row0_col0" class="data row0 col0" >Sim</td>
#       <td id="T_29bcd_row0_col1" class="data row0 col1" >40</td>
#       <td id="T_29bcd_row0_col2" class="data row0 col2" >88.89</td>
#     </tr>
#     <tr>
#       <td id="T_29bcd_row1_col0" class="data row1 col0" >Não</td>
#       <td id="T_29bcd_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_29bcd_row1_col2" class="data row1 col2" >11.11</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tempo Individual para se Sentir Confortável
# <style type="text/css">
# #T_34b67 th {
#   text-align: left;
# }
# #T_34b67  {
#   border: 1px solid black;
# }
# #T_34b67 th {
#   border: 1px solid black;
# }
# #T_34b67 td {
#   border: 1px solid black;
# }
# #T_34b67_row0_col0, #T_34b67_row0_col1, #T_34b67_row0_col2, #T_34b67_row1_col0, #T_34b67_row1_col1, #T_34b67_row1_col2, #T_34b67_row2_col0, #T_34b67_row2_col1, #T_34b67_row2_col2, #T_34b67_row3_col0, #T_34b67_row3_col1, #T_34b67_row3_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_34b67">
#   <thead>
#     <tr>
#       <th id="T_34b67_level0_col0" class="col_heading level0 col0" >Tempo</th>
#       <th id="T_34b67_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_34b67_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_34b67_row0_col0" class="data row0 col0" >6-12 meses</td>
#       <td id="T_34b67_row0_col1" class="data row0 col1" >16</td>
#       <td id="T_34b67_row0_col2" class="data row0 col2" >35.56</td>
#     </tr>
#     <tr>
#       <td id="T_34b67_row1_col0" class="data row1 col0" >3-6 meses</td>
#       <td id="T_34b67_row1_col1" class="data row1 col1" >15</td>
#       <td id="T_34b67_row1_col2" class="data row1 col2" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_34b67_row2_col0" class="data row2 col0" >Menos de 3 meses</td>
#       <td id="T_34b67_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_34b67_row2_col2" class="data row2 col2" >17.78</td>
#     </tr>
#     <tr>
#       <td id="T_34b67_row3_col0" class="data row3 col0" >12-18 meses</td>
#       <td id="T_34b67_row3_col1" class="data row3 col1" >6</td>
#       <td id="T_34b67_row3_col2" class="data row3 col2" >13.33</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tempo da Equipe para Colocar em Produção
# <style type="text/css">
# #T_7d6af th {
#   text-align: left;
# }
# #T_7d6af  {
#   border: 1px solid black;
# }
# #T_7d6af th {
#   border: 1px solid black;
# }
# #T_7d6af td {
#   border: 1px solid black;
# }
# #T_7d6af_row0_col0, #T_7d6af_row0_col1, #T_7d6af_row0_col2, #T_7d6af_row1_col0, #T_7d6af_row1_col1, #T_7d6af_row1_col2, #T_7d6af_row2_col0, #T_7d6af_row2_col1, #T_7d6af_row2_col2, #T_7d6af_row3_col0, #T_7d6af_row3_col1, #T_7d6af_row3_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_7d6af">
#   <thead>
#     <tr>
#       <th id="T_7d6af_level0_col0" class="col_heading level0 col0" >Tempo</th>
#       <th id="T_7d6af_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_7d6af_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7d6af_row0_col0" class="data row0 col0" >3-6 meses</td>
#       <td id="T_7d6af_row0_col1" class="data row0 col1" >18</td>
#       <td id="T_7d6af_row0_col2" class="data row0 col2" >40.00</td>
#     </tr>
#     <tr>
#       <td id="T_7d6af_row1_col0" class="data row1 col0" >1-3 meses</td>
#       <td id="T_7d6af_row1_col1" class="data row1 col1" >17</td>
#       <td id="T_7d6af_row1_col2" class="data row1 col2" >37.78</td>
#     </tr>
#     <tr>
#       <td id="T_7d6af_row2_col0" class="data row2 col0" >Menos de 1 mês</td>
#       <td id="T_7d6af_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_7d6af_row2_col2" class="data row2 col2" >15.56</td>
#     </tr>
#     <tr>
#       <td id="T_7d6af_row3_col0" class="data row3 col0" >6-12 meses</td>
#       <td id="T_7d6af_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_7d6af_row3_col2" class="data row3 col2" >6.67</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Fator Mais Importante para Acelerar Aprendizado
# <style type="text/css">
# #T_74b15 th {
#   text-align: left;
# }
# #T_74b15  {
#   border: 1px solid black;
# }
# #T_74b15 th {
#   border: 1px solid black;
# }
# #T_74b15 td {
#   border: 1px solid black;
# }
# #T_74b15_row0_col0, #T_74b15_row0_col1, #T_74b15_row0_col2, #T_74b15_row1_col0, #T_74b15_row1_col1, #T_74b15_row1_col2, #T_74b15_row2_col0, #T_74b15_row2_col1, #T_74b15_row2_col2, #T_74b15_row3_col0, #T_74b15_row3_col1, #T_74b15_row3_col2, #T_74b15_row4_col0, #T_74b15_row4_col1, #T_74b15_row4_col2, #T_74b15_row5_col0, #T_74b15_row5_col1, #T_74b15_row5_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_74b15">
#   <thead>
#     <tr>
#       <th id="T_74b15_level0_col0" class="col_heading level0 col0" >Fator</th>
#       <th id="T_74b15_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_74b15_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_74b15_row0_col0" class="data row0 col0" >Realização de POCs antes de produção</td>
#       <td id="T_74b15_row0_col1" class="data row0 col1" >17</td>
#       <td id="T_74b15_row0_col2" class="data row0 col2" >37.78</td>
#     </tr>
#     <tr>
#       <td id="T_74b15_row1_col0" class="data row1 col0" >Tempo dedicado exclusivo para estudo</td>
#       <td id="T_74b15_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_74b15_row1_col2" class="data row1 col2" >17.78</td>
#     </tr>
#     <tr>
#       <td id="T_74b15_row2_col0" class="data row2 col0" >Experiência prévia com Docker</td>
#       <td id="T_74b15_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_74b15_row2_col2" class="data row2 col2" >17.78</td>
#     </tr>
#     <tr>
#       <td id="T_74b15_row3_col0" class="data row3 col0" >Mentoria de especialistas internos ou externos</td>
#       <td id="T_74b15_row3_col1" class="data row3 col1" >7</td>
#       <td id="T_74b15_row3_col2" class="data row3 col2" >15.56</td>
#     </tr>
#     <tr>
#       <td id="T_74b15_row4_col0" class="data row4 col0" >Treinamento formal estruturado</td>
#       <td id="T_74b15_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_74b15_row4_col2" class="data row4 col2" >8.89</td>
#     </tr>
#     <tr>
#       <td id="T_74b15_row5_col0" class="data row5 col0" >Participação em comunidades técnicas</td>
#       <td id="T_74b15_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_74b15_row5_col2" class="data row5 col2" >2.22</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Avaliação do ROI
# <style type="text/css">
# #T_ab49a th {
#   text-align: left;
# }
# #T_ab49a  {
#   border: 1px solid black;
# }
# #T_ab49a th {
#   border: 1px solid black;
# }
# #T_ab49a td {
#   border: 1px solid black;
# }
# #T_ab49a_row0_col0, #T_ab49a_row0_col1, #T_ab49a_row0_col2, #T_ab49a_row1_col0, #T_ab49a_row1_col1, #T_ab49a_row1_col2, #T_ab49a_row2_col0, #T_ab49a_row2_col1, #T_ab49a_row2_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_ab49a">
#   <thead>
#     <tr>
#       <th id="T_ab49a_level0_col0" class="col_heading level0 col0" >Nota</th>
#       <th id="T_ab49a_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_ab49a_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ab49a_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_ab49a_row0_col1" class="data row0 col1" >24</td>
#       <td id="T_ab49a_row0_col2" class="data row0 col2" >53.33</td>
#     </tr>
#     <tr>
#       <td id="T_ab49a_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_ab49a_row1_col1" class="data row1 col1" >14</td>
#       <td id="T_ab49a_row1_col2" class="data row1 col2" >31.11</td>
#     </tr>
#     <tr>
#       <td id="T_ab49a_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_ab49a_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_ab49a_row2_col2" class="data row2 col2" >15.56</td>
#     </tr>
#   </tbody>
# </table>
# Média: 4.38 | Mediana: 5.00
#
# DISTRIBUIÇÃO: Recomendaria a Adoção de Containers?
# <style type="text/css">
# #T_809de th {
#   text-align: left;
# }
# #T_809de  {
#   border: 1px solid black;
# }
# #T_809de th {
#   border: 1px solid black;
# }
# #T_809de td {
#   border: 1px solid black;
# }
# #T_809de_row0_col0, #T_809de_row0_col1, #T_809de_row0_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_809de">
#   <thead>
#     <tr>
#       <th id="T_809de_level0_col0" class="col_heading level0 col0" >Resposta</th>
#       <th id="T_809de_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_809de_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_809de_row0_col0" class="data row0 col0" >Sim</td>
#       <td id="T_809de_row0_col1" class="data row0 col1" >45</td>
#       <td id="T_809de_row0_col2" class="data row0 col2" >100.00</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# TABELA DE CONTINGÊNCIA: TEMPO PARA SE SENTIR CONFORTÁVEL COM CONTAINERS/ORQUESTRADORES × FONTE DE APRENDIZADO MAIS ÚTIL
# ================================================================================
# <style type="text/css">
# #T_196e0 th {
#   text-align: left;
# }
# #T_196e0  {
#   border: 1px solid black;
# }
# #T_196e0 th {
#   border: 1px solid black;
# }
# #T_196e0 td {
#   border: 1px solid black;
# }
# #T_196e0_row0_col0, #T_196e0_row0_col1, #T_196e0_row0_col2, #T_196e0_row0_col3, #T_196e0_row0_col4, #T_196e0_row0_col5, #T_196e0_row0_col6, #T_196e0_row0_col7, #T_196e0_row0_col8, #T_196e0_row0_col9, #T_196e0_row1_col0, #T_196e0_row1_col1, #T_196e0_row1_col2, #T_196e0_row1_col3, #T_196e0_row1_col4, #T_196e0_row1_col5, #T_196e0_row1_col6, #T_196e0_row1_col7, #T_196e0_row1_col8, #T_196e0_row1_col9, #T_196e0_row2_col0, #T_196e0_row2_col1, #T_196e0_row2_col2, #T_196e0_row2_col3, #T_196e0_row2_col4, #T_196e0_row2_col5, #T_196e0_row2_col6, #T_196e0_row2_col7, #T_196e0_row2_col8, #T_196e0_row2_col9, #T_196e0_row3_col0, #T_196e0_row3_col1, #T_196e0_row3_col2, #T_196e0_row3_col3, #T_196e0_row3_col4, #T_196e0_row3_col5, #T_196e0_row3_col6, #T_196e0_row3_col7, #T_196e0_row3_col8, #T_196e0_row3_col9 {
#   text-align: center;
# }
# </style>
# <table id="T_196e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_196e0_level0_col0" class="col_heading level0 col0" >Agentes de inteligência artificial (IA)</th>
#       <th id="T_196e0_level0_col1" class="col_heading level0 col1" >Aprendizado autodirigido (tentativa e erro)</th>
#       <th id="T_196e0_level0_col2" class="col_heading level0 col2" >Comunidades técnicas (fóruns, Stack Overflow, Reddit)</th>
#       <th id="T_196e0_level0_col3" class="col_heading level0 col3" >Cursos estruturados (online ou presenciais)</th>
#       <th id="T_196e0_level0_col4" class="col_heading level0 col4" >Documentação oficial (Kubernetes, Docker Docs)</th>
#       <th id="T_196e0_level0_col5" class="col_heading level0 col5" >Livros técnicos</th>
#       <th id="T_196e0_level0_col6" class="col_heading level0 col6" >Mentoria interna (desenvolvedores seniores ou especialistas)</th>
#       <th id="T_196e0_level0_col7" class="col_heading level0 col7" >Provas de Conceito (PoCs) e projetos piloto</th>
#       <th id="T_196e0_level0_col8" class="col_heading level0 col8" >Treinamento formal / cursos pagos (ex.: Udemy, Coursera, KodeKloud, Linux Academy)</th>
#       <th id="T_196e0_level0_col9" class="col_heading level0 col9" >Tutoriais e artigos online (blogs, Medium, Dev.to)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_196e0_level0_row0" class="row_heading level0 row0" >12-18 meses</th>
#       <td id="T_196e0_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_196e0_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_196e0_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_196e0_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_196e0_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_196e0_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_196e0_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_196e0_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_196e0_row0_col8" class="data row0 col8" >2</td>
#       <td id="T_196e0_row0_col9" class="data row0 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_196e0_level0_row1" class="row_heading level0 row1" >3-6 meses</th>
#       <td id="T_196e0_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_196e0_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_196e0_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_196e0_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_196e0_row1_col4" class="data row1 col4" >4</td>
#       <td id="T_196e0_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_196e0_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_196e0_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_196e0_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_196e0_row1_col9" class="data row1 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_196e0_level0_row2" class="row_heading level0 row2" >6-12 meses</th>
#       <td id="T_196e0_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_196e0_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_196e0_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_196e0_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_196e0_row2_col4" class="data row2 col4" >5</td>
#       <td id="T_196e0_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_196e0_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_196e0_row2_col7" class="data row2 col7" >3</td>
#       <td id="T_196e0_row2_col8" class="data row2 col8" >4</td>
#       <td id="T_196e0_row2_col9" class="data row2 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_196e0_level0_row3" class="row_heading level0 row3" >Menos de 3 meses</th>
#       <td id="T_196e0_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_196e0_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_196e0_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_196e0_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_196e0_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_196e0_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_196e0_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_196e0_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_196e0_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_196e0_row3_col9" class="data row3 col9" >0</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# TABELA DE CONTINGÊNCIA: REALIZAÇÃO DE POCS × TEMPO DA EQUIPE PARA PRODUÇÃO
# ================================================================================
# <style type="text/css">
# #T_6c649 th {
#   text-align: left;
# }
# #T_6c649  {
#   border: 1px solid black;
# }
# #T_6c649 th {
#   border: 1px solid black;
# }
# #T_6c649 td {
#   border: 1px solid black;
# }
# #T_6c649_row0_col0, #T_6c649_row0_col1, #T_6c649_row0_col2, #T_6c649_row0_col3, #T_6c649_row1_col0, #T_6c649_row1_col1, #T_6c649_row1_col2, #T_6c649_row1_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_6c649">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c649_level0_col0" class="col_heading level0 col0" >1-3 meses</th>
#       <th id="T_6c649_level0_col1" class="col_heading level0 col1" >3-6 meses</th>
#       <th id="T_6c649_level0_col2" class="col_heading level0 col2" >6-12 meses</th>
#       <th id="T_6c649_level0_col3" class="col_heading level0 col3" >Menos de 1 mês</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c649_level0_row0" class="row_heading level0 row0" >Não</th>
#       <td id="T_6c649_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_6c649_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_6c649_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_6c649_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6c649_level0_row1" class="row_heading level0 row1" >Sim</th>
#       <td id="T_6c649_row1_col0" class="data row1 col0" >14</td>
#       <td id="T_6c649_row1_col1" class="data row1 col1" >16</td>
#       <td id="T_6c649_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_6c649_row1_col3" class="data row1 col3" >7</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# ANÁLISE DESCRITIVA CONCLUÍDA
# ================================================================================

# %% [markdown]
# ### Teste Qui-Quadrado

# %%
utils.titulo_secao("Teste Qui-Quadrado")
# %run 02_qui_quadrado.ipynb
# Out:
# ================================================================================
# TESTE QUI-QUADRADO
# ================================================================================
# Usando dados já carregados
#
# ================================================================================
# PORTE DA EMPRESA × PRINCIPAL DESAFIO
# ================================================================================
# <style type="text/css">
# #T_5e0c1 th {
#   text-align: left;
# }
# #T_5e0c1  {
#   border: 1px solid black;
# }
# #T_5e0c1 th {
#   border: 1px solid black;
# }
# #T_5e0c1 td {
#   border: 1px solid black;
# }
# #T_5e0c1_row0_col0, #T_5e0c1_row0_col1, #T_5e0c1_row0_col2, #T_5e0c1_row0_col3, #T_5e0c1_row0_col4, #T_5e0c1_row0_col5, #T_5e0c1_row0_col6, #T_5e0c1_row0_col7, #T_5e0c1_row0_col8, #T_5e0c1_row0_col9, #T_5e0c1_row0_col10, #T_5e0c1_row1_col0, #T_5e0c1_row1_col1, #T_5e0c1_row1_col2, #T_5e0c1_row1_col3, #T_5e0c1_row1_col4, #T_5e0c1_row1_col5, #T_5e0c1_row1_col6, #T_5e0c1_row1_col7, #T_5e0c1_row1_col8, #T_5e0c1_row1_col9, #T_5e0c1_row1_col10, #T_5e0c1_row2_col0, #T_5e0c1_row2_col1, #T_5e0c1_row2_col2, #T_5e0c1_row2_col3, #T_5e0c1_row2_col4, #T_5e0c1_row2_col5, #T_5e0c1_row2_col6, #T_5e0c1_row2_col7, #T_5e0c1_row2_col8, #T_5e0c1_row2_col9, #T_5e0c1_row2_col10 {
#   text-align: center;
# }
# </style>
# <table id="T_5e0c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e0c1_level0_col0" class="col_heading level0 col0" >A adoção foi tranquila.</th>
#       <th id="T_5e0c1_level0_col1" class="col_heading level0 col1" >CI/CD (automação, fluxos de deploy)</th>
#       <th id="T_5e0c1_level0_col2" class="col_heading level0 col2" >Complexidade técnica (curva de aprendizado íngreme, novos conceitos)</th>
#       <th id="T_5e0c1_level0_col3" class="col_heading level0 col3" >Custos de infraestrutura</th>
#       <th id="T_5e0c1_level0_col4" class="col_heading level0 col4" >Escalabilidade</th>
#       <th id="T_5e0c1_level0_col5" class="col_heading level0 col5" >Integração com sistemas legados</th>
#       <th id="T_5e0c1_level0_col6" class="col_heading level0 col6" >Monitoramento e observabilidade (monitoramento, logs, tracing)</th>
#       <th id="T_5e0c1_level0_col7" class="col_heading level0 col7" >Mudanças organizacionais e culturais (adoção de DevOps, colaboração entre equipes)</th>
#       <th id="T_5e0c1_level0_col8" class="col_heading level0 col8" >Persistência de dados e gestão de estado</th>
#       <th id="T_5e0c1_level0_col9" class="col_heading level0 col9" >Segurança</th>
#       <th id="T_5e0c1_level0_col10" class="col_heading level0 col10" >Treinamento e desenvolvimento de habilidades (falta de capacitação, upskilling)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e0c1_level0_row0" class="row_heading level0 row0" >Grande (mais de 250 funcionários)</th>
#       <td id="T_5e0c1_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_5e0c1_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_5e0c1_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_5e0c1_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_5e0c1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_5e0c1_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_5e0c1_row0_col6" class="data row0 col6" >3</td>
#       <td id="T_5e0c1_row0_col7" class="data row0 col7" >5</td>
#       <td id="T_5e0c1_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_5e0c1_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_5e0c1_row0_col10" class="data row0 col10" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5e0c1_level0_row1" class="row_heading level0 row1" >Média (50-250 funcionários)</th>
#       <td id="T_5e0c1_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_5e0c1_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_5e0c1_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_5e0c1_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_5e0c1_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_5e0c1_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_5e0c1_row1_col6" class="data row1 col6" >2</td>
#       <td id="T_5e0c1_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_5e0c1_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_5e0c1_row1_col9" class="data row1 col9" >2</td>
#       <td id="T_5e0c1_row1_col10" class="data row1 col10" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5e0c1_level0_row2" class="row_heading level0 row2" >Pequena (menos de 50 funcionários)</th>
#       <td id="T_5e0c1_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_5e0c1_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_5e0c1_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_5e0c1_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_5e0c1_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_5e0c1_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_5e0c1_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_5e0c1_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_5e0c1_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_5e0c1_row2_col9" class="data row2 col9" >1</td>
#       <td id="T_5e0c1_row2_col10" class="data row2 col10" >1</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 14.0431 | P-value: 0.8283 | Graus de liberdade: 20
# Associação NÃO significativa (p >= 0.05) - Variáveis são independentes
#
#
# ================================================================================
# EMPRESA OFERECEU TREINAMENTO × TEMPO INDIVIDUAL
# ================================================================================
# <style type="text/css">
# #T_bfb12 th {
#   text-align: left;
# }
# #T_bfb12  {
#   border: 1px solid black;
# }
# #T_bfb12 th {
#   border: 1px solid black;
# }
# #T_bfb12 td {
#   border: 1px solid black;
# }
# #T_bfb12_row0_col0, #T_bfb12_row0_col1, #T_bfb12_row0_col2, #T_bfb12_row0_col3, #T_bfb12_row1_col0, #T_bfb12_row1_col1, #T_bfb12_row1_col2, #T_bfb12_row1_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_bfb12">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bfb12_level0_col0" class="col_heading level0 col0" >12-18 meses</th>
#       <th id="T_bfb12_level0_col1" class="col_heading level0 col1" >3-6 meses</th>
#       <th id="T_bfb12_level0_col2" class="col_heading level0 col2" >6-12 meses</th>
#       <th id="T_bfb12_level0_col3" class="col_heading level0 col3" >Menos de 3 meses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfb12_level0_row0" class="row_heading level0 row0" >Não</th>
#       <td id="T_bfb12_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_bfb12_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_bfb12_row0_col2" class="data row0 col2" >9</td>
#       <td id="T_bfb12_row0_col3" class="data row0 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_bfb12_level0_row1" class="row_heading level0 row1" >Sim</th>
#       <td id="T_bfb12_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_bfb12_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_bfb12_row1_col2" class="data row1 col2" >7</td>
#       <td id="T_bfb12_row1_col3" class="data row1 col3" >3</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 0.4195 | P-value: 0.9362 | Graus de liberdade: 3
# Associação NÃO significativa (p >= 0.05) - Variáveis são independentes
#
#
# ================================================================================
# REALIZOU POCS × TEMPO DA EQUIPE
# ================================================================================
# <style type="text/css">
# #T_9c483 th {
#   text-align: left;
# }
# #T_9c483  {
#   border: 1px solid black;
# }
# #T_9c483 th {
#   border: 1px solid black;
# }
# #T_9c483 td {
#   border: 1px solid black;
# }
# #T_9c483_row0_col0, #T_9c483_row0_col1, #T_9c483_row0_col2, #T_9c483_row0_col3, #T_9c483_row1_col0, #T_9c483_row1_col1, #T_9c483_row1_col2, #T_9c483_row1_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_9c483">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c483_level0_col0" class="col_heading level0 col0" >1-3 meses</th>
#       <th id="T_9c483_level0_col1" class="col_heading level0 col1" >3-6 meses</th>
#       <th id="T_9c483_level0_col2" class="col_heading level0 col2" >6-12 meses</th>
#       <th id="T_9c483_level0_col3" class="col_heading level0 col3" >Menos de 1 mês</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c483_level0_row0" class="row_heading level0 row0" >Não</th>
#       <td id="T_9c483_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_9c483_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_9c483_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_9c483_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9c483_level0_row1" class="row_heading level0 row1" >Sim</th>
#       <td id="T_9c483_row1_col0" class="data row1 col0" >14</td>
#       <td id="T_9c483_row1_col1" class="data row1 col1" >16</td>
#       <td id="T_9c483_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_9c483_row1_col3" class="data row1 col3" >7</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 1.9853 | P-value: 0.5755 | Graus de liberdade: 3
# Associação NÃO significativa (p >= 0.05) - Variáveis são independentes
#
#
# ================================================================================
# FONTE MAIS ÚTIL × TEMPO INDIVIDUAL
# ================================================================================
# <style type="text/css">
# #T_9b7ce th {
#   text-align: left;
# }
# #T_9b7ce  {
#   border: 1px solid black;
# }
# #T_9b7ce th {
#   border: 1px solid black;
# }
# #T_9b7ce td {
#   border: 1px solid black;
# }
# #T_9b7ce_row0_col0, #T_9b7ce_row0_col1, #T_9b7ce_row0_col2, #T_9b7ce_row0_col3, #T_9b7ce_row1_col0, #T_9b7ce_row1_col1, #T_9b7ce_row1_col2, #T_9b7ce_row1_col3, #T_9b7ce_row2_col0, #T_9b7ce_row2_col1, #T_9b7ce_row2_col2, #T_9b7ce_row2_col3, #T_9b7ce_row3_col0, #T_9b7ce_row3_col1, #T_9b7ce_row3_col2, #T_9b7ce_row3_col3, #T_9b7ce_row4_col0, #T_9b7ce_row4_col1, #T_9b7ce_row4_col2, #T_9b7ce_row4_col3, #T_9b7ce_row5_col0, #T_9b7ce_row5_col1, #T_9b7ce_row5_col2, #T_9b7ce_row5_col3, #T_9b7ce_row6_col0, #T_9b7ce_row6_col1, #T_9b7ce_row6_col2, #T_9b7ce_row6_col3, #T_9b7ce_row7_col0, #T_9b7ce_row7_col1, #T_9b7ce_row7_col2, #T_9b7ce_row7_col3, #T_9b7ce_row8_col0, #T_9b7ce_row8_col1, #T_9b7ce_row8_col2, #T_9b7ce_row8_col3, #T_9b7ce_row9_col0, #T_9b7ce_row9_col1, #T_9b7ce_row9_col2, #T_9b7ce_row9_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_9b7ce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b7ce_level0_col0" class="col_heading level0 col0" >12-18 meses</th>
#       <th id="T_9b7ce_level0_col1" class="col_heading level0 col1" >3-6 meses</th>
#       <th id="T_9b7ce_level0_col2" class="col_heading level0 col2" >6-12 meses</th>
#       <th id="T_9b7ce_level0_col3" class="col_heading level0 col3" >Menos de 3 meses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b7ce_level0_row0" class="row_heading level0 row0" >Agentes de inteligência artificial (IA)</th>
#       <td id="T_9b7ce_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_9b7ce_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_9b7ce_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_9b7ce_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9b7ce_level0_row1" class="row_heading level0 row1" >Aprendizado autodirigido (tentativa e erro)</th>
#       <td id="T_9b7ce_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_9b7ce_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_9b7ce_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_9b7ce_row1_col3" class="data row1 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9b7ce_level0_row2" class="row_heading level0 row2" >Comunidades técnicas (fóruns, Stack Overflow, Reddit)</th>
#       <td id="T_9b7ce_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_9b7ce_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_9b7ce_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_9b7ce_row2_col3" class="data row2 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9b7ce_level0_row3" class="row_heading level0 row3" >Cursos estruturados (online ou presenciais)</th>
#       <td id="T_9b7ce_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_9b7ce_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_9b7ce_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_9b7ce_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9b7ce_level0_row4" class="row_heading level0 row4" >Documentação oficial (Kubernetes, Docker Docs)</th>
#       <td id="T_9b7ce_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_9b7ce_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_9b7ce_row4_col2" class="data row4 col2" >5</td>
#       <td id="T_9b7ce_row4_col3" class="data row4 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9b7ce_level0_row5" class="row_heading level0 row5" >Livros técnicos</th>
#       <td id="T_9b7ce_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_9b7ce_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_9b7ce_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_9b7ce_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9b7ce_level0_row6" class="row_heading level0 row6" >Mentoria interna (desenvolvedores seniores ou especialistas)</th>
#       <td id="T_9b7ce_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_9b7ce_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_9b7ce_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_9b7ce_row6_col3" class="data row6 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9b7ce_level0_row7" class="row_heading level0 row7" >Provas de Conceito (PoCs) e projetos piloto</th>
#       <td id="T_9b7ce_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_9b7ce_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_9b7ce_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_9b7ce_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9b7ce_level0_row8" class="row_heading level0 row8" >Treinamento formal / cursos pagos (ex.: Udemy, Coursera, KodeKloud, Linux Academy)</th>
#       <td id="T_9b7ce_row8_col0" class="data row8 col0" >2</td>
#       <td id="T_9b7ce_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_9b7ce_row8_col2" class="data row8 col2" >4</td>
#       <td id="T_9b7ce_row8_col3" class="data row8 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9b7ce_level0_row9" class="row_heading level0 row9" >Tutoriais e artigos online (blogs, Medium, Dev.to)</th>
#       <td id="T_9b7ce_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_9b7ce_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_9b7ce_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_9b7ce_row9_col3" class="data row9 col3" >0</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 30.9199 | P-value: 0.2744 | Graus de liberdade: 27
# Associação NÃO significativa (p >= 0.05) - Variáveis são independentes
#
#
# ================================================================================
# CARGO × TEMPO COM CONTAINERS
# ================================================================================
# <style type="text/css">
# #T_751a0 th {
#   text-align: left;
# }
# #T_751a0  {
#   border: 1px solid black;
# }
# #T_751a0 th {
#   border: 1px solid black;
# }
# #T_751a0 td {
#   border: 1px solid black;
# }
# #T_751a0_row0_col0, #T_751a0_row0_col1, #T_751a0_row0_col2, #T_751a0_row0_col3, #T_751a0_row0_col4, #T_751a0_row1_col0, #T_751a0_row1_col1, #T_751a0_row1_col2, #T_751a0_row1_col3, #T_751a0_row1_col4, #T_751a0_row2_col0, #T_751a0_row2_col1, #T_751a0_row2_col2, #T_751a0_row2_col3, #T_751a0_row2_col4, #T_751a0_row3_col0, #T_751a0_row3_col1, #T_751a0_row3_col2, #T_751a0_row3_col3, #T_751a0_row3_col4, #T_751a0_row4_col0, #T_751a0_row4_col1, #T_751a0_row4_col2, #T_751a0_row4_col3, #T_751a0_row4_col4, #T_751a0_row5_col0, #T_751a0_row5_col1, #T_751a0_row5_col2, #T_751a0_row5_col3, #T_751a0_row5_col4, #T_751a0_row6_col0, #T_751a0_row6_col1, #T_751a0_row6_col2, #T_751a0_row6_col3, #T_751a0_row6_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_751a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_751a0_level0_col0" class="col_heading level0 col0" >1-3 anos</th>
#       <th id="T_751a0_level0_col1" class="col_heading level0 col1" >3-5 anos</th>
#       <th id="T_751a0_level0_col2" class="col_heading level0 col2" >6 meses - 1 ano</th>
#       <th id="T_751a0_level0_col3" class="col_heading level0 col3" >Mais de 5 anos</th>
#       <th id="T_751a0_level0_col4" class="col_heading level0 col4" >Menos de 6 meses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_751a0_level0_row0" class="row_heading level0 row0" >Arquiteto de Soluções</th>
#       <td id="T_751a0_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_751a0_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_751a0_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_751a0_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_751a0_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_751a0_level0_row1" class="row_heading level0 row1" >Desenvolvedor</th>
#       <td id="T_751a0_row1_col0" class="data row1 col0" >8</td>
#       <td id="T_751a0_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_751a0_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_751a0_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_751a0_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_751a0_level0_row2" class="row_heading level0 row2" >DevOps Engineer</th>
#       <td id="T_751a0_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_751a0_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_751a0_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_751a0_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_751a0_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_751a0_level0_row3" class="row_heading level0 row3" >Estágio em tecnologia</th>
#       <td id="T_751a0_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_751a0_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_751a0_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_751a0_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_751a0_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_751a0_level0_row4" class="row_heading level0 row4" >Não estou trabalhando no momento</th>
#       <td id="T_751a0_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_751a0_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_751a0_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_751a0_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_751a0_row4_col4" class="data row4 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_751a0_level0_row5" class="row_heading level0 row5" >SRE (Site Reliability Engineer)</th>
#       <td id="T_751a0_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_751a0_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_751a0_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_751a0_row5_col3" class="data row5 col3" >4</td>
#       <td id="T_751a0_row5_col4" class="data row5 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_751a0_level0_row6" class="row_heading level0 row6" >Technical Product Manager</th>
#       <td id="T_751a0_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_751a0_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_751a0_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_751a0_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_751a0_row6_col4" class="data row6 col4" >0</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 52.8451 | P-value: 0.0006 | Graus de liberdade: 24
# Associação significativa (p < 0.05) - Variáveis NÃO são independentes
#
#
# ================================================================================
# SETOR × TECNOLOGIA DE ORQUESTRAÇÃO
# ================================================================================
# <style type="text/css">
# #T_d1a5e th {
#   text-align: left;
# }
# #T_d1a5e  {
#   border: 1px solid black;
# }
# #T_d1a5e th {
#   border: 1px solid black;
# }
# #T_d1a5e td {
#   border: 1px solid black;
# }
# #T_d1a5e_row0_col0, #T_d1a5e_row0_col1, #T_d1a5e_row0_col2, #T_d1a5e_row1_col0, #T_d1a5e_row1_col1, #T_d1a5e_row1_col2, #T_d1a5e_row2_col0, #T_d1a5e_row2_col1, #T_d1a5e_row2_col2, #T_d1a5e_row3_col0, #T_d1a5e_row3_col1, #T_d1a5e_row3_col2, #T_d1a5e_row4_col0, #T_d1a5e_row4_col1, #T_d1a5e_row4_col2, #T_d1a5e_row5_col0, #T_d1a5e_row5_col1, #T_d1a5e_row5_col2, #T_d1a5e_row6_col0, #T_d1a5e_row6_col1, #T_d1a5e_row6_col2, #T_d1a5e_row7_col0, #T_d1a5e_row7_col1, #T_d1a5e_row7_col2, #T_d1a5e_row8_col0, #T_d1a5e_row8_col1, #T_d1a5e_row8_col2, #T_d1a5e_row9_col0, #T_d1a5e_row9_col1, #T_d1a5e_row9_col2, #T_d1a5e_row10_col0, #T_d1a5e_row10_col1, #T_d1a5e_row10_col2, #T_d1a5e_row11_col0, #T_d1a5e_row11_col1, #T_d1a5e_row11_col2, #T_d1a5e_row12_col0, #T_d1a5e_row12_col1, #T_d1a5e_row12_col2, #T_d1a5e_row13_col0, #T_d1a5e_row13_col1, #T_d1a5e_row13_col2, #T_d1a5e_row14_col0, #T_d1a5e_row14_col1, #T_d1a5e_row14_col2, #T_d1a5e_row15_col0, #T_d1a5e_row15_col1, #T_d1a5e_row15_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_d1a5e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1a5e_level0_col0" class="col_heading level0 col0" >Docker Swarm</th>
#       <th id="T_d1a5e_level0_col1" class="col_heading level0 col1" >Kubernetes (self-hosted ou managed: EKS/AKS/GKE)</th>
#       <th id="T_d1a5e_level0_col2" class="col_heading level0 col2" >Outras soluções (Nomad, OpenShift, ECS)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1a5e_level0_row0" class="row_heading level0 row0" >AWS Partner, foco em migrações cloud.</th>
#       <td id="T_d1a5e_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_d1a5e_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_d1a5e_row0_col2" class="data row0 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d1a5e_level0_row1" class="row_heading level0 row1" >Agro</th>
#       <td id="T_d1a5e_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_d1a5e_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_d1a5e_row1_col2" class="data row1 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d1a5e_level0_row2" class="row_heading level0 row2" >Benefícios</th>
#       <td id="T_d1a5e_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_d1a5e_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_d1a5e_row2_col2" class="data row2 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d1a5e_level0_row3" class="row_heading level0 row3" >Consultoria</th>
#       <td id="T_d1a5e_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_d1a5e_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_d1a5e_row3_col2" class="data row3 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d1a5e_level0_row4" class="row_heading level0 row4" >E-commerce/Varejo</th>
#       <td id="T_d1a5e_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_d1a5e_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_d1a5e_row4_col2" class="data row4 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d1a5e_level0_row5" class="row_heading level0 row5" >Educação/EdTech</th>
#       <td id="T_d1a5e_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_d1a5e_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_d1a5e_row5_col2" class="data row5 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d1a5e_level0_row6" class="row_heading level0 row6" >Engenharia Elétrica</th>
#       <td id="T_d1a5e_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_d1a5e_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_d1a5e_row6_col2" class="data row6 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d1a5e_level0_row7" class="row_heading level0 row7" >Fintech/Serviços Financeiros</th>
#       <td id="T_d1a5e_row7_col0" class="data row7 col0" >1</td>
#       <td id="T_d1a5e_row7_col1" class="data row7 col1" >9</td>
#       <td id="T_d1a5e_row7_col2" class="data row7 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d1a5e_level0_row8" class="row_heading level0 row8" >IndTech</th>
#       <td id="T_d1a5e_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_d1a5e_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_d1a5e_row8_col2" class="data row8 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d1a5e_level0_row9" class="row_heading level0 row9" >Manufatura </th>
#       <td id="T_d1a5e_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_d1a5e_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_d1a5e_row9_col2" class="data row9 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d1a5e_level0_row10" class="row_heading level0 row10" >Mídia/Entretenimento</th>
#       <td id="T_d1a5e_row10_col0" class="data row10 col0" >1</td>
#       <td id="T_d1a5e_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_d1a5e_row10_col2" class="data row10 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d1a5e_level0_row11" class="row_heading level0 row11" >Saas/Software</th>
#       <td id="T_d1a5e_row11_col0" class="data row11 col0" >1</td>
#       <td id="T_d1a5e_row11_col1" class="data row11 col1" >9</td>
#       <td id="T_d1a5e_row11_col2" class="data row11 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d1a5e_level0_row12" class="row_heading level0 row12" >Saúde/HealthTech</th>
#       <td id="T_d1a5e_row12_col0" class="data row12 col0" >1</td>
#       <td id="T_d1a5e_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_d1a5e_row12_col2" class="data row12 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d1a5e_level0_row13" class="row_heading level0 row13" >Setor Público</th>
#       <td id="T_d1a5e_row13_col0" class="data row13 col0" >0</td>
#       <td id="T_d1a5e_row13_col1" class="data row13 col1" >2</td>
#       <td id="T_d1a5e_row13_col2" class="data row13 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d1a5e_level0_row14" class="row_heading level0 row14" >Setor logístico + Software</th>
#       <td id="T_d1a5e_row14_col0" class="data row14 col0" >0</td>
#       <td id="T_d1a5e_row14_col1" class="data row14 col1" >0</td>
#       <td id="T_d1a5e_row14_col2" class="data row14 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d1a5e_level0_row15" class="row_heading level0 row15" >Telecom</th>
#       <td id="T_d1a5e_row15_col0" class="data row15 col0" >0</td>
#       <td id="T_d1a5e_row15_col1" class="data row15 col1" >3</td>
#       <td id="T_d1a5e_row15_col2" class="data row15 col2" >0</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 34.1591 | P-value: 0.2745 | Graus de liberdade: 30
# Associação NÃO significativa (p >= 0.05) - Variáveis são independentes
#
#
# ================================================================================
# RESUMO DOS TESTES QUI-QUADRADO
# ================================================================================
#
# Nível de significância: α = 0.05
#
# Porte da Empresa × Principal Desafio
#    χ² = 14.0431, p = 0.8283
#    Associação significativa: NÃO
#
# Empresa Ofereceu Treinamento × Tempo Individual
#    χ² = 0.4195, p = 0.9362
#    Associação significativa: NÃO
#
# Realizou POCs × Tempo da Equipe
#    χ² = 1.9853, p = 0.5755
#    Associação significativa: NÃO
#
# Fonte Mais Útil × Tempo Individual
#    χ² = 30.9199, p = 0.2744
#    Associação significativa: NÃO
#
# Cargo × Tempo com Containers
#    χ² = 52.8451, p = 0.0006
#    Associação significativa: SIM
#
# Setor × Tecnologia de Orquestração
#    χ² = 34.1591, p = 0.2745
#    Associação significativa: NÃO
#
#
# ================================================================================
# TESTES QUI-QUADRADO CONCLUÍDOS
# ================================================================================

# %% [markdown]
# ### ANACOR (Análise de Correspondência)

# %%
utils.titulo_secao("ANACOR - Análise de Correspondência")
# %run 03_anacor.ipynb
# Out:
# ================================================================================
# ANACOR - ANÁLISE DE CORRESPONDÊNCIA
# ================================================================================
# Usando dados já carregados
#
# ================================================================================
# ANACOR: PORTE DA EMPRESA × PRINCIPAL DESAFIO
# ================================================================================
# <style type="text/css">
# #T_331c2 th {
#   text-align: left;
# }
# #T_331c2  {
#   border: 1px solid black;
# }
# #T_331c2 th {
#   border: 1px solid black;
# }
# #T_331c2 td {
#   border: 1px solid black;
# }
# #T_331c2_row0_col0, #T_331c2_row0_col1, #T_331c2_row0_col2, #T_331c2_row0_col3, #T_331c2_row0_col4, #T_331c2_row0_col5, #T_331c2_row0_col6, #T_331c2_row0_col7, #T_331c2_row0_col8, #T_331c2_row0_col9, #T_331c2_row0_col10, #T_331c2_row1_col0, #T_331c2_row1_col1, #T_331c2_row1_col2, #T_331c2_row1_col3, #T_331c2_row1_col4, #T_331c2_row1_col5, #T_331c2_row1_col6, #T_331c2_row1_col7, #T_331c2_row1_col8, #T_331c2_row1_col9, #T_331c2_row1_col10, #T_331c2_row2_col0, #T_331c2_row2_col1, #T_331c2_row2_col2, #T_331c2_row2_col3, #T_331c2_row2_col4, #T_331c2_row2_col5, #T_331c2_row2_col6, #T_331c2_row2_col7, #T_331c2_row2_col8, #T_331c2_row2_col9, #T_331c2_row2_col10 {
#   text-align: center;
# }
# </style>
# <table id="T_331c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_331c2_level0_col0" class="col_heading level0 col0" >A adoção foi tranquila.</th>
#       <th id="T_331c2_level0_col1" class="col_heading level0 col1" >CI/CD (automação, fluxos de deploy)</th>
#       <th id="T_331c2_level0_col2" class="col_heading level0 col2" >Complexidade técnica (curva de aprendizado íngreme, novos conceitos)</th>
#       <th id="T_331c2_level0_col3" class="col_heading level0 col3" >Custos de infraestrutura</th>
#       <th id="T_331c2_level0_col4" class="col_heading level0 col4" >Escalabilidade</th>
#       <th id="T_331c2_level0_col5" class="col_heading level0 col5" >Integração com sistemas legados</th>
#       <th id="T_331c2_level0_col6" class="col_heading level0 col6" >Monitoramento e observabilidade (monitoramento, logs, tracing)</th>
#       <th id="T_331c2_level0_col7" class="col_heading level0 col7" >Mudanças organizacionais e culturais (adoção de DevOps, colaboração entre equipes)</th>
#       <th id="T_331c2_level0_col8" class="col_heading level0 col8" >Persistência de dados e gestão de estado</th>
#       <th id="T_331c2_level0_col9" class="col_heading level0 col9" >Segurança</th>
#       <th id="T_331c2_level0_col10" class="col_heading level0 col10" >Treinamento e desenvolvimento de habilidades (falta de capacitação, upskilling)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_331c2_level0_row0" class="row_heading level0 row0" >Grande (mais de 250 funcionários)</th>
#       <td id="T_331c2_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_331c2_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_331c2_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_331c2_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_331c2_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_331c2_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_331c2_row0_col6" class="data row0 col6" >3</td>
#       <td id="T_331c2_row0_col7" class="data row0 col7" >5</td>
#       <td id="T_331c2_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_331c2_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_331c2_row0_col10" class="data row0 col10" >1</td>
#     </tr>
#     <tr>
#       <th id="T_331c2_level0_row1" class="row_heading level0 row1" >Média (50-250 funcionários)</th>
#       <td id="T_331c2_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_331c2_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_331c2_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_331c2_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_331c2_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_331c2_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_331c2_row1_col6" class="data row1 col6" >2</td>
#       <td id="T_331c2_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_331c2_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_331c2_row1_col9" class="data row1 col9" >2</td>
#       <td id="T_331c2_row1_col10" class="data row1 col10" >2</td>
#     </tr>
#     <tr>
#       <th id="T_331c2_level0_row2" class="row_heading level0 row2" >Pequena (menos de 50 funcionários)</th>
#       <td id="T_331c2_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_331c2_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_331c2_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_331c2_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_331c2_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_331c2_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_331c2_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_331c2_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_331c2_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_331c2_row2_col9" class="data row2 col9" >1</td>
#       <td id="T_331c2_row2_col10" class="data row2 col10" >1</td>
#     </tr>
#   </tbody>
# </table>
# Inércia Explicada por Dimensão:
#    Dimensão 1: 56.89%
#    Dimensão 2: 43.11%
#    Total acumulado: 100.00%
#
# Gráfico salvo: ../resultados/graficos/anacor/anacor_q6_porte_empresa_q18_principal_desafio.png
# ================================================================================
# ANACOR: FONTE DE CONHECIMENTO MAIS ÚTIL × TEMPO ATÉ O PROFISSIONAL SE SENTIR CONFORTÁVEL
# ================================================================================
# <style type="text/css">
# #T_53d0f th {
#   text-align: left;
# }
# #T_53d0f  {
#   border: 1px solid black;
# }
# #T_53d0f th {
#   border: 1px solid black;
# }
# #T_53d0f td {
#   border: 1px solid black;
# }
# #T_53d0f_row0_col0, #T_53d0f_row0_col1, #T_53d0f_row0_col2, #T_53d0f_row0_col3, #T_53d0f_row1_col0, #T_53d0f_row1_col1, #T_53d0f_row1_col2, #T_53d0f_row1_col3, #T_53d0f_row2_col0, #T_53d0f_row2_col1, #T_53d0f_row2_col2, #T_53d0f_row2_col3, #T_53d0f_row3_col0, #T_53d0f_row3_col1, #T_53d0f_row3_col2, #T_53d0f_row3_col3, #T_53d0f_row4_col0, #T_53d0f_row4_col1, #T_53d0f_row4_col2, #T_53d0f_row4_col3, #T_53d0f_row5_col0, #T_53d0f_row5_col1, #T_53d0f_row5_col2, #T_53d0f_row5_col3, #T_53d0f_row6_col0, #T_53d0f_row6_col1, #T_53d0f_row6_col2, #T_53d0f_row6_col3, #T_53d0f_row7_col0, #T_53d0f_row7_col1, #T_53d0f_row7_col2, #T_53d0f_row7_col3, #T_53d0f_row8_col0, #T_53d0f_row8_col1, #T_53d0f_row8_col2, #T_53d0f_row8_col3, #T_53d0f_row9_col0, #T_53d0f_row9_col1, #T_53d0f_row9_col2, #T_53d0f_row9_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_53d0f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53d0f_level0_col0" class="col_heading level0 col0" >12-18 meses</th>
#       <th id="T_53d0f_level0_col1" class="col_heading level0 col1" >3-6 meses</th>
#       <th id="T_53d0f_level0_col2" class="col_heading level0 col2" >6-12 meses</th>
#       <th id="T_53d0f_level0_col3" class="col_heading level0 col3" >Menos de 3 meses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53d0f_level0_row0" class="row_heading level0 row0" >Agentes de inteligência artificial (IA)</th>
#       <td id="T_53d0f_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_53d0f_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_53d0f_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_53d0f_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_53d0f_level0_row1" class="row_heading level0 row1" >Aprendizado autodirigido (tentativa e erro)</th>
#       <td id="T_53d0f_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_53d0f_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_53d0f_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_53d0f_row1_col3" class="data row1 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_53d0f_level0_row2" class="row_heading level0 row2" >Comunidades técnicas (fóruns, Stack Overflow, Reddit)</th>
#       <td id="T_53d0f_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_53d0f_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_53d0f_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_53d0f_row2_col3" class="data row2 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_53d0f_level0_row3" class="row_heading level0 row3" >Cursos estruturados (online ou presenciais)</th>
#       <td id="T_53d0f_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_53d0f_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_53d0f_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_53d0f_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_53d0f_level0_row4" class="row_heading level0 row4" >Documentação oficial (Kubernetes, Docker Docs)</th>
#       <td id="T_53d0f_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_53d0f_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_53d0f_row4_col2" class="data row4 col2" >5</td>
#       <td id="T_53d0f_row4_col3" class="data row4 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_53d0f_level0_row5" class="row_heading level0 row5" >Livros técnicos</th>
#       <td id="T_53d0f_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_53d0f_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_53d0f_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_53d0f_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_53d0f_level0_row6" class="row_heading level0 row6" >Mentoria interna (desenvolvedores seniores ou especialistas)</th>
#       <td id="T_53d0f_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_53d0f_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_53d0f_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_53d0f_row6_col3" class="data row6 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_53d0f_level0_row7" class="row_heading level0 row7" >Provas de Conceito (PoCs) e projetos piloto</th>
#       <td id="T_53d0f_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_53d0f_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_53d0f_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_53d0f_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_53d0f_level0_row8" class="row_heading level0 row8" >Treinamento formal / cursos pagos (ex.: Udemy, Coursera, KodeKloud, Linux Academy)</th>
#       <td id="T_53d0f_row8_col0" class="data row8 col0" >2</td>
#       <td id="T_53d0f_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_53d0f_row8_col2" class="data row8 col2" >4</td>
#       <td id="T_53d0f_row8_col3" class="data row8 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_53d0f_level0_row9" class="row_heading level0 row9" >Tutoriais e artigos online (blogs, Medium, Dev.to)</th>
#       <td id="T_53d0f_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_53d0f_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_53d0f_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_53d0f_row9_col3" class="data row9 col3" >0</td>
#     </tr>
#   </tbody>
# </table>
# Inércia Explicada por Dimensão:
#    Dimensão 1: 64.80%
#    Dimensão 2: 35.20%
#    Total acumulado: 100.00%
#
# Gráfico salvo: ../resultados/graficos/anacor/anacor_q22_fonte_mais_util_q24_tempo_individual.png
# ================================================================================
# ANACOR: FATOR MAIS IMPORTANTE NO APRENDIZADO DA EQUIPE × TEMPO ATÉ O PRIMEIRO DEPLOY EM PRODUÇÃO
# ================================================================================
# <style type="text/css">
# #T_6b0c0 th {
#   text-align: left;
# }
# #T_6b0c0  {
#   border: 1px solid black;
# }
# #T_6b0c0 th {
#   border: 1px solid black;
# }
# #T_6b0c0 td {
#   border: 1px solid black;
# }
# #T_6b0c0_row0_col0, #T_6b0c0_row0_col1, #T_6b0c0_row0_col2, #T_6b0c0_row0_col3, #T_6b0c0_row1_col0, #T_6b0c0_row1_col1, #T_6b0c0_row1_col2, #T_6b0c0_row1_col3, #T_6b0c0_row2_col0, #T_6b0c0_row2_col1, #T_6b0c0_row2_col2, #T_6b0c0_row2_col3, #T_6b0c0_row3_col0, #T_6b0c0_row3_col1, #T_6b0c0_row3_col2, #T_6b0c0_row3_col3, #T_6b0c0_row4_col0, #T_6b0c0_row4_col1, #T_6b0c0_row4_col2, #T_6b0c0_row4_col3, #T_6b0c0_row5_col0, #T_6b0c0_row5_col1, #T_6b0c0_row5_col2, #T_6b0c0_row5_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_6b0c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b0c0_level0_col0" class="col_heading level0 col0" >1-3 meses</th>
#       <th id="T_6b0c0_level0_col1" class="col_heading level0 col1" >3-6 meses</th>
#       <th id="T_6b0c0_level0_col2" class="col_heading level0 col2" >6-12 meses</th>
#       <th id="T_6b0c0_level0_col3" class="col_heading level0 col3" >Menos de 1 mês</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b0c0_level0_row0" class="row_heading level0 row0" >Experiência prévia com Docker</th>
#       <td id="T_6b0c0_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_6b0c0_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_6b0c0_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_6b0c0_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6b0c0_level0_row1" class="row_heading level0 row1" >Mentoria de especialistas internos ou externos</th>
#       <td id="T_6b0c0_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_6b0c0_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_6b0c0_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_6b0c0_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6b0c0_level0_row2" class="row_heading level0 row2" >Participação em comunidades técnicas</th>
#       <td id="T_6b0c0_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_6b0c0_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_6b0c0_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_6b0c0_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6b0c0_level0_row3" class="row_heading level0 row3" >Realização de POCs antes de produção</th>
#       <td id="T_6b0c0_row3_col0" class="data row3 col0" >6</td>
#       <td id="T_6b0c0_row3_col1" class="data row3 col1" >6</td>
#       <td id="T_6b0c0_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_6b0c0_row3_col3" class="data row3 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6b0c0_level0_row4" class="row_heading level0 row4" >Tempo dedicado exclusivo para estudo</th>
#       <td id="T_6b0c0_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_6b0c0_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_6b0c0_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_6b0c0_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6b0c0_level0_row5" class="row_heading level0 row5" >Treinamento formal estruturado</th>
#       <td id="T_6b0c0_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_6b0c0_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_6b0c0_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_6b0c0_row5_col3" class="data row5 col3" >1</td>
#     </tr>
#   </tbody>
# </table>
# Inércia Explicada por Dimensão:
#    Dimensão 1: 78.74%
#    Dimensão 2: 21.26%
#    Total acumulado: 100.00%
#
# Gráfico salvo: ../resultados/graficos/anacor/anacor_q26_fator_mais_importante_q25_tempo_equipe.png
# ================================================================================
# ANACOR CONCLUÍDA
# ================================================================================
#
# Mapas perceptuais gerados:
#    - Porte da Empresa × Principal Desafio
#    - Fonte Mais Útil × Tempo Individual
#    - Fator Mais Importante × Tempo da Equipe
#
# Gráficos salvos em resultados/graficos/anacor/

# %% [markdown]
# ### Regressão Logística

# %%
utils.titulo_secao("Regressão Logística")
# %run 04_regressao.ipynb
# Out:
# ================================================================================
# REGRESSÃO LOGÍSTICA
# ================================================================================
# Usando dados já carregados
#
# ================================================================================
# REGRESSÃO LOGÍSTICA - FATORES PREDITIVOS DA CURVA DE APRENDIZADO
# ================================================================================
#
# MODELO:
#   Variável Dependente: Curva Rápida (< 3 meses)
#   Método: Regressão Logística Binária
#
# VARIÁVEIS PREDITORAS:
#   • Empresa Grande (>250 funcionários)
#   • Empresa Média (50-250 funcionários)
#   • Possui Certificações
#   • Experiência com Containers (3+ anos)
#   • Participa de Comunidades Técnicas
#   • Empresa Ofereceu Treinamento
#   • Realizou POCs antes de Produção
#
# ================================================================================
# RESUMO DOS DADOS
# ================================================================================
#   Total de observações: 45
#   Curva rápida (<3 meses): 8 (17.8%)
#   Curva lenta (≥3 meses): 37 (82.2%)
#
# ================================================================================
# MÉTRICAS DO MODELO
# ================================================================================
#   Pseudo R²: 0.0339
#   Log-Likelihood: -20.35
#   AIC: 54.69
#   BIC: 67.34
#   Convergência: Sim
#
# ALERTA: Separação Quase-Completa Detectada!
# --------------------------------------------------------------------------------
# O modelo apresenta 'quasi-separation' - as variáveis preditoras separam
# quase perfeitamente os casos, resultando em estimativas não confiáveis.
#
# Este é um problema comum com:
#   - Dados simulados (muito 'perfeitos')
#   - Amostras pequenas com padrões muito claros
#   - Variáveis altamente correlacionadas com o desfecho
#
# RECOMENDAÇÕES:
#   1. Usar análise descritiva (qui-quadrado, tabelas de contingência)
#   2. Coletar dados reais com mais variabilidade
#   3. Os Odds Ratios abaixo NÃO são interpretáveis estatisticamente
# ================================================================================
#
# ================================================================================
# INTERPRETAÇÃO DOS COEFICIENTES (Odds Ratios)
# ================================================================================
# <style type="text/css">
# #T_523bd th {
#   text-align: left;
# }
# #T_523bd  {
#   border: 1px solid black;
# }
# #T_523bd th {
#   border: 1px solid black;
# }
# #T_523bd td {
#   border: 1px solid black;
# }
# #T_523bd_row0_col0, #T_523bd_row0_col1, #T_523bd_row0_col2, #T_523bd_row0_col3, #T_523bd_row1_col0, #T_523bd_row1_col1, #T_523bd_row1_col2, #T_523bd_row1_col3, #T_523bd_row2_col0, #T_523bd_row2_col1, #T_523bd_row2_col2, #T_523bd_row2_col3, #T_523bd_row3_col0, #T_523bd_row3_col1, #T_523bd_row3_col2, #T_523bd_row3_col3, #T_523bd_row4_col0, #T_523bd_row4_col1, #T_523bd_row4_col2, #T_523bd_row4_col3, #T_523bd_row5_col0, #T_523bd_row5_col1, #T_523bd_row5_col2, #T_523bd_row5_col3, #T_523bd_row6_col0, #T_523bd_row6_col1, #T_523bd_row6_col2, #T_523bd_row6_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_523bd">
#   <thead>
#     <tr>
#       <th id="T_523bd_level0_col0" class="col_heading level0 col0" >Variável</th>
#       <th id="T_523bd_level0_col1" class="col_heading level0 col1" >Odds Ratio</th>
#       <th id="T_523bd_level0_col2" class="col_heading level0 col2" >P-value</th>
#       <th id="T_523bd_level0_col3" class="col_heading level0 col3" >Significativo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_523bd_row0_col0" class="data row0 col0" >Empresa Grande (>250 funcionários)</td>
#       <td id="T_523bd_row0_col1" class="data row0 col1" >0.761</td>
#       <td id="T_523bd_row0_col2" class="data row0 col2" >0.8509</td>
#       <td id="T_523bd_row0_col3" class="data row0 col3" >Não</td>
#     </tr>
#     <tr>
#       <td id="T_523bd_row1_col0" class="data row1 col0" >Empresa Média (50-250 funcionários)</td>
#       <td id="T_523bd_row1_col1" class="data row1 col1" >0.981</td>
#       <td id="T_523bd_row1_col2" class="data row1 col2" >0.9890</td>
#       <td id="T_523bd_row1_col3" class="data row1 col3" >Não</td>
#     </tr>
#     <tr>
#       <td id="T_523bd_row2_col0" class="data row2 col0" >Possui Certificações</td>
#       <td id="T_523bd_row2_col1" class="data row2 col1" >0.410</td>
#       <td id="T_523bd_row2_col2" class="data row2 col2" >0.3597</td>
#       <td id="T_523bd_row2_col3" class="data row2 col3" >Não</td>
#     </tr>
#     <tr>
#       <td id="T_523bd_row3_col0" class="data row3 col0" >Experiência com Containers (3+ anos)</td>
#       <td id="T_523bd_row3_col1" class="data row3 col1" >0.628</td>
#       <td id="T_523bd_row3_col2" class="data row3 col2" >0.5958</td>
#       <td id="T_523bd_row3_col3" class="data row3 col3" >Não</td>
#     </tr>
#     <tr>
#       <td id="T_523bd_row4_col0" class="data row4 col0" >Participa de Comunidades Técnicas</td>
#       <td id="T_523bd_row4_col1" class="data row4 col1" >0.261</td>
#       <td id="T_523bd_row4_col2" class="data row4 col2" >0.3489</td>
#       <td id="T_523bd_row4_col3" class="data row4 col3" >Não</td>
#     </tr>
#     <tr>
#       <td id="T_523bd_row5_col0" class="data row5 col0" >Empresa Ofereceu Treinamento</td>
#       <td id="T_523bd_row5_col1" class="data row5 col1" >1.397</td>
#       <td id="T_523bd_row5_col2" class="data row5 col2" >0.7366</td>
#       <td id="T_523bd_row5_col3" class="data row5 col3" >Não</td>
#     </tr>
#     <tr>
#       <td id="T_523bd_row6_col0" class="data row6 col0" >Realizou POCs antes de Produção</td>
#       <td id="T_523bd_row6_col1" class="data row6 col1" >1.472</td>
#       <td id="T_523bd_row6_col2" class="data row6 col2" >0.7842</td>
#       <td id="T_523bd_row6_col3" class="data row6 col3" >Não</td>
#     </tr>
#   </tbody>
# </table>
# RESULTADO: Nenhuma variável significativa (p ≥ 0.05 para todas)
#
# ================================================================================
# ANÁLISE DESCRITIVA: Impacto Real de Cada Variável
# ================================================================================
# <style type="text/css">
# #T_0cca5 th {
#   text-align: left;
# }
# #T_0cca5  {
#   border: 1px solid black;
# }
# #T_0cca5 th {
#   border: 1px solid black;
# }
# #T_0cca5 td {
#   border: 1px solid black;
# }
# #T_0cca5_row0_col0, #T_0cca5_row0_col1, #T_0cca5_row0_col2, #T_0cca5_row0_col3, #T_0cca5_row1_col0, #T_0cca5_row1_col1, #T_0cca5_row1_col2, #T_0cca5_row1_col3, #T_0cca5_row2_col0, #T_0cca5_row2_col1, #T_0cca5_row2_col2, #T_0cca5_row2_col3, #T_0cca5_row3_col0, #T_0cca5_row3_col1, #T_0cca5_row3_col2, #T_0cca5_row3_col3, #T_0cca5_row4_col0, #T_0cca5_row4_col1, #T_0cca5_row4_col2, #T_0cca5_row4_col3, #T_0cca5_row5_col0, #T_0cca5_row5_col1, #T_0cca5_row5_col2, #T_0cca5_row5_col3, #T_0cca5_row6_col0, #T_0cca5_row6_col1, #T_0cca5_row6_col2, #T_0cca5_row6_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_0cca5">
#   <thead>
#     <tr>
#       <th id="T_0cca5_level0_col0" class="col_heading level0 col0" >Variável</th>
#       <th id="T_0cca5_level0_col1" class="col_heading level0 col1" >Com fator</th>
#       <th id="T_0cca5_level0_col2" class="col_heading level0 col2" >Sem fator</th>
#       <th id="T_0cca5_level0_col3" class="col_heading level0 col3" >Diferença</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0cca5_row0_col0" class="data row0 col0" >Empresa Grande (>250 funcionários)</td>
#       <td id="T_0cca5_row0_col1" class="data row0 col1" >4/23 (17.4%)</td>
#       <td id="T_0cca5_row0_col2" class="data row0 col2" >4/22 (18.2%)</td>
#       <td id="T_0cca5_row0_col3" class="data row0 col3" >-0.8pp</td>
#     </tr>
#     <tr>
#       <td id="T_0cca5_row1_col0" class="data row1 col0" >Empresa Média (50-250 funcionários)</td>
#       <td id="T_0cca5_row1_col1" class="data row1 col1" >3/16 (18.8%)</td>
#       <td id="T_0cca5_row1_col2" class="data row1 col2" >5/29 (17.2%)</td>
#       <td id="T_0cca5_row1_col3" class="data row1 col3" >+1.5pp</td>
#     </tr>
#     <tr>
#       <td id="T_0cca5_row2_col0" class="data row2 col0" >Possui Certificações</td>
#       <td id="T_0cca5_row2_col1" class="data row2 col1" >2/18 (11.1%)</td>
#       <td id="T_0cca5_row2_col2" class="data row2 col2" >6/27 (22.2%)</td>
#       <td id="T_0cca5_row2_col3" class="data row2 col3" >-11.1pp</td>
#     </tr>
#     <tr>
#       <td id="T_0cca5_row3_col0" class="data row3 col0" >Experiência com Containers (3+ anos)</td>
#       <td id="T_0cca5_row3_col1" class="data row3 col1" >3/22 (13.6%)</td>
#       <td id="T_0cca5_row3_col2" class="data row3 col2" >5/23 (21.7%)</td>
#       <td id="T_0cca5_row3_col3" class="data row3 col3" >-8.1pp</td>
#     </tr>
#     <tr>
#       <td id="T_0cca5_row4_col0" class="data row4 col0" >Participa de Comunidades Técnicas</td>
#       <td id="T_0cca5_row4_col1" class="data row4 col1" >8/45 (17.8%)</td>
#       <td id="T_0cca5_row4_col2" class="data row4 col2" >0/0 (0.0%)</td>
#       <td id="T_0cca5_row4_col3" class="data row4 col3" >+17.8pp</td>
#     </tr>
#     <tr>
#       <td id="T_0cca5_row5_col0" class="data row5 col0" >Empresa Ofereceu Treinamento</td>
#       <td id="T_0cca5_row5_col1" class="data row5 col1" >3/17 (17.6%)</td>
#       <td id="T_0cca5_row5_col2" class="data row5 col2" >5/28 (17.9%)</td>
#       <td id="T_0cca5_row5_col3" class="data row5 col3" >-0.2pp</td>
#     </tr>
#     <tr>
#       <td id="T_0cca5_row6_col0" class="data row6 col0" >Realizou POCs antes de Produção</td>
#       <td id="T_0cca5_row6_col1" class="data row6 col1" >7/40 (17.5%)</td>
#       <td id="T_0cca5_row6_col2" class="data row6 col2" >1/5 (20.0%)</td>
#       <td id="T_0cca5_row6_col3" class="data row6 col3" >-2.5pp</td>
#     </tr>
#   </tbody>
# </table>
# Como interpretar:
#   • 'Com fator': % de curva rápida quando a característica está presente
#   • 'Sem fator': % de curva rápida quando a característica está ausente
#   • 'Diferença': Impacto em pontos percentuais (pp)
#   • Diferença positiva = fator favorece curva rápida
#   • Diferença negativa = fator dificulta curva rápida
# Gráfico salvo: ../resultados/graficos/regressao/impacto_fatores.png
#
# NOTA: Devido à separação quase-completa, este gráfico mostra o impacto
# descritivo (diferença em pontos percentuais) ao invés de Odds Ratios,
# que são mais intuitivos e confiáveis para este dataset.
#
# ================================================================================
# ANÁLISE DE REGRESSÃO LOGÍSTICA CONCLUÍDA
# ================================================================================
#
# Resultados:
#   - Modelo ajustado com sucesso
#   - Análise descritiva de impacto gerada
#   - Gráfico visual salvo em resultados/graficos/regressao/
#
# IMPORTANTE:
#   - Separação quase-completa detectada nos dados
#   - Odds Ratios não são interpretáveis
#   - Use a Análise Descritiva de Impacto (mais confiável)
#
# Próximo passo:
#   - Gerar visualizações adicionais (05_visualizacoes.ipynb)

# %% [markdown]
# ### Visualizações

# %%
utils.titulo_secao("Visualizações")
# %run 05_visualizacoes.ipynb
# Out:
# ================================================================================
# VISUALIZAÇÕES
# ================================================================================
# Usando dados já carregados
# Gráfico salvo: ../resultados/graficos/descritivas/viz_cargos.png
# Gráfico salvo: ../resultados/graficos/descritivas/viz_porte_empresa.png
# Gráfico salvo: ../resultados/graficos/descritivas/viz_desafios_likert.png
# Gráfico salvo: ../resultados/graficos/descritivas/viz_tempo_individual.png
# Gráfico salvo: ../resultados/graficos/descritivas/viz_roi.png
#
# Média de ROI: 4.38
# Mediana de ROI: 5.0
# Gráfico salvo: ../resultados/graficos/descritivas/viz_desafio_por_porte.png
#
# ================================================================================
# VISUALIZAÇÕES CONCLUÍDAS
# ================================================================================
#
# Gráficos salvos em resultados/graficos/descritivas/:
#    - viz_cargos.png
#    - viz_porte_empresa.png
#    - viz_desafios_likert.png
#    - viz_tempo_individual.png
#    - viz_roi.png
#    - viz_desafio_por_porte.png
#
# Pipeline completa de análises finalizada!

# %% [markdown]
# ---
# ## Resumo Final

# %%
utils.titulo_secao("Análises Concluídas")

print("Análise Descritiva")
print("Teste Qui-Quadrado")
print("ANACOR")
print("Regressão Logística")
print("Visualizações")
print(f"\nResultados salvos em: ../resultados/")
# Out:
# ================================================================================
# ANÁLISES CONCLUÍDAS
# ================================================================================
# Análise Descritiva
# Teste Qui-Quadrado
# ANACOR
# Regressão Logística
# Visualizações
#
# Resultados salvos em: ../resultados/

# %% [markdown]
# ### 📚 Referências Metodológicas
#
# - **Qui-Quadrado:** Teste de independência entre variáveis categóricas
# - **ANACOR:** Análise de Correspondência (Hair et al., 2009)
# - **Regressão Logística:** Modelagem de fatores preditivos
