# %% [markdown]
# # Análise Estatística - TCC Engenharia de Software
# ## Tecnologias de Conteinerização: Curva de Aprendizagem Organizacional
#
# **Autor:** Guilherme Magalhães Leite
# **Orientador:** Arthur Pinheiro de Araújo Costa
# **Instituição:** MBA USP/ESALQ - Engenharia de Software
#
# ---
#
# ## Sobre Este Notebook
#
# Notebook principal que **orquestra todas as análises estatísticas** do projeto de pesquisa.
#
# ### Análises Implementadas
#
# 1. **Análise Descritiva** - Frequências, médias, tabelas de contingência
# 2. **Teste Qui-Quadrado** - Associações entre variáveis categóricas
# 3. **ANACOR** - Análise de Correspondência (mapas perceptuais 2D)
# 4. **Regressão Logística** - Fatores preditivos de curva de aprendizado
# 5. **Visualizações** - Gráficos exploratórios e descritivos
#
# ### Como Usar
#
# - **Executar tudo:** `Cell → Run All`
# - **Executar por partes:** Execute cada seção individualmente
# - **Notebooks individuais:** Disponíveis em `01_` até `05_`
#
# ### Estrutura Modular
#
# ```
# notebooks/
# ├── 00_master_analise.ipynb     ← VOCÊ ESTÁ AQUI
# ├── 01_analise_descritiva.ipynb
# ├── 02_qui_quadrado.ipynb
# ├── 03_anacor.ipynb
# ├── 04_regressao.ipynb
# └── 05_visualizacoes.ipynb
#
# src/
# └── utils.py                    # Funções reutilizáveis
# ```

# %% [markdown]
# ---
# ## Configuração Inicial

# %%
# %load_ext autoreload
# %autoreload 2

import sys; sys.path.append('../src')
import pandas as pd, warnings, utils

warnings.filterwarnings('ignore')
utils.configurar_visualizacoes()

# %% [markdown]
# ---
# ## Carregamento e Pré-processamento dos Dados

# %%
df = utils.carregar_e_preparar('../dados/respostas.csv')
# Out:
# Dataset carregado: 110 respostas × 29 variáveis
#   consolidação:         9 colunas
#   múltipla escolha:    26 colunas
#   derivadas:           15 colunas
# Pronto para análise: 110 respostas × 79 variáveis

# %% [markdown]
# ---
# ## Pipeline de Análises
#
# Execute cada análise individualmente ou use os notebooks especializados.

# %% [markdown]
# ### Análise Descritiva

# %%
utils.titulo_secao("Análise Descritiva")
# %run 01_analise_descritiva.ipynb
# Out:
# ================================================================================
# ANÁLISE DESCRITIVA
# ================================================================================
# 110 respostas × 79 variáveis
#
# DISTRIBUIÇÃO: Cargo (consolidado)
# <style type="text/css">
# #T_2f0a0 th {
#   text-align: left;
# }
# #T_2f0a0  {
#   border: 1px solid black;
# }
# #T_2f0a0 th {
#   border: 1px solid black;
# }
# #T_2f0a0 td {
#   border: 1px solid black;
# }
# #T_2f0a0_row0_col0, #T_2f0a0_row0_col1, #T_2f0a0_row0_col2, #T_2f0a0_row1_col0, #T_2f0a0_row1_col1, #T_2f0a0_row1_col2, #T_2f0a0_row2_col0, #T_2f0a0_row2_col1, #T_2f0a0_row2_col2, #T_2f0a0_row3_col0, #T_2f0a0_row3_col1, #T_2f0a0_row3_col2, #T_2f0a0_row4_col0, #T_2f0a0_row4_col1, #T_2f0a0_row4_col2, #T_2f0a0_row5_col0, #T_2f0a0_row5_col1, #T_2f0a0_row5_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_2f0a0">
#   <thead>
#     <tr>
#       <th id="T_2f0a0_level0_col0" class="col_heading level0 col0" >Cargo</th>
#       <th id="T_2f0a0_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_2f0a0_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2f0a0_row0_col0" class="data row0 col0" >Engenheiro DevOps</td>
#       <td id="T_2f0a0_row0_col1" class="data row0 col1" >46</td>
#       <td id="T_2f0a0_row0_col2" class="data row0 col2" >41.82</td>
#     </tr>
#     <tr>
#       <td id="T_2f0a0_row1_col0" class="data row1 col0" >Desenvolvedor de Software</td>
#       <td id="T_2f0a0_row1_col1" class="data row1 col1" >29</td>
#       <td id="T_2f0a0_row1_col2" class="data row1 col2" >26.36</td>
#     </tr>
#     <tr>
#       <td id="T_2f0a0_row2_col0" class="data row2 col0" >Engenheiro de Confiabilidade (SRE)</td>
#       <td id="T_2f0a0_row2_col1" class="data row2 col1" >16</td>
#       <td id="T_2f0a0_row2_col2" class="data row2 col2" >14.55</td>
#     </tr>
#     <tr>
#       <td id="T_2f0a0_row3_col0" class="data row3 col0" >Outros</td>
#       <td id="T_2f0a0_row3_col1" class="data row3 col1" >7</td>
#       <td id="T_2f0a0_row3_col2" class="data row3 col2" >6.36</td>
#     </tr>
#     <tr>
#       <td id="T_2f0a0_row4_col0" class="data row4 col0" >Líder Técnico</td>
#       <td id="T_2f0a0_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_2f0a0_row4_col2" class="data row4 col2" >6.36</td>
#     </tr>
#     <tr>
#       <td id="T_2f0a0_row5_col0" class="data row5 col0" >Arquiteto de Soluções</td>
#       <td id="T_2f0a0_row5_col1" class="data row5 col1" >5</td>
#       <td id="T_2f0a0_row5_col2" class="data row5 col2" >4.55</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tempo de Experiência em TI
# <style type="text/css">
# #T_773f4 th {
#   text-align: left;
# }
# #T_773f4  {
#   border: 1px solid black;
# }
# #T_773f4 th {
#   border: 1px solid black;
# }
# #T_773f4 td {
#   border: 1px solid black;
# }
# #T_773f4_row0_col0, #T_773f4_row0_col1, #T_773f4_row0_col2, #T_773f4_row1_col0, #T_773f4_row1_col1, #T_773f4_row1_col2, #T_773f4_row2_col0, #T_773f4_row2_col1, #T_773f4_row2_col2, #T_773f4_row3_col0, #T_773f4_row3_col1, #T_773f4_row3_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_773f4">
#   <thead>
#     <tr>
#       <th id="T_773f4_level0_col0" class="col_heading level0 col0" >Tempo em TI</th>
#       <th id="T_773f4_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_773f4_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_773f4_row0_col0" class="data row0 col0" >5-10 anos</td>
#       <td id="T_773f4_row0_col1" class="data row0 col1" >39</td>
#       <td id="T_773f4_row0_col2" class="data row0 col2" >35.45</td>
#     </tr>
#     <tr>
#       <td id="T_773f4_row1_col0" class="data row1 col0" >2-5 anos</td>
#       <td id="T_773f4_row1_col1" class="data row1 col1" >37</td>
#       <td id="T_773f4_row1_col2" class="data row1 col2" >33.64</td>
#     </tr>
#     <tr>
#       <td id="T_773f4_row2_col0" class="data row2 col0" >Mais de 10 anos</td>
#       <td id="T_773f4_row2_col1" class="data row2 col1" >27</td>
#       <td id="T_773f4_row2_col2" class="data row2 col2" >24.55</td>
#     </tr>
#     <tr>
#       <td id="T_773f4_row3_col0" class="data row3 col0" >Menos de 2 anos</td>
#       <td id="T_773f4_row3_col1" class="data row3 col1" >7</td>
#       <td id="T_773f4_row3_col2" class="data row3 col2" >6.36</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tempo de Experiência com Containers
# <style type="text/css">
# #T_94725 th {
#   text-align: left;
# }
# #T_94725  {
#   border: 1px solid black;
# }
# #T_94725 th {
#   border: 1px solid black;
# }
# #T_94725 td {
#   border: 1px solid black;
# }
# #T_94725_row0_col0, #T_94725_row0_col1, #T_94725_row0_col2, #T_94725_row1_col0, #T_94725_row1_col1, #T_94725_row1_col2, #T_94725_row2_col0, #T_94725_row2_col1, #T_94725_row2_col2, #T_94725_row3_col0, #T_94725_row3_col1, #T_94725_row3_col2, #T_94725_row4_col0, #T_94725_row4_col1, #T_94725_row4_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_94725">
#   <thead>
#     <tr>
#       <th id="T_94725_level0_col0" class="col_heading level0 col0" >Tempo com Containers</th>
#       <th id="T_94725_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_94725_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_94725_row0_col0" class="data row0 col0" >1-3 anos</td>
#       <td id="T_94725_row0_col1" class="data row0 col1" >34</td>
#       <td id="T_94725_row0_col2" class="data row0 col2" >30.91</td>
#     </tr>
#     <tr>
#       <td id="T_94725_row1_col0" class="data row1 col0" >Mais de 5 anos</td>
#       <td id="T_94725_row1_col1" class="data row1 col1" >34</td>
#       <td id="T_94725_row1_col2" class="data row1 col2" >30.91</td>
#     </tr>
#     <tr>
#       <td id="T_94725_row2_col0" class="data row2 col0" >3-5 anos</td>
#       <td id="T_94725_row2_col1" class="data row2 col1" >31</td>
#       <td id="T_94725_row2_col2" class="data row2 col2" >28.18</td>
#     </tr>
#     <tr>
#       <td id="T_94725_row3_col0" class="data row3 col0" >6 meses - 1 ano</td>
#       <td id="T_94725_row3_col1" class="data row3 col1" >7</td>
#       <td id="T_94725_row3_col2" class="data row3 col2" >6.36</td>
#     </tr>
#     <tr>
#       <td id="T_94725_row4_col0" class="data row4 col0" >Menos de 6 meses</td>
#       <td id="T_94725_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_94725_row4_col2" class="data row4 col2" >3.64</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Porte da Empresa
# <style type="text/css">
# #T_d69f3 th {
#   text-align: left;
# }
# #T_d69f3  {
#   border: 1px solid black;
# }
# #T_d69f3 th {
#   border: 1px solid black;
# }
# #T_d69f3 td {
#   border: 1px solid black;
# }
# #T_d69f3_row0_col0, #T_d69f3_row0_col1, #T_d69f3_row0_col2, #T_d69f3_row1_col0, #T_d69f3_row1_col1, #T_d69f3_row1_col2, #T_d69f3_row2_col0, #T_d69f3_row2_col1, #T_d69f3_row2_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_d69f3">
#   <thead>
#     <tr>
#       <th id="T_d69f3_level0_col0" class="col_heading level0 col0" >Porte</th>
#       <th id="T_d69f3_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_d69f3_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d69f3_row0_col0" class="data row0 col0" >Grande (mais de 250 funcionários)</td>
#       <td id="T_d69f3_row0_col1" class="data row0 col1" >56</td>
#       <td id="T_d69f3_row0_col2" class="data row0 col2" >50.91</td>
#     </tr>
#     <tr>
#       <td id="T_d69f3_row1_col0" class="data row1 col0" >Média (50-250 funcionários)</td>
#       <td id="T_d69f3_row1_col1" class="data row1 col1" >33</td>
#       <td id="T_d69f3_row1_col2" class="data row1 col2" >30.00</td>
#     </tr>
#     <tr>
#       <td id="T_d69f3_row2_col0" class="data row2 col0" >Pequena (menos de 50 funcionários)</td>
#       <td id="T_d69f3_row2_col1" class="data row2 col1" >21</td>
#       <td id="T_d69f3_row2_col2" class="data row2 col2" >19.09</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Setor de Atuação (consolidado)
# <style type="text/css">
# #T_9cf0e th {
#   text-align: left;
# }
# #T_9cf0e  {
#   border: 1px solid black;
# }
# #T_9cf0e th {
#   border: 1px solid black;
# }
# #T_9cf0e td {
#   border: 1px solid black;
# }
# #T_9cf0e_row0_col0, #T_9cf0e_row0_col1, #T_9cf0e_row0_col2, #T_9cf0e_row1_col0, #T_9cf0e_row1_col1, #T_9cf0e_row1_col2, #T_9cf0e_row2_col0, #T_9cf0e_row2_col1, #T_9cf0e_row2_col2, #T_9cf0e_row3_col0, #T_9cf0e_row3_col1, #T_9cf0e_row3_col2, #T_9cf0e_row4_col0, #T_9cf0e_row4_col1, #T_9cf0e_row4_col2, #T_9cf0e_row5_col0, #T_9cf0e_row5_col1, #T_9cf0e_row5_col2, #T_9cf0e_row6_col0, #T_9cf0e_row6_col1, #T_9cf0e_row6_col2, #T_9cf0e_row7_col0, #T_9cf0e_row7_col1, #T_9cf0e_row7_col2, #T_9cf0e_row8_col0, #T_9cf0e_row8_col1, #T_9cf0e_row8_col2, #T_9cf0e_row9_col0, #T_9cf0e_row9_col1, #T_9cf0e_row9_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_9cf0e">
#   <thead>
#     <tr>
#       <th id="T_9cf0e_level0_col0" class="col_heading level0 col0" >Setor</th>
#       <th id="T_9cf0e_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_9cf0e_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9cf0e_row0_col0" class="data row0 col0" >Software/SaaS</td>
#       <td id="T_9cf0e_row0_col1" class="data row0 col1" >34</td>
#       <td id="T_9cf0e_row0_col2" class="data row0 col2" >30.91</td>
#     </tr>
#     <tr>
#       <td id="T_9cf0e_row1_col0" class="data row1 col0" >Fintech/Serviços Financeiros</td>
#       <td id="T_9cf0e_row1_col1" class="data row1 col1" >32</td>
#       <td id="T_9cf0e_row1_col2" class="data row1 col2" >29.09</td>
#     </tr>
#     <tr>
#       <td id="T_9cf0e_row2_col0" class="data row2 col0" >Indústria/Logística</td>
#       <td id="T_9cf0e_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_9cf0e_row2_col2" class="data row2 col2" >7.27</td>
#     </tr>
#     <tr>
#       <td id="T_9cf0e_row3_col0" class="data row3 col0" >Telecom</td>
#       <td id="T_9cf0e_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_9cf0e_row3_col2" class="data row3 col2" >7.27</td>
#     </tr>
#     <tr>
#       <td id="T_9cf0e_row4_col0" class="data row4 col0" >Setor Público</td>
#       <td id="T_9cf0e_row4_col1" class="data row4 col1" >6</td>
#       <td id="T_9cf0e_row4_col2" class="data row4 col2" >5.45</td>
#     </tr>
#     <tr>
#       <td id="T_9cf0e_row5_col0" class="data row5 col0" >E-commerce/Varejo</td>
#       <td id="T_9cf0e_row5_col1" class="data row5 col1" >5</td>
#       <td id="T_9cf0e_row5_col2" class="data row5 col2" >4.55</td>
#     </tr>
#     <tr>
#       <td id="T_9cf0e_row6_col0" class="data row6 col0" >Saúde/HealthTech</td>
#       <td id="T_9cf0e_row6_col1" class="data row6 col1" >5</td>
#       <td id="T_9cf0e_row6_col2" class="data row6 col2" >4.55</td>
#     </tr>
#     <tr>
#       <td id="T_9cf0e_row7_col0" class="data row7 col0" >Educação/EdTech</td>
#       <td id="T_9cf0e_row7_col1" class="data row7 col1" >4</td>
#       <td id="T_9cf0e_row7_col2" class="data row7 col2" >3.64</td>
#     </tr>
#     <tr>
#       <td id="T_9cf0e_row8_col0" class="data row8 col0" >Consultoria/TI</td>
#       <td id="T_9cf0e_row8_col1" class="data row8 col1" >4</td>
#       <td id="T_9cf0e_row8_col2" class="data row8 col2" >3.64</td>
#     </tr>
#     <tr>
#       <td id="T_9cf0e_row9_col0" class="data row9 col0" >Mídia/Games</td>
#       <td id="T_9cf0e_row9_col1" class="data row9 col1" >4</td>
#       <td id="T_9cf0e_row9_col2" class="data row9 col2" >3.64</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tecnologia de Orquestração
# <style type="text/css">
# #T_205c6 th {
#   text-align: left;
# }
# #T_205c6  {
#   border: 1px solid black;
# }
# #T_205c6 th {
#   border: 1px solid black;
# }
# #T_205c6 td {
#   border: 1px solid black;
# }
# #T_205c6_row0_col0, #T_205c6_row0_col1, #T_205c6_row0_col2, #T_205c6_row1_col0, #T_205c6_row1_col1, #T_205c6_row1_col2, #T_205c6_row2_col0, #T_205c6_row2_col1, #T_205c6_row2_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_205c6">
#   <thead>
#     <tr>
#       <th id="T_205c6_level0_col0" class="col_heading level0 col0" >Tecnologia</th>
#       <th id="T_205c6_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_205c6_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_205c6_row0_col0" class="data row0 col0" >Kubernetes (self-hosted ou managed: EKS/AKS/GKE)</td>
#       <td id="T_205c6_row0_col1" class="data row0 col1" >80</td>
#       <td id="T_205c6_row0_col2" class="data row0 col2" >72.73</td>
#     </tr>
#     <tr>
#       <td id="T_205c6_row1_col0" class="data row1 col0" >Outras soluções (Nomad, OpenShift, ECS)</td>
#       <td id="T_205c6_row1_col1" class="data row1 col1" >19</td>
#       <td id="T_205c6_row1_col2" class="data row1 col2" >17.27</td>
#     </tr>
#     <tr>
#       <td id="T_205c6_row2_col0" class="data row2 col0" >Docker Swarm</td>
#       <td id="T_205c6_row2_col1" class="data row2 col1" >11</td>
#       <td id="T_205c6_row2_col2" class="data row2 col2" >10.00</td>
#     </tr>
#   </tbody>
# </table>
# ESTATÍSTICAS DESCRITIVAS: Desafios (Escala Likert 1-5)
# <style type="text/css">
# #T_3ef4b th {
#   text-align: left;
# }
# #T_3ef4b  {
#   border: 1px solid black;
# }
# #T_3ef4b th {
#   border: 1px solid black;
# }
# #T_3ef4b td {
#   border: 1px solid black;
# }
# #T_3ef4b_row0_col0, #T_3ef4b_row0_col1, #T_3ef4b_row0_col2, #T_3ef4b_row0_col3, #T_3ef4b_row0_col4, #T_3ef4b_row0_col5, #T_3ef4b_row1_col0, #T_3ef4b_row1_col1, #T_3ef4b_row1_col2, #T_3ef4b_row1_col3, #T_3ef4b_row1_col4, #T_3ef4b_row1_col5, #T_3ef4b_row2_col0, #T_3ef4b_row2_col1, #T_3ef4b_row2_col2, #T_3ef4b_row2_col3, #T_3ef4b_row2_col4, #T_3ef4b_row2_col5, #T_3ef4b_row3_col0, #T_3ef4b_row3_col1, #T_3ef4b_row3_col2, #T_3ef4b_row3_col3, #T_3ef4b_row3_col4, #T_3ef4b_row3_col5, #T_3ef4b_row4_col0, #T_3ef4b_row4_col1, #T_3ef4b_row4_col2, #T_3ef4b_row4_col3, #T_3ef4b_row4_col4, #T_3ef4b_row4_col5, #T_3ef4b_row5_col0, #T_3ef4b_row5_col1, #T_3ef4b_row5_col2, #T_3ef4b_row5_col3, #T_3ef4b_row5_col4, #T_3ef4b_row5_col5 {
#   text-align: left;
# }
# </style>
# <table id="T_3ef4b">
#   <thead>
#     <tr>
#       <th id="T_3ef4b_level0_col0" class="col_heading level0 col0" >Desafio</th>
#       <th id="T_3ef4b_level0_col1" class="col_heading level0 col1" >Média</th>
#       <th id="T_3ef4b_level0_col2" class="col_heading level0 col2" >Desvio</th>
#       <th id="T_3ef4b_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_3ef4b_level0_col4" class="col_heading level0 col4" >Max</th>
#       <th id="T_3ef4b_level0_col5" class="col_heading level0 col5" >% alto</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3ef4b_row0_col0" class="data row0 col0" >Mudanças organizacionais</td>
#       <td id="T_3ef4b_row0_col1" class="data row0 col1" >3.41</td>
#       <td id="T_3ef4b_row0_col2" class="data row0 col2" >1.20</td>
#       <td id="T_3ef4b_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_3ef4b_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_3ef4b_row0_col5" class="data row0 col5" >51.8</td>
#     </tr>
#     <tr>
#       <td id="T_3ef4b_row1_col0" class="data row1 col0" >Monitoramento</td>
#       <td id="T_3ef4b_row1_col1" class="data row1 col1" >3.19</td>
#       <td id="T_3ef4b_row1_col2" class="data row1 col2" >1.06</td>
#       <td id="T_3ef4b_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_3ef4b_row1_col4" class="data row1 col4" >5</td>
#       <td id="T_3ef4b_row1_col5" class="data row1 col5" >40.0</td>
#     </tr>
#     <tr>
#       <td id="T_3ef4b_row2_col0" class="data row2 col0" >Treinamento</td>
#       <td id="T_3ef4b_row2_col1" class="data row2 col1" >3.00</td>
#       <td id="T_3ef4b_row2_col2" class="data row2 col2" >1.20</td>
#       <td id="T_3ef4b_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_3ef4b_row2_col4" class="data row2 col4" >5</td>
#       <td id="T_3ef4b_row2_col5" class="data row2 col5" >37.3</td>
#     </tr>
#     <tr>
#       <td id="T_3ef4b_row3_col0" class="data row3 col0" >Complexidade</td>
#       <td id="T_3ef4b_row3_col1" class="data row3 col1" >3.11</td>
#       <td id="T_3ef4b_row3_col2" class="data row3 col2" >1.07</td>
#       <td id="T_3ef4b_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_3ef4b_row3_col4" class="data row3 col4" >5</td>
#       <td id="T_3ef4b_row3_col5" class="data row3 col5" >36.4</td>
#     </tr>
#     <tr>
#       <td id="T_3ef4b_row4_col0" class="data row4 col0" >Segurança</td>
#       <td id="T_3ef4b_row4_col1" class="data row4 col1" >3.17</td>
#       <td id="T_3ef4b_row4_col2" class="data row4 col2" >1.05</td>
#       <td id="T_3ef4b_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_3ef4b_row4_col4" class="data row4 col4" >5</td>
#       <td id="T_3ef4b_row4_col5" class="data row4 col5" >35.5</td>
#     </tr>
#     <tr>
#       <td id="T_3ef4b_row5_col0" class="data row5 col0" >CI/CD</td>
#       <td id="T_3ef4b_row5_col1" class="data row5 col1" >2.95</td>
#       <td id="T_3ef4b_row5_col2" class="data row5 col2" >1.18</td>
#       <td id="T_3ef4b_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_3ef4b_row5_col4" class="data row5 col4" >5</td>
#       <td id="T_3ef4b_row5_col5" class="data row5 col5" >32.7</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Principal Desafio Enfrentado (consolidado)
# <style type="text/css">
# #T_4da61 th {
#   text-align: left;
# }
# #T_4da61  {
#   border: 1px solid black;
# }
# #T_4da61 th {
#   border: 1px solid black;
# }
# #T_4da61 td {
#   border: 1px solid black;
# }
# #T_4da61_row0_col0, #T_4da61_row0_col1, #T_4da61_row0_col2, #T_4da61_row1_col0, #T_4da61_row1_col1, #T_4da61_row1_col2, #T_4da61_row2_col0, #T_4da61_row2_col1, #T_4da61_row2_col2, #T_4da61_row3_col0, #T_4da61_row3_col1, #T_4da61_row3_col2, #T_4da61_row4_col0, #T_4da61_row4_col1, #T_4da61_row4_col2, #T_4da61_row5_col0, #T_4da61_row5_col1, #T_4da61_row5_col2, #T_4da61_row6_col0, #T_4da61_row6_col1, #T_4da61_row6_col2, #T_4da61_row7_col0, #T_4da61_row7_col1, #T_4da61_row7_col2, #T_4da61_row8_col0, #T_4da61_row8_col1, #T_4da61_row8_col2, #T_4da61_row9_col0, #T_4da61_row9_col1, #T_4da61_row9_col2, #T_4da61_row10_col0, #T_4da61_row10_col1, #T_4da61_row10_col2, #T_4da61_row11_col0, #T_4da61_row11_col1, #T_4da61_row11_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_4da61">
#   <thead>
#     <tr>
#       <th id="T_4da61_level0_col0" class="col_heading level0 col0" >Desafio</th>
#       <th id="T_4da61_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_4da61_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4da61_row0_col0" class="data row0 col0" >Mudanças organizacionais e culturais (adoção de DevOps, colaboração entre equipes)</td>
#       <td id="T_4da61_row0_col1" class="data row0 col1" >26</td>
#       <td id="T_4da61_row0_col2" class="data row0 col2" >23.64</td>
#     </tr>
#     <tr>
#       <td id="T_4da61_row1_col0" class="data row1 col0" >Complexidade técnica (curva de aprendizado íngreme, novos conceitos)</td>
#       <td id="T_4da61_row1_col1" class="data row1 col1" >18</td>
#       <td id="T_4da61_row1_col2" class="data row1 col2" >16.36</td>
#     </tr>
#     <tr>
#       <td id="T_4da61_row2_col0" class="data row2 col0" >Monitoramento e observabilidade (monitoramento, logs, tracing)</td>
#       <td id="T_4da61_row2_col1" class="data row2 col1" >17</td>
#       <td id="T_4da61_row2_col2" class="data row2 col2" >15.45</td>
#     </tr>
#     <tr>
#       <td id="T_4da61_row3_col0" class="data row3 col0" >Segurança</td>
#       <td id="T_4da61_row3_col1" class="data row3 col1" >12</td>
#       <td id="T_4da61_row3_col2" class="data row3 col2" >10.91</td>
#     </tr>
#     <tr>
#       <td id="T_4da61_row4_col0" class="data row4 col0" >Integração com sistemas legados</td>
#       <td id="T_4da61_row4_col1" class="data row4 col1" >10</td>
#       <td id="T_4da61_row4_col2" class="data row4 col2" >9.09</td>
#     </tr>
#     <tr>
#       <td id="T_4da61_row5_col0" class="data row5 col0" >Treinamento e desenvolvimento de habilidades (falta de capacitação, upskilling)</td>
#       <td id="T_4da61_row5_col1" class="data row5 col1" >7</td>
#       <td id="T_4da61_row5_col2" class="data row5 col2" >6.36</td>
#     </tr>
#     <tr>
#       <td id="T_4da61_row6_col0" class="data row6 col0" >CI/CD (automação, fluxos de deploy)</td>
#       <td id="T_4da61_row6_col1" class="data row6 col1" >7</td>
#       <td id="T_4da61_row6_col2" class="data row6 col2" >6.36</td>
#     </tr>
#     <tr>
#       <td id="T_4da61_row7_col0" class="data row7 col0" >Custos de infraestrutura</td>
#       <td id="T_4da61_row7_col1" class="data row7 col1" >4</td>
#       <td id="T_4da61_row7_col2" class="data row7 col2" >3.64</td>
#     </tr>
#     <tr>
#       <td id="T_4da61_row8_col0" class="data row8 col0" >Escalabilidade</td>
#       <td id="T_4da61_row8_col1" class="data row8 col1" >3</td>
#       <td id="T_4da61_row8_col2" class="data row8 col2" >2.73</td>
#     </tr>
#     <tr>
#       <td id="T_4da61_row9_col0" class="data row9 col0" >Networking</td>
#       <td id="T_4da61_row9_col1" class="data row9 col1" >3</td>
#       <td id="T_4da61_row9_col2" class="data row9 col2" >2.73</td>
#     </tr>
#     <tr>
#       <td id="T_4da61_row10_col0" class="data row10 col0" >Sem desafio relevante</td>
#       <td id="T_4da61_row10_col1" class="data row10 col1" >2</td>
#       <td id="T_4da61_row10_col2" class="data row10 col2" >1.82</td>
#     </tr>
#     <tr>
#       <td id="T_4da61_row11_col0" class="data row11 col0" >Persistência de dados e gestão de estado</td>
#       <td id="T_4da61_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_4da61_row11_col2" class="data row11 col2" >0.91</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Empresa Ofereceu Treinamento?
# <style type="text/css">
# #T_6cfff th {
#   text-align: left;
# }
# #T_6cfff  {
#   border: 1px solid black;
# }
# #T_6cfff th {
#   border: 1px solid black;
# }
# #T_6cfff td {
#   border: 1px solid black;
# }
# #T_6cfff_row0_col0, #T_6cfff_row0_col1, #T_6cfff_row0_col2, #T_6cfff_row1_col0, #T_6cfff_row1_col1, #T_6cfff_row1_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_6cfff">
#   <thead>
#     <tr>
#       <th id="T_6cfff_level0_col0" class="col_heading level0 col0" >Resposta</th>
#       <th id="T_6cfff_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_6cfff_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6cfff_row0_col0" class="data row0 col0" >Não</td>
#       <td id="T_6cfff_row0_col1" class="data row0 col1" >71</td>
#       <td id="T_6cfff_row0_col2" class="data row0 col2" >64.55</td>
#     </tr>
#     <tr>
#       <td id="T_6cfff_row1_col0" class="data row1 col0" >Sim</td>
#       <td id="T_6cfff_row1_col1" class="data row1 col1" >39</td>
#       <td id="T_6cfff_row1_col2" class="data row1 col2" >35.45</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Fonte Mais Útil de Aprendizado (consolidado)
# <style type="text/css">
# #T_a1c40 th {
#   text-align: left;
# }
# #T_a1c40  {
#   border: 1px solid black;
# }
# #T_a1c40 th {
#   border: 1px solid black;
# }
# #T_a1c40 td {
#   border: 1px solid black;
# }
# #T_a1c40_row0_col0, #T_a1c40_row0_col1, #T_a1c40_row0_col2, #T_a1c40_row1_col0, #T_a1c40_row1_col1, #T_a1c40_row1_col2, #T_a1c40_row2_col0, #T_a1c40_row2_col1, #T_a1c40_row2_col2, #T_a1c40_row3_col0, #T_a1c40_row3_col1, #T_a1c40_row3_col2, #T_a1c40_row4_col0, #T_a1c40_row4_col1, #T_a1c40_row4_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_a1c40">
#   <thead>
#     <tr>
#       <th id="T_a1c40_level0_col0" class="col_heading level0 col0" >Fonte</th>
#       <th id="T_a1c40_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_a1c40_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a1c40_row0_col0" class="data row0 col0" >Documentação e autoestudo</td>
#       <td id="T_a1c40_row0_col1" class="data row0 col1" >41</td>
#       <td id="T_a1c40_row0_col2" class="data row0 col2" >37.27</td>
#     </tr>
#     <tr>
#       <td id="T_a1c40_row1_col0" class="data row1 col0" >Treinamento formal</td>
#       <td id="T_a1c40_row1_col1" class="data row1 col1" >30</td>
#       <td id="T_a1c40_row1_col2" class="data row1 col2" >27.27</td>
#     </tr>
#     <tr>
#       <td id="T_a1c40_row2_col0" class="data row2 col0" >Mentoria/Comunidade</td>
#       <td id="T_a1c40_row2_col1" class="data row2 col1" >14</td>
#       <td id="T_a1c40_row2_col2" class="data row2 col2" >12.73</td>
#     </tr>
#     <tr>
#       <td id="T_a1c40_row3_col0" class="data row3 col0" >Prática/PoC</td>
#       <td id="T_a1c40_row3_col1" class="data row3 col1" >13</td>
#       <td id="T_a1c40_row3_col2" class="data row3 col2" >11.82</td>
#     </tr>
#     <tr>
#       <td id="T_a1c40_row4_col0" class="data row4 col0" >Agentes de IA</td>
#       <td id="T_a1c40_row4_col1" class="data row4 col1" >12</td>
#       <td id="T_a1c40_row4_col2" class="data row4 col2" >10.91</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Realizou POCs?
# <style type="text/css">
# #T_e7178 th {
#   text-align: left;
# }
# #T_e7178  {
#   border: 1px solid black;
# }
# #T_e7178 th {
#   border: 1px solid black;
# }
# #T_e7178 td {
#   border: 1px solid black;
# }
# #T_e7178_row0_col0, #T_e7178_row0_col1, #T_e7178_row0_col2, #T_e7178_row1_col0, #T_e7178_row1_col1, #T_e7178_row1_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_e7178">
#   <thead>
#     <tr>
#       <th id="T_e7178_level0_col0" class="col_heading level0 col0" >Resposta</th>
#       <th id="T_e7178_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_e7178_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e7178_row0_col0" class="data row0 col0" >Sim</td>
#       <td id="T_e7178_row0_col1" class="data row0 col1" >91</td>
#       <td id="T_e7178_row0_col2" class="data row0 col2" >82.73</td>
#     </tr>
#     <tr>
#       <td id="T_e7178_row1_col0" class="data row1 col0" >Não</td>
#       <td id="T_e7178_row1_col1" class="data row1 col1" >19</td>
#       <td id="T_e7178_row1_col2" class="data row1 col2" >17.27</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tempo Individual para se Sentir Confortável
# <style type="text/css">
# #T_96259 th {
#   text-align: left;
# }
# #T_96259  {
#   border: 1px solid black;
# }
# #T_96259 th {
#   border: 1px solid black;
# }
# #T_96259 td {
#   border: 1px solid black;
# }
# #T_96259_row0_col0, #T_96259_row0_col1, #T_96259_row0_col2, #T_96259_row1_col0, #T_96259_row1_col1, #T_96259_row1_col2, #T_96259_row2_col0, #T_96259_row2_col1, #T_96259_row2_col2, #T_96259_row3_col0, #T_96259_row3_col1, #T_96259_row3_col2, #T_96259_row4_col0, #T_96259_row4_col1, #T_96259_row4_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_96259">
#   <thead>
#     <tr>
#       <th id="T_96259_level0_col0" class="col_heading level0 col0" >Tempo</th>
#       <th id="T_96259_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_96259_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_96259_row0_col0" class="data row0 col0" >3-6 meses</td>
#       <td id="T_96259_row0_col1" class="data row0 col1" >36</td>
#       <td id="T_96259_row0_col2" class="data row0 col2" >32.73</td>
#     </tr>
#     <tr>
#       <td id="T_96259_row1_col0" class="data row1 col0" >6-12 meses</td>
#       <td id="T_96259_row1_col1" class="data row1 col1" >36</td>
#       <td id="T_96259_row1_col2" class="data row1 col2" >32.73</td>
#     </tr>
#     <tr>
#       <td id="T_96259_row2_col0" class="data row2 col0" >Menos de 3 meses</td>
#       <td id="T_96259_row2_col1" class="data row2 col1" >23</td>
#       <td id="T_96259_row2_col2" class="data row2 col2" >20.91</td>
#     </tr>
#     <tr>
#       <td id="T_96259_row3_col0" class="data row3 col0" >12-18 meses</td>
#       <td id="T_96259_row3_col1" class="data row3 col1" >12</td>
#       <td id="T_96259_row3_col2" class="data row3 col2" >10.91</td>
#     </tr>
#     <tr>
#       <td id="T_96259_row4_col0" class="data row4 col0" >Mais de 18 meses</td>
#       <td id="T_96259_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_96259_row4_col2" class="data row4 col2" >2.73</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tempo da Equipe para Colocar em Produção
# <style type="text/css">
# #T_a70b0 th {
#   text-align: left;
# }
# #T_a70b0  {
#   border: 1px solid black;
# }
# #T_a70b0 th {
#   border: 1px solid black;
# }
# #T_a70b0 td {
#   border: 1px solid black;
# }
# #T_a70b0_row0_col0, #T_a70b0_row0_col1, #T_a70b0_row0_col2, #T_a70b0_row1_col0, #T_a70b0_row1_col1, #T_a70b0_row1_col2, #T_a70b0_row2_col0, #T_a70b0_row2_col1, #T_a70b0_row2_col2, #T_a70b0_row3_col0, #T_a70b0_row3_col1, #T_a70b0_row3_col2, #T_a70b0_row4_col0, #T_a70b0_row4_col1, #T_a70b0_row4_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_a70b0">
#   <thead>
#     <tr>
#       <th id="T_a70b0_level0_col0" class="col_heading level0 col0" >Tempo</th>
#       <th id="T_a70b0_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_a70b0_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a70b0_row0_col0" class="data row0 col0" >3-6 meses</td>
#       <td id="T_a70b0_row0_col1" class="data row0 col1" >40</td>
#       <td id="T_a70b0_row0_col2" class="data row0 col2" >36.36</td>
#     </tr>
#     <tr>
#       <td id="T_a70b0_row1_col0" class="data row1 col0" >1-3 meses</td>
#       <td id="T_a70b0_row1_col1" class="data row1 col1" >30</td>
#       <td id="T_a70b0_row1_col2" class="data row1 col2" >27.27</td>
#     </tr>
#     <tr>
#       <td id="T_a70b0_row2_col0" class="data row2 col0" >Menos de 1 mês</td>
#       <td id="T_a70b0_row2_col1" class="data row2 col1" >24</td>
#       <td id="T_a70b0_row2_col2" class="data row2 col2" >21.82</td>
#     </tr>
#     <tr>
#       <td id="T_a70b0_row3_col0" class="data row3 col0" >6-12 meses</td>
#       <td id="T_a70b0_row3_col1" class="data row3 col1" >14</td>
#       <td id="T_a70b0_row3_col2" class="data row3 col2" >12.73</td>
#     </tr>
#     <tr>
#       <td id="T_a70b0_row4_col0" class="data row4 col0" >Mais de 12 meses</td>
#       <td id="T_a70b0_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_a70b0_row4_col2" class="data row4 col2" >1.82</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Fator Mais Importante para Acelerar Aprendizado
# <style type="text/css">
# #T_6d2ef th {
#   text-align: left;
# }
# #T_6d2ef  {
#   border: 1px solid black;
# }
# #T_6d2ef th {
#   border: 1px solid black;
# }
# #T_6d2ef td {
#   border: 1px solid black;
# }
# #T_6d2ef_row0_col0, #T_6d2ef_row0_col1, #T_6d2ef_row0_col2, #T_6d2ef_row1_col0, #T_6d2ef_row1_col1, #T_6d2ef_row1_col2, #T_6d2ef_row2_col0, #T_6d2ef_row2_col1, #T_6d2ef_row2_col2, #T_6d2ef_row3_col0, #T_6d2ef_row3_col1, #T_6d2ef_row3_col2, #T_6d2ef_row4_col0, #T_6d2ef_row4_col1, #T_6d2ef_row4_col2, #T_6d2ef_row5_col0, #T_6d2ef_row5_col1, #T_6d2ef_row5_col2, #T_6d2ef_row6_col0, #T_6d2ef_row6_col1, #T_6d2ef_row6_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_6d2ef">
#   <thead>
#     <tr>
#       <th id="T_6d2ef_level0_col0" class="col_heading level0 col0" >Fator</th>
#       <th id="T_6d2ef_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_6d2ef_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6d2ef_row0_col0" class="data row0 col0" >Realização de POCs antes de produção</td>
#       <td id="T_6d2ef_row0_col1" class="data row0 col1" >34</td>
#       <td id="T_6d2ef_row0_col2" class="data row0 col2" >30.91</td>
#     </tr>
#     <tr>
#       <td id="T_6d2ef_row1_col0" class="data row1 col0" >Experiência prévia com Docker</td>
#       <td id="T_6d2ef_row1_col1" class="data row1 col1" >23</td>
#       <td id="T_6d2ef_row1_col2" class="data row1 col2" >20.91</td>
#     </tr>
#     <tr>
#       <td id="T_6d2ef_row2_col0" class="data row2 col0" >Tempo dedicado exclusivo para estudo</td>
#       <td id="T_6d2ef_row2_col1" class="data row2 col1" >19</td>
#       <td id="T_6d2ef_row2_col2" class="data row2 col2" >17.27</td>
#     </tr>
#     <tr>
#       <td id="T_6d2ef_row3_col0" class="data row3 col0" >Mentoria de especialistas internos ou externos</td>
#       <td id="T_6d2ef_row3_col1" class="data row3 col1" >15</td>
#       <td id="T_6d2ef_row3_col2" class="data row3 col2" >13.64</td>
#     </tr>
#     <tr>
#       <td id="T_6d2ef_row4_col0" class="data row4 col0" >Treinamento formal estruturado</td>
#       <td id="T_6d2ef_row4_col1" class="data row4 col1" >12</td>
#       <td id="T_6d2ef_row4_col2" class="data row4 col2" >10.91</td>
#     </tr>
#     <tr>
#       <td id="T_6d2ef_row5_col0" class="data row5 col0" >Participação em comunidades técnicas</td>
#       <td id="T_6d2ef_row5_col1" class="data row5 col1" >5</td>
#       <td id="T_6d2ef_row5_col2" class="data row5 col2" >4.55</td>
#     </tr>
#     <tr>
#       <td id="T_6d2ef_row6_col0" class="data row6 col0" >Certificações profissionais</td>
#       <td id="T_6d2ef_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_6d2ef_row6_col2" class="data row6 col2" >1.82</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Avaliação do ROI
# <style type="text/css">
# #T_10bef th {
#   text-align: left;
# }
# #T_10bef  {
#   border: 1px solid black;
# }
# #T_10bef th {
#   border: 1px solid black;
# }
# #T_10bef td {
#   border: 1px solid black;
# }
# #T_10bef_row0_col0, #T_10bef_row0_col1, #T_10bef_row0_col2, #T_10bef_row1_col0, #T_10bef_row1_col1, #T_10bef_row1_col2, #T_10bef_row2_col0, #T_10bef_row2_col1, #T_10bef_row2_col2, #T_10bef_row3_col0, #T_10bef_row3_col1, #T_10bef_row3_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_10bef">
#   <thead>
#     <tr>
#       <th id="T_10bef_level0_col0" class="col_heading level0 col0" >Nota</th>
#       <th id="T_10bef_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_10bef_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_10bef_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_10bef_row0_col1" class="data row0 col1" >55</td>
#       <td id="T_10bef_row0_col2" class="data row0 col2" >50.00</td>
#     </tr>
#     <tr>
#       <td id="T_10bef_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_10bef_row1_col1" class="data row1 col1" >37</td>
#       <td id="T_10bef_row1_col2" class="data row1 col2" >33.64</td>
#     </tr>
#     <tr>
#       <td id="T_10bef_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_10bef_row2_col1" class="data row2 col1" >16</td>
#       <td id="T_10bef_row2_col2" class="data row2 col2" >14.55</td>
#     </tr>
#     <tr>
#       <td id="T_10bef_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_10bef_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_10bef_row3_col2" class="data row3 col2" >1.82</td>
#     </tr>
#   </tbody>
# </table>
# Média: 4.32 | Mediana: 4.50
#
# DISTRIBUIÇÃO: Recomendaria a Adoção de Containers?
# <style type="text/css">
# #T_cf5fc th {
#   text-align: left;
# }
# #T_cf5fc  {
#   border: 1px solid black;
# }
# #T_cf5fc th {
#   border: 1px solid black;
# }
# #T_cf5fc td {
#   border: 1px solid black;
# }
# #T_cf5fc_row0_col0, #T_cf5fc_row0_col1, #T_cf5fc_row0_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_cf5fc">
#   <thead>
#     <tr>
#       <th id="T_cf5fc_level0_col0" class="col_heading level0 col0" >Resposta</th>
#       <th id="T_cf5fc_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_cf5fc_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cf5fc_row0_col0" class="data row0 col0" >Sim</td>
#       <td id="T_cf5fc_row0_col1" class="data row0 col1" >110</td>
#       <td id="T_cf5fc_row0_col2" class="data row0 col2" >100.00</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# TABELA DE CONTINGÊNCIA: TEMPO PARA SE SENTIR CONFORTÁVEL (Q24) × FONTE DE APRENDIZADO MAIS ÚTIL (Q22 CONSOLIDADA)
# ================================================================================
# <style type="text/css">
# #T_deba8 th {
#   text-align: left;
# }
# #T_deba8  {
#   border: 1px solid black;
# }
# #T_deba8 th {
#   border: 1px solid black;
# }
# #T_deba8 td {
#   border: 1px solid black;
# }
# #T_deba8_row0_col0, #T_deba8_row0_col1, #T_deba8_row0_col2, #T_deba8_row0_col3, #T_deba8_row0_col4, #T_deba8_row1_col0, #T_deba8_row1_col1, #T_deba8_row1_col2, #T_deba8_row1_col3, #T_deba8_row1_col4, #T_deba8_row2_col0, #T_deba8_row2_col1, #T_deba8_row2_col2, #T_deba8_row2_col3, #T_deba8_row2_col4, #T_deba8_row3_col0, #T_deba8_row3_col1, #T_deba8_row3_col2, #T_deba8_row3_col3, #T_deba8_row3_col4, #T_deba8_row4_col0, #T_deba8_row4_col1, #T_deba8_row4_col2, #T_deba8_row4_col3, #T_deba8_row4_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_deba8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_deba8_level0_col0" class="col_heading level0 col0" >Agentes de IA</th>
#       <th id="T_deba8_level0_col1" class="col_heading level0 col1" >Documentação e autoestudo</th>
#       <th id="T_deba8_level0_col2" class="col_heading level0 col2" >Mentoria/Comunidade</th>
#       <th id="T_deba8_level0_col3" class="col_heading level0 col3" >Prática/PoC</th>
#       <th id="T_deba8_level0_col4" class="col_heading level0 col4" >Treinamento formal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_deba8_level0_row0" class="row_heading level0 row0" >12-18 meses</th>
#       <td id="T_deba8_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_deba8_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_deba8_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_deba8_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_deba8_row0_col4" class="data row0 col4" >5</td>
#     </tr>
#     <tr>
#       <th id="T_deba8_level0_row1" class="row_heading level0 row1" >3-6 meses</th>
#       <td id="T_deba8_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_deba8_row1_col1" class="data row1 col1" >15</td>
#       <td id="T_deba8_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_deba8_row1_col3" class="data row1 col3" >5</td>
#       <td id="T_deba8_row1_col4" class="data row1 col4" >6</td>
#     </tr>
#     <tr>
#       <th id="T_deba8_level0_row2" class="row_heading level0 row2" >6-12 meses</th>
#       <td id="T_deba8_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_deba8_row2_col1" class="data row2 col1" >12</td>
#       <td id="T_deba8_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_deba8_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_deba8_row2_col4" class="data row2 col4" >13</td>
#     </tr>
#     <tr>
#       <th id="T_deba8_level0_row3" class="row_heading level0 row3" >Mais de 18 meses</th>
#       <td id="T_deba8_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_deba8_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_deba8_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_deba8_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_deba8_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_deba8_level0_row4" class="row_heading level0 row4" >Menos de 3 meses</th>
#       <td id="T_deba8_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_deba8_row4_col1" class="data row4 col1" >10</td>
#       <td id="T_deba8_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_deba8_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_deba8_row4_col4" class="data row4 col4" >5</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# TABELA DE CONTINGÊNCIA: REALIZAÇÃO DE POCS × TEMPO DA EQUIPE PARA PRODUÇÃO
# ================================================================================
# <style type="text/css">
# #T_1070a th {
#   text-align: left;
# }
# #T_1070a  {
#   border: 1px solid black;
# }
# #T_1070a th {
#   border: 1px solid black;
# }
# #T_1070a td {
#   border: 1px solid black;
# }
# #T_1070a_row0_col0, #T_1070a_row0_col1, #T_1070a_row0_col2, #T_1070a_row0_col3, #T_1070a_row0_col4, #T_1070a_row1_col0, #T_1070a_row1_col1, #T_1070a_row1_col2, #T_1070a_row1_col3, #T_1070a_row1_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_1070a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1070a_level0_col0" class="col_heading level0 col0" >1-3 meses</th>
#       <th id="T_1070a_level0_col1" class="col_heading level0 col1" >3-6 meses</th>
#       <th id="T_1070a_level0_col2" class="col_heading level0 col2" >6-12 meses</th>
#       <th id="T_1070a_level0_col3" class="col_heading level0 col3" >Mais de 12 meses</th>
#       <th id="T_1070a_level0_col4" class="col_heading level0 col4" >Menos de 1 mês</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1070a_level0_row0" class="row_heading level0 row0" >Não</th>
#       <td id="T_1070a_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_1070a_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_1070a_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_1070a_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_1070a_row0_col4" class="data row0 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_1070a_level0_row1" class="row_heading level0 row1" >Sim</th>
#       <td id="T_1070a_row1_col0" class="data row1 col0" >25</td>
#       <td id="T_1070a_row1_col1" class="data row1 col1" >34</td>
#       <td id="T_1070a_row1_col2" class="data row1 col2" >11</td>
#       <td id="T_1070a_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_1070a_row1_col4" class="data row1 col4" >20</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# ANÁLISE DESCRITIVA CONCLUÍDA
# ================================================================================

# %% [markdown]
# ### Teste Qui-Quadrado

# %%
utils.titulo_secao("Teste Qui-Quadrado")
# %run 02_qui_quadrado.ipynb
# Out:
# ================================================================================
# TESTE QUI-QUADRADO
# ================================================================================
# 110 respostas × 79 variáveis
# Bateria definida: 12 testes
#
#
# ================================================================================
# SEGURANÇA × CURVA RÁPIDA DA EQUIPE
# ================================================================================
# <style type="text/css">
# #T_76a25 th {
#   text-align: left;
# }
# #T_76a25  {
#   border: 1px solid black;
# }
# #T_76a25 th {
#   border: 1px solid black;
# }
# #T_76a25 td {
#   border: 1px solid black;
# }
# #T_76a25_row0_col0, #T_76a25_row0_col1, #T_76a25_row1_col0, #T_76a25_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_76a25">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76a25_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_76a25_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76a25_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76a25_row0_col0" class="data row0 col0" >32</td>
#       <td id="T_76a25_row0_col1" class="data row0 col1" >39</td>
#     </tr>
#     <tr>
#       <th id="T_76a25_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_76a25_row1_col0" class="data row1 col0" >24</td>
#       <td id="T_76a25_row1_col1" class="data row1 col1" >15</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 2.1124 | p: 0.1461 | gl: 1 | V de Cramér: 0.139
# Fisher exato: p = 0.1138
# Esperado < 5: 0/4 (0%) | mínimo: 19.15
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# COMPLEXIDADE × CURVA RÁPIDA DA EQUIPE
# ================================================================================
# <style type="text/css">
# #T_a956e th {
#   text-align: left;
# }
# #T_a956e  {
#   border: 1px solid black;
# }
# #T_a956e th {
#   border: 1px solid black;
# }
# #T_a956e td {
#   border: 1px solid black;
# }
# #T_a956e_row0_col0, #T_a956e_row0_col1, #T_a956e_row1_col0, #T_a956e_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_a956e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a956e_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a956e_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a956e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a956e_row0_col0" class="data row0 col0" >32</td>
#       <td id="T_a956e_row0_col1" class="data row0 col1" >38</td>
#     </tr>
#     <tr>
#       <th id="T_a956e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a956e_row1_col0" class="data row1 col0" >24</td>
#       <td id="T_a956e_row1_col1" class="data row1 col1" >16</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 1.5463 | p: 0.2137 | gl: 1 | V de Cramér: 0.119
# Fisher exato: p = 0.1693
# Esperado < 5: 0/4 (0%) | mínimo: 19.64
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# MONITORAMENTO × CURVA RÁPIDA DA EQUIPE
# ================================================================================
# <style type="text/css">
# #T_fc47d th {
#   text-align: left;
# }
# #T_fc47d  {
#   border: 1px solid black;
# }
# #T_fc47d th {
#   border: 1px solid black;
# }
# #T_fc47d td {
#   border: 1px solid black;
# }
# #T_fc47d_row0_col0, #T_fc47d_row0_col1, #T_fc47d_row1_col0, #T_fc47d_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_fc47d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc47d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_fc47d_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc47d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc47d_row0_col0" class="data row0 col0" >33</td>
#       <td id="T_fc47d_row0_col1" class="data row0 col1" >33</td>
#     </tr>
#     <tr>
#       <th id="T_fc47d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc47d_row1_col0" class="data row1 col0" >23</td>
#       <td id="T_fc47d_row1_col1" class="data row1 col1" >21</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 0.0015 | p: 0.9689 | gl: 1 | V de Cramér: 0.004
# Fisher exato: p = 0.8476
# Esperado < 5: 0/4 (0%) | mínimo: 21.60
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# MUDANÇAS ORGANIZACIONAIS × CURVA RÁPIDA DA EQUIPE
# ================================================================================
# <style type="text/css">
# #T_a5612 th {
#   text-align: left;
# }
# #T_a5612  {
#   border: 1px solid black;
# }
# #T_a5612 th {
#   border: 1px solid black;
# }
# #T_a5612 td {
#   border: 1px solid black;
# }
# #T_a5612_row0_col0, #T_a5612_row0_col1, #T_a5612_row1_col0, #T_a5612_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_a5612">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5612_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a5612_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5612_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5612_row0_col0" class="data row0 col0" >23</td>
#       <td id="T_a5612_row0_col1" class="data row0 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_a5612_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5612_row1_col0" class="data row1 col0" >33</td>
#       <td id="T_a5612_row1_col1" class="data row1 col1" >24</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 1.7663 | p: 0.1838 | gl: 1 | V de Cramér: 0.127
# Fisher exato: p = 0.1813
# Esperado < 5: 0/4 (0%) | mínimo: 26.02
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# TREINAMENTO × CURVA RÁPIDA DA EQUIPE
# ================================================================================
# <style type="text/css">
# #T_dceaf th {
#   text-align: left;
# }
# #T_dceaf  {
#   border: 1px solid black;
# }
# #T_dceaf th {
#   border: 1px solid black;
# }
# #T_dceaf td {
#   border: 1px solid black;
# }
# #T_dceaf_row0_col0, #T_dceaf_row0_col1, #T_dceaf_row1_col0, #T_dceaf_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_dceaf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dceaf_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_dceaf_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dceaf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dceaf_row0_col0" class="data row0 col0" >36</td>
#       <td id="T_dceaf_row0_col1" class="data row0 col1" >33</td>
#     </tr>
#     <tr>
#       <th id="T_dceaf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dceaf_row1_col0" class="data row1 col0" >20</td>
#       <td id="T_dceaf_row1_col1" class="data row1 col1" >21</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 0.0216 | p: 0.8831 | gl: 1 | V de Cramér: 0.014
# Fisher exato: p = 0.8440
# Esperado < 5: 0/4 (0%) | mínimo: 20.13
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# CI/CD × CURVA RÁPIDA DA EQUIPE
# ================================================================================
# <style type="text/css">
# #T_c0cd3 th {
#   text-align: left;
# }
# #T_c0cd3  {
#   border: 1px solid black;
# }
# #T_c0cd3 th {
#   border: 1px solid black;
# }
# #T_c0cd3 td {
#   border: 1px solid black;
# }
# #T_c0cd3_row0_col0, #T_c0cd3_row0_col1, #T_c0cd3_row1_col0, #T_c0cd3_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_c0cd3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0cd3_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_c0cd3_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0cd3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0cd3_row0_col0" class="data row0 col0" >30</td>
#       <td id="T_c0cd3_row0_col1" class="data row0 col1" >44</td>
#     </tr>
#     <tr>
#       <th id="T_c0cd3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c0cd3_row1_col0" class="data row1 col0" >26</td>
#       <td id="T_c0cd3_row1_col1" class="data row1 col1" >10</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 8.5002 | p: 0.0036 | gl: 1 | V de Cramér: 0.278
# Fisher exato: p = 0.0023
# Esperado < 5: 0/4 (0%) | mínimo: 17.67
# Associação significativa (p < 0.05).
#
#
# ================================================================================
# SEGURANÇA × CURVA RÁPIDA INDIVIDUAL
# ================================================================================
# <style type="text/css">
# #T_e8e6b th {
#   text-align: left;
# }
# #T_e8e6b  {
#   border: 1px solid black;
# }
# #T_e8e6b th {
#   border: 1px solid black;
# }
# #T_e8e6b td {
#   border: 1px solid black;
# }
# #T_e8e6b_row0_col0, #T_e8e6b_row0_col1, #T_e8e6b_row1_col0, #T_e8e6b_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_e8e6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8e6b_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e8e6b_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8e6b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8e6b_row0_col0" class="data row0 col0" >30</td>
#       <td id="T_e8e6b_row0_col1" class="data row0 col1" >41</td>
#     </tr>
#     <tr>
#       <th id="T_e8e6b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8e6b_row1_col0" class="data row1 col0" >21</td>
#       <td id="T_e8e6b_row1_col1" class="data row1 col1" >18</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 0.9341 | p: 0.3338 | gl: 1 | V de Cramér: 0.092
# Fisher exato: p = 0.3179
# Esperado < 5: 0/4 (0%) | mínimo: 18.08
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# COMPLEXIDADE × CURVA RÁPIDA INDIVIDUAL
# ================================================================================
# <style type="text/css">
# #T_d159b th {
#   text-align: left;
# }
# #T_d159b  {
#   border: 1px solid black;
# }
# #T_d159b th {
#   border: 1px solid black;
# }
# #T_d159b td {
#   border: 1px solid black;
# }
# #T_d159b_row0_col0, #T_d159b_row0_col1, #T_d159b_row1_col0, #T_d159b_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_d159b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d159b_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_d159b_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d159b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d159b_row0_col0" class="data row0 col0" >29</td>
#       <td id="T_d159b_row0_col1" class="data row0 col1" >41</td>
#     </tr>
#     <tr>
#       <th id="T_d159b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d159b_row1_col0" class="data row1 col0" >22</td>
#       <td id="T_d159b_row1_col1" class="data row1 col1" >18</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 1.3790 | p: 0.2403 | gl: 1 | V de Cramér: 0.112
# Fisher exato: p = 0.2330
# Esperado < 5: 0/4 (0%) | mínimo: 18.55
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# MONITORAMENTO × CURVA RÁPIDA INDIVIDUAL
# ================================================================================
# <style type="text/css">
# #T_55e79 th {
#   text-align: left;
# }
# #T_55e79  {
#   border: 1px solid black;
# }
# #T_55e79 th {
#   border: 1px solid black;
# }
# #T_55e79 td {
#   border: 1px solid black;
# }
# #T_55e79_row0_col0, #T_55e79_row0_col1, #T_55e79_row1_col0, #T_55e79_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_55e79">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55e79_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_55e79_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55e79_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_55e79_row0_col0" class="data row0 col0" >27</td>
#       <td id="T_55e79_row0_col1" class="data row0 col1" >39</td>
#     </tr>
#     <tr>
#       <th id="T_55e79_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_55e79_row1_col0" class="data row1 col0" >24</td>
#       <td id="T_55e79_row1_col1" class="data row1 col1" >20</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 1.4638 | p: 0.2263 | gl: 1 | V de Cramér: 0.115
# Fisher exato: p = 0.1768
# Esperado < 5: 0/4 (0%) | mínimo: 20.40
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# MUDANÇAS ORGANIZACIONAIS × CURVA RÁPIDA INDIVIDUAL
# ================================================================================
# <style type="text/css">
# #T_4b4a6 th {
#   text-align: left;
# }
# #T_4b4a6  {
#   border: 1px solid black;
# }
# #T_4b4a6 th {
#   border: 1px solid black;
# }
# #T_4b4a6 td {
#   border: 1px solid black;
# }
# #T_4b4a6_row0_col0, #T_4b4a6_row0_col1, #T_4b4a6_row1_col0, #T_4b4a6_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_4b4a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b4a6_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_4b4a6_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b4a6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4b4a6_row0_col0" class="data row0 col0" >23</td>
#       <td id="T_4b4a6_row0_col1" class="data row0 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_4b4a6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4b4a6_row1_col0" class="data row1 col0" >28</td>
#       <td id="T_4b4a6_row1_col1" class="data row1 col1" >29</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 0.1685 | p: 0.6815 | gl: 1 | V de Cramér: 0.039
# Fisher exato: p = 0.5714
# Esperado < 5: 0/4 (0%) | mínimo: 24.57
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# TREINAMENTO × CURVA RÁPIDA INDIVIDUAL
# ================================================================================
# <style type="text/css">
# #T_0fcf6 th {
#   text-align: left;
# }
# #T_0fcf6  {
#   border: 1px solid black;
# }
# #T_0fcf6 th {
#   border: 1px solid black;
# }
# #T_0fcf6 td {
#   border: 1px solid black;
# }
# #T_0fcf6_row0_col0, #T_0fcf6_row0_col1, #T_0fcf6_row1_col0, #T_0fcf6_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_0fcf6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0fcf6_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_0fcf6_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0fcf6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0fcf6_row0_col0" class="data row0 col0" >37</td>
#       <td id="T_0fcf6_row0_col1" class="data row0 col1" >32</td>
#     </tr>
#     <tr>
#       <th id="T_0fcf6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0fcf6_row1_col0" class="data row1 col0" >14</td>
#       <td id="T_0fcf6_row1_col1" class="data row1 col1" >27</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 3.1791 | p: 0.0746 | gl: 1 | V de Cramér: 0.170
# Fisher exato: p = 0.0516
# Esperado < 5: 0/4 (0%) | mínimo: 19.01
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# CI/CD × CURVA RÁPIDA INDIVIDUAL
# ================================================================================
# <style type="text/css">
# #T_88f3a th {
#   text-align: left;
# }
# #T_88f3a  {
#   border: 1px solid black;
# }
# #T_88f3a th {
#   border: 1px solid black;
# }
# #T_88f3a td {
#   border: 1px solid black;
# }
# #T_88f3a_row0_col0, #T_88f3a_row0_col1, #T_88f3a_row1_col0, #T_88f3a_row1_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_88f3a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88f3a_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_88f3a_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88f3a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_88f3a_row0_col0" class="data row0 col0" >33</td>
#       <td id="T_88f3a_row0_col1" class="data row0 col1" >41</td>
#     </tr>
#     <tr>
#       <th id="T_88f3a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_88f3a_row1_col0" class="data row1 col0" >18</td>
#       <td id="T_88f3a_row1_col1" class="data row1 col1" >18</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 0.1087 | p: 0.7416 | gl: 1 | V de Cramér: 0.031
# Fisher exato: p = 0.6848
# Esperado < 5: 0/4 (0%) | mínimo: 16.69
# Sem evidência de associação (p >= 0.05).
#
#
# ================================================================================
# RESUMO DA BATERIA (12 TESTES, CORREÇÃO FDR_BH)
# ================================================================================
#
# Premissa atendida em 12/12. Em 2x2 o p é o do Fisher exato.
# <style type="text/css">
# #T_82bea th {
#   text-align: left;
# }
# #T_82bea  {
#   border: 1px solid black;
# }
# #T_82bea th {
#   border: 1px solid black;
# }
# #T_82bea td {
#   border: 1px solid black;
# }
# #T_82bea_row0_col0, #T_82bea_row0_col1, #T_82bea_row0_col2, #T_82bea_row0_col3, #T_82bea_row0_col4, #T_82bea_row0_col5, #T_82bea_row0_col6, #T_82bea_row0_col7, #T_82bea_row0_col8, #T_82bea_row0_col9, #T_82bea_row1_col0, #T_82bea_row1_col1, #T_82bea_row1_col2, #T_82bea_row1_col3, #T_82bea_row1_col4, #T_82bea_row1_col5, #T_82bea_row1_col6, #T_82bea_row1_col7, #T_82bea_row1_col8, #T_82bea_row1_col9, #T_82bea_row2_col0, #T_82bea_row2_col1, #T_82bea_row2_col2, #T_82bea_row2_col3, #T_82bea_row2_col4, #T_82bea_row2_col5, #T_82bea_row2_col6, #T_82bea_row2_col7, #T_82bea_row2_col8, #T_82bea_row2_col9, #T_82bea_row3_col0, #T_82bea_row3_col1, #T_82bea_row3_col2, #T_82bea_row3_col3, #T_82bea_row3_col4, #T_82bea_row3_col5, #T_82bea_row3_col6, #T_82bea_row3_col7, #T_82bea_row3_col8, #T_82bea_row3_col9, #T_82bea_row4_col0, #T_82bea_row4_col1, #T_82bea_row4_col2, #T_82bea_row4_col3, #T_82bea_row4_col4, #T_82bea_row4_col5, #T_82bea_row4_col6, #T_82bea_row4_col7, #T_82bea_row4_col8, #T_82bea_row4_col9, #T_82bea_row5_col0, #T_82bea_row5_col1, #T_82bea_row5_col2, #T_82bea_row5_col3, #T_82bea_row5_col4, #T_82bea_row5_col5, #T_82bea_row5_col6, #T_82bea_row5_col7, #T_82bea_row5_col8, #T_82bea_row5_col9, #T_82bea_row6_col0, #T_82bea_row6_col1, #T_82bea_row6_col2, #T_82bea_row6_col3, #T_82bea_row6_col4, #T_82bea_row6_col5, #T_82bea_row6_col6, #T_82bea_row6_col7, #T_82bea_row6_col8, #T_82bea_row6_col9, #T_82bea_row7_col0, #T_82bea_row7_col1, #T_82bea_row7_col2, #T_82bea_row7_col3, #T_82bea_row7_col4, #T_82bea_row7_col5, #T_82bea_row7_col6, #T_82bea_row7_col7, #T_82bea_row7_col8, #T_82bea_row7_col9, #T_82bea_row8_col0, #T_82bea_row8_col1, #T_82bea_row8_col2, #T_82bea_row8_col3, #T_82bea_row8_col4, #T_82bea_row8_col5, #T_82bea_row8_col6, #T_82bea_row8_col7, #T_82bea_row8_col8, #T_82bea_row8_col9, #T_82bea_row9_col0, #T_82bea_row9_col1, #T_82bea_row9_col2, #T_82bea_row9_col3, #T_82bea_row9_col4, #T_82bea_row9_col5, #T_82bea_row9_col6, #T_82bea_row9_col7, #T_82bea_row9_col8, #T_82bea_row9_col9, #T_82bea_row10_col0, #T_82bea_row10_col1, #T_82bea_row10_col2, #T_82bea_row10_col3, #T_82bea_row10_col4, #T_82bea_row10_col5, #T_82bea_row10_col6, #T_82bea_row10_col7, #T_82bea_row10_col8, #T_82bea_row10_col9, #T_82bea_row11_col0, #T_82bea_row11_col1, #T_82bea_row11_col2, #T_82bea_row11_col3, #T_82bea_row11_col4, #T_82bea_row11_col5, #T_82bea_row11_col6, #T_82bea_row11_col7, #T_82bea_row11_col8, #T_82bea_row11_col9 {
#   text-align: left;
# }
# </style>
# <table id="T_82bea">
#   <thead>
#     <tr>
#       <th id="T_82bea_level0_col0" class="col_heading level0 col0" >Teste</th>
#       <th id="T_82bea_level0_col1" class="col_heading level0 col1" >n</th>
#       <th id="T_82bea_level0_col2" class="col_heading level0 col2" >Tabela</th>
#       <th id="T_82bea_level0_col3" class="col_heading level0 col3" >gl</th>
#       <th id="T_82bea_level0_col4" class="col_heading level0 col4" >Qui-quadrado</th>
#       <th id="T_82bea_level0_col5" class="col_heading level0 col5" >V de Cramér</th>
#       <th id="T_82bea_level0_col6" class="col_heading level0 col6" >p</th>
#       <th id="T_82bea_level0_col7" class="col_heading level0 col7" >p ajustado</th>
#       <th id="T_82bea_level0_col8" class="col_heading level0 col8" >Premissa</th>
#       <th id="T_82bea_level0_col9" class="col_heading level0 col9" >Significativo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_82bea_row0_col0" class="data row0 col0" >Segurança × curva rápida da equipe</td>
#       <td id="T_82bea_row0_col1" class="data row0 col1" >110</td>
#       <td id="T_82bea_row0_col2" class="data row0 col2" >2x2</td>
#       <td id="T_82bea_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_82bea_row0_col4" class="data row0 col4" >2.112000</td>
#       <td id="T_82bea_row0_col5" class="data row0 col5" >0.139000</td>
#       <td id="T_82bea_row0_col6" class="data row0 col6" >0.113800</td>
#       <td id="T_82bea_row0_col7" class="data row0 col7" >0.362700</td>
#       <td id="T_82bea_row0_col8" class="data row0 col8" >OK</td>
#       <td id="T_82bea_row0_col9" class="data row0 col9" >não</td>
#     </tr>
#     <tr>
#       <td id="T_82bea_row1_col0" class="data row1 col0" >Complexidade × curva rápida da equipe</td>
#       <td id="T_82bea_row1_col1" class="data row1 col1" >110</td>
#       <td id="T_82bea_row1_col2" class="data row1 col2" >2x2</td>
#       <td id="T_82bea_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_82bea_row1_col4" class="data row1 col4" >1.546000</td>
#       <td id="T_82bea_row1_col5" class="data row1 col5" >0.119000</td>
#       <td id="T_82bea_row1_col6" class="data row1 col6" >0.169300</td>
#       <td id="T_82bea_row1_col7" class="data row1 col7" >0.362700</td>
#       <td id="T_82bea_row1_col8" class="data row1 col8" >OK</td>
#       <td id="T_82bea_row1_col9" class="data row1 col9" >não</td>
#     </tr>
#     <tr>
#       <td id="T_82bea_row2_col0" class="data row2 col0" >Monitoramento × curva rápida da equipe</td>
#       <td id="T_82bea_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_82bea_row2_col2" class="data row2 col2" >2x2</td>
#       <td id="T_82bea_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_82bea_row2_col4" class="data row2 col4" >0.002000</td>
#       <td id="T_82bea_row2_col5" class="data row2 col5" >0.004000</td>
#       <td id="T_82bea_row2_col6" class="data row2 col6" >0.847600</td>
#       <td id="T_82bea_row2_col7" class="data row2 col7" >0.847600</td>
#       <td id="T_82bea_row2_col8" class="data row2 col8" >OK</td>
#       <td id="T_82bea_row2_col9" class="data row2 col9" >não</td>
#     </tr>
#     <tr>
#       <td id="T_82bea_row3_col0" class="data row3 col0" >Mudanças organizacionais × curva rápida da equipe</td>
#       <td id="T_82bea_row3_col1" class="data row3 col1" >110</td>
#       <td id="T_82bea_row3_col2" class="data row3 col2" >2x2</td>
#       <td id="T_82bea_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_82bea_row3_col4" class="data row3 col4" >1.766000</td>
#       <td id="T_82bea_row3_col5" class="data row3 col5" >0.127000</td>
#       <td id="T_82bea_row3_col6" class="data row3 col6" >0.181300</td>
#       <td id="T_82bea_row3_col7" class="data row3 col7" >0.362700</td>
#       <td id="T_82bea_row3_col8" class="data row3 col8" >OK</td>
#       <td id="T_82bea_row3_col9" class="data row3 col9" >não</td>
#     </tr>
#     <tr>
#       <td id="T_82bea_row4_col0" class="data row4 col0" >Treinamento × curva rápida da equipe</td>
#       <td id="T_82bea_row4_col1" class="data row4 col1" >110</td>
#       <td id="T_82bea_row4_col2" class="data row4 col2" >2x2</td>
#       <td id="T_82bea_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_82bea_row4_col4" class="data row4 col4" >0.022000</td>
#       <td id="T_82bea_row4_col5" class="data row4 col5" >0.014000</td>
#       <td id="T_82bea_row4_col6" class="data row4 col6" >0.844000</td>
#       <td id="T_82bea_row4_col7" class="data row4 col7" >0.847600</td>
#       <td id="T_82bea_row4_col8" class="data row4 col8" >OK</td>
#       <td id="T_82bea_row4_col9" class="data row4 col9" >não</td>
#     </tr>
#     <tr>
#       <td id="T_82bea_row5_col0" class="data row5 col0" >CI/CD × curva rápida da equipe</td>
#       <td id="T_82bea_row5_col1" class="data row5 col1" >110</td>
#       <td id="T_82bea_row5_col2" class="data row5 col2" >2x2</td>
#       <td id="T_82bea_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_82bea_row5_col4" class="data row5 col4" >8.500000</td>
#       <td id="T_82bea_row5_col5" class="data row5 col5" >0.278000</td>
#       <td id="T_82bea_row5_col6" class="data row5 col6" >0.002300</td>
#       <td id="T_82bea_row5_col7" class="data row5 col7" >0.027200</td>
#       <td id="T_82bea_row5_col8" class="data row5 col8" >OK</td>
#       <td id="T_82bea_row5_col9" class="data row5 col9" >sim</td>
#     </tr>
#     <tr>
#       <td id="T_82bea_row6_col0" class="data row6 col0" >Segurança × curva rápida individu
# ACHADOS: 1
#   CI/CD × curva rápida da equipe: p = 0.0023 | ajustado = 0.0272 | V = 0.278
#
# INDÍCIOS (não sobrevivem à correção): 0
#
# Habilitados para ANACOR: 1
#   CI/CD × curva rápida da equipe

# %% [markdown]
# ### ANACOR (Análise de Correspondência)

# %%
utils.titulo_secao("ANACOR - Análise de Correspondência")
# %run 03_anacor.ipynb
# Out:
# ================================================================================
# ANACOR - ANÁLISE DE CORRESPONDÊNCIA
# ================================================================================
# 110 respostas × 79 variáveis
# Pares testados no notebook 02: 12
#
#   CI/CD × curva rápida da equipe
#     tabela 2x2 | dimensões possíveis: 1 | NÃO gera mapa 2D
#
# ================================================================================
# PRÉ-TESTE: PERFIL DE DESAFIO (Q17 CI/CD × Q13 COMPLEXIDADE) × TEMPO DA EQUIPE ATÉ PRODUÇÃO (Q25)
# ================================================================================
# <style type="text/css">
# #T_53404 th {
#   text-align: left;
# }
# #T_53404  {
#   border: 1px solid black;
# }
# #T_53404 th {
#   border: 1px solid black;
# }
# #T_53404 td {
#   border: 1px solid black;
# }
# #T_53404_row0_col0, #T_53404_row0_col1, #T_53404_row0_col2, #T_53404_row1_col0, #T_53404_row1_col1, #T_53404_row1_col2, #T_53404_row2_col0, #T_53404_row2_col1, #T_53404_row2_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_53404">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53404_level0_col0" class="col_heading level0 col0" >Menos de 1 mês</th>
#       <th id="T_53404_level0_col1" class="col_heading level0 col1" >1-3 meses</th>
#       <th id="T_53404_level0_col2" class="col_heading level0 col2" >Mais de 3 meses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53404_level0_row0" class="row_heading level0 row0" >Apenas complexidade alta</th>
#       <td id="T_53404_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_53404_row0_col1" class="data row0 col1" >8</td>
#       <td id="T_53404_row0_col2" class="data row0 col2" >13</td>
#     </tr>
#     <tr>
#       <th id="T_53404_level0_row1" class="row_heading level0 row1" >Baixo desafio</th>
#       <td id="T_53404_row1_col0" class="data row1 col0" >17</td>
#       <td id="T_53404_row1_col1" class="data row1 col1" >16</td>
#       <td id="T_53404_row1_col2" class="data row1 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_53404_level0_row2" class="row_heading level0 row2" >CI/CD alto</th>
#       <td id="T_53404_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_53404_row2_col1" class="data row2 col1" >6</td>
#       <td id="T_53404_row2_col2" class="data row2 col2" >26</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 14.5356 | p: 0.0058 | gl: 4 | V de Cramér: 0.257
# Esperado < 5: 0/9 (0%) | mínimo: 5.24
# Associação significativa (p < 0.05).
#
# Resíduos padronizados ajustados (* = |r| > 1,96):
#                          Menos de 1 mês 1-3 meses Mais de 3 meses
# Apenas complexidade alta         -1.25     +0.75           +0.36
# Baixo desafio                    +2.82*    +1.02           -3.24*
# CI/CD alto                       -1.90     -1.74           +3.12*
#
# Pré-requisitos atendidos (p = 0.0058, V de Cramér = 0.257). Aplicando ANACOR.
#
#
# ================================================================================
# ANACOR: PERFIL DE DESAFIO (Q17 CI/CD × Q13 COMPLEXIDADE) × TEMPO DA EQUIPE ATÉ PRODUÇÃO (Q25)
# ================================================================================
# <style type="text/css">
# #T_be707 th {
#   text-align: left;
# }
# #T_be707  {
#   border: 1px solid black;
# }
# #T_be707 th {
#   border: 1px solid black;
# }
# #T_be707 td {
#   border: 1px solid black;
# }
# #T_be707_row0_col0, #T_be707_row0_col1, #T_be707_row0_col2, #T_be707_row1_col0, #T_be707_row1_col1, #T_be707_row1_col2, #T_be707_row2_col0, #T_be707_row2_col1, #T_be707_row2_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_be707">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be707_level0_col0" class="col_heading level0 col0" >Menos de 1 mês</th>
#       <th id="T_be707_level0_col1" class="col_heading level0 col1" >1-3 meses</th>
#       <th id="T_be707_level0_col2" class="col_heading level0 col2" >Mais de 3 meses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be707_level0_row0" class="row_heading level0 row0" >Apenas complexidade alta</th>
#       <td id="T_be707_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_be707_row0_col1" class="data row0 col1" >8</td>
#       <td id="T_be707_row0_col2" class="data row0 col2" >13</td>
#     </tr>
#     <tr>
#       <th id="T_be707_level0_row1" class="row_heading level0 row1" >Baixo desafio</th>
#       <td id="T_be707_row1_col0" class="data row1 col0" >17</td>
#       <td id="T_be707_row1_col1" class="data row1 col1" >16</td>
#       <td id="T_be707_row1_col2" class="data row1 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_be707_level0_row2" class="row_heading level0 row2" >CI/CD alto</th>
#       <td id="T_be707_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_be707_row2_col1" class="data row2 col1" >6</td>
#       <td id="T_be707_row2_col2" class="data row2 col2" >26</td>
#     </tr>
#   </tbody>
# </table>
# Inércia total: 0.1321
#   Dimensão 1: 91.28%
#   Dimensão 2: 8.72%
#   Acumulado: 100.00%  (a tabela admite exatamente 2 dimensões)
#
# Gráfico salvo: ../resultados/graficos/anacor/anacor_perfil_desafio_3_q25_faixa_deploy.png
# ================================================================================
# PRÉ-TESTE: PORTE DA EMPRESA (Q6) × PRINCIPAL DESAFIO (Q18)
# ================================================================================
# <style type="text/css">
# #T_7cb62 th {
#   text-align: left;
# }
# #T_7cb62  {
#   border: 1px solid black;
# }
# #T_7cb62 th {
#   border: 1px solid black;
# }
# #T_7cb62 td {
#   border: 1px solid black;
# }
# #T_7cb62_row0_col0, #T_7cb62_row0_col1, #T_7cb62_row0_col2, #T_7cb62_row0_col3, #T_7cb62_row0_col4, #T_7cb62_row0_col5, #T_7cb62_row0_col6, #T_7cb62_row0_col7, #T_7cb62_row1_col0, #T_7cb62_row1_col1, #T_7cb62_row1_col2, #T_7cb62_row1_col3, #T_7cb62_row1_col4, #T_7cb62_row1_col5, #T_7cb62_row1_col6, #T_7cb62_row1_col7, #T_7cb62_row2_col0, #T_7cb62_row2_col1, #T_7cb62_row2_col2, #T_7cb62_row2_col3, #T_7cb62_row2_col4, #T_7cb62_row2_col5, #T_7cb62_row2_col6, #T_7cb62_row2_col7 {
#   text-align: center;
# }
# </style>
# <table id="T_7cb62">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7cb62_level0_col0" class="col_heading level0 col0" >CI/CD</th>
#       <th id="T_7cb62_level0_col1" class="col_heading level0 col1" >Complexidade técnica</th>
#       <th id="T_7cb62_level0_col2" class="col_heading level0 col2" >Infra/Escala</th>
#       <th id="T_7cb62_level0_col3" class="col_heading level0 col3" >Legado/Migração</th>
#       <th id="T_7cb62_level0_col4" class="col_heading level0 col4" >Monitoramento</th>
#       <th id="T_7cb62_level0_col5" class="col_heading level0 col5" >Organizacional/Cultural</th>
#       <th id="T_7cb62_level0_col6" class="col_heading level0 col6" >Segurança</th>
#       <th id="T_7cb62_level0_col7" class="col_heading level0 col7" >Sem desafio relevante</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7cb62_level0_row0" class="row_heading level0 row0" >Grande (mais de 250 funcionários)</th>
#       <td id="T_7cb62_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_7cb62_row0_col1" class="data row0 col1" >8</td>
#       <td id="T_7cb62_row0_col2" class="data row0 col2" >6</td>
#       <td id="T_7cb62_row0_col3" class="data row0 col3" >7</td>
#       <td id="T_7cb62_row0_col4" class="data row0 col4" >9</td>
#       <td id="T_7cb62_row0_col5" class="data row0 col5" >15</td>
#       <td id="T_7cb62_row0_col6" class="data row0 col6" >6</td>
#       <td id="T_7cb62_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7cb62_level0_row1" class="row_heading level0 row1" >Média (50-250 funcionários)</th>
#       <td id="T_7cb62_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_7cb62_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_7cb62_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_7cb62_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_7cb62_row1_col4" class="data row1 col4" >4</td>
#       <td id="T_7cb62_row1_col5" class="data row1 col5" >12</td>
#       <td id="T_7cb62_row1_col6" class="data row1 col6" >4</td>
#       <td id="T_7cb62_row1_col7" class="data row1 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7cb62_level0_row2" class="row_heading level0 row2" >Pequena (menos de 50 funcionários)</th>
#       <td id="T_7cb62_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_7cb62_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_7cb62_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_7cb62_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_7cb62_row2_col4" class="data row2 col4" >4</td>
#       <td id="T_7cb62_row2_col5" class="data row2 col5" >6</td>
#       <td id="T_7cb62_row2_col6" class="data row2 col6" >2</td>
#       <td id="T_7cb62_row2_col7" class="data row2 col7" >1</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 7.8122 | p: 0.8989 | gl: 14 | V de Cramér: 0.188
# Esperado < 5: 14/24 (58%) | mínimo: 0.38
# Premissa VIOLADA - p-valor não interpretável.
#
# ANACOR NÃO APLICADA a 'Porte da empresa (Q6) × Principal desafio (Q18)': premissa das frequências esperadas violada (58% das células com esperado < 5).
#
#
# ================================================================================
# PRÉ-TESTE: FONTE DE APRENDIZADO MAIS ÚTIL (Q22) × TEMPO INDIVIDUAL (Q24)
# ================================================================================
# <style type="text/css">
# #T_245ba th {
#   text-align: left;
# }
# #T_245ba  {
#   border: 1px solid black;
# }
# #T_245ba th {
#   border: 1px solid black;
# }
# #T_245ba td {
#   border: 1px solid black;
# }
# #T_245ba_row0_col0, #T_245ba_row0_col1, #T_245ba_row0_col2, #T_245ba_row1_col0, #T_245ba_row1_col1, #T_245ba_row1_col2, #T_245ba_row2_col0, #T_245ba_row2_col1, #T_245ba_row2_col2, #T_245ba_row3_col0, #T_245ba_row3_col1, #T_245ba_row3_col2, #T_245ba_row4_col0, #T_245ba_row4_col1, #T_245ba_row4_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_245ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_245ba_level0_col0" class="col_heading level0 col0" >Até 3 meses</th>
#       <th id="T_245ba_level0_col1" class="col_heading level0 col1" >3-6 meses</th>
#       <th id="T_245ba_level0_col2" class="col_heading level0 col2" >Mais de 6 meses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_245ba_level0_row0" class="row_heading level0 row0" >Agentes de IA</th>
#       <td id="T_245ba_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_245ba_row0_col1" class="data row0 col1" >7</td>
#       <td id="T_245ba_row0_col2" class="data row0 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_245ba_level0_row1" class="row_heading level0 row1" >Documentação e autoestudo</th>
#       <td id="T_245ba_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_245ba_row1_col1" class="data row1 col1" >15</td>
#       <td id="T_245ba_row1_col2" class="data row1 col2" >16</td>
#     </tr>
#     <tr>
#       <th id="T_245ba_level0_row2" class="row_heading level0 row2" >Mentoria/Comunidade</th>
#       <td id="T_245ba_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_245ba_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_245ba_row2_col2" class="data row2 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_245ba_level0_row3" class="row_heading level0 row3" >Prática/PoC</th>
#       <td id="T_245ba_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_245ba_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_245ba_row3_col2" class="data row3 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_245ba_level0_row4" class="row_heading level0 row4" >Treinamento formal</th>
#       <td id="T_245ba_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_245ba_row4_col1" class="data row4 col1" >6</td>
#       <td id="T_245ba_row4_col2" class="data row4 col2" >19</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 9.4952 | p: 0.3023 | gl: 8 | V de Cramér: 0.208
# Esperado < 5: 6/15 (40%) | mínimo: 2.51
# Premissa VIOLADA - p-valor não interpretável.
#
# ANACOR NÃO APLICADA a 'Fonte de aprendizado mais útil (Q22) × Tempo individual (Q24)': premissa das frequências esperadas violada (40% das células com esperado < 5).
#
#
# ================================================================================
# PRÉ-TESTE: FATOR ACELERADOR (Q26) × TEMPO DA EQUIPE (Q25)
# ================================================================================
# <style type="text/css">
# #T_ecf37 th {
#   text-align: left;
# }
# #T_ecf37  {
#   border: 1px solid black;
# }
# #T_ecf37 th {
#   border: 1px solid black;
# }
# #T_ecf37 td {
#   border: 1px solid black;
# }
# #T_ecf37_row0_col0, #T_ecf37_row0_col1, #T_ecf37_row0_col2, #T_ecf37_row1_col0, #T_ecf37_row1_col1, #T_ecf37_row1_col2, #T_ecf37_row2_col0, #T_ecf37_row2_col1, #T_ecf37_row2_col2, #T_ecf37_row3_col0, #T_ecf37_row3_col1, #T_ecf37_row3_col2, #T_ecf37_row4_col0, #T_ecf37_row4_col1, #T_ecf37_row4_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_ecf37">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ecf37_level0_col0" class="col_heading level0 col0" >Menos de 1 mês</th>
#       <th id="T_ecf37_level0_col1" class="col_heading level0 col1" >1-3 meses</th>
#       <th id="T_ecf37_level0_col2" class="col_heading level0 col2" >Mais de 3 meses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ecf37_level0_row0" class="row_heading level0 row0" >Experiência prévia</th>
#       <td id="T_ecf37_row0_col0" class="data row0 col0" >7</td>
#       <td id="T_ecf37_row0_col1" class="data row0 col1" >8</td>
#       <td id="T_ecf37_row0_col2" class="data row0 col2" >8</td>
#     </tr>
#     <tr>
#       <th id="T_ecf37_level0_row1" class="row_heading level0 row1" >Formal/Certificação</th>
#       <td id="T_ecf37_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_ecf37_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_ecf37_row1_col2" class="data row1 col2" >9</td>
#     </tr>
#     <tr>
#       <th id="T_ecf37_level0_row2" class="row_heading level0 row2" >Mentoria/Comunidade</th>
#       <td id="T_ecf37_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_ecf37_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_ecf37_row2_col2" class="data row2 col2" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ecf37_level0_row3" class="row_heading level0 row3" >Prática/PoC</th>
#       <td id="T_ecf37_row3_col0" class="data row3 col0" >6</td>
#       <td id="T_ecf37_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_ecf37_row3_col2" class="data row3 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_ecf37_level0_row4" class="row_heading level0 row4" >Tempo dedicado</th>
#       <td id="T_ecf37_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_ecf37_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_ecf37_row4_col2" class="data row4 col2" >11</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 4.4111 | p: 0.8183 | gl: 8 | V de Cramér: 0.142
# Esperado < 5: 4/15 (27%) | mínimo: 3.05
# Premissa VIOLADA - p-valor não interpretável.
#
# ANACOR NÃO APLICADA a 'Fator acelerador (Q26) × Tempo da equipe (Q25)': premissa das frequências esperadas violada (27% das células com esperado < 5).
#
#
# ================================================================================
# PRÉ-TESTE: SENSIBILIDADE: FONTE MAIS ÚTIL EM 3 NÍVEIS (Q22) × TEMPO INDIVIDUAL (Q24)
# ================================================================================
# <style type="text/css">
# #T_05200 th {
#   text-align: left;
# }
# #T_05200  {
#   border: 1px solid black;
# }
# #T_05200 th {
#   border: 1px solid black;
# }
# #T_05200 td {
#   border: 1px solid black;
# }
# #T_05200_row0_col0, #T_05200_row0_col1, #T_05200_row0_col2, #T_05200_row1_col0, #T_05200_row1_col1, #T_05200_row1_col2, #T_05200_row2_col0, #T_05200_row2_col1, #T_05200_row2_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_05200">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05200_level0_col0" class="col_heading level0 col0" >Até 3 meses</th>
#       <th id="T_05200_level0_col1" class="col_heading level0 col1" >3-6 meses</th>
#       <th id="T_05200_level0_col2" class="col_heading level0 col2" >Mais de 6 meses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05200_level0_row0" class="row_heading level0 row0" >Autoestudo</th>
#       <td id="T_05200_row0_col0" class="data row0 col0" >12</td>
#       <td id="T_05200_row0_col1" class="data row0 col1" >22</td>
#       <td id="T_05200_row0_col2" class="data row0 col2" >19</td>
#     </tr>
#     <tr>
#       <th id="T_05200_level0_row1" class="row_heading level0 row1" >Social/Prática</th>
#       <td id="T_05200_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_05200_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_05200_row1_col2" class="data row1 col2" >13</td>
#     </tr>
#     <tr>
#       <th id="T_05200_level0_row2" class="row_heading level0 row2" >Treinamento formal</th>
#       <td id="T_05200_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_05200_row2_col1" class="data row2 col1" >6</td>
#       <td id="T_05200_row2_col2" class="data row2 col2" >19</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 6.3153 | p: 0.1768 | gl: 4 | V de Cramér: 0.169
# Esperado < 5: 0/9 (0%) | mínimo: 5.65
# Sem evidência de associação (p >= 0.05).
#
# ANACOR NÃO APLICADA a 'Sensibilidade: Fonte mais útil em 3 níveis (Q22) × Tempo individual (Q24)': associação não significativa (p = 0.1768).
#
#
# ================================================================================
# ANACOR CONCLUÍDA
# ================================================================================
#
# Pares avaliados: 5 | mapas gerados: 1
#
#   MAPA     Perfil de desafio × Tempo da equipe
#            dim1 91.28% | dim2 8.72%
#   recusado Porte da empresa (Q6) × Principal desafio (Q18)
#            premissa das frequências esperadas violada (58% das células com esperado < 5)
#   recusado Fonte de aprendizado mais útil (Q22) × Tempo individual (Q24)
#            premissa das frequências esperadas violada (40% das células com esperado < 5)
#   recusado Fator acelerador (Q26) × Tempo da equipe (Q25)
#            premissa das frequências esperadas violada (27% das células com esperado < 5)
#   recusado Sensibilidade: Fonte em 3 níveis × Tempo individual
#            associação não significativa (p = 0.1768)

# %% [markdown]
# ### Regressão Logística

# %%
utils.titulo_secao("Regressão Logística")
# %run 04_regressao.ipynb
# Out:
# ================================================================================
# REGRESSÃO LOGÍSTICA
# ================================================================================
# 110 respostas × 79 variáveis
#
# ================================================================================
# REGRESSÃO LOGÍSTICA - FATORES PREDITIVOS DA CURVA DE APRENDIZADO
# ================================================================================
#
# MODELO:
#   Variável Dependente: Curva Rápida individual (até 6 meses)
#   Método: Regressão Logística Binária
#
# VARIÁVEIS PREDITORAS:
#   • Realizou provas de conceito antes da produção
#   • Possui certificação técnica
#   • Empresa ofereceu treinamento formal
#   • Experiência com contêineres (3 anos ou mais)
#
# ================================================================================
# RESUMO DOS DADOS
# ================================================================================
#   Total de observações: 110
#   Curva rápida (até 6 meses): 59 (53.6%)
#   Curva lenta (mais de 6 meses): 51 (46.4%)
#
# ================================================================================
# MÉTRICAS DO MODELO
# ================================================================================
#   Pseudo R² (McFadden): 0.0299
#   Log-Likelihood: -73.68
#   Teste de razão de verossimilhança: LR = 4.543 | gl = 4 | p = 0.3375
#   AIC: 157.37
#   BIC: 170.87
#   Convergência: Sim
#
# ================================================================================
# INTERPRETAÇÃO DOS COEFICIENTES (Odds Ratios)
# ================================================================================
# <style type="text/css">
# #T_521ca th {
#   text-align: left;
# }
# #T_521ca  {
#   border: 1px solid black;
# }
# #T_521ca th {
#   border: 1px solid black;
# }
# #T_521ca td {
#   border: 1px solid black;
# }
# #T_521ca_row0_col0, #T_521ca_row0_col1, #T_521ca_row0_col2, #T_521ca_row0_col3, #T_521ca_row0_col4, #T_521ca_row1_col0, #T_521ca_row1_col1, #T_521ca_row1_col2, #T_521ca_row1_col3, #T_521ca_row1_col4, #T_521ca_row2_col0, #T_521ca_row2_col1, #T_521ca_row2_col2, #T_521ca_row2_col3, #T_521ca_row2_col4, #T_521ca_row3_col0, #T_521ca_row3_col1, #T_521ca_row3_col2, #T_521ca_row3_col3, #T_521ca_row3_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_521ca">
#   <thead>
#     <tr>
#       <th id="T_521ca_level0_col0" class="col_heading level0 col0" >Variável</th>
#       <th id="T_521ca_level0_col1" class="col_heading level0 col1" >Razão de chances</th>
#       <th id="T_521ca_level0_col2" class="col_heading level0 col2" >IC 95%</th>
#       <th id="T_521ca_level0_col3" class="col_heading level0 col3" >p-valor</th>
#       <th id="T_521ca_level0_col4" class="col_heading level0 col4" >Significativo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_521ca_row0_col0" class="data row0 col0" >Realizou provas de conceito antes da produção</td>
#       <td id="T_521ca_row0_col1" class="data row0 col1" >1.488</td>
#       <td id="T_521ca_row0_col2" class="data row0 col2" >[0.51; 4.33]</td>
#       <td id="T_521ca_row0_col3" class="data row0 col3" >0.4663</td>
#       <td id="T_521ca_row0_col4" class="data row0 col4" >Não</td>
#     </tr>
#     <tr>
#       <td id="T_521ca_row1_col0" class="data row1 col0" >Possui certificação técnica</td>
#       <td id="T_521ca_row1_col1" class="data row1 col1" >0.461</td>
#       <td id="T_521ca_row1_col2" class="data row1 col2" >[0.20; 1.06]</td>
#       <td id="T_521ca_row1_col3" class="data row1 col3" >0.0684</td>
#       <td id="T_521ca_row1_col4" class="data row1 col4" >Não</td>
#     </tr>
#     <tr>
#       <td id="T_521ca_row2_col0" class="data row2 col0" >Empresa ofereceu treinamento formal</td>
#       <td id="T_521ca_row2_col1" class="data row2 col1" >0.812</td>
#       <td id="T_521ca_row2_col2" class="data row2 col2" >[0.36; 1.84]</td>
#       <td id="T_521ca_row2_col3" class="data row2 col3" >0.6176</td>
#       <td id="T_521ca_row2_col4" class="data row2 col4" >Não</td>
#     </tr>
#     <tr>
#       <td id="T_521ca_row3_col0" class="data row3 col0" >Experiência com contêineres (3 anos ou mais)</td>
#       <td id="T_521ca_row3_col1" class="data row3 col1" >1.276</td>
#       <td id="T_521ca_row3_col2" class="data row3 col2" >[0.55; 2.94]</td>
#       <td id="T_521ca_row3_col3" class="data row3 col3" >0.5666</td>
#       <td id="T_521ca_row3_col4" class="data row3 col4" >Não</td>
#     </tr>
#   </tbody>
# </table>
# RESULTADO: Nenhuma variável significativa (p ≥ 0.05 para todas)
#
# ================================================================================
# ANÁLISE DESCRITIVA: Impacto Real de Cada Variável
# ================================================================================
# <style type="text/css">
# #T_9ce93 th {
#   text-align: left;
# }
# #T_9ce93  {
#   border: 1px solid black;
# }
# #T_9ce93 th {
#   border: 1px solid black;
# }
# #T_9ce93 td {
#   border: 1px solid black;
# }
# #T_9ce93_row0_col0, #T_9ce93_row0_col1, #T_9ce93_row0_col2, #T_9ce93_row0_col3, #T_9ce93_row1_col0, #T_9ce93_row1_col1, #T_9ce93_row1_col2, #T_9ce93_row1_col3, #T_9ce93_row2_col0, #T_9ce93_row2_col1, #T_9ce93_row2_col2, #T_9ce93_row2_col3, #T_9ce93_row3_col0, #T_9ce93_row3_col1, #T_9ce93_row3_col2, #T_9ce93_row3_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_9ce93">
#   <thead>
#     <tr>
#       <th id="T_9ce93_level0_col0" class="col_heading level0 col0" >Variável</th>
#       <th id="T_9ce93_level0_col1" class="col_heading level0 col1" >Com fator</th>
#       <th id="T_9ce93_level0_col2" class="col_heading level0 col2" >Sem fator</th>
#       <th id="T_9ce93_level0_col3" class="col_heading level0 col3" >Diferença</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ce93_row0_col0" class="data row0 col0" >Realizou provas de conceito antes da produção</td>
#       <td id="T_9ce93_row0_col1" class="data row0 col1" >50/91 (54.9%)</td>
#       <td id="T_9ce93_row0_col2" class="data row0 col2" >9/19 (47.4%)</td>
#       <td id="T_9ce93_row0_col3" class="data row0 col3" >+7.6pp</td>
#     </tr>
#     <tr>
#       <td id="T_9ce93_row1_col0" class="data row1 col0" >Possui certificação técnica</td>
#       <td id="T_9ce93_row1_col1" class="data row1 col1" >17/40 (42.5%)</td>
#       <td id="T_9ce93_row1_col2" class="data row1 col2" >42/70 (60.0%)</td>
#       <td id="T_9ce93_row1_col3" class="data row1 col3" >-17.5pp</td>
#     </tr>
#     <tr>
#       <td id="T_9ce93_row2_col0" class="data row2 col0" >Empresa ofereceu treinamento formal</td>
#       <td id="T_9ce93_row2_col1" class="data row2 col1" >19/39 (48.7%)</td>
#       <td id="T_9ce93_row2_col2" class="data row2 col2" >40/71 (56.3%)</td>
#       <td id="T_9ce93_row2_col3" class="data row2 col3" >-7.6pp</td>
#     </tr>
#     <tr>
#       <td id="T_9ce93_row3_col0" class="data row3 col0" >Experiência com contêineres (3 anos ou mais)</td>
#       <td id="T_9ce93_row3_col1" class="data row3 col1" >36/65 (55.4%)</td>
#       <td id="T_9ce93_row3_col2" class="data row3 col2" >23/45 (51.1%)</td>
#       <td id="T_9ce93_row3_col3" class="data row3 col3" >+4.3pp</td>
#     </tr>
#   </tbody>
# </table>
# Como interpretar:
#   • 'Com fator': % de curva rápida quando a característica está presente
#   • 'Sem fator': % de curva rápida quando a característica está ausente
#   • 'Diferença': Impacto em pontos percentuais (pp)
#   • Diferença positiva = fator favorece curva rápida
#   • Diferença negativa = fator dificulta curva rápida
# Gráfico salvo: ../resultados/graficos/regressao/impacto_fatores.png
#
# ================================================================================
# ANÁLISE DE REGRESSÃO LOGÍSTICA CONCLUÍDA
# ================================================================================
#
# Resultados:
#   - Modelo ajustado com sucesso
#   - Análise descritiva de impacto gerada
#   - Gráfico visual salvo em resultados/graficos/regressao/
#
# Próximo passo:
#   - Gerar visualizações adicionais (05_visualizacoes.ipynb)

# %% [markdown]
# ### Visualizações

# %%
utils.titulo_secao("Visualizações")
# %run 05_visualizacoes.ipynb
# Out:
# ================================================================================
# VISUALIZAÇÕES
# ================================================================================
# 110 respostas × 79 variáveis
# Gráfico salvo: ../resultados/graficos/descritivas/viz_cargos.png
# Gráfico salvo: ../resultados/graficos/descritivas/viz_porte_empresa.png
# Gráfico salvo: ../resultados/graficos/descritivas/viz_desafios_likert.png
# Gráfico salvo: ../resultados/graficos/descritivas/viz_tempo_individual.png
# Gráfico salvo: ../resultados/graficos/descritivas/viz_roi.png
#
# Média de ROI: 4.32
# Mediana de ROI: 4.5
# Gráfico salvo: ../resultados/graficos/descritivas/viz_desafio_por_porte.png
# Figura salva: ../resultados/graficos/descritivas/figura2_cargo.png
# Figura salva: ../resultados/graficos/descritivas/figura3_tempo_ti.png
# Figura salva: ../resultados/graficos/descritivas/figura4_tempo_conteineres.png
#
# ================================================================================
# VISUALIZAÇÕES CONCLUÍDAS
# ================================================================================
#
# Gráficos salvos em resultados/graficos/descritivas/:
#    - viz_cargos.png
#    - viz_porte_empresa.png
#    - viz_desafios_likert.png
#    - viz_tempo_individual.png
#    - viz_roi.png
#    - viz_desafio_por_porte.png
#
# Pipeline completa de análises finalizada!

# %% [markdown]
# ---
# ## Resumo Final

# %%
utils.titulo_secao("Análises Concluídas")

print("Análise Descritiva")
print("Teste Qui-Quadrado")
print("ANACOR")
print("Regressão Logística")
print("Visualizações")
print(f"\nResultados salvos em: ../resultados/")
# Out:
# ================================================================================
# ANÁLISES CONCLUÍDAS
# ================================================================================
# Análise Descritiva
# Teste Qui-Quadrado
# ANACOR
# Regressão Logística
# Visualizações
#
# Resultados salvos em: ../resultados/

# %% [markdown]
# ### 📚 Referências Metodológicas
#
# - **Qui-Quadrado:** Teste de independência entre variáveis categóricas
# - **ANACOR:** Análise de Correspondência (Hair et al., 2009)
# - **Regressão Logística:** Modelagem de fatores preditivos
