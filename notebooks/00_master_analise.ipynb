# %% [markdown]
# # Análise Estatística - TCC Engenharia de Software
# ## Tecnologias de Conteinerização: Curva de Aprendizagem Organizacional
#
# **Autor:** Guilherme Magalhães Leite
# **Orientador:** Arthur Pinheiro de Araújo Costa
# **Instituição:** MBA USP/ESALQ - Engenharia de Software
#
# ---
#
# ## Sobre Este Notebook
#
# Notebook principal que **orquestra todas as análises estatísticas** do projeto de pesquisa.
#
# ### Análises Implementadas
#
# 1. **Análise Descritiva** - Frequências, médias, tabelas de contingência
# 2. **Teste Qui-Quadrado** - Associações entre variáveis categóricas
# 3. **ANACOR** - Análise de Correspondência (mapas perceptuais 2D)
# 4. **Regressão Logística** - Fatores preditivos de curva de aprendizado
# 5. **Visualizações** - Gráficos exploratórios e descritivos
#
# ### Como Usar
#
# - **Executar tudo:** `Cell → Run All`
# - **Executar por partes:** Execute cada seção individualmente
# - **Notebooks individuais:** Disponíveis em `01_` até `05_`
#
# ### Estrutura Modular
#
# ```
# notebooks/
# ├── 00_master_analise.ipynb     ← VOCÊ ESTÁ AQUI
# ├── 01_analise_descritiva.ipynb
# ├── 02_qui_quadrado.ipynb
# ├── 03_anacor.ipynb
# ├── 04_regressao.ipynb
# └── 05_visualizacoes.ipynb
#
# src/
# └── utils.py                    # Funções reutilizáveis
# ```

# %% [markdown]
# ---
# ## Configuração Inicial

# %%
# %load_ext autoreload
# %autoreload 2

import sys; sys.path.append('../src')
import pandas as pd, warnings, utils

warnings.filterwarnings('ignore')
utils.configurar_visualizacoes()

# %% [markdown]
# ---
# ## Carregamento e Pré-processamento dos Dados

# %%
df = utils.carregar_dados('../dados/respostas.csv')
print(f"Dataset carregado: {len(df)} respostas × {len(df.columns)} variáveis")
# Out:
# Dataset carregado: 47 respostas × 29 variáveis

# %% [markdown]
# ---
# ## Pipeline de Análises
#
# Execute cada análise individualmente ou use os notebooks especializados.

# %% [markdown]
# ### Análise Descritiva

# %%
utils.titulo_secao("Análise Descritiva")
# %run 01_analise_descritiva.ipynb
# Out:
# ================================================================================
# ANÁLISE DESCRITIVA
# ================================================================================
# Usando dados já carregados
#
# DISTRIBUIÇÃO: Cargo
# <style type="text/css">
# #T_3e920 th {
#   text-align: left;
# }
# #T_3e920  {
#   border: 1px solid black;
# }
# #T_3e920 th {
#   border: 1px solid black;
# }
# #T_3e920 td {
#   border: 1px solid black;
# }
# #T_3e920_row0_col0, #T_3e920_row0_col1, #T_3e920_row0_col2, #T_3e920_row1_col0, #T_3e920_row1_col1, #T_3e920_row1_col2, #T_3e920_row2_col0, #T_3e920_row2_col1, #T_3e920_row2_col2, #T_3e920_row3_col0, #T_3e920_row3_col1, #T_3e920_row3_col2, #T_3e920_row4_col0, #T_3e920_row4_col1, #T_3e920_row4_col2, #T_3e920_row5_col0, #T_3e920_row5_col1, #T_3e920_row5_col2, #T_3e920_row6_col0, #T_3e920_row6_col1, #T_3e920_row6_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_3e920">
#   <thead>
#     <tr>
#       <th id="T_3e920_level0_col0" class="col_heading level0 col0" >Cargo</th>
#       <th id="T_3e920_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_3e920_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3e920_row0_col0" class="data row0 col0" >DevOps Engineer</td>
#       <td id="T_3e920_row0_col1" class="data row0 col1" >21</td>
#       <td id="T_3e920_row0_col2" class="data row0 col2" >44.68</td>
#     </tr>
#     <tr>
#       <td id="T_3e920_row1_col0" class="data row1 col0" >Desenvolvedor</td>
#       <td id="T_3e920_row1_col1" class="data row1 col1" >13</td>
#       <td id="T_3e920_row1_col2" class="data row1 col2" >27.66</td>
#     </tr>
#     <tr>
#       <td id="T_3e920_row2_col0" class="data row2 col0" >SRE (Site Reliability Engineer)</td>
#       <td id="T_3e920_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_3e920_row2_col2" class="data row2 col2" >14.89</td>
#     </tr>
#     <tr>
#       <td id="T_3e920_row3_col0" class="data row3 col0" >Arquiteto de Soluções</td>
#       <td id="T_3e920_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_3e920_row3_col2" class="data row3 col2" >4.26</td>
#     </tr>
#     <tr>
#       <td id="T_3e920_row4_col0" class="data row4 col0" >Estágio em tecnologia</td>
#       <td id="T_3e920_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_3e920_row4_col2" class="data row4 col2" >4.26</td>
#     </tr>
#     <tr>
#       <td id="T_3e920_row5_col0" class="data row5 col0" >Não estou trabalhando no momento</td>
#       <td id="T_3e920_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_3e920_row5_col2" class="data row5 col2" >2.13</td>
#     </tr>
#     <tr>
#       <td id="T_3e920_row6_col0" class="data row6 col0" >Technical Product Manager</td>
#       <td id="T_3e920_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_3e920_row6_col2" class="data row6 col2" >2.13</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tempo de Experiência em TI
# <style type="text/css">
# #T_cabe3 th {
#   text-align: left;
# }
# #T_cabe3  {
#   border: 1px solid black;
# }
# #T_cabe3 th {
#   border: 1px solid black;
# }
# #T_cabe3 td {
#   border: 1px solid black;
# }
# #T_cabe3_row0_col0, #T_cabe3_row0_col1, #T_cabe3_row0_col2, #T_cabe3_row1_col0, #T_cabe3_row1_col1, #T_cabe3_row1_col2, #T_cabe3_row2_col0, #T_cabe3_row2_col1, #T_cabe3_row2_col2, #T_cabe3_row3_col0, #T_cabe3_row3_col1, #T_cabe3_row3_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_cabe3">
#   <thead>
#     <tr>
#       <th id="T_cabe3_level0_col0" class="col_heading level0 col0" >Tempo em TI</th>
#       <th id="T_cabe3_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_cabe3_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cabe3_row0_col0" class="data row0 col0" >2-5 anos</td>
#       <td id="T_cabe3_row0_col1" class="data row0 col1" >17</td>
#       <td id="T_cabe3_row0_col2" class="data row0 col2" >36.17</td>
#     </tr>
#     <tr>
#       <td id="T_cabe3_row1_col0" class="data row1 col0" >5-10 anos</td>
#       <td id="T_cabe3_row1_col1" class="data row1 col1" >15</td>
#       <td id="T_cabe3_row1_col2" class="data row1 col2" >31.91</td>
#     </tr>
#     <tr>
#       <td id="T_cabe3_row2_col0" class="data row2 col0" >Mais de 10 anos</td>
#       <td id="T_cabe3_row2_col1" class="data row2 col1" >11</td>
#       <td id="T_cabe3_row2_col2" class="data row2 col2" >23.40</td>
#     </tr>
#     <tr>
#       <td id="T_cabe3_row3_col0" class="data row3 col0" >Menos de 2 anos</td>
#       <td id="T_cabe3_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_cabe3_row3_col2" class="data row3 col2" >8.51</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tempo de Experiência com Containers
# <style type="text/css">
# #T_f3f9a th {
#   text-align: left;
# }
# #T_f3f9a  {
#   border: 1px solid black;
# }
# #T_f3f9a th {
#   border: 1px solid black;
# }
# #T_f3f9a td {
#   border: 1px solid black;
# }
# #T_f3f9a_row0_col0, #T_f3f9a_row0_col1, #T_f3f9a_row0_col2, #T_f3f9a_row1_col0, #T_f3f9a_row1_col1, #T_f3f9a_row1_col2, #T_f3f9a_row2_col0, #T_f3f9a_row2_col1, #T_f3f9a_row2_col2, #T_f3f9a_row3_col0, #T_f3f9a_row3_col1, #T_f3f9a_row3_col2, #T_f3f9a_row4_col0, #T_f3f9a_row4_col1, #T_f3f9a_row4_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_f3f9a">
#   <thead>
#     <tr>
#       <th id="T_f3f9a_level0_col0" class="col_heading level0 col0" >Tempo com Containers</th>
#       <th id="T_f3f9a_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_f3f9a_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f3f9a_row0_col0" class="data row0 col0" >1-3 anos</td>
#       <td id="T_f3f9a_row0_col1" class="data row0 col1" >18</td>
#       <td id="T_f3f9a_row0_col2" class="data row0 col2" >38.30</td>
#     </tr>
#     <tr>
#       <td id="T_f3f9a_row1_col0" class="data row1 col0" >3-5 anos</td>
#       <td id="T_f3f9a_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_f3f9a_row1_col2" class="data row1 col2" >25.53</td>
#     </tr>
#     <tr>
#       <td id="T_f3f9a_row2_col0" class="data row2 col0" >Mais de 5 anos</td>
#       <td id="T_f3f9a_row2_col1" class="data row2 col1" >10</td>
#       <td id="T_f3f9a_row2_col2" class="data row2 col2" >21.28</td>
#     </tr>
#     <tr>
#       <td id="T_f3f9a_row3_col0" class="data row3 col0" >6 meses - 1 ano</td>
#       <td id="T_f3f9a_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_f3f9a_row3_col2" class="data row3 col2" >8.51</td>
#     </tr>
#     <tr>
#       <td id="T_f3f9a_row4_col0" class="data row4 col0" >Menos de 6 meses</td>
#       <td id="T_f3f9a_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_f3f9a_row4_col2" class="data row4 col2" >6.38</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Porte da Empresa
# <style type="text/css">
# #T_8d9ad th {
#   text-align: left;
# }
# #T_8d9ad  {
#   border: 1px solid black;
# }
# #T_8d9ad th {
#   border: 1px solid black;
# }
# #T_8d9ad td {
#   border: 1px solid black;
# }
# #T_8d9ad_row0_col0, #T_8d9ad_row0_col1, #T_8d9ad_row0_col2, #T_8d9ad_row1_col0, #T_8d9ad_row1_col1, #T_8d9ad_row1_col2, #T_8d9ad_row2_col0, #T_8d9ad_row2_col1, #T_8d9ad_row2_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_8d9ad">
#   <thead>
#     <tr>
#       <th id="T_8d9ad_level0_col0" class="col_heading level0 col0" >Porte</th>
#       <th id="T_8d9ad_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_8d9ad_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8d9ad_row0_col0" class="data row0 col0" >Grande (mais de 250 funcionários)</td>
#       <td id="T_8d9ad_row0_col1" class="data row0 col1" >23</td>
#       <td id="T_8d9ad_row0_col2" class="data row0 col2" >48.94</td>
#     </tr>
#     <tr>
#       <td id="T_8d9ad_row1_col0" class="data row1 col0" >Média (50-250 funcionários)</td>
#       <td id="T_8d9ad_row1_col1" class="data row1 col1" >18</td>
#       <td id="T_8d9ad_row1_col2" class="data row1 col2" >38.30</td>
#     </tr>
#     <tr>
#       <td id="T_8d9ad_row2_col0" class="data row2 col0" >Pequena (menos de 50 funcionários)</td>
#       <td id="T_8d9ad_row2_col1" class="data row2 col1" >6</td>
#       <td id="T_8d9ad_row2_col2" class="data row2 col2" >12.77</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Setor de Atuação
# <style type="text/css">
# #T_e0b7d th {
#   text-align: left;
# }
# #T_e0b7d  {
#   border: 1px solid black;
# }
# #T_e0b7d th {
#   border: 1px solid black;
# }
# #T_e0b7d td {
#   border: 1px solid black;
# }
# #T_e0b7d_row0_col0, #T_e0b7d_row0_col1, #T_e0b7d_row0_col2, #T_e0b7d_row1_col0, #T_e0b7d_row1_col1, #T_e0b7d_row1_col2, #T_e0b7d_row2_col0, #T_e0b7d_row2_col1, #T_e0b7d_row2_col2, #T_e0b7d_row3_col0, #T_e0b7d_row3_col1, #T_e0b7d_row3_col2, #T_e0b7d_row4_col0, #T_e0b7d_row4_col1, #T_e0b7d_row4_col2, #T_e0b7d_row5_col0, #T_e0b7d_row5_col1, #T_e0b7d_row5_col2, #T_e0b7d_row6_col0, #T_e0b7d_row6_col1, #T_e0b7d_row6_col2, #T_e0b7d_row7_col0, #T_e0b7d_row7_col1, #T_e0b7d_row7_col2, #T_e0b7d_row8_col0, #T_e0b7d_row8_col1, #T_e0b7d_row8_col2, #T_e0b7d_row9_col0, #T_e0b7d_row9_col1, #T_e0b7d_row9_col2, #T_e0b7d_row10_col0, #T_e0b7d_row10_col1, #T_e0b7d_row10_col2, #T_e0b7d_row11_col0, #T_e0b7d_row11_col1, #T_e0b7d_row11_col2, #T_e0b7d_row12_col0, #T_e0b7d_row12_col1, #T_e0b7d_row12_col2, #T_e0b7d_row13_col0, #T_e0b7d_row13_col1, #T_e0b7d_row13_col2, #T_e0b7d_row14_col0, #T_e0b7d_row14_col1, #T_e0b7d_row14_col2, #T_e0b7d_row15_col0, #T_e0b7d_row15_col1, #T_e0b7d_row15_col2, #T_e0b7d_row16_col0, #T_e0b7d_row16_col1, #T_e0b7d_row16_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_e0b7d">
#   <thead>
#     <tr>
#       <th id="T_e0b7d_level0_col0" class="col_heading level0 col0" >Setor</th>
#       <th id="T_e0b7d_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_e0b7d_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e0b7d_row0_col0" class="data row0 col0" >Fintech/Serviços Financeiros</td>
#       <td id="T_e0b7d_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_e0b7d_row0_col2" class="data row0 col2" >25.53</td>
#     </tr>
#     <tr>
#       <td id="T_e0b7d_row1_col0" class="data row1 col0" >Saas/Software</td>
#       <td id="T_e0b7d_row1_col1" class="data row1 col1" >11</td>
#       <td id="T_e0b7d_row1_col2" class="data row1 col2" >23.40</td>
#     </tr>
#     <tr>
#       <td id="T_e0b7d_row2_col0" class="data row2 col0" >Setor Público</td>
#       <td id="T_e0b7d_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_e0b7d_row2_col2" class="data row2 col2" >8.51</td>
#     </tr>
#     <tr>
#       <td id="T_e0b7d_row3_col0" class="data row3 col0" >Telecom</td>
#       <td id="T_e0b7d_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_e0b7d_row3_col2" class="data row3 col2" >6.38</td>
#     </tr>
#     <tr>
#       <td id="T_e0b7d_row4_col0" class="data row4 col0" >Saúde/HealthTech</td>
#       <td id="T_e0b7d_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_e0b7d_row4_col2" class="data row4 col2" >4.26</td>
#     </tr>
#     <tr>
#       <td id="T_e0b7d_row5_col0" class="data row5 col0" >Educação/EdTech</td>
#       <td id="T_e0b7d_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_e0b7d_row5_col2" class="data row5 col2" >4.26</td>
#     </tr>
#     <tr>
#       <td id="T_e0b7d_row6_col0" class="data row6 col0" >E-commerce/Varejo</td>
#       <td id="T_e0b7d_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_e0b7d_row6_col2" class="data row6 col2" >4.26</td>
#     </tr>
#     <tr>
#       <td id="T_e0b7d_row7_col0" class="data row7 col0" >Mídia/Entretenimento</td>
#       <td id="T_e0b7d_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_e0b7d_row7_col2" class="data row7 col2" >4.26</td>
#     </tr>
#     <tr>
#       <td id="T_e0b7d_row8_col0" class="data row8 col0" >Setor logístico + Software</td>
#       <td id="T_e0b7d_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_e0b7d_row8_col2" class="data row8 col2" >2.13</td>
#     </tr>
#     <tr>
#       <td id="T_e0b7d_row9_col0" class="data row9 col0" >Engenharia Elétrica</td>
#       <td id="T_e0b7d_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_e0b7d_row9_col2" class="data row9 col2" >2.13</td>
#     </tr>
#     <tr>
#       <td id="T_e0b7d_row10_col0" class="data row10 col0" >Manufatura </td>
#       <td id="T_e0b7d_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_e0b7d_row10_col2" class="data row10 col2" >2.13</td>
#     </tr>
#     <tr>
#       <td id="T_e0b7d_row11_col0" class="data row11 col0" >Agro</td>
#       <td id="T_e0b7d_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_e0b7d_row11_col2" class="data row11 col2" >2.13</td>
#     </tr>
#     <tr>
#       <td id="T_e0b7d_row12_col0" class="data row12 col0" >AWS Partner, foco em migrações cloud.</td>
#       <td id="T_e0b7d_row12_col1" class="data row12 col1" >1</td>
#       <td id="T_e0b7d_row12_col2" class="data row12 col2" >2.13</td>
#     </tr>
#     <tr>
#       <td id="T_e0b7d_row13_col0" class="data row13 col0" >Consultoria</td>
#       <td id="T_e0b7d_row13_col1" class="data row13 col1" >1</td>
#       <td id="T_e0b7d_row13_col2" class="data row13 col2" >2.13</td>
#     </tr>
#     <tr>
#       <td id="T_e0b7d_row14_col0" class="data row14 col0" >IndTech</td>
#       <td id="T_e0b7d_row14_col1" class="data row14 col1" >1</td>
#       <td id="T_e0b7d_row14_col2" class="data row14 col2" >2.13</td>
#     </tr>
#     <tr>
#       <td id="T_e0b7d_row15_col0" class="data row15 col0" >Benefícios</td>
#       <td id="T_e0b7d_row15_col1" class="data row15 col1" >1</td>
#       <td id="T_e0b7d_row15_col2" class="data row15 col2" >2.13</td>
#     </tr>
#     <tr>
#       <td id="T_e0b7d_row16_col0" class="data row16 col0" >tecnologia. Infraestrutura e monitoramento.</td>
#       <td id="T_e0b7d_row16_col1" class="data row16 col1" >1</td>
#       <td id="T_e0b7d_row16_col2" class="data row16 col2" >2.13</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tecnologia de Orquestração
# <style type="text/css">
# #T_3ea08 th {
#   text-align: left;
# }
# #T_3ea08  {
#   border: 1px solid black;
# }
# #T_3ea08 th {
#   border: 1px solid black;
# }
# #T_3ea08 td {
#   border: 1px solid black;
# }
# #T_3ea08_row0_col0, #T_3ea08_row0_col1, #T_3ea08_row0_col2, #T_3ea08_row1_col0, #T_3ea08_row1_col1, #T_3ea08_row1_col2, #T_3ea08_row2_col0, #T_3ea08_row2_col1, #T_3ea08_row2_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_3ea08">
#   <thead>
#     <tr>
#       <th id="T_3ea08_level0_col0" class="col_heading level0 col0" >Tecnologia</th>
#       <th id="T_3ea08_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_3ea08_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3ea08_row0_col0" class="data row0 col0" >Kubernetes (self-hosted ou managed: EKS/AKS/GKE)</td>
#       <td id="T_3ea08_row0_col1" class="data row0 col1" >34</td>
#       <td id="T_3ea08_row0_col2" class="data row0 col2" >72.34</td>
#     </tr>
#     <tr>
#       <td id="T_3ea08_row1_col0" class="data row1 col0" >Outras soluções (Nomad, OpenShift, ECS)</td>
#       <td id="T_3ea08_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_3ea08_row1_col2" class="data row1 col2" >17.02</td>
#     </tr>
#     <tr>
#       <td id="T_3ea08_row2_col0" class="data row2 col0" >Docker Swarm</td>
#       <td id="T_3ea08_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_3ea08_row2_col2" class="data row2 col2" >10.64</td>
#     </tr>
#   </tbody>
# </table>
# ESTATÍSTICAS DESCRITIVAS: Desafios (Escala Likert 1-5)
# <style type="text/css">
# #T_3fe73 th {
#   text-align: left;
# }
# #T_3fe73  {
#   border: 1px solid black;
# }
# #T_3fe73 th {
#   border: 1px solid black;
# }
# #T_3fe73 td {
#   border: 1px solid black;
# }
# #T_3fe73_row0_col0, #T_3fe73_row0_col1, #T_3fe73_row0_col2, #T_3fe73_row0_col3, #T_3fe73_row0_col4, #T_3fe73_row1_col0, #T_3fe73_row1_col1, #T_3fe73_row1_col2, #T_3fe73_row1_col3, #T_3fe73_row1_col4, #T_3fe73_row2_col0, #T_3fe73_row2_col1, #T_3fe73_row2_col2, #T_3fe73_row2_col3, #T_3fe73_row2_col4, #T_3fe73_row3_col0, #T_3fe73_row3_col1, #T_3fe73_row3_col2, #T_3fe73_row3_col3, #T_3fe73_row3_col4, #T_3fe73_row4_col0, #T_3fe73_row4_col1, #T_3fe73_row4_col2, #T_3fe73_row4_col3, #T_3fe73_row4_col4, #T_3fe73_row5_col0, #T_3fe73_row5_col1, #T_3fe73_row5_col2, #T_3fe73_row5_col3, #T_3fe73_row5_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_3fe73">
#   <thead>
#     <tr>
#       <th id="T_3fe73_level0_col0" class="col_heading level0 col0" >Desafio</th>
#       <th id="T_3fe73_level0_col1" class="col_heading level0 col1" >Média</th>
#       <th id="T_3fe73_level0_col2" class="col_heading level0 col2" >Desvio</th>
#       <th id="T_3fe73_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_3fe73_level0_col4" class="col_heading level0 col4" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3fe73_row0_col0" class="data row0 col0" >Segurança</td>
#       <td id="T_3fe73_row0_col1" class="data row0 col1" >3.15</td>
#       <td id="T_3fe73_row0_col2" class="data row0 col2" >0.86</td>
#       <td id="T_3fe73_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_3fe73_row0_col4" class="data row0 col4" >5</td>
#     </tr>
#     <tr>
#       <td id="T_3fe73_row1_col0" class="data row1 col0" >Complexidade</td>
#       <td id="T_3fe73_row1_col1" class="data row1 col1" >2.96</td>
#       <td id="T_3fe73_row1_col2" class="data row1 col2" >1.04</td>
#       <td id="T_3fe73_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_3fe73_row1_col4" class="data row1 col4" >5</td>
#     </tr>
#     <tr>
#       <td id="T_3fe73_row2_col0" class="data row2 col0" >Monitoramento</td>
#       <td id="T_3fe73_row2_col1" class="data row2 col1" >3.04</td>
#       <td id="T_3fe73_row2_col2" class="data row2 col2" >1.04</td>
#       <td id="T_3fe73_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_3fe73_row2_col4" class="data row2 col4" >5</td>
#     </tr>
#     <tr>
#       <td id="T_3fe73_row3_col0" class="data row3 col0" >Mudanças Organizacionais</td>
#       <td id="T_3fe73_row3_col1" class="data row3 col1" >3.28</td>
#       <td id="T_3fe73_row3_col2" class="data row3 col2" >1.33</td>
#       <td id="T_3fe73_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_3fe73_row3_col4" class="data row3 col4" >5</td>
#     </tr>
#     <tr>
#       <td id="T_3fe73_row4_col0" class="data row4 col0" >Treinamento</td>
#       <td id="T_3fe73_row4_col1" class="data row4 col1" >2.85</td>
#       <td id="T_3fe73_row4_col2" class="data row4 col2" >1.23</td>
#       <td id="T_3fe73_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_3fe73_row4_col4" class="data row4 col4" >5</td>
#     </tr>
#     <tr>
#       <td id="T_3fe73_row5_col0" class="data row5 col0" >CI/CD</td>
#       <td id="T_3fe73_row5_col1" class="data row5 col1" >2.77</td>
#       <td id="T_3fe73_row5_col2" class="data row5 col2" >1.20</td>
#       <td id="T_3fe73_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_3fe73_row5_col4" class="data row5 col4" >5</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Principal Desafio Enfrentado
# <style type="text/css">
# #T_3d1bd th {
#   text-align: left;
# }
# #T_3d1bd  {
#   border: 1px solid black;
# }
# #T_3d1bd th {
#   border: 1px solid black;
# }
# #T_3d1bd td {
#   border: 1px solid black;
# }
# #T_3d1bd_row0_col0, #T_3d1bd_row0_col1, #T_3d1bd_row0_col2, #T_3d1bd_row1_col0, #T_3d1bd_row1_col1, #T_3d1bd_row1_col2, #T_3d1bd_row2_col0, #T_3d1bd_row2_col1, #T_3d1bd_row2_col2, #T_3d1bd_row3_col0, #T_3d1bd_row3_col1, #T_3d1bd_row3_col2, #T_3d1bd_row4_col0, #T_3d1bd_row4_col1, #T_3d1bd_row4_col2, #T_3d1bd_row5_col0, #T_3d1bd_row5_col1, #T_3d1bd_row5_col2, #T_3d1bd_row6_col0, #T_3d1bd_row6_col1, #T_3d1bd_row6_col2, #T_3d1bd_row7_col0, #T_3d1bd_row7_col1, #T_3d1bd_row7_col2, #T_3d1bd_row8_col0, #T_3d1bd_row8_col1, #T_3d1bd_row8_col2, #T_3d1bd_row9_col0, #T_3d1bd_row9_col1, #T_3d1bd_row9_col2, #T_3d1bd_row10_col0, #T_3d1bd_row10_col1, #T_3d1bd_row10_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_3d1bd">
#   <thead>
#     <tr>
#       <th id="T_3d1bd_level0_col0" class="col_heading level0 col0" >Desafio</th>
#       <th id="T_3d1bd_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_3d1bd_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3d1bd_row0_col0" class="data row0 col0" >Complexidade técnica (curva de aprendizado íngreme, novos conceitos)</td>
#       <td id="T_3d1bd_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_3d1bd_row0_col2" class="data row0 col2" >19.15</td>
#     </tr>
#     <tr>
#       <td id="T_3d1bd_row1_col0" class="data row1 col0" >Mudanças organizacionais e culturais (adoção de DevOps, colaboração entre equipes)</td>
#       <td id="T_3d1bd_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_3d1bd_row1_col2" class="data row1 col2" >17.02</td>
#     </tr>
#     <tr>
#       <td id="T_3d1bd_row2_col0" class="data row2 col0" >Monitoramento e observabilidade (monitoramento, logs, tracing)</td>
#       <td id="T_3d1bd_row2_col1" class="data row2 col1" >6</td>
#       <td id="T_3d1bd_row2_col2" class="data row2 col2" >12.77</td>
#     </tr>
#     <tr>
#       <td id="T_3d1bd_row3_col0" class="data row3 col0" >Treinamento e desenvolvimento de habilidades (falta de capacitação, upskilling)</td>
#       <td id="T_3d1bd_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_3d1bd_row3_col2" class="data row3 col2" >10.64</td>
#     </tr>
#     <tr>
#       <td id="T_3d1bd_row4_col0" class="data row4 col0" >CI/CD (automação, fluxos de deploy)</td>
#       <td id="T_3d1bd_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_3d1bd_row4_col2" class="data row4 col2" >10.64</td>
#     </tr>
#     <tr>
#       <td id="T_3d1bd_row5_col0" class="data row5 col0" >Segurança</td>
#       <td id="T_3d1bd_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_3d1bd_row5_col2" class="data row5 col2" >8.51</td>
#     </tr>
#     <tr>
#       <td id="T_3d1bd_row6_col0" class="data row6 col0" >Integração com sistemas legados</td>
#       <td id="T_3d1bd_row6_col1" class="data row6 col1" >4</td>
#       <td id="T_3d1bd_row6_col2" class="data row6 col2" >8.51</td>
#     </tr>
#     <tr>
#       <td id="T_3d1bd_row7_col0" class="data row7 col0" >Custos de infraestrutura</td>
#       <td id="T_3d1bd_row7_col1" class="data row7 col1" >3</td>
#       <td id="T_3d1bd_row7_col2" class="data row7 col2" >6.38</td>
#     </tr>
#     <tr>
#       <td id="T_3d1bd_row8_col0" class="data row8 col0" >Escalabilidade</td>
#       <td id="T_3d1bd_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_3d1bd_row8_col2" class="data row8 col2" >2.13</td>
#     </tr>
#     <tr>
#       <td id="T_3d1bd_row9_col0" class="data row9 col0" >A adoção foi tranquila.</td>
#       <td id="T_3d1bd_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_3d1bd_row9_col2" class="data row9 col2" >2.13</td>
#     </tr>
#     <tr>
#       <td id="T_3d1bd_row10_col0" class="data row10 col0" >Persistência de dados e gestão de estado</td>
#       <td id="T_3d1bd_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_3d1bd_row10_col2" class="data row10 col2" >2.13</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Empresa Ofereceu Treinamento?
# <style type="text/css">
# #T_f7240 th {
#   text-align: left;
# }
# #T_f7240  {
#   border: 1px solid black;
# }
# #T_f7240 th {
#   border: 1px solid black;
# }
# #T_f7240 td {
#   border: 1px solid black;
# }
# #T_f7240_row0_col0, #T_f7240_row0_col1, #T_f7240_row0_col2, #T_f7240_row1_col0, #T_f7240_row1_col1, #T_f7240_row1_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_f7240">
#   <thead>
#     <tr>
#       <th id="T_f7240_level0_col0" class="col_heading level0 col0" >Resposta</th>
#       <th id="T_f7240_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_f7240_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f7240_row0_col0" class="data row0 col0" >Não</td>
#       <td id="T_f7240_row0_col1" class="data row0 col1" >29</td>
#       <td id="T_f7240_row0_col2" class="data row0 col2" >61.70</td>
#     </tr>
#     <tr>
#       <td id="T_f7240_row1_col0" class="data row1 col0" >Sim</td>
#       <td id="T_f7240_row1_col1" class="data row1 col1" >18</td>
#       <td id="T_f7240_row1_col2" class="data row1 col2" >38.30</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Fonte Mais Útil de Aprendizado
# <style type="text/css">
# #T_d13dc th {
#   text-align: left;
# }
# #T_d13dc  {
#   border: 1px solid black;
# }
# #T_d13dc th {
#   border: 1px solid black;
# }
# #T_d13dc td {
#   border: 1px solid black;
# }
# #T_d13dc_row0_col0, #T_d13dc_row0_col1, #T_d13dc_row0_col2, #T_d13dc_row1_col0, #T_d13dc_row1_col1, #T_d13dc_row1_col2, #T_d13dc_row2_col0, #T_d13dc_row2_col1, #T_d13dc_row2_col2, #T_d13dc_row3_col0, #T_d13dc_row3_col1, #T_d13dc_row3_col2, #T_d13dc_row4_col0, #T_d13dc_row4_col1, #T_d13dc_row4_col2, #T_d13dc_row5_col0, #T_d13dc_row5_col1, #T_d13dc_row5_col2, #T_d13dc_row6_col0, #T_d13dc_row6_col1, #T_d13dc_row6_col2, #T_d13dc_row7_col0, #T_d13dc_row7_col1, #T_d13dc_row7_col2, #T_d13dc_row8_col0, #T_d13dc_row8_col1, #T_d13dc_row8_col2, #T_d13dc_row9_col0, #T_d13dc_row9_col1, #T_d13dc_row9_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_d13dc">
#   <thead>
#     <tr>
#       <th id="T_d13dc_level0_col0" class="col_heading level0 col0" >Fonte</th>
#       <th id="T_d13dc_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_d13dc_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d13dc_row0_col0" class="data row0 col0" >Documentação oficial (Kubernetes, Docker Docs)</td>
#       <td id="T_d13dc_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_d13dc_row0_col2" class="data row0 col2" >21.28</td>
#     </tr>
#     <tr>
#       <td id="T_d13dc_row1_col0" class="data row1 col0" >Aprendizado autodirigido (tentativa e erro)</td>
#       <td id="T_d13dc_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_d13dc_row1_col2" class="data row1 col2" >14.89</td>
#     </tr>
#     <tr>
#       <td id="T_d13dc_row2_col0" class="data row2 col0" >Treinamento formal / cursos pagos (ex.: Udemy, Coursera, KodeKloud, Linux Academy)</td>
#       <td id="T_d13dc_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_d13dc_row2_col2" class="data row2 col2" >14.89</td>
#     </tr>
#     <tr>
#       <td id="T_d13dc_row3_col0" class="data row3 col0" >Agentes de inteligência artificial (IA)</td>
#       <td id="T_d13dc_row3_col1" class="data row3 col1" >6</td>
#       <td id="T_d13dc_row3_col2" class="data row3 col2" >12.77</td>
#     </tr>
#     <tr>
#       <td id="T_d13dc_row4_col0" class="data row4 col0" >Comunidades técnicas (fóruns, Stack Overflow, Reddit)</td>
#       <td id="T_d13dc_row4_col1" class="data row4 col1" >6</td>
#       <td id="T_d13dc_row4_col2" class="data row4 col2" >12.77</td>
#     </tr>
#     <tr>
#       <td id="T_d13dc_row5_col0" class="data row5 col0" >Provas de Conceito (PoCs) e projetos piloto</td>
#       <td id="T_d13dc_row5_col1" class="data row5 col1" >5</td>
#       <td id="T_d13dc_row5_col2" class="data row5 col2" >10.64</td>
#     </tr>
#     <tr>
#       <td id="T_d13dc_row6_col0" class="data row6 col0" >Mentoria interna (desenvolvedores seniores ou especialistas)</td>
#       <td id="T_d13dc_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_d13dc_row6_col2" class="data row6 col2" >6.38</td>
#     </tr>
#     <tr>
#       <td id="T_d13dc_row7_col0" class="data row7 col0" >Cursos estruturados (online ou presenciais)</td>
#       <td id="T_d13dc_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_d13dc_row7_col2" class="data row7 col2" >2.13</td>
#     </tr>
#     <tr>
#       <td id="T_d13dc_row8_col0" class="data row8 col0" >Tutoriais e artigos online (blogs, Medium, Dev.to)</td>
#       <td id="T_d13dc_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_d13dc_row8_col2" class="data row8 col2" >2.13</td>
#     </tr>
#     <tr>
#       <td id="T_d13dc_row9_col0" class="data row9 col0" >Livros técnicos</td>
#       <td id="T_d13dc_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_d13dc_row9_col2" class="data row9 col2" >2.13</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Realizou POCs?
# <style type="text/css">
# #T_4f73e th {
#   text-align: left;
# }
# #T_4f73e  {
#   border: 1px solid black;
# }
# #T_4f73e th {
#   border: 1px solid black;
# }
# #T_4f73e td {
#   border: 1px solid black;
# }
# #T_4f73e_row0_col0, #T_4f73e_row0_col1, #T_4f73e_row0_col2, #T_4f73e_row1_col0, #T_4f73e_row1_col1, #T_4f73e_row1_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_4f73e">
#   <thead>
#     <tr>
#       <th id="T_4f73e_level0_col0" class="col_heading level0 col0" >Resposta</th>
#       <th id="T_4f73e_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_4f73e_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4f73e_row0_col0" class="data row0 col0" >Sim</td>
#       <td id="T_4f73e_row0_col1" class="data row0 col1" >41</td>
#       <td id="T_4f73e_row0_col2" class="data row0 col2" >87.23</td>
#     </tr>
#     <tr>
#       <td id="T_4f73e_row1_col0" class="data row1 col0" >Não</td>
#       <td id="T_4f73e_row1_col1" class="data row1 col1" >6</td>
#       <td id="T_4f73e_row1_col2" class="data row1 col2" >12.77</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tempo Individual para se Sentir Confortável
# <style type="text/css">
# #T_1004e th {
#   text-align: left;
# }
# #T_1004e  {
#   border: 1px solid black;
# }
# #T_1004e th {
#   border: 1px solid black;
# }
# #T_1004e td {
#   border: 1px solid black;
# }
# #T_1004e_row0_col0, #T_1004e_row0_col1, #T_1004e_row0_col2, #T_1004e_row1_col0, #T_1004e_row1_col1, #T_1004e_row1_col2, #T_1004e_row2_col0, #T_1004e_row2_col1, #T_1004e_row2_col2, #T_1004e_row3_col0, #T_1004e_row3_col1, #T_1004e_row3_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_1004e">
#   <thead>
#     <tr>
#       <th id="T_1004e_level0_col0" class="col_heading level0 col0" >Tempo</th>
#       <th id="T_1004e_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_1004e_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1004e_row0_col0" class="data row0 col0" >6-12 meses</td>
#       <td id="T_1004e_row0_col1" class="data row0 col1" >17</td>
#       <td id="T_1004e_row0_col2" class="data row0 col2" >36.17</td>
#     </tr>
#     <tr>
#       <td id="T_1004e_row1_col0" class="data row1 col0" >3-6 meses</td>
#       <td id="T_1004e_row1_col1" class="data row1 col1" >16</td>
#       <td id="T_1004e_row1_col2" class="data row1 col2" >34.04</td>
#     </tr>
#     <tr>
#       <td id="T_1004e_row2_col0" class="data row2 col0" >Menos de 3 meses</td>
#       <td id="T_1004e_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_1004e_row2_col2" class="data row2 col2" >17.02</td>
#     </tr>
#     <tr>
#       <td id="T_1004e_row3_col0" class="data row3 col0" >12-18 meses</td>
#       <td id="T_1004e_row3_col1" class="data row3 col1" >6</td>
#       <td id="T_1004e_row3_col2" class="data row3 col2" >12.77</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Tempo da Equipe para Colocar em Produção
# <style type="text/css">
# #T_292b7 th {
#   text-align: left;
# }
# #T_292b7  {
#   border: 1px solid black;
# }
# #T_292b7 th {
#   border: 1px solid black;
# }
# #T_292b7 td {
#   border: 1px solid black;
# }
# #T_292b7_row0_col0, #T_292b7_row0_col1, #T_292b7_row0_col2, #T_292b7_row1_col0, #T_292b7_row1_col1, #T_292b7_row1_col2, #T_292b7_row2_col0, #T_292b7_row2_col1, #T_292b7_row2_col2, #T_292b7_row3_col0, #T_292b7_row3_col1, #T_292b7_row3_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_292b7">
#   <thead>
#     <tr>
#       <th id="T_292b7_level0_col0" class="col_heading level0 col0" >Tempo</th>
#       <th id="T_292b7_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_292b7_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_292b7_row0_col0" class="data row0 col0" >1-3 meses</td>
#       <td id="T_292b7_row0_col1" class="data row0 col1" >18</td>
#       <td id="T_292b7_row0_col2" class="data row0 col2" >38.30</td>
#     </tr>
#     <tr>
#       <td id="T_292b7_row1_col0" class="data row1 col0" >3-6 meses</td>
#       <td id="T_292b7_row1_col1" class="data row1 col1" >18</td>
#       <td id="T_292b7_row1_col2" class="data row1 col2" >38.30</td>
#     </tr>
#     <tr>
#       <td id="T_292b7_row2_col0" class="data row2 col0" >Menos de 1 mês</td>
#       <td id="T_292b7_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_292b7_row2_col2" class="data row2 col2" >14.89</td>
#     </tr>
#     <tr>
#       <td id="T_292b7_row3_col0" class="data row3 col0" >6-12 meses</td>
#       <td id="T_292b7_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_292b7_row3_col2" class="data row3 col2" >8.51</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Fator Mais Importante para Acelerar Aprendizado
# <style type="text/css">
# #T_398c7 th {
#   text-align: left;
# }
# #T_398c7  {
#   border: 1px solid black;
# }
# #T_398c7 th {
#   border: 1px solid black;
# }
# #T_398c7 td {
#   border: 1px solid black;
# }
# #T_398c7_row0_col0, #T_398c7_row0_col1, #T_398c7_row0_col2, #T_398c7_row1_col0, #T_398c7_row1_col1, #T_398c7_row1_col2, #T_398c7_row2_col0, #T_398c7_row2_col1, #T_398c7_row2_col2, #T_398c7_row3_col0, #T_398c7_row3_col1, #T_398c7_row3_col2, #T_398c7_row4_col0, #T_398c7_row4_col1, #T_398c7_row4_col2, #T_398c7_row5_col0, #T_398c7_row5_col1, #T_398c7_row5_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_398c7">
#   <thead>
#     <tr>
#       <th id="T_398c7_level0_col0" class="col_heading level0 col0" >Fator</th>
#       <th id="T_398c7_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_398c7_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_398c7_row0_col0" class="data row0 col0" >Realização de POCs antes de produção</td>
#       <td id="T_398c7_row0_col1" class="data row0 col1" >17</td>
#       <td id="T_398c7_row0_col2" class="data row0 col2" >36.17</td>
#     </tr>
#     <tr>
#       <td id="T_398c7_row1_col0" class="data row1 col0" >Experiência prévia com Docker</td>
#       <td id="T_398c7_row1_col1" class="data row1 col1" >9</td>
#       <td id="T_398c7_row1_col2" class="data row1 col2" >19.15</td>
#     </tr>
#     <tr>
#       <td id="T_398c7_row2_col0" class="data row2 col0" >Tempo dedicado exclusivo para estudo</td>
#       <td id="T_398c7_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_398c7_row2_col2" class="data row2 col2" >17.02</td>
#     </tr>
#     <tr>
#       <td id="T_398c7_row3_col0" class="data row3 col0" >Mentoria de especialistas internos ou externos</td>
#       <td id="T_398c7_row3_col1" class="data row3 col1" >7</td>
#       <td id="T_398c7_row3_col2" class="data row3 col2" >14.89</td>
#     </tr>
#     <tr>
#       <td id="T_398c7_row4_col0" class="data row4 col0" >Treinamento formal estruturado</td>
#       <td id="T_398c7_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_398c7_row4_col2" class="data row4 col2" >8.51</td>
#     </tr>
#     <tr>
#       <td id="T_398c7_row5_col0" class="data row5 col0" >Participação em comunidades técnicas</td>
#       <td id="T_398c7_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_398c7_row5_col2" class="data row5 col2" >4.26</td>
#     </tr>
#   </tbody>
# </table>
# DISTRIBUIÇÃO: Avaliação do ROI
# <style type="text/css">
# #T_36b34 th {
#   text-align: left;
# }
# #T_36b34  {
#   border: 1px solid black;
# }
# #T_36b34 th {
#   border: 1px solid black;
# }
# #T_36b34 td {
#   border: 1px solid black;
# }
# #T_36b34_row0_col0, #T_36b34_row0_col1, #T_36b34_row0_col2, #T_36b34_row1_col0, #T_36b34_row1_col1, #T_36b34_row1_col2, #T_36b34_row2_col0, #T_36b34_row2_col1, #T_36b34_row2_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_36b34">
#   <thead>
#     <tr>
#       <th id="T_36b34_level0_col0" class="col_heading level0 col0" >Nota</th>
#       <th id="T_36b34_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_36b34_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_36b34_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_36b34_row0_col1" class="data row0 col1" >25</td>
#       <td id="T_36b34_row0_col2" class="data row0 col2" >53.19</td>
#     </tr>
#     <tr>
#       <td id="T_36b34_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_36b34_row1_col1" class="data row1 col1" >14</td>
#       <td id="T_36b34_row1_col2" class="data row1 col2" >29.79</td>
#     </tr>
#     <tr>
#       <td id="T_36b34_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_36b34_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_36b34_row2_col2" class="data row2 col2" >17.02</td>
#     </tr>
#   </tbody>
# </table>
# Média: 4.36 | Mediana: 5.00
#
# DISTRIBUIÇÃO: Recomendaria a Adoção de Containers?
# <style type="text/css">
# #T_0a24f th {
#   text-align: left;
# }
# #T_0a24f  {
#   border: 1px solid black;
# }
# #T_0a24f th {
#   border: 1px solid black;
# }
# #T_0a24f td {
#   border: 1px solid black;
# }
# #T_0a24f_row0_col0, #T_0a24f_row0_col1, #T_0a24f_row0_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_0a24f">
#   <thead>
#     <tr>
#       <th id="T_0a24f_level0_col0" class="col_heading level0 col0" >Resposta</th>
#       <th id="T_0a24f_level0_col1" class="col_heading level0 col1" >Frequência</th>
#       <th id="T_0a24f_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0a24f_row0_col0" class="data row0 col0" >Sim</td>
#       <td id="T_0a24f_row0_col1" class="data row0 col1" >47</td>
#       <td id="T_0a24f_row0_col2" class="data row0 col2" >100.00</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# TABELA DE CONTINGÊNCIA: TEMPO PARA SE SENTIR CONFORTÁVEL COM CONTAINERS/ORQUESTRADORES × FONTE DE APRENDIZADO MAIS ÚTIL
# ================================================================================
# <style type="text/css">
# #T_02007 th {
#   text-align: left;
# }
# #T_02007  {
#   border: 1px solid black;
# }
# #T_02007 th {
#   border: 1px solid black;
# }
# #T_02007 td {
#   border: 1px solid black;
# }
# #T_02007_row0_col0, #T_02007_row0_col1, #T_02007_row0_col2, #T_02007_row0_col3, #T_02007_row0_col4, #T_02007_row0_col5, #T_02007_row0_col6, #T_02007_row0_col7, #T_02007_row0_col8, #T_02007_row0_col9, #T_02007_row1_col0, #T_02007_row1_col1, #T_02007_row1_col2, #T_02007_row1_col3, #T_02007_row1_col4, #T_02007_row1_col5, #T_02007_row1_col6, #T_02007_row1_col7, #T_02007_row1_col8, #T_02007_row1_col9, #T_02007_row2_col0, #T_02007_row2_col1, #T_02007_row2_col2, #T_02007_row2_col3, #T_02007_row2_col4, #T_02007_row2_col5, #T_02007_row2_col6, #T_02007_row2_col7, #T_02007_row2_col8, #T_02007_row2_col9, #T_02007_row3_col0, #T_02007_row3_col1, #T_02007_row3_col2, #T_02007_row3_col3, #T_02007_row3_col4, #T_02007_row3_col5, #T_02007_row3_col6, #T_02007_row3_col7, #T_02007_row3_col8, #T_02007_row3_col9 {
#   text-align: center;
# }
# </style>
# <table id="T_02007">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02007_level0_col0" class="col_heading level0 col0" >Agentes de inteligência artificial (IA)</th>
#       <th id="T_02007_level0_col1" class="col_heading level0 col1" >Aprendizado autodirigido (tentativa e erro)</th>
#       <th id="T_02007_level0_col2" class="col_heading level0 col2" >Comunidades técnicas (fóruns, Stack Overflow, Reddit)</th>
#       <th id="T_02007_level0_col3" class="col_heading level0 col3" >Cursos estruturados (online ou presenciais)</th>
#       <th id="T_02007_level0_col4" class="col_heading level0 col4" >Documentação oficial (Kubernetes, Docker Docs)</th>
#       <th id="T_02007_level0_col5" class="col_heading level0 col5" >Livros técnicos</th>
#       <th id="T_02007_level0_col6" class="col_heading level0 col6" >Mentoria interna (desenvolvedores seniores ou especialistas)</th>
#       <th id="T_02007_level0_col7" class="col_heading level0 col7" >Provas de Conceito (PoCs) e projetos piloto</th>
#       <th id="T_02007_level0_col8" class="col_heading level0 col8" >Treinamento formal / cursos pagos (ex.: Udemy, Coursera, KodeKloud, Linux Academy)</th>
#       <th id="T_02007_level0_col9" class="col_heading level0 col9" >Tutoriais e artigos online (blogs, Medium, Dev.to)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02007_level0_row0" class="row_heading level0 row0" >12-18 meses</th>
#       <td id="T_02007_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_02007_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_02007_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_02007_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_02007_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_02007_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_02007_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_02007_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_02007_row0_col8" class="data row0 col8" >2</td>
#       <td id="T_02007_row0_col9" class="data row0 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_02007_level0_row1" class="row_heading level0 row1" >3-6 meses</th>
#       <td id="T_02007_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_02007_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_02007_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_02007_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_02007_row1_col4" class="data row1 col4" >4</td>
#       <td id="T_02007_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_02007_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_02007_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_02007_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_02007_row1_col9" class="data row1 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_02007_level0_row2" class="row_heading level0 row2" >6-12 meses</th>
#       <td id="T_02007_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_02007_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_02007_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_02007_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_02007_row2_col4" class="data row2 col4" >6</td>
#       <td id="T_02007_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_02007_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_02007_row2_col7" class="data row2 col7" >3</td>
#       <td id="T_02007_row2_col8" class="data row2 col8" >4</td>
#       <td id="T_02007_row2_col9" class="data row2 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_02007_level0_row3" class="row_heading level0 row3" >Menos de 3 meses</th>
#       <td id="T_02007_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_02007_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_02007_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_02007_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_02007_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_02007_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_02007_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_02007_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_02007_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_02007_row3_col9" class="data row3 col9" >0</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# TABELA DE CONTINGÊNCIA: REALIZAÇÃO DE POCS × TEMPO DA EQUIPE PARA PRODUÇÃO
# ================================================================================
# <style type="text/css">
# #T_2945c th {
#   text-align: left;
# }
# #T_2945c  {
#   border: 1px solid black;
# }
# #T_2945c th {
#   border: 1px solid black;
# }
# #T_2945c td {
#   border: 1px solid black;
# }
# #T_2945c_row0_col0, #T_2945c_row0_col1, #T_2945c_row0_col2, #T_2945c_row0_col3, #T_2945c_row1_col0, #T_2945c_row1_col1, #T_2945c_row1_col2, #T_2945c_row1_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_2945c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2945c_level0_col0" class="col_heading level0 col0" >1-3 meses</th>
#       <th id="T_2945c_level0_col1" class="col_heading level0 col1" >3-6 meses</th>
#       <th id="T_2945c_level0_col2" class="col_heading level0 col2" >6-12 meses</th>
#       <th id="T_2945c_level0_col3" class="col_heading level0 col3" >Menos de 1 mês</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2945c_level0_row0" class="row_heading level0 row0" >Não</th>
#       <td id="T_2945c_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_2945c_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_2945c_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_2945c_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2945c_level0_row1" class="row_heading level0 row1" >Sim</th>
#       <td id="T_2945c_row1_col0" class="data row1 col0" >15</td>
#       <td id="T_2945c_row1_col1" class="data row1 col1" >16</td>
#       <td id="T_2945c_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_2945c_row1_col3" class="data row1 col3" >7</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# ANÁLISE DESCRITIVA CONCLUÍDA
# ================================================================================

# %% [markdown]
# ### Teste Qui-Quadrado

# %%
utils.titulo_secao("Teste Qui-Quadrado")
# %run 02_qui_quadrado.ipynb
# Out:
# ================================================================================
# TESTE QUI-QUADRADO
# ================================================================================
# Usando dados já carregados
#
# ================================================================================
# PORTE DA EMPRESA × PRINCIPAL DESAFIO
# ================================================================================
# <style type="text/css">
# #T_ba87d th {
#   text-align: left;
# }
# #T_ba87d  {
#   border: 1px solid black;
# }
# #T_ba87d th {
#   border: 1px solid black;
# }
# #T_ba87d td {
#   border: 1px solid black;
# }
# #T_ba87d_row0_col0, #T_ba87d_row0_col1, #T_ba87d_row0_col2, #T_ba87d_row0_col3, #T_ba87d_row0_col4, #T_ba87d_row0_col5, #T_ba87d_row0_col6, #T_ba87d_row0_col7, #T_ba87d_row0_col8, #T_ba87d_row0_col9, #T_ba87d_row0_col10, #T_ba87d_row1_col0, #T_ba87d_row1_col1, #T_ba87d_row1_col2, #T_ba87d_row1_col3, #T_ba87d_row1_col4, #T_ba87d_row1_col5, #T_ba87d_row1_col6, #T_ba87d_row1_col7, #T_ba87d_row1_col8, #T_ba87d_row1_col9, #T_ba87d_row1_col10, #T_ba87d_row2_col0, #T_ba87d_row2_col1, #T_ba87d_row2_col2, #T_ba87d_row2_col3, #T_ba87d_row2_col4, #T_ba87d_row2_col5, #T_ba87d_row2_col6, #T_ba87d_row2_col7, #T_ba87d_row2_col8, #T_ba87d_row2_col9, #T_ba87d_row2_col10 {
#   text-align: center;
# }
# </style>
# <table id="T_ba87d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba87d_level0_col0" class="col_heading level0 col0" >A adoção foi tranquila.</th>
#       <th id="T_ba87d_level0_col1" class="col_heading level0 col1" >CI/CD (automação, fluxos de deploy)</th>
#       <th id="T_ba87d_level0_col2" class="col_heading level0 col2" >Complexidade técnica (curva de aprendizado íngreme, novos conceitos)</th>
#       <th id="T_ba87d_level0_col3" class="col_heading level0 col3" >Custos de infraestrutura</th>
#       <th id="T_ba87d_level0_col4" class="col_heading level0 col4" >Escalabilidade</th>
#       <th id="T_ba87d_level0_col5" class="col_heading level0 col5" >Integração com sistemas legados</th>
#       <th id="T_ba87d_level0_col6" class="col_heading level0 col6" >Monitoramento e observabilidade (monitoramento, logs, tracing)</th>
#       <th id="T_ba87d_level0_col7" class="col_heading level0 col7" >Mudanças organizacionais e culturais (adoção de DevOps, colaboração entre equipes)</th>
#       <th id="T_ba87d_level0_col8" class="col_heading level0 col8" >Persistência de dados e gestão de estado</th>
#       <th id="T_ba87d_level0_col9" class="col_heading level0 col9" >Segurança</th>
#       <th id="T_ba87d_level0_col10" class="col_heading level0 col10" >Treinamento e desenvolvimento de habilidades (falta de capacitação, upskilling)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba87d_level0_row0" class="row_heading level0 row0" >Grande (mais de 250 funcionários)</th>
#       <td id="T_ba87d_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_ba87d_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_ba87d_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_ba87d_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_ba87d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ba87d_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_ba87d_row0_col6" class="data row0 col6" >3</td>
#       <td id="T_ba87d_row0_col7" class="data row0 col7" >5</td>
#       <td id="T_ba87d_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_ba87d_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_ba87d_row0_col10" class="data row0 col10" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ba87d_level0_row1" class="row_heading level0 row1" >Média (50-250 funcionários)</th>
#       <td id="T_ba87d_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_ba87d_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_ba87d_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_ba87d_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_ba87d_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_ba87d_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_ba87d_row1_col6" class="data row1 col6" >2</td>
#       <td id="T_ba87d_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_ba87d_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_ba87d_row1_col9" class="data row1 col9" >2</td>
#       <td id="T_ba87d_row1_col10" class="data row1 col10" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ba87d_level0_row2" class="row_heading level0 row2" >Pequena (menos de 50 funcionários)</th>
#       <td id="T_ba87d_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_ba87d_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_ba87d_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_ba87d_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_ba87d_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_ba87d_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_ba87d_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_ba87d_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_ba87d_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_ba87d_row2_col9" class="data row2 col9" >1</td>
#       <td id="T_ba87d_row2_col10" class="data row2 col10" >1</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 14.2334 | P-value: 0.8185 | Graus de liberdade: 20
# Associação NÃO significativa (p >= 0.05) - Variáveis são independentes
#
#
# ================================================================================
# EMPRESA OFERECEU TREINAMENTO × TEMPO INDIVIDUAL
# ================================================================================
# <style type="text/css">
# #T_1a370 th {
#   text-align: left;
# }
# #T_1a370  {
#   border: 1px solid black;
# }
# #T_1a370 th {
#   border: 1px solid black;
# }
# #T_1a370 td {
#   border: 1px solid black;
# }
# #T_1a370_row0_col0, #T_1a370_row0_col1, #T_1a370_row0_col2, #T_1a370_row0_col3, #T_1a370_row1_col0, #T_1a370_row1_col1, #T_1a370_row1_col2, #T_1a370_row1_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_1a370">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a370_level0_col0" class="col_heading level0 col0" >12-18 meses</th>
#       <th id="T_1a370_level0_col1" class="col_heading level0 col1" >3-6 meses</th>
#       <th id="T_1a370_level0_col2" class="col_heading level0 col2" >6-12 meses</th>
#       <th id="T_1a370_level0_col3" class="col_heading level0 col3" >Menos de 3 meses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a370_level0_row0" class="row_heading level0 row0" >Não</th>
#       <td id="T_1a370_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_1a370_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_1a370_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_1a370_row0_col3" class="data row0 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_1a370_level0_row1" class="row_heading level0 row1" >Sim</th>
#       <td id="T_1a370_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_1a370_row1_col1" class="data row1 col1" >6</td>
#       <td id="T_1a370_row1_col2" class="data row1 col2" >7</td>
#       <td id="T_1a370_row1_col3" class="data row1 col3" >3</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 0.1287 | P-value: 0.9882 | Graus de liberdade: 3
# Associação NÃO significativa (p >= 0.05) - Variáveis são independentes
#
#
# ================================================================================
# REALIZOU POCS × TEMPO DA EQUIPE
# ================================================================================
# <style type="text/css">
# #T_8b765 th {
#   text-align: left;
# }
# #T_8b765  {
#   border: 1px solid black;
# }
# #T_8b765 th {
#   border: 1px solid black;
# }
# #T_8b765 td {
#   border: 1px solid black;
# }
# #T_8b765_row0_col0, #T_8b765_row0_col1, #T_8b765_row0_col2, #T_8b765_row0_col3, #T_8b765_row1_col0, #T_8b765_row1_col1, #T_8b765_row1_col2, #T_8b765_row1_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_8b765">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b765_level0_col0" class="col_heading level0 col0" >1-3 meses</th>
#       <th id="T_8b765_level0_col1" class="col_heading level0 col1" >3-6 meses</th>
#       <th id="T_8b765_level0_col2" class="col_heading level0 col2" >6-12 meses</th>
#       <th id="T_8b765_level0_col3" class="col_heading level0 col3" >Menos de 1 mês</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b765_level0_row0" class="row_heading level0 row0" >Não</th>
#       <td id="T_8b765_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_8b765_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_8b765_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_8b765_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8b765_level0_row1" class="row_heading level0 row1" >Sim</th>
#       <td id="T_8b765_row1_col0" class="data row1 col0" >15</td>
#       <td id="T_8b765_row1_col1" class="data row1 col1" >16</td>
#       <td id="T_8b765_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_8b765_row1_col3" class="data row1 col3" >7</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 1.8522 | P-value: 0.6036 | Graus de liberdade: 3
# Associação NÃO significativa (p >= 0.05) - Variáveis são independentes
#
#
# ================================================================================
# FONTE MAIS ÚTIL × TEMPO INDIVIDUAL
# ================================================================================
# <style type="text/css">
# #T_0d303 th {
#   text-align: left;
# }
# #T_0d303  {
#   border: 1px solid black;
# }
# #T_0d303 th {
#   border: 1px solid black;
# }
# #T_0d303 td {
#   border: 1px solid black;
# }
# #T_0d303_row0_col0, #T_0d303_row0_col1, #T_0d303_row0_col2, #T_0d303_row0_col3, #T_0d303_row1_col0, #T_0d303_row1_col1, #T_0d303_row1_col2, #T_0d303_row1_col3, #T_0d303_row2_col0, #T_0d303_row2_col1, #T_0d303_row2_col2, #T_0d303_row2_col3, #T_0d303_row3_col0, #T_0d303_row3_col1, #T_0d303_row3_col2, #T_0d303_row3_col3, #T_0d303_row4_col0, #T_0d303_row4_col1, #T_0d303_row4_col2, #T_0d303_row4_col3, #T_0d303_row5_col0, #T_0d303_row5_col1, #T_0d303_row5_col2, #T_0d303_row5_col3, #T_0d303_row6_col0, #T_0d303_row6_col1, #T_0d303_row6_col2, #T_0d303_row6_col3, #T_0d303_row7_col0, #T_0d303_row7_col1, #T_0d303_row7_col2, #T_0d303_row7_col3, #T_0d303_row8_col0, #T_0d303_row8_col1, #T_0d303_row8_col2, #T_0d303_row8_col3, #T_0d303_row9_col0, #T_0d303_row9_col1, #T_0d303_row9_col2, #T_0d303_row9_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_0d303">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d303_level0_col0" class="col_heading level0 col0" >12-18 meses</th>
#       <th id="T_0d303_level0_col1" class="col_heading level0 col1" >3-6 meses</th>
#       <th id="T_0d303_level0_col2" class="col_heading level0 col2" >6-12 meses</th>
#       <th id="T_0d303_level0_col3" class="col_heading level0 col3" >Menos de 3 meses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d303_level0_row0" class="row_heading level0 row0" >Agentes de inteligência artificial (IA)</th>
#       <td id="T_0d303_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_0d303_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_0d303_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_0d303_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0d303_level0_row1" class="row_heading level0 row1" >Aprendizado autodirigido (tentativa e erro)</th>
#       <td id="T_0d303_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_0d303_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_0d303_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_0d303_row1_col3" class="data row1 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_0d303_level0_row2" class="row_heading level0 row2" >Comunidades técnicas (fóruns, Stack Overflow, Reddit)</th>
#       <td id="T_0d303_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_0d303_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_0d303_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_0d303_row2_col3" class="data row2 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_0d303_level0_row3" class="row_heading level0 row3" >Cursos estruturados (online ou presenciais)</th>
#       <td id="T_0d303_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_0d303_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_0d303_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_0d303_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0d303_level0_row4" class="row_heading level0 row4" >Documentação oficial (Kubernetes, Docker Docs)</th>
#       <td id="T_0d303_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_0d303_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_0d303_row4_col2" class="data row4 col2" >6</td>
#       <td id="T_0d303_row4_col3" class="data row4 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0d303_level0_row5" class="row_heading level0 row5" >Livros técnicos</th>
#       <td id="T_0d303_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_0d303_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_0d303_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_0d303_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0d303_level0_row6" class="row_heading level0 row6" >Mentoria interna (desenvolvedores seniores ou especialistas)</th>
#       <td id="T_0d303_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_0d303_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_0d303_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_0d303_row6_col3" class="data row6 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0d303_level0_row7" class="row_heading level0 row7" >Provas de Conceito (PoCs) e projetos piloto</th>
#       <td id="T_0d303_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_0d303_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_0d303_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_0d303_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0d303_level0_row8" class="row_heading level0 row8" >Treinamento formal / cursos pagos (ex.: Udemy, Coursera, KodeKloud, Linux Academy)</th>
#       <td id="T_0d303_row8_col0" class="data row8 col0" >2</td>
#       <td id="T_0d303_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_0d303_row8_col2" class="data row8 col2" >4</td>
#       <td id="T_0d303_row8_col3" class="data row8 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0d303_level0_row9" class="row_heading level0 row9" >Tutoriais e artigos online (blogs, Medium, Dev.to)</th>
#       <td id="T_0d303_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_0d303_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_0d303_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_0d303_row9_col3" class="data row9 col3" >0</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 30.7653 | P-value: 0.2809 | Graus de liberdade: 27
# Associação NÃO significativa (p >= 0.05) - Variáveis são independentes
#
#
# ================================================================================
# CARGO × TEMPO COM CONTAINERS
# ================================================================================
# <style type="text/css">
# #T_079f3 th {
#   text-align: left;
# }
# #T_079f3  {
#   border: 1px solid black;
# }
# #T_079f3 th {
#   border: 1px solid black;
# }
# #T_079f3 td {
#   border: 1px solid black;
# }
# #T_079f3_row0_col0, #T_079f3_row0_col1, #T_079f3_row0_col2, #T_079f3_row0_col3, #T_079f3_row0_col4, #T_079f3_row1_col0, #T_079f3_row1_col1, #T_079f3_row1_col2, #T_079f3_row1_col3, #T_079f3_row1_col4, #T_079f3_row2_col0, #T_079f3_row2_col1, #T_079f3_row2_col2, #T_079f3_row2_col3, #T_079f3_row2_col4, #T_079f3_row3_col0, #T_079f3_row3_col1, #T_079f3_row3_col2, #T_079f3_row3_col3, #T_079f3_row3_col4, #T_079f3_row4_col0, #T_079f3_row4_col1, #T_079f3_row4_col2, #T_079f3_row4_col3, #T_079f3_row4_col4, #T_079f3_row5_col0, #T_079f3_row5_col1, #T_079f3_row5_col2, #T_079f3_row5_col3, #T_079f3_row5_col4, #T_079f3_row6_col0, #T_079f3_row6_col1, #T_079f3_row6_col2, #T_079f3_row6_col3, #T_079f3_row6_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_079f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_079f3_level0_col0" class="col_heading level0 col0" >1-3 anos</th>
#       <th id="T_079f3_level0_col1" class="col_heading level0 col1" >3-5 anos</th>
#       <th id="T_079f3_level0_col2" class="col_heading level0 col2" >6 meses - 1 ano</th>
#       <th id="T_079f3_level0_col3" class="col_heading level0 col3" >Mais de 5 anos</th>
#       <th id="T_079f3_level0_col4" class="col_heading level0 col4" >Menos de 6 meses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_079f3_level0_row0" class="row_heading level0 row0" >Arquiteto de Soluções</th>
#       <td id="T_079f3_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_079f3_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_079f3_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_079f3_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_079f3_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_079f3_level0_row1" class="row_heading level0 row1" >Desenvolvedor</th>
#       <td id="T_079f3_row1_col0" class="data row1 col0" >8</td>
#       <td id="T_079f3_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_079f3_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_079f3_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_079f3_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_079f3_level0_row2" class="row_heading level0 row2" >DevOps Engineer</th>
#       <td id="T_079f3_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_079f3_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_079f3_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_079f3_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_079f3_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_079f3_level0_row3" class="row_heading level0 row3" >Estágio em tecnologia</th>
#       <td id="T_079f3_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_079f3_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_079f3_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_079f3_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_079f3_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_079f3_level0_row4" class="row_heading level0 row4" >Não estou trabalhando no momento</th>
#       <td id="T_079f3_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_079f3_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_079f3_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_079f3_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_079f3_row4_col4" class="data row4 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_079f3_level0_row5" class="row_heading level0 row5" >SRE (Site Reliability Engineer)</th>
#       <td id="T_079f3_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_079f3_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_079f3_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_079f3_row5_col3" class="data row5 col3" >4</td>
#       <td id="T_079f3_row5_col4" class="data row5 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_079f3_level0_row6" class="row_heading level0 row6" >Technical Product Manager</th>
#       <td id="T_079f3_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_079f3_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_079f3_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_079f3_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_079f3_row6_col4" class="data row6 col4" >0</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 49.9550 | P-value: 0.0014 | Graus de liberdade: 24
# Associação significativa (p < 0.05) - Variáveis NÃO são independentes
#
#
# ================================================================================
# SETOR × TECNOLOGIA DE ORQUESTRAÇÃO
# ================================================================================
# <style type="text/css">
# #T_2b02a th {
#   text-align: left;
# }
# #T_2b02a  {
#   border: 1px solid black;
# }
# #T_2b02a th {
#   border: 1px solid black;
# }
# #T_2b02a td {
#   border: 1px solid black;
# }
# #T_2b02a_row0_col0, #T_2b02a_row0_col1, #T_2b02a_row0_col2, #T_2b02a_row1_col0, #T_2b02a_row1_col1, #T_2b02a_row1_col2, #T_2b02a_row2_col0, #T_2b02a_row2_col1, #T_2b02a_row2_col2, #T_2b02a_row3_col0, #T_2b02a_row3_col1, #T_2b02a_row3_col2, #T_2b02a_row4_col0, #T_2b02a_row4_col1, #T_2b02a_row4_col2, #T_2b02a_row5_col0, #T_2b02a_row5_col1, #T_2b02a_row5_col2, #T_2b02a_row6_col0, #T_2b02a_row6_col1, #T_2b02a_row6_col2, #T_2b02a_row7_col0, #T_2b02a_row7_col1, #T_2b02a_row7_col2, #T_2b02a_row8_col0, #T_2b02a_row8_col1, #T_2b02a_row8_col2, #T_2b02a_row9_col0, #T_2b02a_row9_col1, #T_2b02a_row9_col2, #T_2b02a_row10_col0, #T_2b02a_row10_col1, #T_2b02a_row10_col2, #T_2b02a_row11_col0, #T_2b02a_row11_col1, #T_2b02a_row11_col2, #T_2b02a_row12_col0, #T_2b02a_row12_col1, #T_2b02a_row12_col2, #T_2b02a_row13_col0, #T_2b02a_row13_col1, #T_2b02a_row13_col2, #T_2b02a_row14_col0, #T_2b02a_row14_col1, #T_2b02a_row14_col2, #T_2b02a_row15_col0, #T_2b02a_row15_col1, #T_2b02a_row15_col2, #T_2b02a_row16_col0, #T_2b02a_row16_col1, #T_2b02a_row16_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_2b02a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b02a_level0_col0" class="col_heading level0 col0" >Docker Swarm</th>
#       <th id="T_2b02a_level0_col1" class="col_heading level0 col1" >Kubernetes (self-hosted ou managed: EKS/AKS/GKE)</th>
#       <th id="T_2b02a_level0_col2" class="col_heading level0 col2" >Outras soluções (Nomad, OpenShift, ECS)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b02a_level0_row0" class="row_heading level0 row0" >AWS Partner, foco em migrações cloud.</th>
#       <td id="T_2b02a_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_2b02a_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_2b02a_row0_col2" class="data row0 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2b02a_level0_row1" class="row_heading level0 row1" >Agro</th>
#       <td id="T_2b02a_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_2b02a_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_2b02a_row1_col2" class="data row1 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2b02a_level0_row2" class="row_heading level0 row2" >Benefícios</th>
#       <td id="T_2b02a_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_2b02a_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_2b02a_row2_col2" class="data row2 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2b02a_level0_row3" class="row_heading level0 row3" >Consultoria</th>
#       <td id="T_2b02a_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_2b02a_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_2b02a_row3_col2" class="data row3 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2b02a_level0_row4" class="row_heading level0 row4" >E-commerce/Varejo</th>
#       <td id="T_2b02a_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_2b02a_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_2b02a_row4_col2" class="data row4 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2b02a_level0_row5" class="row_heading level0 row5" >Educação/EdTech</th>
#       <td id="T_2b02a_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_2b02a_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_2b02a_row5_col2" class="data row5 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2b02a_level0_row6" class="row_heading level0 row6" >Engenharia Elétrica</th>
#       <td id="T_2b02a_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_2b02a_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_2b02a_row6_col2" class="data row6 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2b02a_level0_row7" class="row_heading level0 row7" >Fintech/Serviços Financeiros</th>
#       <td id="T_2b02a_row7_col0" class="data row7 col0" >1</td>
#       <td id="T_2b02a_row7_col1" class="data row7 col1" >9</td>
#       <td id="T_2b02a_row7_col2" class="data row7 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2b02a_level0_row8" class="row_heading level0 row8" >IndTech</th>
#       <td id="T_2b02a_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_2b02a_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_2b02a_row8_col2" class="data row8 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2b02a_level0_row9" class="row_heading level0 row9" >Manufatura </th>
#       <td id="T_2b02a_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_2b02a_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_2b02a_row9_col2" class="data row9 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2b02a_level0_row10" class="row_heading level0 row10" >Mídia/Entretenimento</th>
#       <td id="T_2b02a_row10_col0" class="data row10 col0" >1</td>
#       <td id="T_2b02a_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_2b02a_row10_col2" class="data row10 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2b02a_level0_row11" class="row_heading level0 row11" >Saas/Software</th>
#       <td id="T_2b02a_row11_col0" class="data row11 col0" >2</td>
#       <td id="T_2b02a_row11_col1" class="data row11 col1" >9</td>
#       <td id="T_2b02a_row11_col2" class="data row11 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2b02a_level0_row12" class="row_heading level0 row12" >Saúde/HealthTech</th>
#       <td id="T_2b02a_row12_col0" class="data row12 col0" >1</td>
#       <td id="T_2b02a_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_2b02a_row12_col2" class="data row12 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2b02a_level0_row13" class="row_heading level0 row13" >Setor Público</th>
#       <td id="T_2b02a_row13_col0" class="data row13 col0" >0</td>
#       <td id="T_2b02a_row13_col1" class="data row13 col1" >2</td>
#       <td id="T_2b02a_row13_col2" class="data row13 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2b02a_level0_row14" class="row_heading level0 row14" >Setor logístico + Software</th>
#       <td id="T_2b02a_row14_col0" class="data row14 col0" >0</td>
#       <td id="T_2b02a_row14_col1" class="data row14 col1" >0</td>
#       <td id="T_2b02a_row14_col2" class="data row14 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2b02a_level0_row15" class="row_heading level0 row15" >Telecom</th>
#       <td id="T_2b02a_row15_col0" class="data row15 col0" >0</td>
#       <td id="T_2b02a_row15_col1" class="data row15 col1" >3</td>
#       <td id="T_2b02a_row15_col2" class="data row15 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2b02a_level0_row16" class="row_heading level0 row16" >tecnologia. Infraestrutura e monitoramento.</th>
#       <td id="T_2b02a_row16_col0" class="data row16 col0" >0</td>
#       <td id="T_2b02a_row16_col1" class="data row16 col1" >1</td>
#       <td id="T_2b02a_row16_col2" class="data row16 col2" >0</td>
#     </tr>
#   </tbody>
# </table>
# Qui-quadrado: 34.5515 | P-value: 0.3469 | Graus de liberdade: 32
# Associação NÃO significativa (p >= 0.05) - Variáveis são independentes
#
#
# ================================================================================
# RESUMO DOS TESTES QUI-QUADRADO
# ================================================================================
#
# Nível de significância: α = 0.05
#
# Porte da Empresa × Principal Desafio
#    χ² = 14.2334, p = 0.8185
#    Associação significativa: NÃO
#
# Empresa Ofereceu Treinamento × Tempo Individual
#    χ² = 0.1287, p = 0.9882
#    Associação significativa: NÃO
#
# Realizou POCs × Tempo da Equipe
#    χ² = 1.8522, p = 0.6036
#    Associação significativa: NÃO
#
# Fonte Mais Útil × Tempo Individual
#    χ² = 30.7653, p = 0.2809
#    Associação significativa: NÃO
#
# Cargo × Tempo com Containers
#    χ² = 49.9550, p = 0.0014
#    Associação significativa: SIM
#
# Setor × Tecnologia de Orquestração
#    χ² = 34.5515, p = 0.3469
#    Associação significativa: NÃO
#
#
# ================================================================================
# TESTES QUI-QUADRADO CONCLUÍDOS
# ================================================================================

# %% [markdown]
# ### ANACOR (Análise de Correspondência)

# %%
utils.titulo_secao("ANACOR - Análise de Correspondência")
# %run 03_anacor.ipynb
# Out:
# ================================================================================
# ANACOR - ANÁLISE DE CORRESPONDÊNCIA
# ================================================================================
# Usando dados já carregados
#
# ================================================================================
# ANACOR: PORTE DA EMPRESA × PRINCIPAL DESAFIO
# ================================================================================
# <style type="text/css">
# #T_23597 th {
#   text-align: left;
# }
# #T_23597  {
#   border: 1px solid black;
# }
# #T_23597 th {
#   border: 1px solid black;
# }
# #T_23597 td {
#   border: 1px solid black;
# }
# #T_23597_row0_col0, #T_23597_row0_col1, #T_23597_row0_col2, #T_23597_row0_col3, #T_23597_row0_col4, #T_23597_row0_col5, #T_23597_row0_col6, #T_23597_row0_col7, #T_23597_row0_col8, #T_23597_row0_col9, #T_23597_row0_col10, #T_23597_row1_col0, #T_23597_row1_col1, #T_23597_row1_col2, #T_23597_row1_col3, #T_23597_row1_col4, #T_23597_row1_col5, #T_23597_row1_col6, #T_23597_row1_col7, #T_23597_row1_col8, #T_23597_row1_col9, #T_23597_row1_col10, #T_23597_row2_col0, #T_23597_row2_col1, #T_23597_row2_col2, #T_23597_row2_col3, #T_23597_row2_col4, #T_23597_row2_col5, #T_23597_row2_col6, #T_23597_row2_col7, #T_23597_row2_col8, #T_23597_row2_col9, #T_23597_row2_col10 {
#   text-align: center;
# }
# </style>
# <table id="T_23597">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23597_level0_col0" class="col_heading level0 col0" >A adoção foi tranquila.</th>
#       <th id="T_23597_level0_col1" class="col_heading level0 col1" >CI/CD (automação, fluxos de deploy)</th>
#       <th id="T_23597_level0_col2" class="col_heading level0 col2" >Complexidade técnica (curva de aprendizado íngreme, novos conceitos)</th>
#       <th id="T_23597_level0_col3" class="col_heading level0 col3" >Custos de infraestrutura</th>
#       <th id="T_23597_level0_col4" class="col_heading level0 col4" >Escalabilidade</th>
#       <th id="T_23597_level0_col5" class="col_heading level0 col5" >Integração com sistemas legados</th>
#       <th id="T_23597_level0_col6" class="col_heading level0 col6" >Monitoramento e observabilidade (monitoramento, logs, tracing)</th>
#       <th id="T_23597_level0_col7" class="col_heading level0 col7" >Mudanças organizacionais e culturais (adoção de DevOps, colaboração entre equipes)</th>
#       <th id="T_23597_level0_col8" class="col_heading level0 col8" >Persistência de dados e gestão de estado</th>
#       <th id="T_23597_level0_col9" class="col_heading level0 col9" >Segurança</th>
#       <th id="T_23597_level0_col10" class="col_heading level0 col10" >Treinamento e desenvolvimento de habilidades (falta de capacitação, upskilling)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23597_level0_row0" class="row_heading level0 row0" >Grande (mais de 250 funcionários)</th>
#       <td id="T_23597_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_23597_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_23597_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_23597_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_23597_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_23597_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_23597_row0_col6" class="data row0 col6" >3</td>
#       <td id="T_23597_row0_col7" class="data row0 col7" >5</td>
#       <td id="T_23597_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_23597_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_23597_row0_col10" class="data row0 col10" >1</td>
#     </tr>
#     <tr>
#       <th id="T_23597_level0_row1" class="row_heading level0 row1" >Média (50-250 funcionários)</th>
#       <td id="T_23597_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_23597_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_23597_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_23597_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_23597_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_23597_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_23597_row1_col6" class="data row1 col6" >2</td>
#       <td id="T_23597_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_23597_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_23597_row1_col9" class="data row1 col9" >2</td>
#       <td id="T_23597_row1_col10" class="data row1 col10" >3</td>
#     </tr>
#     <tr>
#       <th id="T_23597_level0_row2" class="row_heading level0 row2" >Pequena (menos de 50 funcionários)</th>
#       <td id="T_23597_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_23597_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_23597_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_23597_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_23597_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_23597_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_23597_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_23597_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_23597_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_23597_row2_col9" class="data row2 col9" >1</td>
#       <td id="T_23597_row2_col10" class="data row2 col10" >1</td>
#     </tr>
#   </tbody>
# </table>
# Inércia Explicada por Dimensão:
#    Dimensão 1: 60.94%
#    Dimensão 2: 39.06%
#    Total acumulado: 100.00%
#
# Gráfico salvo: ../resultados/graficos/anacor/anacor_q6_porte_empresa_q18_principal_desafio.png
# ================================================================================
# ANACOR: FONTE DE CONHECIMENTO MAIS ÚTIL × TEMPO ATÉ O PROFISSIONAL SE SENTIR CONFORTÁVEL
# ================================================================================
# <style type="text/css">
# #T_8d06f th {
#   text-align: left;
# }
# #T_8d06f  {
#   border: 1px solid black;
# }
# #T_8d06f th {
#   border: 1px solid black;
# }
# #T_8d06f td {
#   border: 1px solid black;
# }
# #T_8d06f_row0_col0, #T_8d06f_row0_col1, #T_8d06f_row0_col2, #T_8d06f_row0_col3, #T_8d06f_row1_col0, #T_8d06f_row1_col1, #T_8d06f_row1_col2, #T_8d06f_row1_col3, #T_8d06f_row2_col0, #T_8d06f_row2_col1, #T_8d06f_row2_col2, #T_8d06f_row2_col3, #T_8d06f_row3_col0, #T_8d06f_row3_col1, #T_8d06f_row3_col2, #T_8d06f_row3_col3, #T_8d06f_row4_col0, #T_8d06f_row4_col1, #T_8d06f_row4_col2, #T_8d06f_row4_col3, #T_8d06f_row5_col0, #T_8d06f_row5_col1, #T_8d06f_row5_col2, #T_8d06f_row5_col3, #T_8d06f_row6_col0, #T_8d06f_row6_col1, #T_8d06f_row6_col2, #T_8d06f_row6_col3, #T_8d06f_row7_col0, #T_8d06f_row7_col1, #T_8d06f_row7_col2, #T_8d06f_row7_col3, #T_8d06f_row8_col0, #T_8d06f_row8_col1, #T_8d06f_row8_col2, #T_8d06f_row8_col3, #T_8d06f_row9_col0, #T_8d06f_row9_col1, #T_8d06f_row9_col2, #T_8d06f_row9_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_8d06f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d06f_level0_col0" class="col_heading level0 col0" >12-18 meses</th>
#       <th id="T_8d06f_level0_col1" class="col_heading level0 col1" >3-6 meses</th>
#       <th id="T_8d06f_level0_col2" class="col_heading level0 col2" >6-12 meses</th>
#       <th id="T_8d06f_level0_col3" class="col_heading level0 col3" >Menos de 3 meses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d06f_level0_row0" class="row_heading level0 row0" >Agentes de inteligência artificial (IA)</th>
#       <td id="T_8d06f_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_8d06f_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_8d06f_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_8d06f_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8d06f_level0_row1" class="row_heading level0 row1" >Aprendizado autodirigido (tentativa e erro)</th>
#       <td id="T_8d06f_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_8d06f_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_8d06f_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_8d06f_row1_col3" class="data row1 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_8d06f_level0_row2" class="row_heading level0 row2" >Comunidades técnicas (fóruns, Stack Overflow, Reddit)</th>
#       <td id="T_8d06f_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_8d06f_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_8d06f_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_8d06f_row2_col3" class="data row2 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_8d06f_level0_row3" class="row_heading level0 row3" >Cursos estruturados (online ou presenciais)</th>
#       <td id="T_8d06f_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_8d06f_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_8d06f_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_8d06f_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8d06f_level0_row4" class="row_heading level0 row4" >Documentação oficial (Kubernetes, Docker Docs)</th>
#       <td id="T_8d06f_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_8d06f_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_8d06f_row4_col2" class="data row4 col2" >6</td>
#       <td id="T_8d06f_row4_col3" class="data row4 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8d06f_level0_row5" class="row_heading level0 row5" >Livros técnicos</th>
#       <td id="T_8d06f_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_8d06f_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_8d06f_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_8d06f_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8d06f_level0_row6" class="row_heading level0 row6" >Mentoria interna (desenvolvedores seniores ou especialistas)</th>
#       <td id="T_8d06f_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_8d06f_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_8d06f_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_8d06f_row6_col3" class="data row6 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8d06f_level0_row7" class="row_heading level0 row7" >Provas de Conceito (PoCs) e projetos piloto</th>
#       <td id="T_8d06f_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_8d06f_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_8d06f_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_8d06f_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8d06f_level0_row8" class="row_heading level0 row8" >Treinamento formal / cursos pagos (ex.: Udemy, Coursera, KodeKloud, Linux Academy)</th>
#       <td id="T_8d06f_row8_col0" class="data row8 col0" >2</td>
#       <td id="T_8d06f_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_8d06f_row8_col2" class="data row8 col2" >4</td>
#       <td id="T_8d06f_row8_col3" class="data row8 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8d06f_level0_row9" class="row_heading level0 row9" >Tutoriais e artigos online (blogs, Medium, Dev.to)</th>
#       <td id="T_8d06f_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_8d06f_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_8d06f_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_8d06f_row9_col3" class="data row9 col3" >0</td>
#     </tr>
#   </tbody>
# </table>
# Inércia Explicada por Dimensão:
#    Dimensão 1: 59.00%
#    Dimensão 2: 41.00%
#    Total acumulado: 100.00%
#
# Gráfico salvo: ../resultados/graficos/anacor/anacor_q22_fonte_mais_util_q24_tempo_individual.png
# ================================================================================
# ANACOR: FATOR MAIS IMPORTANTE NO APRENDIZADO DA EQUIPE × TEMPO ATÉ O PRIMEIRO DEPLOY EM PRODUÇÃO
# ================================================================================
# <style type="text/css">
# #T_7572c th {
#   text-align: left;
# }
# #T_7572c  {
#   border: 1px solid black;
# }
# #T_7572c th {
#   border: 1px solid black;
# }
# #T_7572c td {
#   border: 1px solid black;
# }
# #T_7572c_row0_col0, #T_7572c_row0_col1, #T_7572c_row0_col2, #T_7572c_row0_col3, #T_7572c_row1_col0, #T_7572c_row1_col1, #T_7572c_row1_col2, #T_7572c_row1_col3, #T_7572c_row2_col0, #T_7572c_row2_col1, #T_7572c_row2_col2, #T_7572c_row2_col3, #T_7572c_row3_col0, #T_7572c_row3_col1, #T_7572c_row3_col2, #T_7572c_row3_col3, #T_7572c_row4_col0, #T_7572c_row4_col1, #T_7572c_row4_col2, #T_7572c_row4_col3, #T_7572c_row5_col0, #T_7572c_row5_col1, #T_7572c_row5_col2, #T_7572c_row5_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_7572c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7572c_level0_col0" class="col_heading level0 col0" >1-3 meses</th>
#       <th id="T_7572c_level0_col1" class="col_heading level0 col1" >3-6 meses</th>
#       <th id="T_7572c_level0_col2" class="col_heading level0 col2" >6-12 meses</th>
#       <th id="T_7572c_level0_col3" class="col_heading level0 col3" >Menos de 1 mês</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7572c_level0_row0" class="row_heading level0 row0" >Experiência prévia com Docker</th>
#       <td id="T_7572c_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_7572c_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_7572c_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_7572c_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7572c_level0_row1" class="row_heading level0 row1" >Mentoria de especialistas internos ou externos</th>
#       <td id="T_7572c_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_7572c_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_7572c_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_7572c_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7572c_level0_row2" class="row_heading level0 row2" >Participação em comunidades técnicas</th>
#       <td id="T_7572c_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_7572c_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_7572c_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_7572c_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7572c_level0_row3" class="row_heading level0 row3" >Realização de POCs antes de produção</th>
#       <td id="T_7572c_row3_col0" class="data row3 col0" >6</td>
#       <td id="T_7572c_row3_col1" class="data row3 col1" >6</td>
#       <td id="T_7572c_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_7572c_row3_col3" class="data row3 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7572c_level0_row4" class="row_heading level0 row4" >Tempo dedicado exclusivo para estudo</th>
#       <td id="T_7572c_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_7572c_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_7572c_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_7572c_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7572c_level0_row5" class="row_heading level0 row5" >Treinamento formal estruturado</th>
#       <td id="T_7572c_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_7572c_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_7572c_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_7572c_row5_col3" class="data row5 col3" >1</td>
#     </tr>
#   </tbody>
# </table>
# Inércia Explicada por Dimensão:
#    Dimensão 1: 82.31%
#    Dimensão 2: 17.69%
#    Total acumulado: 100.00%
#
# Gráfico salvo: ../resultados/graficos/anacor/anacor_q26_fator_mais_importante_q25_tempo_equipe.png
# ================================================================================
# ANACOR CONCLUÍDA
# ================================================================================
#
# Mapas perceptuais gerados:
#    - Porte da Empresa × Principal Desafio
#    - Fonte Mais Útil × Tempo Individual
#    - Fator Mais Importante × Tempo da Equipe
#
# Gráficos salvos em resultados/graficos/anacor/

# %% [markdown]
# ### Regressão Logística

# %%
utils.titulo_secao("Regressão Logística")
# %run 04_regressao.ipynb
# Out:
# ================================================================================
# REGRESSÃO LOGÍSTICA
# ================================================================================
# Usando dados já carregados
#
# ================================================================================
# REGRESSÃO LOGÍSTICA - FATORES PREDITIVOS DA CURVA DE APRENDIZADO
# ================================================================================
#
# MODELO:
#   Variável Dependente: Curva Rápida (< 3 meses)
#   Método: Regressão Logística Binária
#
# VARIÁVEIS PREDITORAS:
#   • Empresa Grande (>250 funcionários)
#   • Empresa Média (50-250 funcionários)
#   • Possui Certificações
#   • Experiência com Containers (3+ anos)
#   • Participa de Comunidades Técnicas
#   • Empresa Ofereceu Treinamento
#   • Realizou POCs antes de Produção
#
# ================================================================================
# RESUMO DOS DADOS
# ================================================================================
#   Total de observações: 47
#   Curva rápida (<3 meses): 8 (17.0%)
#   Curva lenta (≥3 meses): 39 (83.0%)
#
# ================================================================================
# MÉTRICAS DO MODELO
# ================================================================================
#   Pseudo R²: 0.0250
#   Log-Likelihood: -20.91
#   AIC: 55.81
#   BIC: 68.76
#   Convergência: Sim
#
# ================================================================================
# INTERPRETAÇÃO DOS COEFICIENTES (Odds Ratios)
# ================================================================================
# <style type="text/css">
# #T_aa3fd th {
#   text-align: left;
# }
# #T_aa3fd  {
#   border: 1px solid black;
# }
# #T_aa3fd th {
#   border: 1px solid black;
# }
# #T_aa3fd td {
#   border: 1px solid black;
# }
# #T_aa3fd_row0_col0, #T_aa3fd_row0_col1, #T_aa3fd_row0_col2, #T_aa3fd_row0_col3, #T_aa3fd_row1_col0, #T_aa3fd_row1_col1, #T_aa3fd_row1_col2, #T_aa3fd_row1_col3, #T_aa3fd_row2_col0, #T_aa3fd_row2_col1, #T_aa3fd_row2_col2, #T_aa3fd_row2_col3, #T_aa3fd_row3_col0, #T_aa3fd_row3_col1, #T_aa3fd_row3_col2, #T_aa3fd_row3_col3, #T_aa3fd_row4_col0, #T_aa3fd_row4_col1, #T_aa3fd_row4_col2, #T_aa3fd_row4_col3, #T_aa3fd_row5_col0, #T_aa3fd_row5_col1, #T_aa3fd_row5_col2, #T_aa3fd_row5_col3, #T_aa3fd_row6_col0, #T_aa3fd_row6_col1, #T_aa3fd_row6_col2, #T_aa3fd_row6_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_aa3fd">
#   <thead>
#     <tr>
#       <th id="T_aa3fd_level0_col0" class="col_heading level0 col0" >Variável</th>
#       <th id="T_aa3fd_level0_col1" class="col_heading level0 col1" >Odds Ratio</th>
#       <th id="T_aa3fd_level0_col2" class="col_heading level0 col2" >P-value</th>
#       <th id="T_aa3fd_level0_col3" class="col_heading level0 col3" >Significativo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_aa3fd_row0_col0" class="data row0 col0" >Empresa Grande (>250 funcionários)</td>
#       <td id="T_aa3fd_row0_col1" class="data row0 col1" >0.813</td>
#       <td id="T_aa3fd_row0_col2" class="data row0 col2" >0.8837</td>
#       <td id="T_aa3fd_row0_col3" class="data row0 col3" >Não</td>
#     </tr>
#     <tr>
#       <td id="T_aa3fd_row1_col0" class="data row1 col0" >Empresa Média (50-250 funcionários)</td>
#       <td id="T_aa3fd_row1_col1" class="data row1 col1" >0.825</td>
#       <td id="T_aa3fd_row1_col2" class="data row1 col2" >0.8871</td>
#       <td id="T_aa3fd_row1_col3" class="data row1 col3" >Não</td>
#     </tr>
#     <tr>
#       <td id="T_aa3fd_row2_col0" class="data row2 col0" >Possui Certificações</td>
#       <td id="T_aa3fd_row2_col1" class="data row2 col1" >0.472</td>
#       <td id="T_aa3fd_row2_col2" class="data row2 col2" >0.4334</td>
#       <td id="T_aa3fd_row2_col3" class="data row2 col3" >Não</td>
#     </tr>
#     <tr>
#       <td id="T_aa3fd_row3_col0" class="data row3 col0" >Experiência com Containers (3+ anos)</td>
#       <td id="T_aa3fd_row3_col1" class="data row3 col1" >0.661</td>
#       <td id="T_aa3fd_row3_col2" class="data row3 col2" >0.6365</td>
#       <td id="T_aa3fd_row3_col3" class="data row3 col3" >Não</td>
#     </tr>
#     <tr>
#       <td id="T_aa3fd_row4_col0" class="data row4 col0" >Participa de Comunidades Técnicas</td>
#       <td id="T_aa3fd_row4_col1" class="data row4 col1" >0.229</td>
#       <td id="T_aa3fd_row4_col2" class="data row4 col2" >0.2982</td>
#       <td id="T_aa3fd_row4_col3" class="data row4 col3" >Não</td>
#     </tr>
#     <tr>
#       <td id="T_aa3fd_row5_col0" class="data row5 col0" >Empresa Ofereceu Treinamento</td>
#       <td id="T_aa3fd_row5_col1" class="data row5 col1" >1.216</td>
#       <td id="T_aa3fd_row5_col2" class="data row5 col2" >0.8330</td>
#       <td id="T_aa3fd_row5_col3" class="data row5 col3" >Não</td>
#     </tr>
#     <tr>
#       <td id="T_aa3fd_row6_col0" class="data row6 col0" >Realizou POCs antes de Produção</td>
#       <td id="T_aa3fd_row6_col1" class="data row6 col1" >1.606</td>
#       <td id="T_aa3fd_row6_col2" class="data row6 col2" >0.7177</td>
#       <td id="T_aa3fd_row6_col3" class="data row6 col3" >Não</td>
#     </tr>
#   </tbody>
# </table>
# RESULTADO: Nenhuma variável significativa (p ≥ 0.05 para todas)
#
# ================================================================================
# ANÁLISE DESCRITIVA: Impacto Real de Cada Variável
# ================================================================================
# <style type="text/css">
# #T_00509 th {
#   text-align: left;
# }
# #T_00509  {
#   border: 1px solid black;
# }
# #T_00509 th {
#   border: 1px solid black;
# }
# #T_00509 td {
#   border: 1px solid black;
# }
# #T_00509_row0_col0, #T_00509_row0_col1, #T_00509_row0_col2, #T_00509_row0_col3, #T_00509_row1_col0, #T_00509_row1_col1, #T_00509_row1_col2, #T_00509_row1_col3, #T_00509_row2_col0, #T_00509_row2_col1, #T_00509_row2_col2, #T_00509_row2_col3, #T_00509_row3_col0, #T_00509_row3_col1, #T_00509_row3_col2, #T_00509_row3_col3, #T_00509_row4_col0, #T_00509_row4_col1, #T_00509_row4_col2, #T_00509_row4_col3, #T_00509_row5_col0, #T_00509_row5_col1, #T_00509_row5_col2, #T_00509_row5_col3, #T_00509_row6_col0, #T_00509_row6_col1, #T_00509_row6_col2, #T_00509_row6_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_00509">
#   <thead>
#     <tr>
#       <th id="T_00509_level0_col0" class="col_heading level0 col0" >Variável</th>
#       <th id="T_00509_level0_col1" class="col_heading level0 col1" >Com fator</th>
#       <th id="T_00509_level0_col2" class="col_heading level0 col2" >Sem fator</th>
#       <th id="T_00509_level0_col3" class="col_heading level0 col3" >Diferença</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_00509_row0_col0" class="data row0 col0" >Empresa Grande (>250 funcionários)</td>
#       <td id="T_00509_row0_col1" class="data row0 col1" >4/23 (17.4%)</td>
#       <td id="T_00509_row0_col2" class="data row0 col2" >4/24 (16.7%)</td>
#       <td id="T_00509_row0_col3" class="data row0 col3" >+0.7pp</td>
#     </tr>
#     <tr>
#       <td id="T_00509_row1_col0" class="data row1 col0" >Empresa Média (50-250 funcionários)</td>
#       <td id="T_00509_row1_col1" class="data row1 col1" >3/18 (16.7%)</td>
#       <td id="T_00509_row1_col2" class="data row1 col2" >5/29 (17.2%)</td>
#       <td id="T_00509_row1_col3" class="data row1 col3" >-0.6pp</td>
#     </tr>
#     <tr>
#       <td id="T_00509_row2_col0" class="data row2 col0" >Possui Certificações</td>
#       <td id="T_00509_row2_col1" class="data row2 col1" >2/18 (11.1%)</td>
#       <td id="T_00509_row2_col2" class="data row2 col2" >6/29 (20.7%)</td>
#       <td id="T_00509_row2_col3" class="data row2 col3" >-9.6pp</td>
#     </tr>
#     <tr>
#       <td id="T_00509_row3_col0" class="data row3 col0" >Experiência com Containers (3+ anos)</td>
#       <td id="T_00509_row3_col1" class="data row3 col1" >3/22 (13.6%)</td>
#       <td id="T_00509_row3_col2" class="data row3 col2" >5/25 (20.0%)</td>
#       <td id="T_00509_row3_col3" class="data row3 col3" >-6.4pp</td>
#     </tr>
#     <tr>
#       <td id="T_00509_row4_col0" class="data row4 col0" >Participa de Comunidades Técnicas</td>
#       <td id="T_00509_row4_col1" class="data row4 col1" >8/47 (17.0%)</td>
#       <td id="T_00509_row4_col2" class="data row4 col2" >0/0 (0.0%)</td>
#       <td id="T_00509_row4_col3" class="data row4 col3" >+17.0pp</td>
#     </tr>
#     <tr>
#       <td id="T_00509_row5_col0" class="data row5 col0" >Empresa Ofereceu Treinamento</td>
#       <td id="T_00509_row5_col1" class="data row5 col1" >3/18 (16.7%)</td>
#       <td id="T_00509_row5_col2" class="data row5 col2" >5/29 (17.2%)</td>
#       <td id="T_00509_row5_col3" class="data row5 col3" >-0.6pp</td>
#     </tr>
#     <tr>
#       <td id="T_00509_row6_col0" class="data row6 col0" >Realizou POCs antes de Produção</td>
#       <td id="T_00509_row6_col1" class="data row6 col1" >7/41 (17.1%)</td>
#       <td id="T_00509_row6_col2" class="data row6 col2" >1/6 (16.7%)</td>
#       <td id="T_00509_row6_col3" class="data row6 col3" >+0.4pp</td>
#     </tr>
#   </tbody>
# </table>
# Como interpretar:
#   • 'Com fator': % de curva rápida quando a característica está presente
#   • 'Sem fator': % de curva rápida quando a característica está ausente
#   • 'Diferença': Impacto em pontos percentuais (pp)
#   • Diferença positiva = fator favorece curva rápida
#   • Diferença negativa = fator dificulta curva rápida
# Gráfico salvo: ../resultados/graficos/regressao/impacto_fatores.png
#
# ================================================================================
# ANÁLISE DE REGRESSÃO LOGÍSTICA CONCLUÍDA
# ================================================================================
#
# Resultados:
#   - Modelo ajustado com sucesso
#   - Análise descritiva de impacto gerada
#   - Gráfico visual salvo em resultados/graficos/regressao/
#
# Próximo passo:
#   - Gerar visualizações adicionais (05_visualizacoes.ipynb)

# %% [markdown]
# ### Visualizações

# %%
utils.titulo_secao("Visualizações")
# %run 05_visualizacoes.ipynb
# Out:
# ================================================================================
# VISUALIZAÇÕES
# ================================================================================
# Usando dados já carregados
# Gráfico salvo: ../resultados/graficos/descritivas/viz_cargos.png
# Gráfico salvo: ../resultados/graficos/descritivas/viz_porte_empresa.png
# Gráfico salvo: ../resultados/graficos/descritivas/viz_desafios_likert.png
# Gráfico salvo: ../resultados/graficos/descritivas/viz_tempo_individual.png
# Gráfico salvo: ../resultados/graficos/descritivas/viz_roi.png
#
# Média de ROI: 4.36
# Mediana de ROI: 5.0
# Gráfico salvo: ../resultados/graficos/descritivas/viz_desafio_por_porte.png
#
# ================================================================================
# VISUALIZAÇÕES CONCLUÍDAS
# ================================================================================
#
# Gráficos salvos em resultados/graficos/descritivas/:
#    - viz_cargos.png
#    - viz_porte_empresa.png
#    - viz_desafios_likert.png
#    - viz_tempo_individual.png
#    - viz_roi.png
#    - viz_desafio_por_porte.png
#
# Pipeline completa de análises finalizada!

# %% [markdown]
# ---
# ## Resumo Final

# %%
utils.titulo_secao("Análises Concluídas")

print("Análise Descritiva")
print("Teste Qui-Quadrado")
print("ANACOR")
print("Regressão Logística")
print("Visualizações")
print(f"\nResultados salvos em: ../resultados/")
# Out:
# ================================================================================
# ANÁLISES CONCLUÍDAS
# ================================================================================
# Análise Descritiva
# Teste Qui-Quadrado
# ANACOR
# Regressão Logística
# Visualizações
#
# Resultados salvos em: ../resultados/

# %% [markdown]
# ### 📚 Referências Metodológicas
#
# - **Qui-Quadrado:** Teste de independência entre variáveis categóricas
# - **ANACOR:** Análise de Correspondência (Hair et al., 2009)
# - **Regressão Logística:** Modelagem de fatores preditivos
